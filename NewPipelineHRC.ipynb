# %%
# General modules
import os
import openai
from dotenv import load_dotenv

# Language models
load_dotenv()
openai_api_key = os.getenv("OPENAI_API_KEY")
openai.api_key = openai_api_key
client = openai.Client()

chat_model_name = 'gpt-4o-mini'
embed_model_name = "all-MiniLM-L6-v2"
# embedding_model_name = 'sentence-transformers/all-mpnet-base-v2'


# Paths

root_dir = r'C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis'
path_input = os.path.join(root_dir, "Data", "2024 Trimester 1.xlsx")
path_db_prepared = os.path.join(root_dir, "Data", "db_prepared_HRC.json")

path_db_analysed = os.path.join(root_dir, "Data", "db_analysed_empty.json")
path_db_progress_backup = os.path.join(root_dir, "Data", "db_progress_backup.json")

path_db_embedded = os.path.join(root_dir, "Data", "db_embedded.json")
path_db_clustered = os.path.join(root_dir, "Data", "db_clustered.json")
path_db_final = os.path.join(root_dir, "Data", "db_final.json")

# %%
import logging
logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")
logger = logging.getLogger(__name__)

logging.getLogger("openai").setLevel(logging.ERROR)
logging.getLogger("httpx").setLevel(logging.ERROR)
import pandas as pd

def load_excel_to_data(excel_path):
    """
    Loads an Excel file and converts it into a list of dictionaries,
    ensuring proper encoding.
    
    Args:
        excel_path (str): Path to the input Excel file.
    Returns:
        list: List of dictionaries representing the data.
    """
    try:
        logger.info("Loading Excel file: %s", excel_path)
        dataframe = pd.read_excel(excel_path, engine='openpyxl')  # Ensure the correct engine is used
        data_as_dict = dataframe.to_dict(orient='records')
        if data_as_dict:
            logger.info("Removing the first entry of the dataset.")
            data_as_dict = data_as_dict[1:]  # Remove the first row if necessary
        logger.info("Excel data successfully loaded and converted to dictionary.")
        return data_as_dict
    except Exception as e:
        logger.error("Error loading Excel: %s", e)
        raise

# %%
data = load_excel_to_data(path_input)
# Out:
# 2024-11-19 15:49:31,587 - INFO - Loading Excel file: C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\2024 Trimester 1.xlsx
# 2024-11-19 15:49:39,008 - INFO - Removing the first entry of the dataset.
# 2024-11-19 15:49:39,008 - INFO - Excel data successfully loaded and converted to dictionary.

# %%
data[14]
# Out:
# {'Unnamed: 0': 15,
#  'Respondent ID': 114588000000,
#  'Collector ID': 431039728,
#  'Start Date': Timestamp('2024-04-29 15:05:34'),
#  'End Date': Timestamp('2024-04-29 15:09:57'),
#  'IP Address': '132.184.130.75',
#  'Email Address': nan,
#  'First Name': nan,
#  'Last Name': nan,
#  'Custom Data 1': nan,
#  '1_Rate_Overall Rival Stars Horse Racing': 2,
#  '1_Rate_Breeding': 2,
#  '1_Rate_Training my horses': 2,
#  '1_Rate_Racing - Story': 2,
#  '1_Rate_Steeplechase': 2,
#  '1_Rate_Cross Country': 2,
#  '1_Rate_Free Roam': 2,
#  '1_Rate_Live Events & Leaderboards (Flat racing & Cross Country)': 2,
#  '1_Rate_Completing Story Goals': 2,
#  '1_Rate_Foal Caring': 2,
#  '1_Rate_Pasture': 2,
#  '1_Rate_Foaling season event': 2,
#  '1_Rate_Steeplechase Stars': 2,
#  '1_Rate_Arabian Days': 2,
#  '1_Rate_Empowering my horse with skills': '3 (Neutral)',
#  '1_Rate_Customizing my horse with tack': 2,
#  '1_Rate_Teams': '1 (Strongly Dislike)',
#  '2_LeastEnjoy_Breeding horses for Coats': nan,
#  '2_LeastEnjoy_Breeding horses for Stats': 'Breeding horses for Stats',
#  '2_LeastEnjoy_Training my Horses': nan,
#  '2_LeastEnjoy_Racing - Story': nan,
#  '2_LeastEnjoy_Steeplechase': nan,
#  '2_LeastEnjoy_Cross Country': nan,
#  '2_LeastEnjoy_Free Roam': nan,
#  '2_LeastEnjoy_Racing - Live Events & Leaderboards  (Flat racing & Cross Country)': nan,
#  '2_LeastEnjoy_Completing Story Goals': nan,
#  '2_LeastEnjoy_Foal Caring': nan,
#  '2_LeastEnjoy_Pasture': 'Pasture',
#  '2_LeastEnjoy_Foaling season event': nan,
#  '2_LeastEnjoy_Steeplechase Stars': nan,
#  '2_LeastEnjoy_Arabian Days': nan,
#  '2_LeastEnjoy_Empowering my Horse with Skills': nan,
#  '2_LeastEnjoy_Customizing my Horse with Tack': nan,
#  '2_LeastEnjoy_Teams': 'Teams',
#  '2_LeastEnjoy_Browsing the new Horse offers': nan,
#  '3_OE_LeastEnjoy': 'stats',
#  '4_Changes_More social aspects': 'Undesirable',
#  '4_Changes_More competitions and leaderboards': 'Strongly undesirable',
#  '4_Changes_More fast-paced and thrilling experiences': 'Strongly undesirable',
#  '4_Changes_More opportunities to have peaceful experiences': 'Strongly undesirable',
#  '4_Changes_More directed goals/missions': 'Strongly undesirable',
#  '4_Changes_More ways to improve the level of my horse': 'Undesirable',
#  '4_Changes_More thinking and planning opportunities': 'Strongly undesirable',
#  '4_Changes_More opportunities for immersive experience with my horse': 'Strongly undesirable',
#  '4_Changes_More narrative': 'No preference (Good as it is)',
#  '4_Changes_Ability to explore the world with my horse on my own terms': 'Strongly undesirable',
#  '4_Changes_More horse, jockey and stables customization options': 'Strongly undesirable',
#  '4_Changes_More challenging goals/missions': 'Strongly undesirable',
#  '5_Goal_What is your main goal when you play Rival Stars Horse Racing?': 'I want to care for foals',
#  '6_NewFeature_Which NEW feature would you most want to see added to the game?': 'More horse breeds',
#  '6_NewFeature_Other': nan,
#  '7_OE_NewFeature_What do you expect {{ Q6 }} to be like?': nan,
#  '8_How would you like to see Show Jumping added in the game?': 'Similar to Free Roam where I can explore with my horse',
#  '8_ShowJumping_Other': nan,
#  '9_How would you like to see jump mechanic to be in Show jumping?': 'Auto jump (similar to that in Cross Country)',
#  '9_Other': nan,
#  '10_Have you ever participated in the Leaps & Bounds Cross Country Limited Time Event?': 'Yes',
#  '11_What is the main reason for you to NOT participate in the Leaps & Bounds Cross Country Limited Time Event?': nan,
#  '11_Other (please specify)': nan,
#  '12_Please rate your experience playing Leaps & Bounds Cross Country Limited Time Event.': 4.0,
#  '13_OE_[Optional] Please briefly explain why you you rated your experience playing Leaps & Bounds Cross Country Limited Time Event the way you did.': nan,
#  '14_AgreeDisagree_Riding too frequently was exhausting': 'Agree',
#  '14_AgreeDisagree_I liked the variety of tasks in the event': 'Strongly agree',
#  '14_AgreeDisagree_I liked that I had freedom to choose the task to complete': 'Agree',
#  '14_AgreeDisagree_I felt greatly rewarded for the effort I put into the event': 'Strongly agree',
#  '14_AgreeDisagree_I feel like if I had chance to prepare, I could have completed the event more easily': 'Strongly agree',
#  '14_AgreeDisagree_I developed a strategy to complete event more efficiently (combine multiple tasks in single race to gain more points)': 'Agree',
#  '14_AgreeDisagree_I liked the difficulty level of the tasks': 'Strongly agree',
#  '15_Scale_How successful do you think you were in gaining the rewards you wanted in the Event?': 8.0,
#  '16_How did you feel about the rewards of the Leaps & Bounds Cross Country Limited Time Event?': "I loved the rewards but I couldn't complete the goals to get them",
#  '17_OE_[Optional] How do you feel about Leaps and Bounds Cross Country event compared to Foaling season, Arabian days and Steeplechase Stars?': nan,
#  '18_Rank_LTE_Starting Time & Date': 2.0,
#  '18_Rank_LTE_Event Duration (e.g. 2-3 days)': 1.0,
#  '18_Rank_LTE_Tasks Information': 6.0,
#  '18_Rank_LTE_Rewards (Regular and/or Premium)': 3.0,
#  '18_Rank_LTE_Final Reward': 5.0,
#  '18_Rank_LTE_Reward Track': 4.0,
#  '18_Rank_LTE_Reward Track Price': 7.0,
#  '18_Rank_LTE_Bundles info': 8.0,
#  '19_Rank_LiveRaces_Event Starting Time & Date': 1.0,
#  '19_Rank_LiveRaces_Track Distance': 2.0,
#  '19_Rank_LiveRaces_Track Surface': 4.0,
#  '19_Rank_LiveRaces_Grade stream (even/uneven, e.g. Grade 1-2 vs Grade 1-3, etc)': 3.0,
#  '19_Rank_LiveRaces_Race mode': 5.0,
#  '19_Rank_LiveRaces_Leaderboard Prizes': 6.0,
#  '20_Which gender do you identify yourself with?': 'Male',
#  '21_What is your age group?': '25-34',
#  '22_Are you a member of Rival Stars Horse Racing Facebook community?': 'Yes',
#  '23_How frequently are you active on the Rival Stars Horse Racing Facebook community?': 'Few times a month',
#  "24_[OPTIONAL] Is there anything you'd like to share about the game (good, bad, frustrating, improvement, wishlist, etc.)?": nan,
#  '25_We may run paid online interviews in the future to help us improve the game, if you are interested please leave your email below.': 'Markossanj22@gmail.com',
#  'pcubed_id': 395464555,
#  'days_seen': 115.0,
#  'name': 'United States',
#  'channel': 'play',
#  'is_organic': 0.0,
#  'retention_day': 841.0,
#  'player_lifetime': 839.0,
#  'ever_been_free_trial_subscriber': 0.0,
#  'is_current_subscriber': 0.0,
#  'ever_been_subscriber': 0.0,
#  'spending': 0.0,
#  'number_of_ads_watched_in_last_45_days': 110.0,
#  'app_version': '1.42.2',
#  'test_group': 'GoldUpsell_30Percent_PriceDiscount',
#  'prestige_rank': 17.0,
#  'ever_purchased_horse_lto': 0.0,
#  'ever_purchased_event_horse_lto': 0.0,
#  'segment_no_ads_no_iap': 0.0,
#  'segment_some_ads_no_iap': 0.0,
#  'segment_lots_ads_no_iap': 1.0,
#  'segment_some_iap': 0.0,
#  'segment_lots_iap': 0.0,
#  'segment_subscriber': 0.0,
#  'segment_everyday_short_ret': 0.0,
#  'segment_not_everyday_long_ret': 1.0,
#  'segment_mid_days_seen': 0.0,
#  'segment_long_days_seen': 1.0,
#  'breeding_with_premium_stud': 1.0,
#  'n_premium_skiptimer': 1.0,
#  'n_ads_watched_skiptimer': 175.0,
#  'ever_watched_ads': 1.0,
#  'ever_completed_time_trial': 0.0,
#  'ever_join_team': 1.0,
#  'number_cross_country': 431.0,
#  'number_quick_ride': 1.0,
#  'number_live_event': 86.0,
#  'number_racing_runs': 919.0,
#  'qf_label': nan,
#  'standard_team_races': 72.0,
#  'special_team_races': 11.0,
#  'current_captain': 0.0,
#  'current_in_team': 1.0,
#  'highest_grade_horse': 40.0,
#  'milestone': nan,
#  'num_horse_bred': nan,
#  'avg_horse_grade': nan,
#  'max_event_prestige': nan,
#  'previous_race_pass_purchases': 0.0,
#  'arabiandays_race_pass_purchase': 0.0,
#  'milestone_at_purchase': 0.0,
#  'event_participation': 'No',
#  'crosscountry1_racepass': 'N',
#  'crosscountry1_bundle': 'N',
#  'crosscountry1_max_milestone': 9,
#  'crosscountry2_racepass': 'N',
#  'crosscountry2_bundle': 'N',
#  'crosscountry2_max_milestone': 0}

# %%
import json
import numpy as np

def clean_json_data(data):
    """
    Cleans a list of dictionaries to ensure all entries are JSON-serializable 
    and handles missing or invalid values appropriately.
    Args:
        data (list): List of dictionaries representing the dataset.
    Returns:
        list: Cleaned list of dictionaries.
    """
    def is_serializable(value):
        """
        Checks if a value can be serialized to JSON.
        """
        try:
            json.dumps(value)
            return True
        except (TypeError, ValueError):
            return False

    def clean_value(value):
        """
        Cleans individual values in the dataset:
        - Replaces NaN or None with an empty string.
        - Leaves JSON-serializable values unchanged.
        """
        if value is None or (isinstance(value, float) and np.isnan(value)):
            return ""
        if is_serializable(value):
            return value
        # For any non-serializable value, convert it to a string
        return str(value)

    def clean_entry(entry):
        """
        Cleans a single dictionary by applying `clean_value` to each field.
        """
        return {key: clean_value(value) for key, value in entry.items()}

    cleaned_data = [clean_entry(entry) for entry in data]
    original_count = len(data)
    cleaned_count = len(cleaned_data)
    print(f"Cleaned {original_count - cleaned_count} entries from the dataset.")
    return cleaned_data

# %%
data_cleaned = clean_json_data(data)
# Out:
# Cleaned 0 entries from the dataset.

# %%
data_cleaned[2]
# Out:
# {'Unnamed: 0': 3,
#  'Respondent ID': 114585000000,
#  'Collector ID': 431039728,
#  'Start Date': '2024-04-24 19:30:24',
#  'End Date': '2024-04-29 20:41:02',
#  'IP Address': '31.94.74.128',
#  'Email Address': '',
#  'First Name': '',
#  'Last Name': '',
#  'Custom Data 1': '',
#  '1_Rate_Overall Rival Stars Horse Racing': '5 (Strongly Like)',
#  '1_Rate_Breeding': '3 (Neutral)',
#  '1_Rate_Training my horses': '3 (Neutral)',
#  '1_Rate_Racing - Story': 4,
#  '1_Rate_Steeplechase': 2,
#  '1_Rate_Cross Country': 4,
#  '1_Rate_Free Roam': '3 (Neutral)',
#  '1_Rate_Live Events & Leaderboards (Flat racing & Cross Country)': '5 (Strongly Like)',
#  '1_Rate_Completing Story Goals': '3 (Neutral)',
#  '1_Rate_Foal Caring': '3 (Neutral)',
#  '1_Rate_Pasture': '3 (Neutral)',
#  '1_Rate_Foaling season event': '3 (Neutral)',
#  '1_Rate_Steeplechase Stars': '1 (Strongly Dislike)',
#  '1_Rate_Arabian Days': 2,
#  '1_Rate_Empowering my horse with skills': '5 (Strongly Like)',
#  '1_Rate_Customizing my horse with tack': 4,
#  '1_Rate_Teams': '5 (Strongly Like)',
#  '2_LeastEnjoy_Breeding horses for Coats': 'Breeding horses for Coats',
#  '2_LeastEnjoy_Breeding horses for Stats': '',
#  '2_LeastEnjoy_Training my Horses': '',
#  '2_LeastEnjoy_Racing - Story': '',
#  '2_LeastEnjoy_Steeplechase': 'Steeplechase',
#  '2_LeastEnjoy_Cross Country': '',
#  '2_LeastEnjoy_Free Roam': 'Free Roam',
#  '2_LeastEnjoy_Racing - Live Events & Leaderboards  (Flat racing & Cross Country)': '',
#  '2_LeastEnjoy_Completing Story Goals': '',
#  '2_LeastEnjoy_Foal Caring': '',
#  '2_LeastEnjoy_Pasture': '',
#  '2_LeastEnjoy_Foaling season event': '',
#  '2_LeastEnjoy_Steeplechase Stars': '',
#  '2_LeastEnjoy_Arabian Days': '',
#  '2_LeastEnjoy_Empowering my Horse with Skills': '',
#  '2_LeastEnjoy_Customizing my Horse with Tack': '',
#  '2_LeastEnjoy_Teams': '',
#  '2_LeastEnjoy_Browsing the new Horse offers': '',
#  '3_OE_LeastEnjoy': 'I never use free roam. I have other things to focus on in game like training. Coats are second to stays for me and I have the splash white face/ pinto fade curse to eradicate. Steeple chase is a bit tedious once you get a good lead over the NPCs',
#  '4_Changes_More social aspects': 'Desirable',
#  '4_Changes_More competitions and leaderboards': 'Strongly Desirable',
#  '4_Changes_More fast-paced and thrilling experiences': 'Strongly Desirable',
#  '4_Changes_More opportunities to have peaceful experiences': 'No preference (Good as it is)',
#  '4_Changes_More directed goals/missions': 'No preference (Good as it is)',
#  '4_Changes_More ways to improve the level of my horse': 'Desirable',
#  '4_Changes_More thinking and planning opportunities': 'Desirable',
#  '4_Changes_More opportunities for immersive experience with my horse': 'No preference (Good as it is)',
#  '4_Changes_More narrative': 'No preference (Good as it is)',
#  '4_Changes_Ability to explore the world with my horse on my own terms': 'No preference (Good as it is)',
#  '4_Changes_More horse, jockey and stables customization options': 'Desirable',
#  '4_Changes_More challenging goals/missions': 'No preference (Good as it is)',
#  '5_Goal_What is your main goal when you play Rival Stars Horse Racing?': 'I want my horse to become a champion racer',
#  '6_NewFeature_Which NEW feature would you most want to see added to the game?': 'Show jumping',
#  '6_NewFeature_Other': '',
#  '7_OE_NewFeature_What do you expect {{ Q6 }} to be like?': "I'm guessing similar to how xc and SC works currently! Perhaps with a mechanic where the fences can be knocked down if you miss a perfect jump. ",
#  '8_How would you like to see Show Jumping added in the game?': 'A separate fully developed game mode similar to (Flat racing, cross country and steeplechase)',
#  '8_ShowJumping_Other': '',
#  '9_How would you like to see jump mechanic to be in Show jumping?': "Fully Manual jump (where horse won't jump unless you decide to do so)",
#  '9_Other': '',
#  '10_Have you ever participated in the Leaps & Bounds Cross Country Limited Time Event?': 'Yes',
#  '11_What is the main reason for you to NOT participate in the Leaps & Bounds Cross Country Limited Time Event?': '',
#  '11_Other (please specify)': '',
#  '12_Please rate your experience playing Leaps & Bounds Cross Country Limited Time Event.': 4.0,
#  '13_OE_[Optional] Please briefly explain why you you rated your experience playing Leaps & Bounds Cross Country Limited Time Event the way you did.': 'It got a little tedious particularly if no race pass. ',
#  '14_AgreeDisagree_Riding too frequently was exhausting': 'Strongly agree',
#  '14_AgreeDisagree_I liked the variety of tasks in the event': 'Agree',
#  '14_AgreeDisagree_I liked that I had freedom to choose the task to complete': 'Strongly agree',
#  '14_AgreeDisagree_I felt greatly rewarded for the effort I put into the event': 'Agree',
#  '14_AgreeDisagree_I feel like if I had chance to prepare, I could have completed the event more easily': 'Strongly agree',
#  '14_AgreeDisagree_I developed a strategy to complete event more efficiently (combine multiple tasks in single race to gain more points)': 'Agree',
#  '14_AgreeDisagree_I liked the difficulty level of the tasks': 'Agree',
#  '15_Scale_How successful do you think you were in gaining the rewards you wanted in the Event?': 10.0,
#  '16_How did you feel about the rewards of the Leaps & Bounds Cross Country Limited Time Event?': 'I loved the rewards and enjoyed completing the goals to gain rewards',
#  '17_OE_[Optional] How do you feel about Leaps and Bounds Cross Country event compared to Foaling season, Arabian days and Steeplechase Stars?': 'I like it, definitely more than Sc Stars',
#  '18_Rank_LTE_Starting Time & Date': 1.0,
#  '18_Rank_LTE_Event Duration (e.g. 2-3 days)': 2.0,
#  '18_Rank_LTE_Tasks Information': 3.0,
#  '18_Rank_LTE_Rewards (Regular and/or Premium)': 4.0,
#  '18_Rank_LTE_Final Reward': 6.0,
#  '18_Rank_LTE_Reward Track': 7.0,
#  '18_Rank_LTE_Reward Track Price': 5.0,
#  '18_Rank_LTE_Bundles info': 8.0,
#  '19_Rank_LiveRaces_Event Starting Time & Date': 1.0,
#  '19_Rank_LiveRaces_Track Distance': 2.0,
#  '19_Rank_LiveRaces_Track Surface': 3.0,
#  '19_Rank_LiveRaces_Grade stream (even/uneven, e.g. Grade 1-2 vs Grade 1-3, etc)': 4.0,
#  '19_Rank_LiveRaces_Race mode': 5.0,
#  '19_Rank_LiveRaces_Leaderboard Prizes': 6.0,
#  '20_Which gender do you identify yourself with?': 'Female',
#  '21_What is your age group?': '35-44',
#  '22_Are you a member of Rival Stars Horse Racing Facebook community?': 'Yes',
#  '23_How frequently are you active on the Rival Stars Horse Racing Facebook community?': 'At least once a day',
#  "24_[OPTIONAL] Is there anything you'd like to share about the game (good, bad, frustrating, improvement, wishlist, etc.)?": "Pasture is hard to use. Would prefer to be able to scroll through horses like in stables.  Access to previous weeks team (individual players) points. Events end at 1am for UK people and it's not fair to expect us to be up at that time to grab screenshots for record keeping. On that note an export function would be amazing.    Instant breeding on studs is amazing.  Spin the pony is a nice touch.  Id like more variety of tack available to win in races. I have hundreds of Jade Jewels!  The anniversary event was awesome. Thankyou.",
#  '25_We may run paid online interviews in the future to help us improve the game, if you are interested please leave your email below.': 'broadbeanicecream@gmail.com',
#  'pcubed_id': 531632623,
#  'days_seen': 314.0,
#  'name': 'United Kingdom',
#  'channel': 'play',
#  'is_organic': 0.0,
#  'retention_day': 332.0,
#  'player_lifetime': 330.0,
#  'ever_been_free_trial_subscriber': 0.0,
#  'is_current_subscriber': 1.0,
#  'ever_been_subscriber': 1.0,
#  'spending': 347.0438734374294,
#  'number_of_ads_watched_in_last_45_days': 359.0,
#  'app_version': '',
#  'test_group': '',
#  'prestige_rank': 18.0,
#  'ever_purchased_horse_lto': 0.0,
#  'ever_purchased_event_horse_lto': 0.0,
#  'segment_no_ads_no_iap': 0.0,
#  'segment_some_ads_no_iap': 0.0,
#  'segment_lots_ads_no_iap': 0.0,
#  'segment_some_iap': 0.0,
#  'segment_lots_iap': 1.0,
#  'segment_subscriber': 0.0,
#  'segment_everyday_short_ret': 0.0,
#  'segment_not_everyday_long_ret': 1.0,
#  'segment_mid_days_seen': 0.0,
#  'segment_long_days_seen': 1.0,
#  'breeding_with_premium_stud': 1.0,
#  'n_premium_skiptimer': 227.0,
#  'n_ads_watched_skiptimer': 326.0,
#  'ever_watched_ads': 1.0,
#  'ever_completed_time_trial': 0.0,
#  'ever_join_team': 1.0,
#  'number_cross_country': 1054.0,
#  'number_quick_ride': 4.0,
#  'number_live_event': 909.0,
#  'number_racing_runs': 5138.0,
#  'qf_label': '',
#  'standard_team_races': 552.0,
#  'special_team_races': 163.0,
#  'current_captain': 0.0,
#  'current_in_team': 1.0,
#  'highest_grade_horse': 45.0,
#  'milestone': '',
#  'num_horse_bred': '',
#  'avg_horse_grade': '',
#  'max_event_prestige': '',
#  'previous_race_pass_purchases': 8.0,
#  'arabiandays_race_pass_purchase': 1.0,
#  'milestone_at_purchase': 2.0,
#  'event_participation': 'Yes',
#  'crosscountry1_racepass': 'Y',
#  'crosscountry1_bundle': 'N',
#  'crosscountry1_max_milestone': 11,
#  'crosscountry2_racepass': 'Y',
#  'crosscountry2_bundle': 'N',
#  'crosscountry2_max_milestone': 11}

# %%
def filter_and_enrich_data(data, columns_of_interest):
    """
    Filters and enriches a dataset by specified columns.

    Args:
        data (list): List of dictionaries representing the dataset.
        columns_of_interest (list): List of column names to check in each entry.

    Returns:
        list: Filtered and enriched dataset.
    """
    removed_count = 0  # Track the number of removed entries
    filtered_data = []  # List to store the remaining entries

    for entry_idx, entry in enumerate(data):
        try:
            # Check if all specified columns are empty
            if all(
                not str(entry.get(col, "")).strip() for col in columns_of_interest
            ):
                removed_count += 1  # Count this entry as removed
                logger.debug(f"Removed entry #{entry_idx}: All columns empty: {entry}")
            else:
                # Create a new key 'player_response' with concatenated text from specified columns
                player_response = " ".join(
                    str(entry.get(col, "")).strip()
                    for col in columns_of_interest
                    if str(entry.get(col, "")).strip()
                )
                
                # Check if player_response has more than 3 words
                if len(player_response.split()) > 3:
                    entry["player_response"] = player_response
                    filtered_data.append(entry)
                else:
                    removed_count += 1  # Count this entry as removed
                    logger.debug(f"Removed entry #{entry_idx}: player_response too short: {entry}")
        except Exception as e:
            logger.error(f"Error processing entry #{entry_idx}: {e}")
            raise

    # Log and print the number of removed entries
    logger.info(f"Total entries removed: {removed_count}")
    print(f"Total entries removed: {removed_count}")

    return filtered_data

# %%
columns_of_interest = [
    "24_[OPTIONAL] Is there anything you'd like to share about the game (good, bad, frustrating, improvement, wishlist, etc.)?"
]

# %%
filtered_data = filter_and_enrich_data(data_cleaned, columns_of_interest)
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# 2024-11-19 16:55:21,282 - INFO - Total entries removed: 4397
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Total entries removed: 4397

# %%
filtered_data[10]
# Out:
# {'Unnamed: 0': 31,
#  'Respondent ID': 114588000000,
#  'Collector ID': 431039728,
#  'Start Date': '2024-04-29 13:26:55',
#  'End Date': '2024-04-29 13:40:08',
#  'IP Address': '99.251.136.92',
#  'Email Address': '',
#  'First Name': '',
#  'Last Name': '',
#  'Custom Data 1': '',
#  '1_Rate_Overall Rival Stars Horse Racing': '5 (Strongly Like)',
#  '1_Rate_Breeding': 4,
#  '1_Rate_Training my horses': 4,
#  '1_Rate_Racing - Story': 4,
#  '1_Rate_Steeplechase': 4,
#  '1_Rate_Cross Country': 4,
#  '1_Rate_Free Roam': 4,
#  '1_Rate_Live Events & Leaderboards (Flat racing & Cross Country)': 4,
#  '1_Rate_Completing Story Goals': 4,
#  '1_Rate_Foal Caring': '3 (Neutral)',
#  '1_Rate_Pasture': 2,
#  '1_Rate_Foaling season event': '5 (Strongly Like)',
#  '1_Rate_Steeplechase Stars': 4,
#  '1_Rate_Arabian Days': '5 (Strongly Like)',
#  '1_Rate_Empowering my horse with skills': '3 (Neutral)',
#  '1_Rate_Customizing my horse with tack': '5 (Strongly Like)',
#  '1_Rate_Teams': '5 (Strongly Like)',
#  '2_LeastEnjoy_Breeding horses for Coats': '',
#  '2_LeastEnjoy_Breeding horses for Stats': '',
#  '2_LeastEnjoy_Training my Horses': '',
#  '2_LeastEnjoy_Racing - Story': '',
#  '2_LeastEnjoy_Steeplechase': '',
#  '2_LeastEnjoy_Cross Country': '',
#  '2_LeastEnjoy_Free Roam': '',
#  '2_LeastEnjoy_Racing - Live Events & Leaderboards  (Flat racing & Cross Country)': '',
#  '2_LeastEnjoy_Completing Story Goals': '',
#  '2_LeastEnjoy_Foal Caring': 'Foal Caring',
#  '2_LeastEnjoy_Pasture': 'Pasture',
#  '2_LeastEnjoy_Foaling season event': '',
#  '2_LeastEnjoy_Steeplechase Stars': '',
#  '2_LeastEnjoy_Arabian Days': '',
#  '2_LeastEnjoy_Empowering my Horse with Skills': '',
#  '2_LeastEnjoy_Customizing my Horse with Tack': '',
#  '2_LeastEnjoy_Teams': '',
#  '2_LeastEnjoy_Browsing the new Horse offers': '',
#  '3_OE_LeastEnjoy': 'I donâ€™t like that foal caring takes so long and i donâ€™t like that you habve limited stalls so you have to put them in the limited pasture that takes 3 hours to bring back a horse. Also i donâ€™t like how expensive breeding horses is because i can never get the right feeds and that stalls are super expensive in gold and so is everything else.',
#  '4_Changes_More social aspects': 'Desirable',
#  '4_Changes_More competitions and leaderboards': 'No preference (Good as it is)',
#  '4_Changes_More fast-paced and thrilling experiences': 'Desirable',
#  '4_Changes_More opportunities to have peaceful experiences': 'Desirable',
#  '4_Changes_More directed goals/missions': 'No preference (Good as it is)',
#  '4_Changes_More ways to improve the level of my horse': 'Desirable',
#  '4_Changes_More thinking and planning opportunities': 'No preference (Good as it is)',
#  '4_Changes_More opportunities for immersive experience with my horse': 'Strongly Desirable',
#  '4_Changes_More narrative': 'No preference (Good as it is)',
#  '4_Changes_Ability to explore the world with my horse on my own terms': 'Strongly Desirable',
#  '4_Changes_More horse, jockey and stables customization options': 'Desirable',
#  '4_Changes_More challenging goals/missions': 'No preference (Good as it is)',
#  '5_Goal_What is your main goal when you play Rival Stars Horse Racing?': 'I want my horse to reach its maximum potential',
#  '6_NewFeature_Which NEW feature would you most want to see added to the game?': 'Other (please specify)',
#  '6_NewFeature_Other': 'More horse breeds and breeding and other things being less expensive or time consuming',
#  '7_OE_NewFeature_What do you expect {{ Q6 }} to be like?': 'Not having to race multiple times to just get the feed i want. And adding bigger horses like shires, and showjumping. And i donâ€™t want to have to use gold or a lot of feed to breed my horses, and i think stalls should be easier to get and less expensive.',
#  '8_How would you like to see Show Jumping added in the game?': 'A separate fully developed game mode similar to (Flat racing, cross country and steeplechase)',
#  '8_ShowJumping_Other': '',
#  '9_How would you like to see jump mechanic to be in Show jumping?': 'Semi-auto (similar to Steeplechase jump, where manual attempt is done for better results but horse will auto jump if not done)',
#  '9_Other': '',
#  '10_Have you ever participated in the Leaps & Bounds Cross Country Limited Time Event?': 'Yes',
#  '11_What is the main reason for you to NOT participate in the Leaps & Bounds Cross Country Limited Time Event?': '',
#  '11_Other (please specify)': '',
#  '12_Please rate your experience playing Leaps & Bounds Cross Country Limited Time Event.': 3.0,
#  '13_OE_[Optional] Please briefly explain why you you rated your experience playing Leaps & Bounds Cross Country Limited Time Event the way you did.': 'I think it should be easier to get the rewards.',
#  '14_AgreeDisagree_Riding too frequently was exhausting': 'Agree',
#  '14_AgreeDisagree_I liked the variety of tasks in the event': 'Agree',
#  '14_AgreeDisagree_I liked that I had freedom to choose the task to complete': 'Agree',
#  '14_AgreeDisagree_I felt greatly rewarded for the effort I put into the event': 'Strongly disagree',
#  '14_AgreeDisagree_I feel like if I had chance to prepare, I could have completed the event more easily': 'Disagree',
#  '14_AgreeDisagree_I developed a strategy to complete event more efficiently (combine multiple tasks in single race to gain more points)': 'Disagree',
#  '14_AgreeDisagree_I liked the difficulty level of the tasks': 'Strongly disagree',
#  '15_Scale_How successful do you think you were in gaining the rewards you wanted in the Event?': 1.0,
#  '16_How did you feel about the rewards of the Leaps & Bounds Cross Country Limited Time Event?': "I didn't find the rewards attractive/useful",
#  '17_OE_[Optional] How do you feel about Leaps and Bounds Cross Country event compared to Foaling season, Arabian days and Steeplechase Stars?': 'All of the, should be easier to get rewards, otherwise itâ€™s just pay to win because some of the events require breeding, and sometimes i donâ€™t have enough feed to breed.',
#  '18_Rank_LTE_Starting Time & Date': 4.0,
#  '18_Rank_LTE_Event Duration (e.g. 2-3 days)': 5.0,
#  '18_Rank_LTE_Tasks Information': 3.0,
#  '18_Rank_LTE_Rewards (Regular and/or Premium)': 1.0,
#  '18_Rank_LTE_Final Reward': 2.0,
#  '18_Rank_LTE_Reward Track': 6.0,
#  '18_Rank_LTE_Reward Track Price': 7.0,
#  '18_Rank_LTE_Bundles info': 8.0,
#  '19_Rank_LiveRaces_Event Starting Time & Date': 2.0,
#  '19_Rank_LiveRaces_Track Distance': 3.0,
#  '19_Rank_LiveRaces_Track Surface': 5.0,
#  '19_Rank_LiveRaces_Grade stream (even/uneven, e.g. Grade 1-2 vs Grade 1-3, etc)': 6.0,
#  '19_Rank_LiveRaces_Race mode': 4.0,
#  '19_Rank_LiveRaces_Leaderboard Prizes': 1.0,
#  '20_Which gender do you identify yourself with?': 'Non-binary/Gender diverse',
#  '21_What is your age group?': '13-17',
#  '22_Are you a member of Rival Stars Horse Racing Facebook community?': 'No',
#  '23_How frequently are you active on the Rival Stars Horse Racing Facebook community?': '',
#  "24_[OPTIONAL] Is there anything you'd like to share about the game (good, bad, frustrating, improvement, wishlist, etc.)?": 'I wish for things to be less expensive, easier to get stalls and rewards in live events, and easier to get the feed you need for breeding.',
#  '25_We may run paid online interviews in the future to help us improve the game, if you are interested please leave your email below.': '',
#  'pcubed_id': 494767688,
#  'days_seen': 61.0,
#  'name': 'Canada',
#  'channel': 'iosstore',
#  'is_organic': 0.0,
#  'retention_day': 712.0,
#  'player_lifetime': 710.0,
#  'ever_been_free_trial_subscriber': 0.0,
#  'is_current_subscriber': 0.0,
#  'ever_been_subscriber': 0.0,
#  'spending': 0.0,
#  'number_of_ads_watched_in_last_45_days': 15.0,
#  'app_version': 1.38,
#  'test_group': 'refresh_3_slot',
#  'prestige_rank': 9.0,
#  'ever_purchased_horse_lto': 0.0,
#  'ever_purchased_event_horse_lto': 0.0,
#  'segment_no_ads_no_iap': 0.0,
#  'segment_some_ads_no_iap': 0.0,
#  'segment_lots_ads_no_iap': 1.0,
#  'segment_some_iap': 0.0,
#  'segment_lots_iap': 0.0,
#  'segment_subscriber': 0.0,
#  'segment_everyday_short_ret': 0.0,
#  'segment_not_everyday_long_ret': 1.0,
#  'segment_mid_days_seen': 0.0,
#  'segment_long_days_seen': 1.0,
#  'breeding_with_premium_stud': 1.0,
#  'n_premium_skiptimer': 9.0,
#  'n_ads_watched_skiptimer': 160.0,
#  'ever_watched_ads': 1.0,
#  'ever_completed_time_trial': 0.0,
#  'ever_join_team': 1.0,
#  'number_cross_country': 12.0,
#  'number_quick_ride': 2.0,
#  'number_live_event': 12.0,
#  'number_racing_runs': 247.0,
#  'qf_label': '',
#  'standard_team_races': 5.0,
#  'special_team_races': 1.0,
#  'current_captain': 0.0,
#  'current_in_team': 1.0,
#  'highest_grade_horse': 25.0,
#  'milestone': '',
#  'num_horse_bred': '',
#  'avg_horse_grade': '',
#  'max_event_prestige': '',
#  'previous_race_pass_purchases': 0.0,
#  'arabiandays_race_pass_purchase': 0.0,
#  'milestone_at_purchase': 0.0,
#  'event_participation': 'No',
#  'crosscountry1_racepass': 'N',
#  'crosscountry1_bundle': 'N',
#  'crosscountry1_max_milestone': 0,
#  'crosscountry2_racepass': 'N',
#  'crosscountry2_bundle': 'N',
#  'crosscountry2_max_milestone': 0,
#  'player_response': 'I wish for things to be less expensive, easier to get stalls and rewards in live events, and easier to get the feed you need for breeding.'}

# %%
len(filtered_data)
# Out:
# 2760

# %%
def save_to_json(data, output_path):
    """
    Saves data to a JSON file with proper encoding.
    
    Args:
        data (list): Data to save.
        output_path (str): Path to the output JSON file.
    """
    try:
        with open(output_path, "w", encoding="utf-8") as f:
            json.dump(data, f, ensure_ascii=False, indent=4)
        logger.info(f"Data successfully saved to {output_path}")
    except Exception as e:
        logger.error(f"Error saving JSON: {e}")
        raise

# %%
save_to_json(filtered_data, path_db_prepared)
# Out:
# 2024-11-19 16:56:00,914 - INFO - Data successfully saved to C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\db_prepared.json

# %%
import random

def get_random_sample(data, sample_size, seed=None):
    """
    Returns a random sample of the specified size from the dataset.
    """
    if seed is not None:
        random.seed(seed)  # Set the random seed for reproducibility
    
    if sample_size > len(data):
        raise ValueError(f"Sample size ({sample_size}) cannot exceed the dataset size ({len(data)}).")
    
    return random.sample(data, sample_size)

# %%
sample_size = 100
seed = 42
sample_data = get_random_sample(filtered_data, sample_size, seed=seed)

# %%
sample_data[0]
# Out:
# {'Unnamed: 0': 1520,
#  'Respondent ID': 114587000000,
#  'Collector ID': 431039728,
#  'Start Date': '2024-04-26 21:01:16',
#  'End Date': '2024-04-26 21:09:56',
#  'IP Address': '172.97.49.205',
#  'Email Address': '',
#  'First Name': '',
#  'Last Name': '',
#  'Custom Data 1': '',
#  '1_Rate_Overall Rival Stars Horse Racing': '5 (Strongly Like)',
#  '1_Rate_Breeding': '1 (Strongly Dislike)',
#  '1_Rate_Training my horses': '1 (Strongly Dislike)',
#  '1_Rate_Racing - Story': '3 (Neutral)',
#  '1_Rate_Steeplechase': '3 (Neutral)',
#  '1_Rate_Cross Country': '3 (Neutral)',
#  '1_Rate_Free Roam': '3 (Neutral)',
#  '1_Rate_Live Events & Leaderboards (Flat racing & Cross Country)': 2,
#  '1_Rate_Completing Story Goals': 4,
#  '1_Rate_Foal Caring': '1 (Strongly Dislike)',
#  '1_Rate_Pasture': 2,
#  '1_Rate_Foaling season event': '5 (Strongly Like)',
#  '1_Rate_Steeplechase Stars': '3 (Neutral)',
#  '1_Rate_Arabian Days': '1 (Strongly Dislike)',
#  '1_Rate_Empowering my horse with skills': 4,
#  '1_Rate_Customizing my horse with tack': 4,
#  '1_Rate_Teams': '3 (Neutral)',
#  '2_LeastEnjoy_Breeding horses for Coats': '',
#  '2_LeastEnjoy_Breeding horses for Stats': '',
#  '2_LeastEnjoy_Training my Horses': 'Training my horses',
#  '2_LeastEnjoy_Racing - Story': '',
#  '2_LeastEnjoy_Steeplechase': '',
#  '2_LeastEnjoy_Cross Country': '',
#  '2_LeastEnjoy_Free Roam': '',
#  '2_LeastEnjoy_Racing - Live Events & Leaderboards  (Flat racing & Cross Country)': 'Live Events & Leaderboards (Flat racing & Cross Country)',
#  '2_LeastEnjoy_Completing Story Goals': 'Completing Story Goals',
#  '2_LeastEnjoy_Foal Caring': '',
#  '2_LeastEnjoy_Pasture': '',
#  '2_LeastEnjoy_Foaling season event': '',
#  '2_LeastEnjoy_Steeplechase Stars': '',
#  '2_LeastEnjoy_Arabian Days': '',
#  '2_LeastEnjoy_Empowering my Horse with Skills': '',
#  '2_LeastEnjoy_Customizing my Horse with Tack': '',
#  '2_LeastEnjoy_Teams': '',
#  '2_LeastEnjoy_Browsing the new Horse offers': '',
#  '3_OE_LeastEnjoy': 'Because training takes a lot of time, events are only for people with good horses, and story goals are just hard to complete when you donâ€™t have any silver or gold thingys',
#  '4_Changes_More social aspects': 'No preference (Good as it is)',
#  '4_Changes_More competitions and leaderboards': 'No preference (Good as it is)',
#  '4_Changes_More fast-paced and thrilling experiences': 'No preference (Good as it is)',
#  '4_Changes_More opportunities to have peaceful experiences': 'Strongly Desirable',
#  '4_Changes_More directed goals/missions': 'No preference (Good as it is)',
#  '4_Changes_More ways to improve the level of my horse': 'Undesirable',
#  '4_Changes_More thinking and planning opportunities': 'No preference (Good as it is)',
#  '4_Changes_More opportunities for immersive experience with my horse': 'Strongly Desirable',
#  '4_Changes_More narrative': 'Desirable',
#  '4_Changes_Ability to explore the world with my horse on my own terms': 'Strongly Desirable',
#  '4_Changes_More horse, jockey and stables customization options': 'Strongly Desirable',
#  '4_Changes_More challenging goals/missions': 'Strongly undesirable',
#  '5_Goal_What is your main goal when you play Rival Stars Horse Racing?': 'I want to have aesthetically pleasing horse that I could show to my friends',
#  '6_NewFeature_Which NEW feature would you most want to see added to the game?': 'Show jumping',
#  '6_NewFeature_Other': '',
#  '7_OE_NewFeature_What do you expect {{ Q6 }} to be like?': 'Like real life but in game..? Lol ',
#  '8_How would you like to see Show Jumping added in the game?': 'Similar to Free Roam where I can explore with my horse',
#  '8_ShowJumping_Other': '',
#  '9_How would you like to see jump mechanic to be in Show jumping?': "Fully Manual jump (where horse won't jump unless you decide to do so)",
#  '9_Other': '',
#  '10_Have you ever participated in the Leaps & Bounds Cross Country Limited Time Event?': 'Yes',
#  '11_What is the main reason for you to NOT participate in the Leaps & Bounds Cross Country Limited Time Event?': '',
#  '11_Other (please specify)': '',
#  '12_Please rate your experience playing Leaps & Bounds Cross Country Limited Time Event.': 3.0,
#  '13_OE_[Optional] Please briefly explain why you you rated your experience playing Leaps & Bounds Cross Country Limited Time Event the way you did.': '',
#  '14_AgreeDisagree_Riding too frequently was exhausting': 'Strongly agree',
#  '14_AgreeDisagree_I liked the variety of tasks in the event': 'Strongly disagree',
#  '14_AgreeDisagree_I liked that I had freedom to choose the task to complete': 'Strongly disagree',
#  '14_AgreeDisagree_I felt greatly rewarded for the effort I put into the event': 'Strongly disagree',
#  '14_AgreeDisagree_I feel like if I had chance to prepare, I could have completed the event more easily': 'Agree',
#  '14_AgreeDisagree_I developed a strategy to complete event more efficiently (combine multiple tasks in single race to gain more points)': 'Agree',
#  '14_AgreeDisagree_I liked the difficulty level of the tasks': 'Strongly disagree',
#  '15_Scale_How successful do you think you were in gaining the rewards you wanted in the Event?': 4.0,
#  '16_How did you feel about the rewards of the Leaps & Bounds Cross Country Limited Time Event?': "I loved the rewards but I couldn't complete the goals to get them",
#  '17_OE_[Optional] How do you feel about Leaps and Bounds Cross Country event compared to Foaling season, Arabian days and Steeplechase Stars?': '',
#  '18_Rank_LTE_Starting Time & Date': 4.0,
#  '18_Rank_LTE_Event Duration (e.g. 2-3 days)': 2.0,
#  '18_Rank_LTE_Tasks Information': 5.0,
#  '18_Rank_LTE_Rewards (Regular and/or Premium)': 1.0,
#  '18_Rank_LTE_Final Reward': 3.0,
#  '18_Rank_LTE_Reward Track': 6.0,
#  '18_Rank_LTE_Reward Track Price': 7.0,
#  '18_Rank_LTE_Bundles info': 8.0,
#  '19_Rank_LiveRaces_Event Starting Time & Date': 2.0,
#  '19_Rank_LiveRaces_Track Distance': 3.0,
#  '19_Rank_LiveRaces_Track Surface': 4.0,
#  '19_Rank_LiveRaces_Grade stream (even/uneven, e.g. Grade 1-2 vs Grade 1-3, etc)': 5.0,
#  '19_Rank_LiveRaces_Race mode': 6.0,
#  '19_Rank_LiveRaces_Leaderboard Prizes': 1.0,
#  '20_Which gender do you identify yourself with?': 'Female',
#  '21_What is your age group?': '13-17',
#  '22_Are you a member of Rival Stars Horse Racing Facebook community?': 'Yes',
#  '23_How frequently are you active on the Rival Stars Horse Racing Facebook community?': 'Few times a month',
#  "24_[OPTIONAL] Is there anything you'd like to share about the game (good, bad, frustrating, improvement, wishlist, etc.)?": 'I love the game, but the hidden coats make it really hard to get a good coat if you donâ€™t know it, Iâ€™ve been playing for a long time, and Iâ€™m not complaining at all! I just find it difficult to breed food coats, itâ€™s also hard to get the things you need to breed horses',
#  '25_We may run paid online interviews in the future to help us improve the game, if you are interested please leave your email below.': '',
#  'pcubed_id': 495130407,
#  'days_seen': 88.0,
#  'name': 'Canada',
#  'channel': 'iosstore',
#  'is_organic': 1.0,
#  'retention_day': 705.0,
#  'player_lifetime': 704.0,
#  'ever_been_free_trial_subscriber': 0.0,
#  'is_current_subscriber': 0.0,
#  'ever_been_subscriber': 0.0,
#  'spending': 0.7076745687170027,
#  'number_of_ads_watched_in_last_45_days': 3.0,
#  'app_version': '1.43.2',
#  'test_group': 'GoldUpsell_NoDiscount_NoBonus',
#  'prestige_rank': 10.0,
#  'ever_purchased_horse_lto': 0.0,
#  'ever_purchased_event_horse_lto': 0.0,
#  'segment_no_ads_no_iap': 0.0,
#  'segment_some_ads_no_iap': 0.0,
#  'segment_lots_ads_no_iap': 0.0,
#  'segment_some_iap': 1.0,
#  'segment_lots_iap': 0.0,
#  'segment_subscriber': 0.0,
#  'segment_everyday_short_ret': 0.0,
#  'segment_not_everyday_long_ret': 1.0,
#  'segment_mid_days_seen': 0.0,
#  'segment_long_days_seen': 1.0,
#  'breeding_with_premium_stud': 1.0,
#  'n_premium_skiptimer': 33.0,
#  'n_ads_watched_skiptimer': 171.0,
#  'ever_watched_ads': 1.0,
#  'ever_completed_time_trial': 0.0,
#  'ever_join_team': 1.0,
#  'number_cross_country': 12.0,
#  'number_quick_ride': 3.0,
#  'number_live_event': 19.0,
#  'number_racing_runs': 160.0,
#  'qf_label': '',
#  'standard_team_races': 10.0,
#  'special_team_races': 7.0,
#  'current_captain': 0.0,
#  'current_in_team': 1.0,
#  'highest_grade_horse': 25.0,
#  'milestone': '',
#  'num_horse_bred': '',
#  'avg_horse_grade': '',
#  'max_event_prestige': '',
#  'previous_race_pass_purchases': 0.0,
#  'arabiandays_race_pass_purchase': 0.0,
#  'milestone_at_purchase': 0.0,
#  'event_participation': 'No',
#  'crosscountry1_racepass': 'N',
#  'crosscountry1_bundle': 'N',
#  'crosscountry1_max_milestone': 0,
#  'crosscountry2_racepass': 'N',
#  'crosscountry2_bundle': 'N',
#  'crosscountry2_max_milestone': 0,
#  'player_response': 'I love the game, but the hidden coats make it really hard to get a good coat if you donâ€™t know it, Iâ€™ve been playing for a long time, and Iâ€™m not complaining at all! I just find it difficult to breed food coats, itâ€™s also hard to get the things you need to breed horses'}

# %%
save_to_json(sample_data, path_db_prepared)
# Out:
# 2024-11-19 16:56:39,212 - INFO - Data successfully saved to C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\db_prepared.json

# %% [markdown]
# ## Translate

# %%
from lingua import Language, LanguageDetectorBuilder


def detect_player_language(data):
    """
    Detects the language of the 'player_response' field for each JSON tuple
    and adds a new key 'player_language' with the detected language.

    Args:
        data (list): List of JSON-like dictionaries.

    Returns:
        list: Updated list of dictionaries with 'player_language' key.
    """
    # Initialize the language detector
    detector = LanguageDetectorBuilder.from_languages(
        Language.ENGLISH, Language.SPANISH, Language.CHINESE, Language.GERMAN, Language.FRENCH
    ).build()

    for entry in data:
        player_response = entry.get("player_response", "")
        if player_response.strip():  # Check if 'player_response' is not empty
            language = detector.detect_language_of(player_response)
            entry["player_language"] = language.name.lower()  # Store language name in lowercase
        else:
            entry["player_language"] = None  # No language detected for empty responses
    return data

# %%
import json

def read_json(file_path):
    """
    Reads a JSON file and returns its contents as a Python object.

    Args:
        file_path (str): Path to the JSON file.

    Returns:
        object: The contents of the JSON file as a Python data structure (e.g., dict or list).
    """
    try:
        with open(file_path, "r", encoding="utf-8") as f:
            data = json.load(f)
        return data
    except FileNotFoundError:
        print(f"Error: The file '{file_path}' was not found.")
        raise
    except json.JSONDecodeError as e:
        print(f"Error: Failed to decode JSON from file '{file_path}': {e}")
        raise
    except Exception as e:
        print(f"An unexpected error occurred while reading the file '{file_path}': {e}")
        raise

# %%
data = read_json(path_db_prepared)

# %%
language = detect_player_language(data)

# %%
language[3]
# Out:
# {'Unnamed: 0': 3046,
#  'Respondent ID': 114585000000,
#  'Collector ID': 431039728,
#  'Start Date': '2024-04-25 07:47:24',
#  'End Date': '2024-04-25 08:15:36',
#  'IP Address': '68.229.99.20',
#  'Email Address': '',
#  'First Name': '',
#  'Last Name': '',
#  'Custom Data 1': '',
#  '1_Rate_Overall Rival Stars Horse Racing': '5 (Strongly Like)',
#  '1_Rate_Breeding': 4,
#  '1_Rate_Training my horses': '5 (Strongly Like)',
#  '1_Rate_Racing - Story': '5 (Strongly Like)',
#  '1_Rate_Steeplechase': '5 (Strongly Like)',
#  '1_Rate_Cross Country': '5 (Strongly Like)',
#  '1_Rate_Free Roam': '3 (Neutral)',
#  '1_Rate_Live Events & Leaderboards (Flat racing & Cross Country)': '3 (Neutral)',
#  '1_Rate_Completing Story Goals': '5 (Strongly Like)',
#  '1_Rate_Foal Caring': '3 (Neutral)',
#  '1_Rate_Pasture': 4,
#  '1_Rate_Foaling season event': 4,
#  '1_Rate_Steeplechase Stars': '5 (Strongly Like)',
#  '1_Rate_Arabian Days': '5 (Strongly Like)',
#  '1_Rate_Empowering my horse with skills': '3 (Neutral)',
#  '1_Rate_Customizing my horse with tack': '3 (Neutral)',
#  '1_Rate_Teams': '3 (Neutral)',
#  '2_LeastEnjoy_Breeding horses for Coats': '',
#  '2_LeastEnjoy_Breeding horses for Stats': 'Breeding horses for Stats',
#  '2_LeastEnjoy_Training my Horses': '',
#  '2_LeastEnjoy_Racing - Story': '',
#  '2_LeastEnjoy_Steeplechase': '',
#  '2_LeastEnjoy_Cross Country': '',
#  '2_LeastEnjoy_Free Roam': '',
#  '2_LeastEnjoy_Racing - Live Events & Leaderboards  (Flat racing & Cross Country)': 'Live Events & Leaderboards (Flat racing & Cross Country)',
#  '2_LeastEnjoy_Completing Story Goals': '',
#  '2_LeastEnjoy_Foal Caring': 'Foal Caring',
#  '2_LeastEnjoy_Pasture': '',
#  '2_LeastEnjoy_Foaling season event': '',
#  '2_LeastEnjoy_Steeplechase Stars': '',
#  '2_LeastEnjoy_Arabian Days': '',
#  '2_LeastEnjoy_Empowering my Horse with Skills': 'Empowering my horse with skills',
#  '2_LeastEnjoy_Customizing my Horse with Tack': '',
#  '2_LeastEnjoy_Teams': '',
#  '2_LeastEnjoy_Browsing the new Horse offers': '',
#  '3_OE_LeastEnjoy': 'Itâ€™s not that I donâ€™t like them per say; I just donâ€™t use or care about these features.',
#  '4_Changes_More social aspects': 'No preference (Good as it is)',
#  '4_Changes_More competitions and leaderboards': 'No preference (Good as it is)',
#  '4_Changes_More fast-paced and thrilling experiences': 'No preference (Good as it is)',
#  '4_Changes_More opportunities to have peaceful experiences': 'No preference (Good as it is)',
#  '4_Changes_More directed goals/missions': 'Desirable',
#  '4_Changes_More ways to improve the level of my horse': 'No preference (Good as it is)',
#  '4_Changes_More thinking and planning opportunities': 'No preference (Good as it is)',
#  '4_Changes_More opportunities for immersive experience with my horse': 'Desirable',
#  '4_Changes_More narrative': 'Desirable',
#  '4_Changes_Ability to explore the world with my horse on my own terms': 'No preference (Good as it is)',
#  '4_Changes_More horse, jockey and stables customization options': 'Strongly Desirable',
#  '4_Changes_More challenging goals/missions': 'Desirable',
#  '5_Goal_What is your main goal when you play Rival Stars Horse Racing?': 'I want my horse to become a champion racer',
#  '6_NewFeature_Which NEW feature would you most want to see added to the game?': 'More customization options',
#  '6_NewFeature_Other': '',
#  '7_OE_NewFeature_What do you expect {{ Q6 }} to be like?': 'Choose a tack design and then colors. Add ear net, sheepskin,  blinders, etc.  More jockey silk patterns and able to choose colors from color wheel. Choose use of gloves and goggles.  Choose option to use leg wraps.  Stuff like that.',
#  '8_How would you like to see Show Jumping added in the game?': 'Other (please specify)',
#  '8_ShowJumping_Other': 'I would like it but itâ€™s not an absolute need.',
#  '9_How would you like to see jump mechanic to be in Show jumping?': 'Semi-auto (similar to Steeplechase jump, where manual attempt is done for better results but horse will auto jump if not done)',
#  '9_Other': '',
#  '10_Have you ever participated in the Leaps & Bounds Cross Country Limited Time Event?': 'Yes',
#  '11_What is the main reason for you to NOT participate in the Leaps & Bounds Cross Country Limited Time Event?': '',
#  '11_Other (please specify)': '',
#  '12_Please rate your experience playing Leaps & Bounds Cross Country Limited Time Event.': 5.0,
#  '13_OE_[Optional] Please briefly explain why you you rated your experience playing Leaps & Bounds Cross Country Limited Time Event the way you did.': 'Plenty of time to complete.',
#  '14_AgreeDisagree_Riding too frequently was exhausting': 'Disagree',
#  '14_AgreeDisagree_I liked the variety of tasks in the event': 'Disagree',
#  '14_AgreeDisagree_I liked that I had freedom to choose the task to complete': 'Agree',
#  '14_AgreeDisagree_I felt greatly rewarded for the effort I put into the event': 'Agree',
#  '14_AgreeDisagree_I feel like if I had chance to prepare, I could have completed the event more easily': 'Strongly disagree',
#  '14_AgreeDisagree_I developed a strategy to complete event more efficiently (combine multiple tasks in single race to gain more points)': 'Strongly agree',
#  '14_AgreeDisagree_I liked the difficulty level of the tasks': 'Disagree',
#  '15_Scale_How successful do you think you were in gaining the rewards you wanted in the Event?': 10.0,
#  '16_How did you feel about the rewards of the Leaps & Bounds Cross Country Limited Time Event?': "I didn't find the rewards attractive/useful",
#  '17_OE_[Optional] How do you feel about Leaps and Bounds Cross Country event compared to Foaling season, Arabian days and Steeplechase Stars?': '',
#  '18_Rank_LTE_Starting Time & Date': 1.0,
#  '18_Rank_LTE_Event Duration (e.g. 2-3 days)': 2.0,
#  '18_Rank_LTE_Tasks Information': 7.0,
#  '18_Rank_LTE_Rewards (Regular and/or Premium)': 3.0,
#  '18_Rank_LTE_Final Reward': 4.0,
#  '18_Rank_LTE_Reward Track': 5.0,
#  '18_Rank_LTE_Reward Track Price': 6.0,
#  '18_Rank_LTE_Bundles info': 8.0,
#  '19_Rank_LiveRaces_Event Starting Time & Date': 3.0,
#  '19_Rank_LiveRaces_Track Distance': 4.0,
#  '19_Rank_LiveRaces_Track Surface': 5.0,
#  '19_Rank_LiveRaces_Grade stream (even/uneven, e.g. Grade 1-2 vs Grade 1-3, etc)': 2.0,
#  '19_Rank_LiveRaces_Race mode': 1.0,
#  '19_Rank_LiveRaces_Leaderboard Prizes': 6.0,
#  '20_Which gender do you identify yourself with?': 'Female',
#  '21_What is your age group?': '25-34',
#  '22_Are you a member of Rival Stars Horse Racing Facebook community?': 'Yes',
#  '23_How frequently are you active on the Rival Stars Horse Racing Facebook community?': 'Never',
#  "24_[OPTIONAL] Is there anything you'd like to share about the game (good, bad, frustrating, improvement, wishlist, etc.)?": 'Breeding for stats still feels extremely hard. I learned from FB that itâ€™s easier to breed high stats when breeding down a grade but I donâ€™t see how thatâ€™s realistic.',
#  '25_We may run paid online interviews in the future to help us improve the game, if you are interested please leave your email below.': 'kbnwillow@msn.com',
#  'pcubed_id': 389314118,
#  'days_seen': 234.0,
#  'name': 'United States',
#  'channel': 'play',
#  'is_organic': 1.0,
#  'retention_day': 1046.0,
#  'player_lifetime': 1045.0,
#  'ever_been_free_trial_subscriber': 0.0,
#  'is_current_subscriber': 0.0,
#  'ever_been_subscriber': 0.0,
#  'spending': 0.0,
#  'number_of_ads_watched_in_last_45_days': 98.0,
#  'app_version': '1.35.1',
#  'test_group': 'No_Rewards',
#  'prestige_rank': 12.0,
#  'ever_purchased_horse_lto': 0.0,
#  'ever_purchased_event_horse_lto': 0.0,
#  'segment_no_ads_no_iap': 0.0,
#  'segment_some_ads_no_iap': 0.0,
#  'segment_lots_ads_no_iap': 1.0,
#  'segment_some_iap': 0.0,
#  'segment_lots_iap': 0.0,
#  'segment_subscriber': 0.0,
#  'segment_everyday_short_ret': 0.0,
#  'segment_not_everyday_long_ret': 1.0,
#  'segment_mid_days_seen': 0.0,
#  'segment_long_days_seen': 1.0,
#  'breeding_with_premium_stud': 1.0,
#  'n_premium_skiptimer': 6.0,
#  'n_ads_watched_skiptimer': 935.0,
#  'ever_watched_ads': 1.0,
#  'ever_completed_time_trial': 0.0,
#  'ever_join_team': 1.0,
#  'number_cross_country': 155.0,
#  'number_quick_ride': 3.0,
#  'number_live_event': 193.0,
#  'number_racing_runs': 1946.0,
#  'qf_label': '',
#  'standard_team_races': 106.0,
#  'special_team_races': 43.0,
#  'current_captain': 0.0,
#  'current_in_team': 1.0,
#  'highest_grade_horse': 35.0,
#  'milestone': '',
#  'num_horse_bred': '',
#  'avg_horse_grade': '',
#  'max_event_prestige': '',
#  'previous_race_pass_purchases': 0.0,
#  'arabiandays_race_pass_purchase': 0.0,
#  'milestone_at_purchase': 0.0,
#  'event_participation': 'No',
#  'crosscountry1_racepass': 'N',
#  'crosscountry1_bundle': 'N',
#  'crosscountry1_max_milestone': 10,
#  'crosscountry2_racepass': 'N',
#  'crosscountry2_bundle': 'N',
#  'crosscountry2_max_milestone': 11,
#  'player_response': 'Breeding for stats still feels extremely hard. I learned from FB that itâ€™s easier to breed high stats when breeding down a grade but I donâ€™t see how thatâ€™s realistic.',
#  'player_language': 'english'}

# %%
# Initialize token counters
prompt_tokens = 0
completion_tokens = 0

# Global API settings
api_settings = {"client": None, "model": None}

def configure_api(api_client, model_name):
    """
    Configures the global API client and model.
    Args:
        api_client: The initialized OpenAI client.
        model_name (str): The model name to use.
    """
    global api_settings
    api_settings["client"] = api_client
    api_settings["model"] = model_name


def track_tokens(response):
    """
    Updates the global token counters based on the response.
    """
    global prompt_tokens, completion_tokens
    prompt_tokens += response.usage.prompt_tokens
    completion_tokens += response.usage.completion_tokens

# %%
configure_api(client, chat_model_name)

# %%
from langchain.prompts import PromptTemplate

# Define the translation prompt template with examples
prompt_template_translation = PromptTemplate.from_template(
'''You are a professional translator. Translate the following text into English if it is not already in English.

[h0]==================================================================[\h0]
TEXT: "兄弟们，我把星空退款的钱拿来买这个了，我做的对吗"

TRANSLATION: "Brothers, I used the refund money from the stars to buy this. Did I do the right thing?"

[h0]==================================================================[\h0]
TEXT: "Me toma demasiado tiempo entrenar caballos."

TRANSLATION: "It takes too much time to train horses."

[h0]==================================================================[\h0]
TEXT: "Grinding just to get good tack, grain etc. Itâ€™s very time consuming sadly"

TRANSLATION: "Grinding just to get good tack, grain etc. It's very time consuming sadly"

[h0]==================================================================[\h0]
TEXT: "{text}"

TRANSLATION:
'''
)

# %%
def translate_player_responses(data, api_settings):
    """
    Translates the 'player_response' field for entries where 'player_language' is not 'english'.

    Args:
        data (list): List of JSON-like dictionaries.
        api_settings (dict): Dictionary with API settings, including the client and model.

    Returns:
        list: Updated list with translated 'player_response' fields.
    """
    for entry_idx, entry in enumerate(data):
        try:
            detected_language = entry.get("player_language", "none")
            player_response = entry.get("player_response", "")

            # Skip translation for English or empty responses
            if detected_language in ["english", "none"] or not player_response.strip():
                continue

            logger.info(f"Translating entry #{entry_idx} (Language: {detected_language})")
            
            # Format the prompt
            prompt_translation = prompt_template_translation.format(
                text=player_response
            )

            # Make API call to translate
            response = api_settings["client"].chat.completions.create(
                model=api_settings["model"],
                messages=[
                    {"role": "system", "content": "You are a helpful assistant for translation."},
                    {"role": "user", "content": prompt_translation},
                ],
                max_tokens=1024
            )

            # Track tokens if needed
            if "track_tokens" in api_settings:
                api_settings["track_tokens"](response)

            # Extract translation from the response
            translation_text = response.choices[0].message.content.strip()

            # Replace the 'player_response' with the translated text
            entry["player_response"] = translation_text

        except Exception as e:
            logger.error(f"Error translating entry #{entry_idx}: {e}")
            raise

    return data

# %%
translated_data = translate_player_responses(data, api_settings)
# Out:
# 2024-11-20 08:10:01,380 - INFO - Translating entry #23 (Language: german)
# 2024-11-20 08:10:03,406 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"

# %%
translated_data[10]
# Out:
# {'Unnamed: 0': 428,
#  'Respondent ID': 114588000000,
#  'Collector ID': 431039728,
#  'Start Date': '2024-04-28 16:34:49',
#  'End Date': '2024-04-28 16:46:12',
#  'IP Address': '172.226.36.83',
#  'Email Address': '',
#  'First Name': '',
#  'Last Name': '',
#  'Custom Data 1': '',
#  '1_Rate_Overall Rival Stars Horse Racing': '3 (Neutral)',
#  '1_Rate_Breeding': '3 (Neutral)',
#  '1_Rate_Training my horses': 2,
#  '1_Rate_Racing - Story': '3 (Neutral)',
#  '1_Rate_Steeplechase': '3 (Neutral)',
#  '1_Rate_Cross Country': '3 (Neutral)',
#  '1_Rate_Free Roam': 2,
#  '1_Rate_Live Events & Leaderboards (Flat racing & Cross Country)': '3 (Neutral)',
#  '1_Rate_Completing Story Goals': '3 (Neutral)',
#  '1_Rate_Foal Caring': 2,
#  '1_Rate_Pasture': '3 (Neutral)',
#  '1_Rate_Foaling season event': '3 (Neutral)',
#  '1_Rate_Steeplechase Stars': '3 (Neutral)',
#  '1_Rate_Arabian Days': '3 (Neutral)',
#  '1_Rate_Empowering my horse with skills': 2,
#  '1_Rate_Customizing my horse with tack': '3 (Neutral)',
#  '1_Rate_Teams': 2,
#  '2_LeastEnjoy_Breeding horses for Coats': '',
#  '2_LeastEnjoy_Breeding horses for Stats': '',
#  '2_LeastEnjoy_Training my Horses': 'Training my horses',
#  '2_LeastEnjoy_Racing - Story': '',
#  '2_LeastEnjoy_Steeplechase': '',
#  '2_LeastEnjoy_Cross Country': '',
#  '2_LeastEnjoy_Free Roam': 'Free Roam',
#  '2_LeastEnjoy_Racing - Live Events & Leaderboards  (Flat racing & Cross Country)': 'Live Events & Leaderboards (Flat racing & Cross Country)',
#  '2_LeastEnjoy_Completing Story Goals': '',
#  '2_LeastEnjoy_Foal Caring': 'Foal Caring',
#  '2_LeastEnjoy_Pasture': '',
#  '2_LeastEnjoy_Foaling season event': '',
#  '2_LeastEnjoy_Steeplechase Stars': '',
#  '2_LeastEnjoy_Arabian Days': '',
#  '2_LeastEnjoy_Empowering my Horse with Skills': '',
#  '2_LeastEnjoy_Customizing my Horse with Tack': '',
#  '2_LeastEnjoy_Teams': '',
#  '2_LeastEnjoy_Browsing the new Horse offers': '',
#  '3_OE_LeastEnjoy': 'Training could be interactive with horse and player instead of just a bunk gimmick way to get money from players ',
#  '4_Changes_More social aspects': 'Undesirable',
#  '4_Changes_More competitions and leaderboards': 'Undesirable',
#  '4_Changes_More fast-paced and thrilling experiences': 'No preference (Good as it is)',
#  '4_Changes_More opportunities to have peaceful experiences': 'No preference (Good as it is)',
#  '4_Changes_More directed goals/missions': 'Undesirable',
#  '4_Changes_More ways to improve the level of my horse': 'Undesirable',
#  '4_Changes_More thinking and planning opportunities': 'Undesirable',
#  '4_Changes_More opportunities for immersive experience with my horse': 'No preference (Good as it is)',
#  '4_Changes_More narrative': 'Undesirable',
#  '4_Changes_Ability to explore the world with my horse on my own terms': 'No preference (Good as it is)',
#  '4_Changes_More horse, jockey and stables customization options': 'No preference (Good as it is)',
#  '4_Changes_More challenging goals/missions': 'Undesirable',
#  '5_Goal_What is your main goal when you play Rival Stars Horse Racing?': 'I want my horse to become a champion racer',
#  '6_NewFeature_Which NEW feature would you most want to see added to the game?': 'Other (please specify)',
#  '6_NewFeature_Other': 'Get rid of all the useless items needed to train, to feed a fowl, and to build shit',
#  '7_OE_NewFeature_What do you expect {{ Q6 }} to be like?': 'If itâ€™s a game about racing and training horses get rid of the useless crap. Like having to build stalls and shit. If I wanted to build a bigger workshop Iâ€™d play a game about building useless shit  ',
#  '8_How would you like to see Show Jumping added in the game?': 'Other (please specify)',
#  '8_ShowJumping_Other': 'Donâ€™t want it added ',
#  '9_How would you like to see jump mechanic to be in Show jumping?': 'Other (please specify)',
#  '9_Other': 'Again donâ€™t want jumping could care less',
#  '10_Have you ever participated in the Leaps & Bounds Cross Country Limited Time Event?': 'No',
#  '11_What is the main reason for you to NOT participate in the Leaps & Bounds Cross Country Limited Time Event?': 'Other (please specify)',
#  '11_Other (please specify)': 'Havenâ€™t been playing game when said event occured',
#  '12_Please rate your experience playing Leaps & Bounds Cross Country Limited Time Event.': '',
#  '13_OE_[Optional] Please briefly explain why you you rated your experience playing Leaps & Bounds Cross Country Limited Time Event the way you did.': '',
#  '14_AgreeDisagree_Riding too frequently was exhausting': '',
#  '14_AgreeDisagree_I liked the variety of tasks in the event': '',
#  '14_AgreeDisagree_I liked that I had freedom to choose the task to complete': '',
#  '14_AgreeDisagree_I felt greatly rewarded for the effort I put into the event': '',
#  '14_AgreeDisagree_I feel like if I had chance to prepare, I could have completed the event more easily': '',
#  '14_AgreeDisagree_I developed a strategy to complete event more efficiently (combine multiple tasks in single race to gain more points)': '',
#  '14_AgreeDisagree_I liked the difficulty level of the tasks': '',
#  '15_Scale_How successful do you think you were in gaining the rewards you wanted in the Event?': '',
#  '16_How did you feel about the rewards of the Leaps & Bounds Cross Country Limited Time Event?': '',
#  '17_OE_[Optional] How do you feel about Leaps and Bounds Cross Country event compared to Foaling season, Arabian days and Steeplechase Stars?': '',
#  '18_Rank_LTE_Starting Time & Date': 1.0,
#  '18_Rank_LTE_Event Duration (e.g. 2-3 days)': 2.0,
#  '18_Rank_LTE_Tasks Information': 4.0,
#  '18_Rank_LTE_Rewards (Regular and/or Premium)': 3.0,
#  '18_Rank_LTE_Final Reward': 5.0,
#  '18_Rank_LTE_Reward Track': 6.0,
#  '18_Rank_LTE_Reward Track Price': 7.0,
#  '18_Rank_LTE_Bundles info': 8.0,
#  '19_Rank_LiveRaces_Event Starting Time & Date': 2.0,
#  '19_Rank_LiveRaces_Track Distance': 1.0,
#  '19_Rank_LiveRaces_Track Surface': 3.0,
#  '19_Rank_LiveRaces_Grade stream (even/uneven, e.g. Grade 1-2 vs Grade 1-3, etc)': 4.0,
#  '19_Rank_LiveRaces_Race mode': 5.0,
#  '19_Rank_LiveRaces_Leaderboard Prizes': 6.0,
#  '20_Which gender do you identify yourself with?': 'Male',
#  '21_What is your age group?': '35-44',
#  '22_Are you a member of Rival Stars Horse Racing Facebook community?': 'Yes',
#  '23_How frequently are you active on the Rival Stars Horse Racing Facebook community?': 'Never',
#  "24_[OPTIONAL] Is there anything you'd like to share about the game (good, bad, frustrating, improvement, wishlist, etc.)?": 'To much useless nonesense',
#  '25_We may run paid online interviews in the future to help us improve the game, if you are interested please leave your email below.': 'krob80@mac.com',
#  'pcubed_id': 461494658,
#  'days_seen': 18.0,
#  'name': 'United States',
#  'channel': 'iosstore',
#  'is_organic': 1.0,
#  'retention_day': 55.0,
#  'player_lifetime': 53.0,
#  'ever_been_free_trial_subscriber': 0.0,
#  'is_current_subscriber': 0.0,
#  'ever_been_subscriber': 0.0,
#  'spending': 9.771999692916868,
#  'number_of_ads_watched_in_last_45_days': 119.0,
#  'app_version': '',
#  'test_group': '',
#  'prestige_rank': 9.0,
#  'ever_purchased_horse_lto': 0.0,
#  'ever_purchased_event_horse_lto': 0.0,
#  'segment_no_ads_no_iap': 0.0,
#  'segment_some_ads_no_iap': 0.0,
#  'segment_lots_ads_no_iap': 0.0,
#  'segment_some_iap': 1.0,
#  'segment_lots_iap': 0.0,
#  'segment_subscriber': 0.0,
#  'segment_everyday_short_ret': 0.0,
#  'segment_not_everyday_long_ret': 1.0,
#  'segment_mid_days_seen': 0.0,
#  'segment_long_days_seen': 1.0,
#  'breeding_with_premium_stud': 1.0,
#  'n_premium_skiptimer': 30.0,
#  'n_ads_watched_skiptimer': 48.0,
#  'ever_watched_ads': 1.0,
#  'ever_completed_time_trial': 0.0,
#  'ever_join_team': 1.0,
#  'number_cross_country': 15.0,
#  'number_quick_ride': 2.0,
#  'number_live_event': 8.0,
#  'number_racing_runs': 174.0,
#  'qf_label': '',
#  'standard_team_races': 6.0,
#  'special_team_races': 2.0,
#  'current_captain': 0.0,
#  'current_in_team': 1.0,
#  'highest_grade_horse': 20.0,
#  'milestone': '',
#  'num_horse_bred': '',
#  'avg_horse_grade': '',
#  'max_event_prestige': '',
#  'previous_race_pass_purchases': 0.0,
#  'arabiandays_race_pass_purchase': 0.0,
#  'milestone_at_purchase': 0.0,
#  'event_participation': 'No',
#  'crosscountry1_racepass': 'N',
#  'crosscountry1_bundle': 'N',
#  'crosscountry1_max_milestone': 0,
#  'crosscountry2_racepass': 'N',
#  'crosscountry2_bundle': 'N',
#  'crosscountry2_max_milestone': 0,
#  'player_response': 'To much useless nonesense',
#  'player_language': 'english'}

# %%
save_to_json(translated_data, path_db_prepared)
# Out:
# 2024-11-20 08:10:56,628 - INFO - Data successfully saved to C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\db_prepared.json

# %%
import random

def list_player_responses(data, shuffle=False, sample_size=20):
    """
    Lists a specified number of 'player_response' values from the dataset.

    Args:
        data (list): List of dictionaries containing player responses.
        shuffle (bool): Whether to shuffle the data before listing. Defaults to False.
        sample_size (int): Number of player responses to list. Defaults to 20.

    Returns:
        list: A list of 'player_response' values.
    """
    if shuffle:
        random.shuffle(data)  # Shuffle data for randomness

    responses = [
        entry.get("player_response", "No response available") for entry in data
    ]

    # Limit the output to the sample size
    return responses[:sample_size]

# %%
# List 20 player responses, shuffled
responses = list_player_responses(translated_data, shuffle=True)
print(responses)
# Out:
# ['wishlist ( things that could be added) :D   1. Show jumping!   2. The ability to train the horse or at least earn XP while riding in free roam.   3. Being able to clean, feed, pet, hug the horses. build Relationships with them fr.ex., doing good things for it like feeding it cleaning it hugging it would increase the bond but not doing these things or doing the opposite would decrease the bond. Also! The ability clean their stables. ( with this, maybe an option to sign a contract with a permanent Stable hand - each hire has different skills and characteristics and pay (Same could be done with jockeys) )  4.Stable customizations (construction and color wise )   5. More focus on our human character. More outfit customizations that could match with the saddles. More physical appearance customizations, and maybe Personality.', 'I would really love to be able to pet my horses or brush them and interact with them more, and also more animations. I would also like more western disciplines, especially barrel racing. Being able to visit other peopleâ€™s stable would be fun too, and more interacting with other players for example a team could organize a weekly trail ride together and take care of other peopleâ€™s foals and horses and use our friendâ€™s studs', 'Really enjoy trying to breed perfect horses with beautiful coats thatâ€™s my fav part but itâ€™s discouraging when the breeding tends to be more randomly generated and not reflective of the grades/training/coats of the horses being bred', 'I would love to be able to have more stalls,and pasture space, I also wish that the club thing would be deleted. Itâ€™s a dumb concept and is WAYYYYYY over priced. I donâ€™t want to spend money on virtual horses..', 'This game is great', 'Need more space, adding new breeds is frustrating to have to start over breeding new horses with the new bonuses just to stay competitive in the live events, algorithm controling items won isnt great so Im always short of one item in every level while I have 50+ of every other item in that level (ex.: 2 basic acceleration, 34 basic speed, 35 basic sprint, 37 basic tack, etc.)', 'Better free prizes for events more stalls and pasture space and options to buy them with silver earned in game, separate barns for each breed and mustangs', 'Have the free roam available without haveing to watch an ad', 'Having to spend less gold or money would be great or at least earning more gold for accomplishing missions or races/ events', 'I donâ€™t like how itâ€™s really hard to get roses and good horses', 'I wish breeding was more accurate and predictable', 'Please sort the training out itâ€™s so frustrating to spend time and effort to train , then breed or new breed better and have to start all over again . Make new breeds have clear better skills for each event eg Arabs definitely better for cc thouroughbreds racing', 'Wish we could sell the skills we never use. That would be an amazing option.', 'I love the game, but the hidden coats make it really hard to get a good coat if you donâ€™t know it, Iâ€™ve been playing for a long time, and Iâ€™m not complaining at all! I just find it difficult to breed food coats, itâ€™s also hard to get the things you need to breed horses', 'I really love the game, still what I said before about the horse caring. I thinks thatâ€™s a big win. Also to make it real, like in real life the horses need to be outside. It also makes the horse in better shape. I would like to see some of it in the game', 'When breeding my own horses cost should not be the same as when breeding with studs', "The game is awesome.  The new updates are awesome.  Pik Pok does a wonderful job keeping the game fresh and attracting new players.  The only turn off for me, is how the same people constantly complain about the new updates.  It's frustrating.  There should be something enforced so that those people can't constantly complain and scare the new players off.", 'I wish there was More space in the pasture for people that  ...

# %% [markdown]
# ## Topic extraction

# %%
prompt_template_topic = PromptTemplate.from_template(
'''Please list the most important topics and their respective original context in the review of a game in a JSON format with "Topic", "Category", and "Context" arguments. No more than 10 topics.
Topics should focus on specific game features or aspects. A feature in the game should be a noun rather than a verb or an adjective.
Each topic should be categorized as a "fact" or a "request".
Respond in JSON format.

[h0]==================================================================[\h0]
REVIEW: 

"The customization options for characters are so limited, and it's frustrating not to have more outfit choices. Also, why can't I rename my horse after I buy it? However, I do enjoy the free roam mode—riding through open fields feels relaxing and immersive."

TOPICS:

{{"Topics":
    [
        {{
            "Topic": "Character Customization",
            "Category": "request",
            "Context": "The customization options for characters are so limited, and it's frustrating not to have more outfit choices."
        }},
        {{
            "Topic": "Horse Renaming",
            "Category": "request",
            "Context": "It's frustrating not to be able to rename my horse after I buy it."
        }},
        {{
            "Topic": "Free Roam",
            "Category": "fact",
            "Context": "Riding through open fields feels relaxing and immersive."
        }}
    ]
}}

[h0]==================================================================[\h0]
REVIEW: 

"Too much useless nonsense."

TOPICS:

{{"Topics":
    [
        {{"Topic": "Game Content",
          "Category": "request",
          "Context": "Too much useless nonsense."
        }}
    ]
}}

[h0]==================================================================[\h0]
REVIEW: 

"This game has great mechanics, but the breeding system feels random and unfair. I've bred so many horses, yet the coats and stats don't seem to follow any logical pattern. On the other hand, I appreciate how detailed the horse animations are—it makes the game come alive."

TOPICS:

{{"Topics":
    [
        {{
            "Topic": "Game Mechanics",
            "Category": "fact",
            "Context": "This game has great mechanics"
        }},
        {{
            "Topic": "Breeding System",
            "Category": "request",
            "Context": "The breeding system feels random and unfair. Coats and stats don't seem to follow any logical pattern."
        }},
        {{
            "Topic": "Horse Animations",
            "Category": "fact",
            "Context": "The horse animations are detailed and make the game come alive."
        }}
    ]
}}

[h0]==================================================================[\h0]
REVIEW: 

"{review}"

TOPICS:

'''
)

# %%
# Initialize token counters
prompt_tokens = 0
completion_tokens = 0

def configure_api(api_client, model_name):
    """
    Configures the global API client and model.

    Args:
        api_client: The initialized API client.
        model_name (str): The model name to use.
    """
    global api_settings
    api_settings["client"] = api_client
    api_settings["model"] = model_name
    logger.info(f"API configured with model: {model_name}")

def track_tokens(response):
    """
    Updates the global token counters based on the API response.

    Args:
        response: The API response containing token usage.
    """
    global prompt_tokens, completion_tokens
    prompt_tokens += response.usage.prompt_tokens
    completion_tokens += response.usage.completion_tokens
    logger.info(f"Tokens used - Prompt: {response.usage.prompt_tokens}, Completion: {response.usage.completion_tokens}")


# def extract_topics(entry, prompt_template_topic, api_settings, review_fields):
#     """
#     Extracts topics from an entry's combined review fields using a prompt template.
# 
#     Args:
#         entry (dict): The review entry containing multiple fields to combine.
#         prompt_template (PromptTemplate): The template used for topic extraction.
#         api_settings (dict): API configuration with 'client' and 'model'.
#         review_fields (list): List of fields to combine for the review.
# 
#     Returns:
#         dict: Extracted topics in JSON format.
#     """
#     # Combine review fields
#     combined_review = " ".join(entry.get(field, "").strip() for field in review_fields)
# 
#     # Generate the prompt using the combined review
#     prompt_topic = prompt_template_topic.format(review=combined_review)
# 
#     # Log the entry ID (assumes the entry has an 'ID' field for tracking)
#     entry_id = entry.get("Respondent ID", "unknown")
#     logger.info(f"Extracting topics for entry ID {entry_id}")
# 
#     try:
#         # Send the request to the API
#         response = api_settings["client"].chat.completions.create(
#             model=api_settings["model"],
#             messages=[
#                 {"role": "system", "content": "You are a helpful assistant for game review analysis."},
#                 {"role": "user", "content": prompt_topic},
#             ],
#             max_tokens=1024,
#             response_format={"type": "json_object"}
#         )
#         track_tokens(response)
#         return json.loads(response.choices[0].message.content)
# 
#     except Exception as e:
#         logger.error(f"Error extracting topics for entry ID {entry_id}: {e}")
#         return {"error": str(e)}

# %%
# Configure the API
configure_api(client, chat_model_name)
# Out:
# 2024-11-20 08:38:39,429 - INFO - API configured with model: gpt-4o-mini

# %%
review_fields = ["player_response"]
topics = extract_topics(translated_data[1], prompt_template_topic, api_settings, review_fields)
# Out:
# 2024-11-20 08:45:19,022 - INFO - Extracting topics for entry ID 114585000000
# 2024-11-20 08:45:22,906 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-11-20 08:45:22,906 - INFO - Tokens used - Prompt: 658, Completion: 235

# %%
topics
# Out:
# {'Topics': [{'Topic': 'Horse Interaction',
#    'Category': 'request',
#    'Context': 'I would really love to be able to pet my horses or brush them and interact with them more.'},
#   {'Topic': 'Western Disciplines',
#    'Category': 'request',
#    'Context': 'I would like more western disciplines, especially barrel racing.'},
#   {'Topic': 'Stable Visits',
#    'Category': 'request',
#    'Context': 'Being able to visit other people’s stables would be fun too.'},
#   {'Topic': 'Player Interaction',
#    'Category': 'request',
#    'Context': 'More interacting with other players, for example, a team could organize a weekly trail ride together.'},
#   {'Topic': 'Foal Care',
#    'Category': 'request',
#    'Context': 'Take care of other people’s foals and horses.'},
#   {'Topic': "Friend's Studs",
#    'Category': 'request',
#    'Context': 'Use our friend’s studs.'}]}

# %%
translated_data[1]
# Out:
# {'Unnamed: 0': 4524,
#  'Respondent ID': 114585000000,
#  'Collector ID': 431039728,
#  'Start Date': '2024-04-24 22:11:39',
#  'End Date': '2024-04-24 22:43:48',
#  'IP Address': '142.170.79.11',
#  'Email Address': '',
#  'First Name': '',
#  'Last Name': '',
#  'Custom Data 1': '',
#  '1_Rate_Overall Rival Stars Horse Racing': '5 (Strongly Like)',
#  '1_Rate_Breeding': 4,
#  '1_Rate_Training my horses': 4,
#  '1_Rate_Racing - Story': '5 (Strongly Like)',
#  '1_Rate_Steeplechase': 4,
#  '1_Rate_Cross Country': '3 (Neutral)',
#  '1_Rate_Free Roam': '3 (Neutral)',
#  '1_Rate_Live Events & Leaderboards (Flat racing & Cross Country)': '5 (Strongly Like)',
#  '1_Rate_Completing Story Goals': '5 (Strongly Like)',
#  '1_Rate_Foal Caring': 2,
#  '1_Rate_Pasture': 4,
#  '1_Rate_Foaling season event': 4,
#  '1_Rate_Steeplechase Stars': '5 (Strongly Like)',
#  '1_Rate_Arabian Days': '3 (Neutral)',
#  '1_Rate_Empowering my horse with skills': '5 (Strongly Like)',
#  '1_Rate_Customizing my horse with tack': '5 (Strongly Like)',
#  '1_Rate_Teams': 4,
#  '2_LeastEnjoy_Breeding horses for Coats': '',
#  '2_LeastEnjoy_Breeding horses for Stats': '',
#  '2_LeastEnjoy_Training my Horses': '',
#  '2_LeastEnjoy_Racing - Story': '',
#  '2_LeastEnjoy_Steeplechase': '',
#  '2_LeastEnjoy_Cross Country': 'Cross Country',
#  '2_LeastEnjoy_Free Roam': '',
#  '2_LeastEnjoy_Racing - Live Events & Leaderboards  (Flat racing & Cross Country)': '',
#  '2_LeastEnjoy_Completing Story Goals': '',
#  '2_LeastEnjoy_Foal Caring': 'Foal Caring',
#  '2_LeastEnjoy_Pasture': '',
#  '2_LeastEnjoy_Foaling season event': 'Foaling season event',
#  '2_LeastEnjoy_Steeplechase Stars': '',
#  '2_LeastEnjoy_Arabian Days': '',
#  '2_LeastEnjoy_Empowering my Horse with Skills': '',
#  '2_LeastEnjoy_Customizing my Horse with Tack': '',
#  '2_LeastEnjoy_Teams': '',
#  '2_LeastEnjoy_Browsing the new Horse offers': '',
#  '3_OE_LeastEnjoy': 'Cross country is too slow. Foal caring is boring because i can only feed the foal and i would like to be able to interact with it more. Also, you have to feed them several times a day to get maximum bonus points and i loose the possibility of getting max bonus points when i go to sleep. I donâ€™t like foaling season because breeding takes a lot of resources and time.',
#  '4_Changes_More social aspects': 'Desirable',
#  '4_Changes_More competitions and leaderboards': 'No preference (Good as it is)',
#  '4_Changes_More fast-paced and thrilling experiences': 'Desirable',
#  '4_Changes_More opportunities to have peaceful experiences': 'Strongly Desirable',
#  '4_Changes_More directed goals/missions': 'No preference (Good as it is)',
#  '4_Changes_More ways to improve the level of my horse': 'Desirable',
#  '4_Changes_More thinking and planning opportunities': 'No preference (Good as it is)',
#  '4_Changes_More opportunities for immersive experience with my horse': 'Strongly Desirable',
#  '4_Changes_More narrative': 'Desirable',
#  '4_Changes_Ability to explore the world with my horse on my own terms': 'Desirable',
#  '4_Changes_More horse, jockey and stables customization options': 'Strongly Desirable',
#  '4_Changes_More challenging goals/missions': 'No preference (Good as it is)',
#  '5_Goal_What is your main goal when you play Rival Stars Horse Racing?': 'I want my horse to proudly represent our stables',
#  '6_NewFeature_Which NEW feature would you most want to see added to the game?': 'Barrel racing',
#  '6_NewFeature_Other': '',
#  '7_OE_NewFeature_What do you expect {{ Q6 }} to be like?': 'Horses could have a preference of starting from the left barrel or the right barrel and you have to choose quickly in the beginning which barrel to go to first. The gallop from the last barrel to the chute could be like the last gallop in flat racing, where you use all of your sprint energy and its very fast',
#  '8_How would you like to see Show Jumping added in the game?': 'A separate fully developed game mode similar to (Flat racing, cross country and steeplechase)',
#  '8_ShowJumping_Other': '',
#  '9_How would you like to see jump mechanic to be in Show jumping?': 'Semi-auto (similar to Steeplechase jump, where manual attempt is done for better results but horse will auto jump if not done)',
#  '9_Other': '',
#  '10_Have you ever participated in the Leaps & Bounds Cross Country Limited Time Event?': 'No',
#  '11_What is the main reason for you to NOT participate in the Leaps & Bounds Cross Country Limited Time Event?': 'The rewards do not seem worth it',
#  '11_Other (please specify)': '',
#  '12_Please rate your experience playing Leaps & Bounds Cross Country Limited Time Event.': '',
#  '13_OE_[Optional] Please briefly explain why you you rated your experience playing Leaps & Bounds Cross Country Limited Time Event the way you did.': '',
#  '14_AgreeDisagree_Riding too frequently was exhausting': '',
#  '14_AgreeDisagree_I liked the variety of tasks in the event': '',
#  '14_AgreeDisagree_I liked that I had freedom to choose the task to complete': '',
#  '14_AgreeDisagree_I felt greatly rewarded for the effort I put into the event': '',
#  '14_AgreeDisagree_I feel like if I had chance to prepare, I could have completed the event more easily': '',
#  '14_AgreeDisagree_I developed a strategy to complete event more efficiently (combine multiple tasks in single race to gain more points)': '',
#  '14_AgreeDisagree_I liked the difficulty level of the tasks': '',
#  '15_Scale_How successful do you think you were in gaining the rewards you wanted in the Event?': '',
#  '16_How did you feel about the rewards of the Leaps & Bounds Cross Country Limited Time Event?': '',
#  '17_OE_[Optional] How do you feel about Leaps and Bounds Cross Country event compared to Foaling season, Arabian days and Steeplechase Stars?': '',
#  '18_Rank_LTE_Starting Time & Date': 1.0,
#  '18_Rank_LTE_Event Duration (e.g. 2-3 days)': 2.0,
#  '18_Rank_LTE_Tasks Information': 3.0,
#  '18_Rank_LTE_Rewards (Regular and/or Premium)': 4.0,
#  '18_Rank_LTE_Final Reward': 5.0,
#  '18_Rank_LTE_Reward Track': 6.0,
#  '18_Rank_LTE_Reward Track Price': 7.0,
#  '18_Rank_LTE_Bundles info': 8.0,
#  '19_Rank_LiveRaces_Event Starting Time & Date': 1.0,
#  '19_Rank_LiveRaces_Track Distance': 3.0,
#  '19_Rank_LiveRaces_Track Surface': 4.0,
#  '19_Rank_LiveRaces_Grade stream (even/uneven, e.g. Grade 1-2 vs Grade 1-3, etc)': 2.0,
#  '19_Rank_LiveRaces_Race mode': 5.0,
#  '19_Rank_LiveRaces_Leaderboard Prizes': 6.0,
#  '20_Which gender do you identify yourself with?': 'Female',
#  '21_What is your age group?': '13-17',
#  '22_Are you a member of Rival Stars Horse Racing Facebook community?': 'Yes',
#  '23_How frequently are you active on the Rival Stars Horse Racing Facebook community?': 'Never',
#  "24_[OPTIONAL] Is there anything you'd like to share about the game (good, bad, frustrating, improvement, wishlist, etc.)?": 'I would really love to be able to pet my horses or brush them and interact with them more, and also more animations. I would also like more western disciplines, especially barrel racing. Being able to visit other peopleâ€™s stable would be fun too, and more interacting with other players for example a team could organize a weekly trail ride together and take care of other peopleâ€™s foals and horses and use our friendâ€™s studs',
#  '25_We may run paid online interviews in the future to help us improve the game, if you are interested please leave your email below.': '',
#  'pcubed_id': 565574591,
#  'days_seen': 62.0,
#  'name': 'United States',
#  'channel': 'iosstore',
#  'is_organic': 1.0,
#  'retention_day': 63.0,
#  'player_lifetime': 62.0,
#  'ever_been_free_trial_subscriber': 0.0,
#  'is_current_subscriber': 0.0,
#  'ever_been_subscriber': 0.0,
#  'spending': 0.0,
#  'number_of_ads_watched_in_last_45_days': 89.0,
#  'app_version': '',
#  'test_group': '',
#  'prestige_rank': 12.0,
#  'ever_purchased_horse_lto': 0.0,
#  'ever_purchased_event_horse_lto': 0.0,
#  'segment_no_ads_no_iap': 0.0,
#  'segment_some_ads_no_iap': 0.0,
#  'segment_lots_ads_no_iap': 1.0,
#  'segment_some_iap': 0.0,
#  'segment_lots_iap': 0.0,
#  'segment_subscriber': 0.0,
#  'segment_everyday_short_ret': 0.0,
#  'segment_not_everyday_long_ret': 1.0,
#  'segment_mid_days_seen': 0.0,
#  'segment_long_days_seen': 1.0,
#  'breeding_with_premium_stud': 1.0,
#  'n_premium_skiptimer': 8.0,
#  'n_ads_watched_skiptimer': 265.0,
#  'ever_watched_ads': 1.0,
#  'ever_completed_time_trial': 0.0,
#  'ever_join_team': 1.0,
#  'number_cross_country': 89.0,
#  'number_quick_ride': 0.0,
#  'number_live_event': 60.0,
#  'number_racing_runs': 481.0,
#  'qf_label': '',
#  'standard_team_races': 23.0,
#  'special_team_races': 0.0,
#  'current_captain': 0.0,
#  'current_in_team': 1.0,
#  'highest_grade_horse': 35.0,
#  'milestone': '',
#  'num_horse_bred': '',
#  'avg_horse_grade': '',
#  'max_event_prestige': '',
#  'previous_race_pass_purchases': 0.0,
#  'arabiandays_race_pass_purchase': 0.0,
#  'milestone_at_purchase': 0.0,
#  'event_participation': 'No',
#  'crosscountry1_racepass': 'N',
#  'crosscountry1_bundle': 'N',
#  'crosscountry1_max_milestone': 11,
#  'crosscountry2_racepass': 'N',
#  'crosscountry2_bundle': 'N',
#  'crosscountry2_max_milestone': 1,
#  'player_response': 'I would really love to be able to pet my horses or brush them and interact with them more, and also more animations. I would also like more western disciplines, especially barrel racing. Being able to visit other peopleâ€™s stable would be fun too, and more interacting with other players for example a team could organize a weekly trail ride together and take care of other peopleâ€™s foals and horses and use our friendâ€™s studs',
#  'player_language': 'english'}

# %%
def append_topics(data, prompt_template, api_settings, review_fields):
    """
    Iterates through the dataset, extracts topics for each entry,
    and appends the extracted topics directly to the JSON tuple.

    Args:
        data (list): List of dictionaries containing the dataset.
        prompt_template (PromptTemplate): The template used for topic extraction.
        api_settings (dict): API configuration with 'client' and 'model'.
        review_fields (list): List of fields to combine for the review.

    Returns:
        list: Updated dataset with extracted topics appended directly.
    """
    updated_data = []

    for entry in data:
        try:
            # Extract topics for the current entry
            extracted_topics = extract_topics(entry, prompt_template, api_settings, review_fields)
            
            # Append the topics directly to the entry
            entry["topics"] = extracted_topics.get("Topics", [])
            
            # Add the updated entry to the result list
            updated_data.append(entry)

        except Exception as e:
            logger.error(f"Failed to process entry ID {entry.get('ID', 'unknown')}: {e}")
            entry["topics"] = [{"error": str(e)}]
            updated_data.append(entry)

    return updated_data

# %%
updated_data = append_topics(translated_data, prompt_template_topic, api_settings, review_fields)
# Out:
# 2024-11-20 08:56:10,910 - INFO - Extracting topics for entry ID 114586000000
# 2024-11-20 08:56:17,951 - INFO - Tokens used - Prompt: 751, Completion: 373
# 2024-11-20 08:56:17,967 - INFO - Extracting topics for entry ID 114585000000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 updated_data = append_topics(translated_data, prompt_template_topic, api_settings, review_fields)
#
# Cell In[33], line 20, in append_topics(data, prompt_template, api_settings, review_fields)
#      17 for entry in data:
#      18     try:
#      19         # Extract topics for the current entry
# ---> 20         extracted_topics = extract_topics(entry, prompt_template, api_settings, review_fields)
#      22         # Append the topics directly to the entry
#      23         entry["topics"] = extracted_topics.get("Topics", [])
#
# Cell In[28], line 56, in extract_topics(entry, prompt_template, api_settings, review_fields)
#      52 logger.info(f"Extracting topics for entry ID {entry_id}")
#      54 try:
#      55     # Send the request to the API
# ---> 56     response = api_settings["client"].chat.completions.create(
#      57         model=api_settings["model"],
#      58         messages=[
#      59             {"role": "system", "content": "You are a helpful assistant for game review analysis."},
#      60             {"role": "user", "content": prompt_topic},
#      61         ],
#      62         max_tokens=1024,
#      63         response_format={"type": "json_object"}
#      64     )
#      65     track_tokens(response)
#      66     return json.loads(response.choices[0].message.content)
#
# File ~\Documents\Venvironments\Lib\site-packages\openai\_utils\_utils.py:274, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     272             msg = f"Missing required argument: {quote(missing[0])}"
#     273     raise TypeError(msg)
# --> 274 return func(*args, **kwargs)
#
# File ~\Documents\Venvironments\Lib\site-packages\openai\resources\chat\completions.py:815, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, presence_penalty, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     775 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     776 def create(
#     777     self,
#    (...)
#     812     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     813 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     814     validate_response_format(response_format)
# --> 815     return self._post(
#     816         "/chat/completions",
#     817         body=maybe_transform(
#     818             {
#     819                 "messages": messages,
#     820                 "model": model,
#     821                 "audio": audio,
#     822                 "frequency_penalty": frequency_penalty,
#     823                 "function_call": function_call,
#     824                 "functions": functions,
#     825                 "logit_bias": logit_bias,
#     826                 "logprobs": logprobs,
#     827                 "max_completion_tokens": max_completion_tokens,
#     828                 "max_tokens": max_tokens,
#     829                 "metadata": metadata,
#     830                 "modalities": modalities,
#     831                 "n": n,
#     832                 "parallel_tool_calls": parallel_tool_calls,
#     833                 "presence_penalty": presence_penalty,
#     834                 "response_format": response_format,
#     835                 "seed": seed,
#     836                 "service_tier": service_tier,
#     837                 "stop": stop,
#     838                 "store": store,
#     839                 "stream": stream,
#     840                 "stream_options": stream_options,
#     841                 "temperature": temperature,
#     842                 "tool_choice": tool_choice,
#     843                 "tools": tools,
#     844                 "top_logprobs": top_logprobs,
#     845                 "top_p": top_p,
#     846                 "user": user,
#     847             },
#     848             completion_create_params.CompletionCreateParams,
#     849         ),
#     850         options=make_request_options(
#     851             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     852         ),
#     853         cast_to=ChatCompletion,
#     854         stream=stream or False,
#     855         stream_cls=Stream[ChatCompletionChunk],
#     856     )
#
# File ~\Documents\Venvironments\Lib\site-packages\openai\_base_client.py:1277, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1263 def post(
#    1264     self,
#    1265     path: str,
#    (...)
#    1272     stream_cls: type[_StreamT] | None = None,
#    1273 ) -> ResponseT | _StreamT:
#    1274     opts = FinalRequestOptions.construct(
#    1275         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1276     )
# -> 1277     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\Documents\Venvironments\Lib\site-packages\openai\_base_client.py:954, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     951 else:
#     952     retries_taken = 0
# --> 954 return self._request(
#     955     cast_to=cast_to,
#     956     options=options,
#     957     stream=stream,
#     958     stream_cls=stream_cls,
#     959     retries_taken=retries_taken,
#     960 )
#
# File ~\Documents\Venvironments\Lib\site-packages\openai\_base_client.py:990, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     987 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     989 try:
# --> 990     response = self._client.send(
#     991         request,
#     992         stream=stream or self._should_stream_response_body(request=request),
#     993         **kwargs,
#     994     )
#     995 except httpx.TimeoutException as err:
#     996     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~\Documents\Venvironments\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     906 follow_redirects = (
#     907     self.follow_redirects
#     908     if isinstance(follow_redirects, UseClientDefault)
#     909     else follow_redirects
#     910 )
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~\Documents\Venvironments\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~\Documents\Venvironments\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~\Documents\Venvironments\Lib\site-packages\httpx\_client.py:1015, in Client._send_single_request(self, request)
#    1010     raise RuntimeError(
#    1011         "Attempted to send an async request with a sync Client instance."
#    1012     )
#    1014 with request_context(request=request):
# -> 1015     response = transport.handle_request(request)
#    1017 assert isinstance(response.stream, SyncByteStream)
#    1019 response.request = request
#
# File ~\Documents\Venvironments\Lib\site-packages\httpx\_transports\default.py:233, in HTTPTransport.handle_request(self, request)
#     220 req = httpcore.Request(
#     221     method=request.method,
#     222     url=httpcore.URL(
#    (...)
#     230     extensions=request.extensions,
#     231 )
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#     237 return Response(
#     238     status_code=resp.status,
#     239     headers=resp.headers,
#     240     stream=ResponseStream(resp.stream),
#     241     extensions=resp.extensions,
#     242 )
#
# File ~\Documents\Venvironments\Lib\site-packages\httpcore\_sync\connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, Iterable)
#
# File ~\Documents\Venvironments\Lib\site-packages\httpcore\_sync\connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     192 connection = pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File ~\Documents\Venvironments\Lib\site-packages\httpcore\_sync\connection.py:101, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File ~\Documents\Venvironments\Lib\site-packages\httpcore\_sync\http11.py:143, in HTTP11Connection.handle_request(self, request)
#     141     with Trace("response_closed", logger, request) as trace:
#     142         self._response_closed()
# --> 143 raise exc
#
# File ~\Documents\Venvironments\Lib\site-packages\httpcore\_sync\http11.py:113, in HTTP11Connection.handle_request(self, request)
#     102     pass
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#     121 network_stream = self._network_stream
#
# File ~\Documents\Venvironments\Lib\site-packages\httpcore\_sync\http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#     188         break
#
# File ~\Documents\Venvironments\Lib\site-packages\httpcore\_sync\http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~\Documents\Venvironments\Lib\site-packages\httpcore\_backends\sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1263, in SSLSocket.recv(self, buflen, flags)
#    1259     if flags != 0:
#    1260         raise ValueError(
#    1261             "non-zero flags not allowed in calls to recv() on %s" %
#    1262             self.__class__)
# -> 1263     return self.read(buflen)
#    1264 else:
#    1265     return super().recv(buflen, flags)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1136, in SSLSocket.read(self, len, buffer)
#    1134         return self._sslobj.read(len, buffer)
#    1135     else:
# -> 1136         return self._sslobj.read(len)
#    1137 except SSLError as x:
#    1138     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
import os
import json

def load_existing_data(file_path):
    """
    Loads the existing analysed data if the file exists, otherwise returns an empty list.

    Args:
        file_path (str): Path to the existing analysed file.

    Returns:
        tuple: A list of processed entries and a set of IDs already processed.
    """
    if os.path.exists(file_path):
        with open(file_path, "r", encoding="utf-8") as f:
            existing_data = json.load(f)
        processed_ids = {entry["ID"] for entry in existing_data}
        return existing_data, processed_ids
    return [], set()


def save_progress(file_path, data):
    """
    Saves the current progress to the specified file.

    Args:
        file_path (str): Path to the file where progress should be saved.
        data (list): List of entries to save.
    """
    with open(file_path, "w", encoding="utf-8") as f:
        json.dump(data, f, ensure_ascii=False, indent=4)


def process_with_failsafe_and_batching(data, prompt_template, api_settings, review_fields, output_path, batch_size=10):
    """
    Processes the dataset in batches, extracts topics, skips already processed entries,
    and saves progress incrementally after each batch.

    Args:
        data (list): List of dictionaries containing the dataset.
        prompt_template (PromptTemplate): The template used for topic extraction.
        api_settings (dict): API configuration with 'client' and 'model'.
        review_fields (list): List of fields to combine for the review.
        output_path (str): Path to save the analysed data.
        batch_size (int): Number of entries to process before saving progress. Defaults to 10.

    Returns:
        None
    """
    # Load existing data and processed IDs
    existing_data, processed_ids = load_existing_data(output_path)
    logger.info(f"Loaded {len(existing_data)} entries from existing file.")

    # Prepare a list for the updated data
    updated_data = existing_data
    batch_counter = 0

    for entry in data:
        entry_id = entry.get("ID")

        # Skip if the ID is already processed
        if entry_id in processed_ids:
            logger.info(f"Skipping already processed entry ID {entry_id}.")
            continue

        try:
            # Extract topics
            extracted_topics = extract_topics(entry, prompt_template, api_settings, review_fields)
            entry["topics"] = extracted_topics.get("Topics", [])

            # Append the entry to updated data
            updated_data.append(entry)
            batch_counter += 1

            # Save progress after processing a batch
            if batch_counter >= batch_size:
                save_progress(output_path, updated_data)
                logger.info(f"Progress saved after processing a batch of {batch_size} entries.")
                batch_counter = 0  # Reset the batch counter

        except Exception as e:
            logger.error(f"Error processing entry ID {entry_id}: {e}")
            entry["topics"] = [{"error": str(e)}]
            updated_data.append(entry)

            # Save progress even after an error
            save_progress(output_path, updated_data)
            logger.info(f"Progress saved after error on entry ID {entry_id}.")

    # Final save after all entries are processed
    save_progress(output_path, updated_data)
    logger.info("Final progress saved after completing all entries.")

# %%
batch_size = 10
process_with_failsafe_and_batching(translated_data, prompt_template_topic, api_settings, review_fields, path_db_analysed, batch_size=batch_size)
# Out:
# 2024-11-20 09:04:34,506 - INFO - Loaded 0 entries from existing file.
# 2024-11-20 09:04:34,507 - INFO - Extracting topics for entry ID 114586000000
# 2024-11-20 09:04:37,196 - INFO - Tokens used - Prompt: 751, Completion: 154
# 2024-11-20 09:04:37,196 - INFO - Extracting topics for entry ID 114585000000
# 2024-11-20 09:04:41,441 - INFO - Tokens used - Prompt: 658, Completion: 267
# 2024-11-20 09:04:41,441 - INFO - Extracting topics for entry ID 114585000000
# 2024-11-20 09:04:43,192 - INFO - Tokens used - Prompt: 617, Completion: 94
# 2024-11-20 09:04:43,208 - INFO - Extracting topics for entry ID 114588000000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[38], line 2
#       1 batch_size = 10
# ----> 2 process_with_failsafe_and_batching(translated_data, prompt_template_topic, api_settings, review_fields, path_db_analysed, batch_size=batch_size)
#
# Cell In[35], line 68, in process_with_failsafe_and_batching(data, prompt_template, api_settings, review_fields, output_path, batch_size)
#      64     continue
#      66 try:
#      67     # Extract topics
# ---> 68     extracted_topics = extract_topics(entry, prompt_template, api_settings, review_fields)
#      69     entry["topics"] = extracted_topics.get("Topics", [])
#      71     # Append the entry to updated data
#
# Cell In[28], line 56, in extract_topics(entry, prompt_template, api_settings, review_fields)
#      52 logger.info(f"Extracting topics for entry ID {entry_id}")
#      54 try:
#      55     # Send the request to the API
# ---> 56     response = api_settings["client"].chat.completions.create(
#      57         model=api_settings["model"],
#      58         messages=[
#      59             {"role": "system", "content": "You are a helpful assistant for game review analysis."},
#      60             {"role": "user", "content": prompt_topic},
#      61         ],
#      62         max_tokens=1024,
#      63         response_format={"type": "json_object"}
#      64     )
#      65     track_tokens(response)
#      66     return json.loads(response.choices[0].message.content)
#
# File ~\Documents\Venvironments\Lib\site-packages\openai\_utils\_utils.py:274, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     272             msg = f"Missing required argument: {quote(missing[0])}"
#     273     raise TypeError(msg)
# --> 274 return func(*args, **kwargs)
#
# File ~\Documents\Venvironments\Lib\site-packages\openai\resources\chat\completions.py:815, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, presence_penalty, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     775 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     776 def create(
#     777     self,
#    (...)
#     812     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     813 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     814     validate_response_format(response_format)
# --> 815     return self._post(
#     816         "/chat/completions",
#     817         body=maybe_transform(
#     818             {
#     819                 "messages": messages,
#     820                 "model": model,
#     821                 "audio": audio,
#     822                 "frequency_penalty": frequency_penalty,
#     823                 "function_call": function_call,
#     824                 "functions": functions,
#     825                 "logit_bias": logit_bias,
#     826                 "logprobs": logprobs,
#     827                 "max_completion_tokens": max_completion_tokens,
#     828                 "max_tokens": max_tokens,
#     829                 "metadata": metadata,
#     830                 "modalities": modalities,
#     831                 "n": n,
#     832                 "parallel_tool_calls": parallel_tool_calls,
#     833                 "presence_penalty": presence_penalty,
#     834                 "response_format": response_format,
#     835                 "seed": seed,
#     836                 "service_tier": service_tier,
#     837                 "stop": stop,
#     838                 "store": store,
#     839                 "stream": stream,
#     840                 "stream_options": stream_options,
#     841                 "temperature": temperature,
#     842                 "tool_choice": tool_choice,
#     843                 "tools": tools,
#     844                 "top_logprobs": top_logprobs,
#     845                 "top_p": top_p,
#     846                 "user": user,
#     847             },
#     848             completion_create_params.CompletionCreateParams,
#     849         ),
#     850         options=make_request_options(
#     851             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     852         ),
#     853         cast_to=ChatCompletion,
#     854         stream=stream or False,
#     855         stream_cls=Stream[ChatCompletionChunk],
#     856     )
#
# File ~\Documents\Venvironments\Lib\site-packages\openai\_base_client.py:1277, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1263 def post(
#    1264     self,
#    1265     path: str,
#    (...)
#    1272     stream_cls: type[_StreamT] | None = None,
#    1273 ) -> ResponseT | _StreamT:
#    1274     opts = FinalRequestOptions.construct(
#    1275         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1276     )
# -> 1277     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\Documents\Venvironments\Lib\site-packages\openai\_base_client.py:954, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     951 else:
#     952     retries_taken = 0
# --> 954 return self._request(
#     955     cast_to=cast_to,
#     956     options=options,
#     957     stream=stream,
#     958     stream_cls=stream_cls,
#     959     retries_taken=retries_taken,
#     960 )
#
# File ~\Documents\Venvironments\Lib\site-packages\openai\_base_client.py:990, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     987 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     989 try:
# --> 990     response = self._client.send(
#     991         request,
#     992         stream=stream or self._should_stream_response_body(request=request),
#     993         **kwargs,
#     994     )
#     995 except httpx.TimeoutException as err:
#     996     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~\Documents\Venvironments\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     906 follow_redirects = (
#     907     self.follow_redirects
#     908     if isinstance(follow_redirects, UseClientDefault)
#     909     else follow_redirects
#     910 )
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~\Documents\Venvironments\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~\Documents\Venvironments\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~\Documents\Venvironments\Lib\site-packages\httpx\_client.py:1015, in Client._send_single_request(self, request)
#    1010     raise RuntimeError(
#    1011         "Attempted to send an async request with a sync Client instance."
#    1012     )
#    1014 with request_context(request=request):
# -> 1015     response = transport.handle_request(request)
#    1017 assert isinstance(response.stream, SyncByteStream)
#    1019 response.request = request
#
# File ~\Documents\Venvironments\Lib\site-packages\httpx\_transports\default.py:233, in HTTPTransport.handle_request(self, request)
#     220 req = httpcore.Request(
#     221     method=request.method,
#     222     url=httpcore.URL(
#    (...)
#     230     extensions=request.extensions,
#     231 )
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#     237 return Response(
#     238     status_code=resp.status,
#     239     headers=resp.headers,
#     240     stream=ResponseStream(resp.stream),
#     241     extensions=resp.extensions,
#     242 )
#
# File ~\Documents\Venvironments\Lib\site-packages\httpcore\_sync\connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, Iterable)
#
# File ~\Documents\Venvironments\Lib\site-packages\httpcore\_sync\connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     192 connection = pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File ~\Documents\Venvironments\Lib\site-packages\httpcore\_sync\connection.py:101, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File ~\Documents\Venvironments\Lib\site-packages\httpcore\_sync\http11.py:143, in HTTP11Connection.handle_request(self, request)
#     141     with Trace("response_closed", logger, request) as trace:
#     142         self._response_closed()
# --> 143 raise exc
#
# File ~\Documents\Venvironments\Lib\site-packages\httpcore\_sync\http11.py:113, in HTTP11Connection.handle_request(self, request)
#     102     pass
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#     121 network_stream = self._network_stream
#
# File ~\Documents\Venvironments\Lib\site-packages\httpcore\_sync\http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#     188         break
#
# File ~\Documents\Venvironments\Lib\site-packages\httpcore\_sync\http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~\Documents\Venvironments\Lib\site-packages\httpcore\_backends\sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1263, in SSLSocket.recv(self, buflen, flags)
#    1259     if flags != 0:
#    1260         raise ValueError(
#    1261             "non-zero flags not allowed in calls to recv() on %s" %
#    1262             self.__class__)
# -> 1263     return self.read(buflen)
#    1264 else:
#    1265     return super().recv(buflen, flags)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1136, in SSLSocket.read(self, len, buffer)
#    1134         return self._sslobj.read(len, buffer)
#    1135     else:
# -> 1136         return self._sslobj.read(len)
#    1137 except SSLError as x:
#    1138     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %% [markdown]
# ## TOPIC + SENTIMENT

# %%
prompt_template_topic = PromptTemplate.from_template(
'''Please list the most important topics and their respective original context in the review of a game in a JSON format with "Topic", "Category", and "Context" arguments. No more than 10 topics.
Topics should focus on specific game features or aspects. A feature in the game should be a noun rather than a verb or an adjective.
Each topic should be categorized as a "fact" or a "request".
Respond in JSON format.

[h0]==================================================================[\h0]
REVIEW: 

"The customization options for characters are so limited, and it's frustrating not to have more outfit choices. Also, why can't I rename my horse after I buy it? However, I do enjoy the free roam mode—riding through open fields feels relaxing and immersive."

TOPICS:

{{"Topics":
    [
        {{
            "Topic": "Character Customization",
            "Category": "request",
            "Context": "The customization options for characters are so limited, and it's frustrating not to have more outfit choices."
        }},
        {{
            "Topic": "Horse Renaming",
            "Category": "request",
            "Context": "It's frustrating not to be able to rename my horse after I buy it."
        }},
        {{
            "Topic": "Free Roam",
            "Category": "fact",
            "Context": "Riding through open fields feels relaxing and immersive."
        }}
    ]
}}

[h0]==================================================================[\h0]
REVIEW: 

"Too much useless nonsense."

TOPICS:

{{"Topics":
    [
        {{"Topic": "Game Content",
          "Category": "request",
          "Context": "Too much useless nonsense."
        }}
    ]
}}

[h0]==================================================================[\h0]
REVIEW: 

"This game has great mechanics, but the breeding system feels random and unfair. I've bred so many horses, yet the coats and stats don't seem to follow any logical pattern. On the other hand, I appreciate how detailed the horse animations are—it makes the game come alive."

TOPICS:

{{"Topics":
    [
        {{
            "Topic": "Game Mechanics",
            "Category": "fact",
            "Context": "This game has great mechanics"
        }},
        {{
            "Topic": "Breeding System",
            "Category": "request",
            "Context": "The breeding system feels random and unfair. Coats and stats don't seem to follow any logical pattern."
        }},
        {{
            "Topic": "Horse Animations",
            "Category": "fact",
            "Context": "The horse animations are detailed and make the game come alive."
        }}
    ]
}}

[h0]==================================================================[\h0]
REVIEW: 

"{review}"

TOPICS:

'''
)

prompt_template_sentiment = PromptTemplate.from_template(
'''What's the sentiment of the review with regard to the topic?
Always answer with 'Positive' or 'Negative' or 'Inconclusive'.

REVIEW: My first D&D experience and I'm enjoying it a lot.
TOPIC: D&D
SENTIMENT: Positive 

REVIEW: This game lacks a proper ending or epilog
TOPIC: epilogue
SENTIMENT: Negative

REVIEW: Posted: August 8
TOPIC: release date
SENTIMENT: Inconclusive 

REVIEW: {review}
TOPIC: {topic}
SENTIMENT: '''
)

# %%
# import json
# import os
# from pathlib import Path
# 
# # Global API settings
# api_settings = {"client": None, "model": None}
# 
# def configure_api(api_client, model_name):
#     """
#     Configures the global API client and model.
#     Args:
#         api_client: The initialized OpenAI client.
#         model_name (str): The model name to use.
#     """
#     global api_settings
#     api_settings["client"] = api_client
#     api_settings["model"] = model_name
# 
# def track_tokens(response):
#     """
#     Updates the global token counters based on the API response.
# 
#     Args:
#         response: The API response containing token usage.
#     """
#     global prompt_tokens, completion_tokens
#     prompt_tokens += response.usage.prompt_tokens
#     completion_tokens += response.usage.completion_tokens
#     logger.info(f"Tokens used - Prompt: {response.usage.prompt_tokens}, Completion: {response.usage.completion_tokens}")
# 
# 
# def extract_topics(entry, id_column, prompt_template_topic, api_settings, review_fields):
#     """
#     Extracts topics from an entry's combined review fields using a prompt template.
# 
#     Args:
#         entry (dict): The review entry containing multiple fields to combine.
#         prompt_template (PromptTemplate): The template used for topic extraction.
#         api_settings (dict): API configuration with 'client' and 'model'.
#         review_fields (list): List of fields to combine for the review.
# 
#     Returns:
#         dict: Extracted topics in JSON format.
#     """
#     # Combine review fields
#     combined_review = " ".join(entry.get(field, "").strip() for field in review_fields)
# 
#     # Generate the prompt using the combined review
#     prompt_topic = prompt_template_topic.format(review=combined_review)
# 
#     # Log the entry ID (assumes the entry has an 'ID' field for tracking)
#     entry_id = entry.get(f"{id_column}", "unknown")
#     logger.info(f"Extracting topics for entry ID {entry_id}")
# 
#     try:
#         # Send the request to the API
#         response = api_settings["client"].chat.completions.create(
#             model=api_settings["model"],
#             messages=[
#                 {"role": "system", "content": "You are a helpful assistant for game review analysis."},
#                 {"role": "user", "content": prompt_topic},
#             ],
#             max_tokens=1024,
#             response_format={"type": "json_object"}
#         )
#         track_tokens(response)
#         return json.loads(response.choices[0].message.content)
# 
#     except Exception as e:
#         logger.error(f"Error extracting topics for entry ID {entry_id}: {e}")
#         return {"error": str(e)}
#  
#     
# def load_existing_progress(output_path, id_column):
#     """
#     Loads existing progress from the output file if it exists.
#     Returns the processed data as a list and the set of processed IDs.
# 
#     Args:
#         output_path (str): Path to the output JSON file.
#         id_column (str): The column name where IDs are stored.
# 
#     Returns:
#         tuple: A list of processed data and a set of processed IDs.
#     """
#     if Path(output_path).exists():
#         logger.info(f"Loading existing progress from {output_path}")
#         with open(output_path, "r", encoding="utf-8") as f:
#             processed_data = json.load(f)
#         processed_ids = {entry[id_column] for entry in processed_data}
#     else:
#         logger.info(f"No existing progress found. Starting fresh.")
#         processed_data = []
#         processed_ids = set()
#     return processed_data, processed_ids
# 
# def save_progress(processed_data, output_path):
#     """
#     Saves the current progress to a JSON file.
# 
#     Args:
#         processed_data (list): The list of processed entries.
#         output_path (str): Path to the output JSON file.
#     """
#     try:
#         logger.info(f"Saving progress to {output_path}")
#         with open(output_path, "w", encoding="utf-8") as f:
#             json.dump(processed_data, f, indent=4, ensure_ascii=False)
#     except Exception as e:
#         logger.error(f"Failed to save progress: {e}")
#         raise
# 
# def process_entry(entry, id_column, prompt_template_topic, prompt_template_sentiment, review_fields):
#     """
#     Processes a single entry by extracting topics and appending them to the entry.
# 
#     Args:
#         entry (dict): The JSON entry to process.
#         prompt_template (PromptTemplate): The prompt template for topic extraction.
#         review_fields (list): List of fields to combine for review text.
# 
#     Returns:
#         dict: The processed entry with extracted topics.
#     """
#     try:
#         topics = extract_topics(entry, id_column, prompt_template_topic, api_settings, review_fields)
#         analyze_sentiments(entry, topics, prompt_template_sentiment, api_settings)
#     except Exception as e:
#         logger.error(f"Error processing entry ID {entry['ID']}: {e}")
#         entry["topics"] = [{"error": str(e)}]
#     return entry
# 
# def analyze_sentiments(entry, id_column, topics, prompt_template_sentiment):
#     """
#     Performs sentiment analysis on extracted topics.
#     """
#     entry["topics"] = []
#     for topic in topics.get("Topics", []):
#         logger.info(f"Analyzing sentiment for topic '{topic['Topic']}' (Entry ID {entry[f'{id_column}']})")
#         prompt_sentiment = prompt_template_sentiment.format(
#             review=topic["Context"],
#             topic=topic["Topic"]
#         )
#         try:
#             response = api_settings["client"].chat.completions.create(
#                 model=api_settings["model"],
#                 messages=[
#                     {"role": "system", "content": "You are a helpful assistant expert in sentiment analysis."},
#                     {"role": "user", "content": prompt_sentiment},
#                 ],
#                 max_tokens=1024
#             )
#             track_tokens(response)
#             sentiment = response.choices[0].message.content.strip()
#             entry["topics"].append({
#                 "topic": topic["Topic"],
#                 "sentiment": sentiment,
#                 "category": topic["Category"],
#                 "sentence": topic["Context"]
#             })
#         except Exception as e:
#             logger.error(f"Error analyzing sentiment for topic '{topic['Topic']}' (Entry ID {entry['ID']}): {e}")
#             raise
# 
# def analyse_data(translated_data, id_column, output_path, prompt_template_topic, prompt_template_sentiment, api_settings, review_fields, batch_size=10):
#     """
#     Main function to analyse translated data with fail-safe batching and progress saving.
# 
#     Args:
#         translated_data (list): The dataset to process.
#         id_column (str): Column name where IDs are stored.
#         output_path (str): Path to save the analysed data.
#         prompt_template (PromptTemplate): The prompt template for topic extraction.
#         api_settings (dict): API configuration with 'client' and 'model'.
#         review_fields (list): List of fields to combine for review text.
#         batch_size (int): Number of entries to process before saving progress. Defaults to 10.
#     """
#     # Load existing progress
#     processed_data, processed_ids = load_existing_progress(output_path, id_column)
# 
#     try:
#         batch_counter = 0
# 
#         for entry in translated_data:
#             entry_id = entry.get(id_column)
#             
#             # Skip already processed entries
#             if entry_id in processed_ids:
#                 logger.info(f"Skipping already processed entry ID {entry_id}")
#                 continue
# 
#             # Process the entry
#             processed_entry = process_entry(entry,id_column, prompt_template_topic, prompt_template_sentiment, review_fields)
#             processed_data.append(processed_entry)
#             processed_ids.add(entry_id)
#             batch_counter += 1
# 
#             # Save progress after every batch
#             if batch_counter >= batch_size:
#                 save_progress(processed_data, output_path)
#                 logger.info(f"Progress saved after processing {batch_counter} entries.")
#                 batch_counter = 0  # Reset batch counter
# 
#     except KeyboardInterrupt:
#         # Save progress if interrupted
#         logger.warning("Processing interrupted by user. Saving progress...")
#         save_progress(processed_data, output_path)
#         raise
# 
#     # Final save after all entries are processed
#     save_progress(processed_data, output_path)
#     logger.info("Processing completed. Final progress saved.")

# %%
id_column = "Unnamed: 0"
review_fields = ["player_response"]
batch_size = 5

# Analyse data
analyse_data(
    translated_data=translated_data,
    id_column=id_column,
    output_path=path_db_analysed,
    prompt_template_topic=prompt_template_topic,
    prompt_template_sentiment=prompt_template_sentiment,
    api_settings=api_settings,
    review_fields=review_fields,
    batch_size=batch_size
)
# Out:
# 2024-11-20 10:02:57,124 - INFO - Loading existing progress from C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\db_analysed.json
# 2024-11-20 10:02:57,124 - INFO - Skipping already processed entry ID 2085
# 2024-11-20 10:02:57,124 - INFO - Skipping already processed entry ID 4524
# 2024-11-20 10:02:57,124 - INFO - Skipping already processed entry ID 4146
# 2024-11-20 10:02:57,139 - INFO - Skipping already processed entry ID 616
# 2024-11-20 10:02:57,139 - INFO - Skipping already processed entry ID 2041
# 2024-11-20 10:02:57,139 - INFO - Skipping already processed entry ID 1369
# 2024-11-20 10:02:57,139 - INFO - Skipping already processed entry ID 3953
# 2024-11-20 10:02:57,139 - INFO - Skipping already processed entry ID 2701
# 2024-11-20 10:02:57,139 - INFO - Extracting topics for entry ID 5005
# 2024-11-20 10:02:57,139 - ERROR - Error extracting topics for entry ID 5005: 'NoneType' object has no attribute 'chat'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[46], line 127, in process_entry(entry, id_column, prompt_template_topic, prompt_template_sentiment, review_fields)
#     126     topics = extract_topics(entry, id_column, prompt_template_topic, api_settings, review_fields)
# --> 127     analyze_sentiments(entry, topics, prompt_template_sentiment, api_settings)
#     128 except Exception as e:
#
# Cell In[46], line 138, in analyze_sentiments(entry, id_column, topics, prompt_template_sentiment)
#     137 entry["topics"] = []
# --> 138 for topic in topics.get("Topics", []):
#     139     logger.info(f"Analyzing sentiment for topic '{topic['Topic']}' (Entry ID {entry[f'{id_column}']})")
#
# AttributeError: 'PromptTemplate' object has no attribute 'get'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[47], line 6
#       3 batch_size = 5
#       5 # Analyse data
# ----> 6 analyse_data(
#       7     translated_data=translated_data,
#       8     id_column=id_column,
#       9     output_path=path_db_analysed,
#      10     prompt_template_topic=prompt_template_topic,
#      11     prompt_template_sentiment=prompt_template_sentiment,
#      12     api_settings=api_settings,
#      13     review_fields=review_fields,
#      14     batch_size=batch_size
#      15 )
#
# Cell In[46], line 193, in analyse_data(translated_data, id_column, output_path, prompt_template_topic, prompt_template_sentiment, api_settings, review_fields, batch_size)
#     190     continue
#     192 # Process the entry
# --> 193 processed_entry = process_entry(entry,id_column, prompt_template_topic, prompt_template_sentiment, review_fields)
#     194 processed_data.append(processed_entry)
#     195 processed_ids.add(entry_id)
#
# Cell In[46], line 129, in process_entry(entry, id_column, prompt_template_topic, prompt_template_sentiment, review_fields)
#     127     analyze_sentiments(entry, topics, prompt_template_sentiment, api_settings)
#     128 except Exception as e:
# --> 129     logger.error(f"Error processing entry ID {entry['ID']}: {e}")
#     130     entry["topics"] = [{"error": str(e)}]
#     131 return entry
#
# KeyError: 'ID'

# %% [markdown]
# ## chat gpt

# %%
import json
import os
from pathlib import Path

api_settings = {"client": None, "model": None}

def configure_api(api_client, model_name):
    """
    Configures the global API client and model.
    Args:
        api_client: The initialized OpenAI client.
        model_name (str): The model name to use.
    """
    global api_settings
    api_settings["client"] = api_client
    api_settings["model"] = model_name


def track_tokens(response):
    """
    Updates the global token counters based on the API response.

    Args:
        response: The API response containing token usage.
    """
    global prompt_tokens, completion_tokens
    prompt_tokens += response.usage.prompt_tokens
    completion_tokens += response.usage.completion_tokens
    # logger.info(f"Tokens used - Prompt: {response.usage.prompt_tokens}, Completion: {response.usage.completion_tokens}")

    
def load_existing_progress(output_path, id_column):
    """
    Loads existing progress from the output file if it exists.
    Returns the processed data as a list and the set of processed IDs.

    Args:
        output_path (str): Path to the output JSON file.
        id_column (str): The column name where IDs are stored.

    Returns:
        tuple: A list of processed data and a set of processed IDs.
    """
    if Path(output_path).exists():
        logger.info(f"Loading existing progress from {output_path}")
        with open(output_path, "r", encoding="utf-8") as f:
            processed_data = json.load(f)
        processed_ids = {entry[id_column] for entry in processed_data}
    else:
        logger.info(f"No existing progress found. Starting fresh.")
        processed_data = []
        processed_ids = set()
    return processed_data, processed_ids

def save_progress(processed_data, output_path):
    """
    Saves the current progress to a JSON file.

    Args:
        processed_data (list): The list of processed entries.
        output_path (str): Path to the output JSON file.
    """
    try:
        logger.info(f"Saving progress to {output_path}")
        with open(output_path, "w", encoding="utf-8") as f:
            json.dump(processed_data, f, indent=4, ensure_ascii=False)
    except Exception as e:
        logger.error(f"Failed to save progress: {e}")
        raise


def extract_topics(entry, entry_id, prompt_template_topic, api_settings, review_fields):
    """
    Extracts topics from an entry's combined review fields using a prompt template.

    Args:
        entry (dict): The review entry containing multiple fields to combine.
        prompt_template_topic (PromptTemplate): The template used for topic extraction.
        api_settings (dict): API configuration with 'client' and 'model'.
        review_fields (list): List of fields to combine for the review.

    Returns:
        dict: Extracted topics in JSON format.
    """
    combined_review = " ".join(entry.get(field, "").strip() for field in review_fields)
    prompt_topic = prompt_template_topic.format(review=combined_review)
    logger.info(f"Extracting topics for entry ID {entry_id}")

    try:
        response = api_settings["client"].chat.completions.create(
            model=api_settings["model"],
            messages=[
                {"role": "system", "content": "You are a helpful assistant for game review analysis."},
                {"role": "user", "content": prompt_topic},
            ],
            max_tokens=1024,
            response_format={"type": "json_object"}
        )
        track_tokens(response)
        return json.loads(response.choices[0].message.content)
    except Exception as e:
        logger.error(f"Error extracting topics for entry ID {entry_id}: {e}")
        return {"error": str(e)}


def analyze_sentiments(entry, entry_id, topics, prompt_template_sentiment, api_settings):
    """
    Performs sentiment analysis on extracted topics.

    Args:
        entry (dict): The JSON entry being processed.
        topics (dict): Topics extracted from the review.
        prompt_template_sentiment (PromptTemplate): Template for sentiment analysis.
        api_settings (dict): API configuration with 'client' and 'model'.

    Returns:
        list: Topics with appended sentiment data.
    """
    entry["topics"] = []
    for topic in topics.get("Topics", []):
        logger.info(f"Analyzing sentiment for topic '{topic['Topic']}' (Entry ID {entry_id})")
        try:
            prompt_sentiment = prompt_template_sentiment.format(
                review=topic["Context"], topic=topic["Topic"]
            )
            response = api_settings["client"].chat.completions.create(
                model=api_settings["model"],
                messages=[
                    {"role": "system", "content": "You are a helpful assistant for sentiment analysis."},
                    {"role": "user", "content": prompt_sentiment},
                ],
                max_tokens=1024,
            )
            track_tokens(response)
            sentiment = response.choices[0].message.content.strip()
            entry["topics"].append({
                "topic": topic["Topic"],
                "sentiment": sentiment,
                "category": topic["Category"],
                "sentence": topic["Context"]
            })
        except Exception as e:
            logger.error(f"Error analyzing sentiment for topic '{topic['Topic']}' (Entry ID {entry_id}): {e}")
            raise


def process_entry(entry, id_column, prompt_template_topic, prompt_template_sentiment, api_settings, review_fields):
    """
    Processes a single entry by extracting topics and analyzing their sentiments.

    Args:
        entry (dict): The JSON entry to process.
        id_column (str): The ID column name.
        prompt_template_topic (PromptTemplate): Template for topic extraction.
        prompt_template_sentiment (PromptTemplate): Template for sentiment analysis.
        api_settings (dict): API configuration.
        review_fields (list): List of review fields to combine.

    Returns:
        dict: Processed entry with topics and sentiments.
    """
    global prompt_tokens, completion_tokens
    logger.info(f"Tokens used so far: Prompt Tokens: {prompt_tokens}, Completion Tokens: {completion_tokens}")
    
    try:
        entry_id = entry.get(id_column, "unknown")
        topics = extract_topics(entry, entry_id, prompt_template_topic, api_settings, review_fields)
        analyze_sentiments(entry, entry_id, topics, prompt_template_sentiment, api_settings)        
    except Exception as e:
        logger.error(f"Error processing entry ID {entry[{id_column}]}: {e}")
    return entry


def analyse_data(translated_data, id_column, output_path, prompt_template_topic, prompt_template_sentiment, api_settings, review_fields, batch_size=10):
    """
    Main function to analyse translated data with fail-safe batching and progress saving.

    Args:
        translated_data (list): Dataset to process.
        id_column (str): Column name where IDs are stored.
        output_path (str): Path to save analysed data.
        prompt_template_topic (PromptTemplate): Template for topic extraction.
        prompt_template_sentiment (PromptTemplate): Template for sentiment analysis.
        api_settings (dict): API configuration.
        review_fields (list): List of review fields to combine.
        batch_size (int): Number of entries to process before saving progress.
    """
    processed_data, processed_ids = load_existing_progress(output_path, id_column)

    try:
        batch_counter = 0
        for entry in translated_data:
            entry_id = entry.get(id_column)
            if entry_id in processed_ids:
                logger.info(f"Skipping already processed entry ID {entry_id}")
                continue

            processed_entry = process_entry(
                entry, id_column, prompt_template_topic, prompt_template_sentiment, api_settings, review_fields
            )
            processed_data.append(processed_entry)
            processed_ids.add(entry_id)
            batch_counter += 1

            if batch_counter >= batch_size:
                save_progress(processed_data, output_path)
                logger.info(f"Progress saved after processing {batch_counter} entries.")
                batch_counter = 0

    except KeyboardInterrupt:
        logger.warning("Processing interrupted by user. Saving progress...")
        save_progress(processed_data, output_path)
        raise
    except Exception as e:
        logger.error(f"Unexpected error: {e}")
    finally:
        save_progress(processed_data, output_path)
        logger.info("Processing completed. Final progress saved.")

# %%
#initialize api

configure_api(client, chat_model_name)

# Parameters
id_column = "Unnamed: 0"                # Column name for entry IDs
review_fields = ["player_response"]     # Which cols should be analyzed?
batch_size = 5                          # Fail-safe batching. The higher the number, the less often the progress is saved.

# Run analysis
analyse_data(
    translated_data=translated_data,
    id_column=id_column,
    output_path=path_db_analysed,
    prompt_template_topic=prompt_template_topic,
    prompt_template_sentiment=prompt_template_sentiment,
    api_settings=api_settings,
    review_fields=review_fields,
    batch_size=batch_size
)
# Out:
# 2024-11-20 10:39:13,153 - INFO - Loading existing progress from C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\db_analysed.json
# 2024-11-20 10:39:13,153 - INFO - Skipping already processed entry ID 2085
# 2024-11-20 10:39:13,153 - INFO - Skipping already processed entry ID 4524
# 2024-11-20 10:39:13,153 - INFO - Skipping already processed entry ID 4146
# 2024-11-20 10:39:13,153 - INFO - Skipping already processed entry ID 616
# 2024-11-20 10:39:13,153 - INFO - Skipping already processed entry ID 2041
# 2024-11-20 10:39:13,153 - INFO - Tokens used so far: Prompt Tokens: 19248, Completion Tokens: 4011
# 2024-11-20 10:39:13,153 - INFO - Extracting topics for entry ID 1369
# 2024-11-20 10:39:16,473 - INFO - Analyzing sentiment for topic 'Breeding Space' (Entry ID 1369)
# 2024-11-20 10:39:16,968 - INFO - Analyzing sentiment for topic 'New Breeds' (Entry ID 1369)
# 2024-11-20 10:39:17,353 - INFO - Analyzing sentiment for topic 'Live Events' (Entry ID 1369)
# 2024-11-20 10:39:17,759 - INFO - Analyzing sentiment for topic 'Item Algorithm' (Entry ID 1369)
# 2024-11-20 10:39:18,280 - INFO - Analyzing sentiment for topic 'Item Inventory' (Entry ID 1369)
# 2024-11-20 10:39:18,772 - INFO - Tokens used so far: Prompt Tokens: 20656, Completion Tokens: 4211
# 2024-11-20 10:39:18,772 - INFO - Extracting topics for entry ID 3953
# 2024-11-20 10:39:21,572 - INFO - Analyzing sentiment for topic 'Free Prizes' (Entry ID 3953)
# 2024-11-20 10:39:22,290 - INFO - Analyzing sentiment for topic 'Stalls' (Entry ID 3953)
# 2024-11-20 10:39:22,696 - INFO - Analyzing sentiment for topic 'Purchasing Options' (Entry ID 3953)
# 2024-11-20 10:39:23,202 - INFO - Analyzing sentiment for topic 'Barns' (Entry ID 3953)
# 2024-11-20 10:39:23,588 - INFO - Analyzing sentiment for topic 'Mustangs' (Entry ID 3953)
# 2024-11-20 10:39:24,024 - INFO - Tokens used so far: Prompt Tokens: 21981, Completion Tokens: 4388
# 2024-11-20 10:39:24,040 - INFO - Extracting topics for entry ID 2701
# 2024-11-20 10:39:24,967 - WARNING - Processing interrupted by user. Saving progress...
# 2024-11-20 10:39:24,967 - INFO - Saving progress to C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\db_analysed.json
# 2024-11-20 10:39:24,967 - INFO - Saving progress to C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\db_analysed.json
# 2024-11-20 10:39:24,967 - INFO - Processing completed. Final progress saved.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[67], line 11
#       8 batch_size = 5
#      10 # Run analysis
# ---> 11 analyse_data(
#      12     translated_data=translated_data,
#      13     id_column=id_column,
#      14     output_path=path_db_analysed,
#      15     prompt_template_topic=prompt_template_topic,
#      16     prompt_template_sentiment=prompt_template_sentiment,
#      17     api_settings=api_settings,
#      18     review_fields=review_fields,
#      19     batch_size=batch_size
#      20 )
#
# Cell In[65], line 198, in analyse_data(translated_data, id_column, output_path, prompt_template_topic, prompt_template_sentiment, api_settings, review_fields, batch_size)
#     195     logger.info(f"Skipping already processed entry ID {entry_id}")
#     196     continue
# --> 198 processed_entry = process_entry(
#     199     entry, id_column, prompt_template_topic, prompt_template_sentiment, api_settings, review_fields
#     200 )
#     201 processed_data.append(processed_entry)
#     202 processed_ids.add(entry_id)
#
# Cell In[65], line 167, in process_entry(entry, id_column, prompt_template_topic, prompt_template_sentiment, api_settings, review_fields)
#     165 try:
#     166     entry_id = entry.get(id_column, "unknown")
# --> 167     topics = extract_topics(entry, entry_id, prompt_template_topic, api_settings, review_fields)
#     168     analyze_sentiments(entry, entry_id, topics, prompt_template_sentiment, api_settings)
#     169 except Exception as e:
#
# Cell In[65], line 90, in extract_topics(entry, entry_id, prompt_template_topic, api_settings, review_fields)
#      87 logger.info(f"Extracting topics for entry ID {entry_id}")
#      89 try:
# ---> 90     response = api_settings["client"].chat.completions.create(
#      91         model=api_settings["model"],
#      92         messages=[
#      93             {"role": "system", "content": "You are a helpful assistant for game review analysis."},
#      94             {"role": "user", "content": prompt_topic},
#      95         ],
#      96         max_tokens=1024,
#      97         response_format={"type": "json_object"}
#      98     )
#      99     track_tokens(response)
#     100     return json.loads(response.choices[0].message.content)
#
# File ~\Documents\Venvironments\Lib\site-packages\openai\_utils\_utils.py:274, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     272             msg = f"Missing required argument: {quote(missing[0])}"
#     273     raise TypeError(msg)
# --> 274 return func(*args, **kwargs)
#
# File ~\Documents\Venvironments\Lib\site-packages\openai\resources\chat\completions.py:815, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, presence_penalty, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     775 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     776 def create(
#     777     self,
#    (...)
#     812     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     813 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     814     validate_response_format(response_format)
# --> 815     return self._post(
#     816         "/chat/completions",
#     817         body=maybe_transform(
#     818             {
#     819                 "messages": messages,
#     820                 "model": model,
#     821                 "audio": audio,
#     822                 "frequency_penalty": frequency_penalty,
#     823                 "function_call": function_call,
#     824                 "functions": functions,
#     825                 "logit_bias": logit_bias,
#     826                 "logprobs": logprobs,
#     827                 "max_completion_tokens": max_completion_tokens,
#     828                 "max_tokens": max_tokens,
#     829                 "metadata": metadata,
#     830                 "modalities": modalities,
#     831                 "n": n,
#     832                 "parallel_tool_calls": parallel_tool_calls,
#     833                 "presence_penalty": presence_penalty,
#     834                 "response_format": response_format,
#     835                 "seed": seed,
#     836                 "service_tier": service_tier,
#     837                 "stop": stop,
#     838                 "store": store,
#     839                 "stream": stream,
#     840                 "stream_options": stream_options,
#     841                 "temperature": temperature,
#     842                 "tool_choice": tool_choice,
#     843                 "tools": tools,
#     844                 "top_logprobs": top_logprobs,
#     845                 "top_p": top_p,
#     846                 "user": user,
#     847             },
#     848             completion_create_params.CompletionCreateParams,
#     849         ),
#     850         options=make_request_options(
#     851             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     852         ),
#     853         cast_to=ChatCompletion,
#     854         stream=stream or False,
#     855         stream_cls=Stream[ChatCompletionChunk],
#     856     )
#
# File ~\Documents\Venvironments\Lib\site-packages\openai\_base_client.py:1277, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1263 def post(
#    1264     self,
#    1265     path: str,
#    (...)
#    1272     stream_cls: type[_StreamT] | None = None,
#    1273 ) -> ResponseT | _StreamT:
#    1274     opts = FinalRequestOptions.construct(
#    1275         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1276     )
# -> 1277     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\Documents\Venvironments\Lib\site-packages\openai\_base_client.py:954, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     951 else:
#     952     retries_taken = 0
# --> 954 return self._request(
#     955     cast_to=cast_to,
#     956     options=options,
#     957     stream=stream,
#     958     stream_cls=stream_cls,
#     959     retries_taken=retries_taken,
#     960 )
#
# File ~\Documents\Venvironments\Lib\site-packages\openai\_base_client.py:990, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     987 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     989 try:
# --> 990     response = self._client.send(
#     991         request,
#     992         stream=stream or self._should_stream_response_body(request=request),
#     993         **kwargs,
#     994     )
#     995 except httpx.TimeoutException as err:
#     996     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~\Documents\Venvironments\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     906 follow_redirects = (
#     907     self.follow_redirects
#     908     if isinstance(follow_redirects, UseClientDefault)
#     909     else follow_redirects
#     910 )
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~\Documents\Venvironments\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~\Documents\Venvironments\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~\Documents\Venvironments\Lib\site-packages\httpx\_client.py:1015, in Client._send_single_request(self, request)
#    1010     raise RuntimeError(
#    1011         "Attempted to send an async request with a sync Client instance."
#    1012     )
#    1014 with request_context(request=request):
# -> 1015     response = transport.handle_request(request)
#    1017 assert isinstance(response.stream, SyncByteStream)
#    1019 response.request = request
#
# File ~\Documents\Venvironments\Lib\site-packages\httpx\_transports\default.py:233, in HTTPTransport.handle_request(self, request)
#     220 req = httpcore.Request(
#     221     method=request.method,
#     222     url=httpcore.URL(
#    (...)
#     230     extensions=request.extensions,
#     231 )
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#     237 return Response(
#     238     status_code=resp.status,
#     239     headers=resp.headers,
#     240     stream=ResponseStream(resp.stream),
#     241     extensions=resp.extensions,
#     242 )
#
# File ~\Documents\Venvironments\Lib\site-packages\httpcore\_sync\connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, Iterable)
#
# File ~\Documents\Venvironments\Lib\site-packages\httpcore\_sync\connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     192 connection = pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File ~\Documents\Venvironments\Lib\site-packages\httpcore\_sync\connection.py:101, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File ~\Documents\Venvironments\Lib\site-packages\httpcore\_sync\http11.py:143, in HTTP11Connection.handle_request(self, request)
#     141     with Trace("response_closed", logger, request) as trace:
#     142         self._response_closed()
# --> 143 raise exc
#
# File ~\Documents\Venvironments\Lib\site-packages\httpcore\_sync\http11.py:113, in HTTP11Connection.handle_request(self, request)
#     102     pass
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#     121 network_stream = self._network_stream
#
# File ~\Documents\Venvironments\Lib\site-packages\httpcore\_sync\http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#     188         break
#
# File ~\Documents\Venvironments\Lib\site-packages\httpcore\_sync\http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~\Documents\Venvironments\Lib\site-packages\httpcore\_backends\sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1263, in SSLSocket.recv(self, buflen, flags)
#    1259     if flags != 0:
#    1260         raise ValueError(
#    1261             "non-zero flags not allowed in calls to recv() on %s" %
#    1262             self.__class__)
# -> 1263     return self.read(buflen)
#    1264 else:
#    1265     return super().recv(buflen, flags)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1136, in SSLSocket.read(self, len, buffer)
#    1134         return self._sslobj.read(len, buffer)
#    1135     else:
# -> 1136         return self._sslobj.read(len)
#    1137 except SSLError as x:
#    1138     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:
