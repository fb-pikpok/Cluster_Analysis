# %%
# General modules
import os
import openai
from dotenv import load_dotenv

# Language models
load_dotenv()
openai_api_key = os.getenv("OPENAI_API_KEY")
openai.api_key = openai_api_key
client = openai.Client()

chat_model_name = 'gpt-4o-mini'
embed_model_name = "all-MiniLM-L6-v2"

# Paths
root_dir = r'C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\Steamapps'
steam_title = 'Market'

path_db_prepared = os.path.join(root_dir, steam_title, "db_prepared.json")
path_db_translated = os.path.join(root_dir, steam_title, "db_translated.json")
path_db_analysed = os.path.join(root_dir, steam_title, "db_analysed.json")
path_db_embedded = os.path.join(root_dir, steam_title, "db_embedded.json")
path_db_clustered = os.path.join(root_dir, steam_title, "db_clustered.json")
path_db_final = os.path.join(root_dir, steam_title, "db_final.json")

# %%
# my imports
from helper.utils import *
from helper.data_analysis import *
from helper.prompt_templates import *
from helper.embedding import *
from helper.cluster_analysis import *
from helper.cluster_naming import *
from helper.steam_scraper import *

configure_api(client, chat_model_name)

# %% [markdown]
# # Scrape Steam reviews

# %%
# My imports
from helper.redshift_conector_standalone import *

# https://store.steampowered.com/app/1166860/Rival_Stars_Horse_Racing_Desktop_Edition/

# SQL Query Redshift
sql_query = """
SELECT * 
FROM steam_review 
where app_id_name = '1166860_Rival_Stars_Horse_Racing_Desktop_Edition' LIMIT 10
"""
logger.info(f"Query Redshift with: {sql_query}")

try:
    results_json, results_df = fetch_query_results(sql_query)
    # Print the first row of the DataFrame
    logger.info("Successfully fetched query results, with shape: %s", results_df.shape)
except Exception as e:
    logger.error(f"Error fetching query results: {e}")
    raise
# Out:
# 2024-12-17 11:18:27,778 - INFO - Query Redshift with:
# SELECT *
# FROM steam_review
# where app_id_name = '1928980_Nightingale' LIMIT 10
#
# 2024-12-17 11:18:29,974 - INFO - Successfully fetched query results, with shape: (10, 13)

# %%
results_df
# Out:
#            app_id_name  recommendationid  playtime_at_review_minutes  \
# 0  1928980_Nightingale         181822070                        2640
# 1  1928980_Nightingale         181314222                         362
# 2  1928980_Nightingale         181142901                          73
# 3  1928980_Nightingale         180636897                       11429
# 4  1928980_Nightingale         179831333                        3342
# 5  1928980_Nightingale         179689295                        2357
# 6  1928980_Nightingale         179634210                       22717
# 7  1928980_Nightingale         179241057                        4714
# 8  1928980_Nightingale         179422776                        6069
# 9  1928980_Nightingale         166287167                        3801
#
#    last_played                                        review_text  \
# 0   1733078257  This game, although starting out a bit iffy in...
# 1   1733152386  Absolutely stunning graphics and fun gameplay....
# 2   1732995552  Gameplay feels junky so far. If you want simil...
# 3   1732840128  It is a fun game for me to play with friends, ...
# 4   1733158890  マルチでも「カード」を組み合わせてワールドを作って\n環境を公開・非公開、建築特化や伐採特化...
# 5   1732605180  A steampunk style Enshrouded / survival crafti...
# 6   1732629971  I love it. Main issue since the beginning is t...
# 7   1728937960  This is a heavy Early Access review, just like...
# 8   1732642702  Great game, specifically love the crafting sys...
# 9   1732387906  Originally, I was very critical of Nightingale...
#
#    timestamp_updated  voted_up  votes_up  votes_funny  weighted_vote_score  \
# 0         1733312161      True         2            0             0.530468
# 1         1733061264      True         1            0             0.000000
# 2         1732995922     False         0            0             0.000000
# 3         1732840896      True         0            0             0.000000
# 4         1732599716      True         0            0             0.000000
# 5         1732412821      True         0            0             0.000000
# 6         1732358180      True         1            0             0.513514
# 7         1732166554      True        90            0             0.871807
# 8         1732104168      True        10            0             0.586593
# 9         1731511994      True         0            0             0.795623
#
#    steam_purchase  received_for_free  written_during_early_access
# 0            True              False                         True
# 1            True              False                         True
# 2            True              False                         True
# 3            True              False                         True
# 4            True              False                         True
# 5            True              False                         True
# 6            True              False                         True
# 7            True              False                         True
# 8            True              False                         True
# 9            True              False                         True

# %%
# https: // store.steampowered.com / app / 455690 / Pixel_Puzzles_Junior_Jigsaw /
# https://store.steampowered.com/app/2093920/Dread_Dawn/
# https://store.steampowered.com/app/1465460/Infection_Free_Zone/
# https://store.steampowered.com/app/1259420/Days_Gone/
appid = '1928980'
n_reviews = 60000     # Number of reviews to scrape

params = {
    'json': 1,
    'filter': 'all',
    'language': 'english',
    'day_range': 9223372036854775807,              # Dont ask, just dont touch this number
    'review_type': 'all',
    'purchase_type': 'all'
}


reviews = get_n_reviews(appid, params, n_reviews)
print(f"Total reviews: {len(reviews)}")
# Out:
# 2024-12-11 13:26:19,104 - INFO - Retrieved 100 reviews in API call. Total so far: 100
# 2024-12-11 13:26:19,957 - INFO - Retrieved 100 reviews in API call. Total so far: 200
# 2024-12-11 13:26:20,564 - INFO - Retrieved 100 reviews in API call. Total so far: 300
# 2024-12-11 13:26:21,114 - INFO - Retrieved 100 reviews in API call. Total so far: 400
# 2024-12-11 13:26:21,652 - INFO - Retrieved 100 reviews in API call. Total so far: 500
# 2024-12-11 13:26:22,412 - INFO - Retrieved 100 reviews in API call. Total so far: 600
# 2024-12-11 13:26:22,994 - INFO - Retrieved 100 reviews in API call. Total so far: 700
# 2024-12-11 13:26:23,589 - INFO - Retrieved 100 reviews in API call. Total so far: 800
# 2024-12-11 13:26:24,135 - INFO - Retrieved 100 reviews in API call. Total so far: 900
# 2024-12-11 13:26:25,035 - INFO - Retrieved 100 reviews in API call. Total so far: 1000
# 2024-12-11 13:26:25,629 - INFO - Retrieved 100 reviews in API call. Total so far: 1100
# 2024-12-11 13:26:26,213 - INFO - Retrieved 100 reviews in API call. Total so far: 1200
# 2024-12-11 13:26:26,880 - INFO - Retrieved 100 reviews in API call. Total so far: 1300
# 2024-12-11 13:26:27,494 - INFO - Retrieved 100 reviews in API call. Total so far: 1400
# 2024-12-11 13:26:28,351 - INFO - Retrieved 100 reviews in API call. Total so far: 1500
# 2024-12-11 13:26:28,847 - INFO - Retrieved 100 reviews in API call. Total so far: 1600
# 2024-12-11 13:26:29,416 - INFO - Retrieved 100 reviews in API call. Total so far: 1700
# 2024-12-11 13:26:29,975 - INFO - Retrieved 100 reviews in API call. Total so far: 1800
# 2024-12-11 13:26:30,535 - INFO - Retrieved 100 reviews in API call. Total so far: 1900
# 2024-12-11 13:26:31,148 - INFO - Retrieved 100 reviews in API call. Total so far: 2000
# 2024-12-11 13:26:31,665 - INFO - Retrieved 100 reviews in API call. Total so far: 2100
# 2024-12-11 13:26:32,237 - INFO - Retrieved 100 reviews in API call. Total so far: 2200
# 2024-12-11 13:26:32,821 - INFO - Retrieved 100 reviews in API call. Total so far: 2300
# 2024-12-11 13:26:33,384 - INFO - Retrieved 100 reviews in API call. Total so far: 2400
# 2024-12-11 13:26:33,946 - INFO - Retrieved 100 reviews in API call. Total so far: 2500
# 2024-12-11 13:26:34,524 - INFO - Retrieved 100 reviews in API call. Total so far: 2600
# 2024-12-11 13:26:35,182 - INFO - Retrieved 100 reviews in API call. Total so far: 2700
# 2024-12-11 13:26:35,963 - INFO - Retrieved 100 reviews in API call. Total so far: 2800
# 2024-12-11 13:26:36,474 - INFO - Retrieved 100 reviews in API call. Total so far: 2900
# 2024-12-11 13:26:37,046 - INFO - Retrieved 100 reviews in API call. Total so far: 3000
# 2024-12-11 13:26:37,664 - INFO - Retrieved 100 reviews in API call. Total so far: 3100
# 2024-12-11 13:26:38,245 - INFO - Retrieved 100 reviews in API call. Total so far: 3200
# 2024-12-11 13:26:39,095 - INFO - Retrieved 100 reviews in API call. Total so far: 3300
# 2024-12-11 13:26:39,763 - INFO - Retrieved 100 reviews in API call. Total so far: 3400
# 2024-12-11 13:26:40,476 - INFO - Retrieved 100 reviews in API call. Total so far: 3500
# 2024-12-11 13:26:41,251 - INFO - Retrieved 100 reviews in API call. Total so far: 3600
# 2024-12-11 13:26:41,829 - INFO - Retrieved 100 reviews in API call. Total so far: 3700
# 2024-12-11 13:26:42,527 - INFO - Retrieved 100 reviews in API call. Total so far: 3800
# 2024-12-11 13:26:43,043 - INFO - Retrieved 100 reviews in API call. Total so far: 3900
# 2024-12-11 13:26:43,731 - INFO - Retrieved 100 reviews in API call. Total so far: 4000
# 2024-12-11 13:26:44,354 - INFO - Retrieved 100 reviews in API call. Total so far: 4100
# 2024-12-11 13:26:45,288 - INFO - Retrieved 100 reviews in API call. Total so far: 4200
# 2024-12-11 13:26:45,882 - INFO - Retrieved 100 reviews in API call. Total so far: 4300
# 2024-12-11 13:26:46,464 - INFO - Retrieved 100 reviews in API call. Total so far: 4400
# 2024-12-11 13:26:47,094 - INFO - Retrieved 100 reviews in API call. Total so far: 4500
# 2024-12-11 13:26:47,694 - INFO - Retrieved 100 reviews in API call. Total so far: 4600
# 2024-12-11 13:26:48,251 - INFO - Retrieved 100 reviews in API call. Total so far: 4700
# 2024-12-11 13:26:48,976 - INFO - Retrieved 100 reviews in API call. Total so far: 4800
# 2024-12-11 13:26:49,560 - INFO - Retrieved 100 reviews in API call. Total so far: 4900
# 2024-12-11 13:26:50,253 - INFO - Retrieved 100 reviews in API call. Total so far: 5000
# 2024-12-11 13:26:50,977 - INFO - Retrieved 100 reviews in API call. Total so far: 5100
# 2024-12-11 13:26:51,666 - INFO - Retrieved 100 reviews in API call. Total so far: 5200
# 2024-12-11 13:26:52,241 - INFO - Retrieved 100 reviews in API call. Total so far: 5300
# 2024-12-11 13:26:52,806 - INFO - Retrieved 100 reviews in API call. Total so far: 5400
# 2024-12-11 13:26:53,989 - INFO - Retrieved 100 reviews in API call. Total so far: 5500
# 2024-12-11 13:26:54,706 - INFO - Retrieved 100 reviews in API call. Total so far: 5600
# 2024-12-11 13:26:55,368 - INFO - Retrieved 100 reviews in API call. Total so far: 5700
# 2024-12-11 13:26:55,900 - INFO - Retrieved 100 reviews in API call. Total so far: 5800
# 2024-12-11 13:26:56,589 - INFO - Retrieved 100 reviews in API call. Total so far: 5900
# 2024-12-11 13:26:57,183 - INFO - Retrieved 100 reviews in API call. Total so far: 6000
# 2024-12-11 13:26:57,669 - INFO - Retrieved 100 reviews in API call. Total so far: 6100
# 2024-12-11 13:26:58,180 - INFO - Retrieved 100 reviews in API call. Total so far: 6200
# 2024-12-11 13:26:59,051 - INFO - Retrieved 100 reviews in API call. Total so far: 6300
# 2024-12-11 13:26:59,794 - INFO - Retrieved 100 reviews in API call. Total so far: 6400
# 2024-12-11 13:27:00,303 - INFO - Retrieved 100 reviews in API call. Total so far: 6500
# 2024-12-11 13:27:00,841 - INFO - Retrieved 100 reviews in API call. Total so far: 6600
# 2024-12-11 13:27:01,354 - INFO - Retrieved 100 reviews in API call. Total so far: 6700
# 2024-12-11 13:27:01,948 - INFO - Retrieved 100 reviews in API call. Total so far: 6800
# 2024-12-11 13:27:02,676 - INFO - Retrieved 100 reviews in API call. Total so far: 6900
# 2024-12-11 13:27:03,313 - INFO - Retrieved 100 reviews in API call. Total so far: 7000
# 2024-12-11 13:27:03,849 - INFO - Retrieved 100 reviews in API call. Total so far: 7100
# 2024-12-11 13:27:04,410 - INFO - Retrieved 100 reviews in API call. Total so far: 7200
# 2024-12-11 13:27:05,039 - INFO - Retrieved 100 reviews in API call. Total so far: 7300
# 2024-12-11 13:27:05,999 - INFO - Retrieved 100 reviews in API call. Total so far: 7400
# 2024-12-11 13:27:06,614 - INFO - Retrieved 100 reviews in API call. Total so far: 7500
# 2024-12-11 13:27:07,129 - INFO - Retrieved 100 reviews in API call. Total so far: 7600
# 2024-12-11 13:27:07,660 - INFO - Retrieved 100 reviews in API call. Total so far: 7700
# 2024-12-11 13:27:08,268 - INFO - Retrieved 100 reviews in API call. Total so far: 7800
# 2024-12-11 13:27:08,839 - INFO - Retrieved 100 reviews in API call. Total so far: 7900
# 2024-12-11 13:27:09,352 - INFO - Retrieved 100 reviews in API call. Total so far: 8000
# 2024-12-11 13:27:09,949 - INFO - Retrieved 100 reviews in API call. Total so far: 8100
# 2024-12-11 13:27:10,727 - INFO - Retrieved 100 reviews in API call. Total so far: 8200
# 2024-12-11 13:27:11,290 - INFO - Retrieved 100 reviews in API call. Total so far: 8300
# 2024-12-11 13:27:12,061 - INFO - Retrieved 100 reviews in API call. Total so far: 8400
# 2024-12-11 13:27:12,630 - INFO - Retrieved 100 reviews in API call. Total so far: 8500
# 2024-12-11 13:27:13,295 - INFO - Retrieved 100 reviews in API call. Total so far: 8600
# 2024-12-11 13:27:13,923 - INFO - Retrieved 100 reviews in API call. Total so far: 8700
# 2024-12-11 13:27:14,488 - INFO - Retrieved 100 reviews in API call. Total so far: 8800
# 2024-12-11 13:27:15,157 - INFO - Retrieved 100 reviews in API call. Total so far: 8900
# 2024-12-11 13:27:15,652 - INFO - Retrieved 100 reviews in API call. Total so far: 9000
# 2024-12-11 13:27:16,189 - INFO - Retrieved 100 reviews in API call. Total so far: 9100
# 2024-12-11 13:27:16,774 - INFO - Retrieved 100 reviews in API call. Total so far: 9200
# 2024-12-11 13:27:17,385 - INFO - Retrieved 100 reviews in API call. Total so far: 9300
# 2024-12-11 13:27:17,970 - INFO - Retrieved 100 reviews in API call. Total so far: 9400
# 2024-12-11 13:27:18,691 - INFO - Retrieved 100 reviews in API call. Total so far: 9500
# 2024-12-11 13:27:19,188 - INFO - Retrieved 100 reviews in API call. Total so far: 9600
# 2024-12-11 13:27:19,785 - INFO - Retrieved 100 reviews in API call. Total so far: 9700
# 2024-12-11 13:27:20,943 - INFO - Retrieved 100 reviews in API call. Total so far: 9800
# 2024-12-11 13:27:21,564 - INFO - Retrieved 100 reviews in API call. Total so far: 9900
# 2024-12-11 13:27:22,119 - INFO - Retrieved 100 reviews in API call. Total so far: 10000
# 2024-12-11 13:27:22,634 - INFO - Retrieved 76 reviews in API call. Total so far: 10076
# 2024-12-11 13:27:22,634 - INFO - Finished fetching all reviews.
# Total reviews: 10076

# %% [markdown]
# # Filter Data
#
# #### -

# %%
# Specify the key where the review text is stored
review_key = 'review'

# Filter the reviews
filtered_data = filter_reviews(reviews, review_key)
# Out:
# 2024-12-11 13:27:33,485 - INFO - Total entries removed: 601

# %%
# Generate sample and save
sample_size = 4500
seed = 42
sample_data = get_random_sample(reviews, sample_size, seed=seed)
save_to_json(sample_data, path_db_prepared)
# Out:
# 2024-12-11 13:27:43,875 - INFO - Generating a random sample of size 4500 with seed 42.
# 2024-12-11 13:27:44,104 - INFO - Data successfully saved to C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\Steamapps\Market\db_prepared.json

# %% [markdown]
# # Translate reviews

# %% [markdown]
# #### This transformation is not pretty but it is used for now to keep using the same helpers as before

# %%
# chang key from 'language' to 'player_language'
data = load_json(path_db_prepared)
def rename_key_in_json(obj, old_key, new_key):
    if isinstance(obj, dict):
        return {new_key if k == old_key else k: rename_key_in_json(v, old_key, new_key) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [rename_key_in_json(i, old_key, new_key) for i in obj]
    return obj

# Rename 'language' to 'player_language'
updated_data = rename_key_in_json(data, 'language', 'player_language')
updated_data = rename_key_in_json(updated_data, 'review', 'player_response')
# Out:
# 2024-12-11 13:27:49,452 - INFO - Loading data from C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\Steamapps\Market\db_prepared.json

# %%
updated_data[0]
# Out:
# {'app_id_name': '1928980_Nightingale',
#  'recommendationid': 181673699,
#  'playtime_at_review_minutes': 346,
#  'last_played': 1733235591,
#  'review_text': '画的饼看着是好的，玩起来都是糙的，新手教程巨长，做完直接不能退款了，神坑',
#  'timestamp_updated': 1733235831,
#  'voted_up': False,
#  'votes_up': 0,
#  'votes_funny': 0,
#  'weighted_vote_score': 0.0,
#  'steam_purchase': True,
#  'received_for_free': False,
#  'written_during_early_access': True}

# %%
id_col = 'recommendationid'
columns_of_interest = ['player_response']
translated_data = translate_data(updated_data, id_col, prompt_template_translation, api_settings, columns_of_interest)

# %%
save_to_json(translated_data, path_db_translated)
# Out:
# 2024-12-11 13:27:59,252 - INFO - Data successfully saved to C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\Steamapps\Market\db_translated.json

# %% [markdown]
# # Topic extraction and sentiment analysis

# %%
# Parameters
id_column = 'recommendationid'                # Column name for entry IDs
columns_of_interest = ["player_response"]     # Which cols should be analyzed?
batch_size = 10                               # Fail-safe batching. The higher the number, the less often the progress is saved.

prepared_data = read_json(path_db_translated)

# Run analysis
analyse_data(
    translated_data=prepared_data,
    id_column=id_column,
    output_path=path_db_analysed,
    prompt_template_topic=prompt_template_topic_steam,
    prompt_template_sentiment=prompt_template_sentiment,
    api_settings=api_settings,
    columns_of_interest=columns_of_interest,
    batch_size=batch_size
)
# Out:
# 2024-12-11 16:21:43,791 - INFO - Loading existing progress from C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\Steamapps\Market\db_analysed.json
# 2024-12-11 16:21:43,807 - INFO - Skipping already processed entry ID 181537175
# 2024-12-11 16:21:43,807 - INFO - Skipping already processed entry ID 159046186
# 2024-12-11 16:21:43,807 - INFO - Skipping already processed entry ID 171360654
# 2024-12-11 16:21:43,807 - INFO - Skipping already processed entry ID 159376789
# 2024-12-11 16:21:43,807 - INFO - Skipping already processed entry ID 159362247
# 2024-12-11 16:21:43,807 - INFO - Skipping already processed entry ID 166544997
# 2024-12-11 16:21:43,807 - INFO - Skipping already processed entry ID 168649247
# 2024-12-11 16:21:43,807 - INFO - Skipping already processed entry ID 181119052
# 2024-12-11 16:21:43,807 - INFO - Skipping already processed entry ID 160155372
# 2024-12-11 16:21:43,821 - INFO - Skipping already processed entry ID 158855733
# 2024-12-11 16:21:43,821 - INFO - Skipping already processed entry ID 175317267
# 2024-12-11 16:21:43,823 - INFO - Skipping already processed entry ID 171692985
# 2024-12-11 16:21:43,823 - INFO - Skipping already processed entry ID 177655363
# 2024-12-11 16:21:43,825 - INFO - Skipping already processed entry ID 159462641
# 2024-12-11 16:21:43,825 - INFO - Skipping already processed entry ID 158953653
# 2024-12-11 16:21:43,825 - INFO - Skipping already processed entry ID 158840575
# 2024-12-11 16:21:43,827 - INFO - Skipping already processed entry ID 166299064
# 2024-12-11 16:21:43,827 - INFO - Skipping already processed entry ID 174978494
# 2024-12-11 16:21:43,827 - INFO - Skipping already processed entry ID 159073041
# 2024-12-11 16:21:43,827 - INFO - Skipping already processed entry ID 158835784
# 2024-12-11 16:21:43,827 - INFO - Skipping already processed entry ID 158870286
# 2024-12-11 16:21:43,827 - INFO - Skipping already processed entry ID 158879266
# 2024-12-11 16:22:44,517 - INFO - Extracting topics for entry ID 166001438
# 2024-12-11 16:22:47,551 - INFO - Analyzing sentiment for topic 'Game Mechanics' (Entry ID 166001438)
# 2024-12-11 16:22:48,534 - INFO - Analyzing sentiment for topic 'Multiplayer Functionality' (Entry ID 166001438)
# 2024-12-11 16:22:48,973 - INFO - Analyzing sentiment for topic 'Gameplay Experience' (Entry ID 166001438)
# 2024-12-11 16:22:49,441 - INFO - Analyzing sentiment for topic 'Player Community' (Entry ID 166001438)
# 2024-12-11 16:22:49,788 - INFO - Tokens used so far: Prompt Tokens: 565764, Completion Tokens: 75886
# 2024-12-11 16:22:49,788 - INFO - Extracting topics for entry ID 160112154
# 2024-12-11 16:22:59,971 - INFO - Analyzing sentiment for topic 'Game Genre Combination' (Entry ID 160112154)
# 2024-12-11 16:23:00,368 - INFO - Analyzing sentiment for topic 'Procedural Generation' (Entry ID 160112154)
# 2024-12-11 16:23:00,765 - INFO - Analyzing sentiment for topic 'Engaging Storyline' (Entry ID 160112154)
# 2024-12-11 16:23:01,293 - INFO - Analyzing sentiment for topic 'Offline Mode Request' (Entry ID 160112154)
# 2024-12-11 16:23:01,825 - INFO - Analyzing sentiment for topic 'Company Communication' (Entry ID 160112154)
# 2024-12-11 16:23:02,263 - INFO - Analyzing sentiment for topic 'Recommendation for Fans' (Entry ID 160112154)
# 2024-12-11 16:23:02,740 - INFO - Tokens used so far: Prompt Tokens: 567412, Completion Tokens: 76143
# 2024-12-11 16:23:02,740 - INFO - Extracting topics for entry ID 166317279
# 2024-12-11 16:23:05,094 - INFO - Analyzing sentiment for topic 'Gameplay' (Entry ID 166317279)
# 2024-12-11 16:23:05,515 - INFO - Analyzing sentiment for topic 'Environment' (Entry ID 166317279)
# 2024-12-11 16:23:05,920 - INFO - Analyzing sentiment for topic 'Recommendation' (Entry ID 166317279)
# 2024-12-11 16:23:06,366 - INFO - Saving progress to C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\Steamapps\Market\db_analysed.json
# 2024-12-11 16:23:06,390 - INFO - Progress saved after processing 10 entries.
# 2024-12-11 16:23:06,390 - INFO - Tokens used so far: Prompt Tokens: 568480, Completion Tokens: 76238
# 2024-12-11 16:23:06,390 - INFO - Extracting topics for entry ID 175229174
# 2024-12-11 16:23:06,878 - INFO - Tokens used so far: Prompt Tokens: 569109, Completion Tokens: 76245
# 2024-12-11 16:23:06,889 - INFO - Extracting topics for entry ID 159149324
# 2024-12-11 16:23:09,123 - INFO - Analyzing sentiment for topic 'Game Play Loop' (Entry ID 159149324)
# 2024-12-11 16:23:09,593 - INFO - Analyzing sentiment for topic 'Quality of Life Features' (Entry ID 159149324)
# 2024-12-11 16:23:10,021 - INFO - Analyzing sentiment for topic 'Planned Quality of Life Improvements' (Entry ID 159149324)
# 2024-12-11 16:23:10,565 - INFO - Tokens used so far: Prompt Tokens: 570234, Completion Tokens: 76376
# 2024-12-11 16:23:10,565 - INFO - Extracting topics for entry ID 160629808
# 2024-12-11 16:23:37,566 - INFO - Analyzing sentiment for topic 'Server Performance' (Entry ID 159025202)
# 2024-12-11 16:23:38,017 - INFO - Analyzing sentiment for topic 'Overall Game Recommendation' (Entry ID 159025202)
# 2024-12-11 16:23:38,474 - INFO - Tokens used so far: Prompt Tokens: 577115, Completion Tokens: 77461
# 2024-12-11 16:23:38,474 - INFO - Extracting topics for entry ID 158936354
# 2024-12-11 16:23:41,170 - INFO - Analyzing sentiment for topic 'Network Errors' (Entry ID 158936354)
# 2024-12-11 16:23:41,718 - INFO - Analyzing sentiment for topic 'Gameplay Experience' (Entry ID 158936354)
# 2024-12-11 16:23:42,104 - INFO - Analyzing sentiment for topic 'Connectivity Issues' (Entry ID 158936354)
# 2024-12-11 16:23:42,500 - INFO - Analyzing sentiment for topic 'Friend Connectivity' (Entry ID 158936354)
# 2024-12-11 16:23:43,107 - INFO - Tokens used so far: Prompt Tokens: 578419, Completion Tokens: 77631
# 2024-12-11 16:23:43,121 - INFO - Extracting topics for entry ID 158922687
# 2024-12-11 16:23:45,444 - INFO - Analyzing sentiment for topic 'Game Performance on 14900K CPU' (Entry ID 158922687)
# 2024-12-11 16:23:45,956 - INFO - Analyzing sentiment for topic 'Visuals' (Entry ID 158922687)
# 2024-12-11 16:23:46,379 - INFO - Analyzing sentiment for topic 'Gameplay Experience' (Entry ID 158922687)
# 2024-12-11 16:23:46,775 - INFO - Analyzing sentiment for topic 'Bugs Warning' (Entry ID 158922687)
# 2024-12-11 16:23:47,190 - INFO - Tokens used so far: Prompt Tokens: 579723, Completion Tokens: 77807
# 2024-12-11 16:23:47,190 - INFO - Extracting topics for entry ID 158830897
# 2024-12-11 16:23:49,180 - INFO - Analyzing sentiment for topic 'Gameplay Loop' (Entry ID 158830897)
# 2024-12-11 16:23:49,864 - INFO - Analyzing sentiment for topic 'Optimization' (Entry ID 158830897)
# 2024-12-11 16:23:50,265 - INFO - Analyzing sentiment for topic 'Future Improvements' (Entry ID 158830897)
# 2024-12-11 16:23:50,680 - INFO - Tokens used so far: Prompt Tokens: 580861, Completion Tokens: 77928
# 2024-12-11 16:23:50,682 - INFO - Extracting topics for entry ID 159050043
# 2024-12-11 16:23:53,342 - INFO - Analyzing sentiment for topic 'Game Foundation' (Entry ID 159050043)
# 2024-12-11 16:23:53,816 - INFO - Analyzing sentiment for topic 'Quality of Life Features' (Entry ID 159050043)
# 2024-12-11 16:23:54,251 - INFO - Analyzing sentiment for topic 'Progression System' (Entry ID 159050043)
# 2024-12-11 16:23:54,727 - INFO - Analyzing sentiment for topic 'Current Game Quality' (Entry ID 159050043)
# 2024-12-11 16:23:55,136 - INFO - Analyzing sentiment for topic 'Early Access Status' (Entry ID 159050043)
# 2024-12-11 16:23:55,591 - INFO - Saving progress to C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\Steamapps\Market\db_analysed.json
# 2024-12-11 16:23:55,639 - INFO - Progress saved after processing 10 entries.
# 2024-12-11 16:23:55,639 - INFO - Tokens used so far: Prompt Tokens: 582303, Completion Tokens: 78134
# 2024-12-11 16:23:55,639 - INFO - Extracting topics for entry ID 175499056
# 2024-12-11 16:24:00,046 - INFO - Analyzing sentiment for topic 'Character Data Deletion' (Entry ID 175499056)
# 2024-12-11 16:24:00,469 - INFO - Analyzing sentiment for topic 'Player Experience' (Entry ID 175499056)
# 2024-12-11 16:24:01,008 - INFO - Analyzing sentiment for topic 'Refund Request' (Entry ID 175499056)
# 2024-12-11 16:24:02,022 - INFO - Analyzing sentiment for topic 'Early Access Issues' (Entry ID 175499056)
# 2024-12-11 16:24:02,569 - INFO - Analyzing sentiment for topic 'Game Development Criticism' (Entry ID 175499056)
# 2024-12-11 16:24:02,987 - INFO - Analyzing sentiment for topic 'Puck Character' (Entry ID 175499056)
# 2024-12-11 16:24:03,395 - INFO - Tokens used so far: Prompt Tokens: 584019, Completion Tokens: 78412
# 2024-12-11 16:24:03,395 - INFO - Extracting topics for entry ID 159660331
# 2024-12-11 16:24:04,393 - INFO - Analyzing sentiment for topic 'Data Loss' (Entry ID 159660331)
# 2024-12-11 16:24:04,916 - INFO - Tokens used so far: Prompt Tokens: 584818, Completion Tokens: 78463
# 2024-12-11 16:24:04,921 - INFO - Extracting topics for entry ID 159081648
# 2024-12-11 16:24:10,579 - INFO - Analyzing sentiment for topic 'Early Access Experience' (Entry ID 159081648)
# 2024-12-11 16:24:11,045 - INFO - Analyzing sentiment for topic 'Developer Responsiveness' (Entry ID 159081648)
# 2024-12-11 16:24:11,492 - INFO - Analyzing sentiment for topic 'Quality of Life Improvements' (Entry ID 159081648)
# 2024-12-11 16:24:11,922 - INFO - Analyzing sentiment for topic 'Melee Combat System' (Entry ID 159081648)
# 2024-12-11 16:24:12,336 - INFO - Analyzing sentiment for topic 'Building System' (Entry ID 159081648)
# 2024-12-11 16:24:12,750 - INFO - Analyzing sentiment for topic 'Crafting Mechanics' (Entry ID 159081648)
# 2024-12-11 16:24:13,176 - INFO - Analyzing sentiment for topic 'Connectivity and Lag' (Entry ID 159081648)
# 2024-12-11 16:24:13,630 - INFO - Analyzing sentiment for topic 'Player Engagement' (Entry ID 159081648)
# 2024-12-11 16:24:14,467 - INFO - Analyzing sentiment for topic 'Game Recommendation' (Entry ID 159081648)
# 2024-12-11 16:24:14,827 - INFO - Analyzing sentiment for topic 'Understanding of Game Mechanics' (Entry ID 159081648)
# 2024-12-11 16:24:16,206 - INFO - Tokens used so far: Prompt Tokens: 587388, Completion Tokens: 78895
# 2024-12-11 16:24:16,206 - INFO - Extracting topics for entry ID 160682623
# 2024-12-11 16:24:18,154 - INFO - Analyzing sentiment for topic 'Game Fun Factor' (Entry ID 160682623)
# 2024-12-11 16:24:18,554 - INFO - Analyzing sentiment for topic 'Server Issues' (Entry ID 160682623)
# 2024-12-11 16:24:19,019 - INFO - Analyzing sentiment for topic 'Internet Connection Requirement' (Entry ID 160682623)
# 2024-12-11 16:24:19,460 - INFO - Tokens used so far: Prompt Tokens: 588485, Completion Tokens: 79003
# 2024-12-11 19:37:15,707 - INFO - Analyzing sentiment for topic 'Generic Missions' (Entry ID 175852447)
# 2024-12-11 19:37:16,182 - INFO - Analyzing sentiment for topic 'Exploration vs. Quest Treadmill' (Entry ID 175852447)
# 2024-12-11 19:37:16,633 - INFO - Analyzing sentiment for topic 'Forced Quests' (Entry ID 175852447)
# 2024-12-11 19:37:17,232 - INFO - Analyzing sentiment for topic 'Underutilized Lore' (Entry ID 175852447)
# 2024-12-11 19:37:17,670 - INFO - Analyzing sentiment for topic 'Pre-Made Realms' (Entry ID 175852447)
# 2024-12-11 19:37:18,129 - INFO - Analyzing sentiment for topic 'Comparison to Mystcraft' (Entry ID 175852447)
# 2024-12-11 19:37:18,788 - INFO - Analyzing sentiment for topic 'Frustration with Game Design' (Entry ID 175852447)
# 2024-12-11 19:37:19,443 - INFO - Tokens used so far: Prompt Tokens: 2275368, Completion Tokens: 303797
# 2024-12-11 19:37:19,443 - INFO - Extracting topics for entry ID 175159395
# 2024-12-11 19:37:24,153 - INFO - Analyzing sentiment for topic 'Gameplay Improvement' (Entry ID 175159395)
# 2024-12-11 19:37:24,606 - INFO - Analyzing sentiment for topic 'Graphics' (Entry ID 175159395)
# 2024-12-11 19:37:25,095 - INFO - Analyzing sentiment for topic 'Atmosphere' (Entry ID 175159395)
# 2024-12-11 19:37:25,639 - INFO - Analyzing sentiment for topic 'Soundtrack' (Entry ID 175159395)
# 2024-12-11 19:37:26,426 - INFO - Analyzing sentiment for topic 'Performance Issues' (Entry ID 175159395)
# 2024-12-11 19:37:26,961 - INFO - Analyzing sentiment for topic 'Update Experience' (Entry ID 175159395)
# 2024-12-11 19:37:27,376 - INFO - Tokens used so far: Prompt Tokens: 2276982, Completion Tokens: 304014
# 2024-12-11 19:37:27,376 - INFO - Extracting topics for entry ID 159859746
# 2024-12-11 19:37:33,444 - INFO - Analyzing sentiment for topic 'Game Stability' (Entry ID 159859746)
# 2024-12-11 19:37:33,862 - INFO - Analyzing sentiment for topic 'Crafting System' (Entry ID 159859746)
# 2024-12-11 19:37:34,325 - INFO - Analyzing sentiment for topic 'Overwhelming Item Variety' (Entry ID 159859746)
# 2024-12-11 19:37:34,694 - INFO - Analyzing sentiment for topic 'Gameplay Feedback' (Entry ID 159859746)
# 2024-12-11 19:37:35,143 - INFO - Analyzing sentiment for topic 'Twist in Gameplay' (Entry ID 159859746)
# 2024-12-11 19:37:35,830 - INFO - Saving progress to C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\Steamapps\Market\db_analysed.json
# 2024-12-11 19:37:35,980 - INFO - Progress saved after processing 10 entries.
# 2024-12-11 19:37:35,980 - INFO - Tokens used so far: Prompt Tokens: 2278666, Completion Tokens: 304252
# 2024-12-11 19:37:35,980 - INFO - Extracting topics for entry ID 158860701
# 2024-12-11 19:37:38,023 - INFO - Analyzing sentiment for topic 'Inopportynity' (Entry ID 158860701)
# 2024-12-11 19:37:38,741 - INFO - Tokens used so far: Prompt Tokens: 2279463, Completion Tokens: 304306
# 2024-12-11 19:38:19,748 - INFO - Analyzing sentiment for topic 'Overall Impression' (Entry ID 159272280)
# 2024-12-11 19:38:20,205 - INFO - Tokens used so far: Prompt Tokens: 2286205, Completion Tokens: 305162
# 2024-12-11 19:38:20,205 - INFO - Extracting topics for entry ID 158825739
# 2024-12-11 19:38:28,390 - INFO - Analyzing sentiment for topic 'Loading Screens' (Entry ID 158825739)
# 2024-12-11 19:38:28,984 - INFO - Analyzing sentiment for topic 'Forced Multiplayer' (Entry ID 158825739)
# 2024-12-11 19:38:29,400 - INFO - Analyzing sentiment for topic 'Laggy Servers' (Entry ID 158825739)
# 2024-12-11 19:38:31,034 - INFO - Analyzing sentiment for topic 'Animation Quality' (Entry ID 158825739)
# 2024-12-11 19:38:31,700 - INFO - Analyzing sentiment for topic 'Combat System' (Entry ID 158825739)
# 2024-12-11 19:38:32,200 - INFO - Analyzing sentiment for topic 'Item Management' (Entry ID 158825739)
# 2024-12-11 19:38:32,701 - INFO - Analyzing sentiment for topic 'Encumbrance System' (Entry ID 158825739)
# 2024-12-11 19:38:33,268 - INFO - Analyzing sentiment for topic 'Censorship of Critique' (Entry ID 158825739)
# 2024-12-11 19:38:33,921 - INFO - Tokens used so far: Prompt Tokens: 2288182, Completion Tokens: 305493
# 2024-12-11 19:38:33,923 - INFO - Extracting topics for entry ID 158882310
# 2024-12-11 19:41:50,958 - ERROR - Error extracting topics for entry ID 158882310: Unterminated string starting at: line 4 column 21 (char 46)
# 2024-12-11 19:41:50,960 - INFO - Tokens used so far: Prompt Tokens: 2288832, Completion Tokens: 309589
# 2024-12-11 19:41:50,965 - INFO - Extracting topics for entry ID 159927714
# 2024-12-11 19:42:01,175 - INFO - Analyzing sentiment for topic 'Art/Styлистic' (Entry ID 159927714)
# 2024-12-11 19:42:01,655 - INFO - Analyzing sentiment for topic '早期访问状态' (Entry ID 159927714)
# 2024-12-11 19:42:02,139 - INFO - Analyzing sentiment for topic '充实的体验' (Entry ID 159927714)
# 2024-12-11 19:42:02,569 - INFO - Tokens used so far: Prompt Tokens: 2289987, Completion Tokens: 309738
# 2024-12-11 19:42:02,579 - INFO - Extracting topics for entry ID 158859126
# 2024-12-11 19:44:03,050 - INFO - Analyzing sentiment for topic 'AI' (Entry ID 158859126)
# 2024-12-11 19:44:03,635 - INFO - Saving progress to C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\Steamapps\Market\db_analysed.json
# 2024-12-11 19:44:03,812 - INFO - Progress saved after processing 10 entries.
# 2024-12-11 19:44:03,812 - INFO - Tokens used so far: Prompt Tokens: 2290791, Completion Tokens: 309923
# 2024-12-11 19:44:03,812 - INFO - Extracting topics for entry ID 158863380
# 2024-12-11 19:44:08,991 - INFO - Analyzing sentiment for topic 'Improving Cooking Minig升级' (Entry ID 158863380)
# 2024-12-11 19:44:09,465 - INFO - Analyzing sentiment for topic '整体功能' (Entry ID 158863380)
# 2024-12-11 19:44:10,061 - INFO - Analyzing sentiment for topic '开发时间' (Entry ID 158863380)
# 2024-12-11 19:45:10,468 - INFO - Analyzing sentiment for topic 'CRAFTING' (Entry ID 175150688)
# 2024-12-11 19:45:10,872 - INFO - Analyzing sentiment for topic 'ADDONS' (Entry ID 175150688)
# 2024-12-11 19:45:11,368 - INFO - Analyzing sentiment for topic 'AMAZING' (Entry ID 175150688)
# 2024-12-11 19:45:11,758 - INFO - Analyzing sentiment for topic 'PLACING' (Entry ID 175150688)
# 2024-12-11 19:45:12,288 - INFO - Tokens used so far: Prompt Tokens: 2298405, Completion Tokens: 311212
# 2024-12-11 19:45:12,299 - INFO - Extracting topics for entry ID 159951456
# 2024-12-11 19:45:19,502 - INFO - Analyzing sentiment for topic 'Food' (Entry ID 159951456)
# 2024-12-11 19:45:20,045 - INFO - Analyzing sentiment for topic 'Coop/MP' (Entry ID 159951456)
# 2024-12-11 19:45:20,738 - INFO - Tokens used so far: Prompt Tokens: 2299394, Completion Tokens: 311348
# 2024-12-11 19:45:20,749 - INFO - Extracting topics for entry ID 159615188
# 2024-12-11 19:45:36,385 - INFO - Analyzing sentiment for topic 'ImprovingASpıt' (Entry ID 159615188)
# 2024-12-11 19:45:36,973 - INFO - Analyzing sentiment for topic 'MonSt₨&ANIMATIoN' (Entry ID 159615188)
# 2024-12-11 19:45:37,704 - INFO - Analyzing sentiment for topic 'PoorLYFëQ' (Entry ID 159615188)
# 2024-12-11 19:45:38,532 - INFO - Analyzing sentiment for topic 'CrAfT̨̛ing' (Entry ID 159615188)
# 2024-12-11 19:45:39,073 - INFO - Analyzing sentiment for topic 'ConfƴǏSǏngQUëSt' (Entry ID 159615188)
# 2024-12-11 19:45:39,078 - ERROR - Error analyzing sentiment for topic 'ConfƴǏSǏngQUëSt' (Entry ID 159615188): 'Context'
# 2024-12-11 19:45:39,078 - ERROR - Unexpected error: unhashable type: 'set'
# 2024-12-11 19:45:39,078 - INFO - Saving progress to C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\Steamapps\Market\db_analysed.json
# 2024-12-11 19:45:39,248 - INFO - Processing completed. Final progress saved.

# %%
sample_for_embedding = os.path.join(root_dir, steam_title, "sample_for_embedding.json")

data = read_json(path_db_analysed)
sample_data = get_random_sample(data, 50, seed=42)
save_to_json(sample_data, sample_for_embedding)
# Out:
# 2024-12-13 15:25:51,258 - INFO - Generating a random sample of size 50 with seed 42.
# 2024-12-13 15:25:51,270 - INFO - Data successfully saved to C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\Steamapps\Market\sample_for_embedding.json

# %% [markdown]
# # Embed reviews

# %%
batch_size = 50
b_override = False  # Change to True if embeddings should be overwritten
embed_key = "topic"  # topic or "sentence"

# embed_model_name = 'sentence-transformers/all-mpnet-base-v2'
# embed_model_name = 'dunzhang/stella_en_1.5B_v5'

# Load the JSON data 
data = read_json(path_db_analysed)

# Initialize an empty list for all processed results
processed_results = []

# Process data in batches
for batch_start in range(0, len(data), batch_size):
    batch_end = min(batch_start + batch_size, len(data))
    batch = data[batch_start:batch_end]
    logger.info(f"Processing batch {batch_start // batch_size + 1} ({batch_start} to {batch_end})")
    processed_batch = process_batch(batch, embed_model, b_override, embed_key=embed_key)
    processed_results.extend(processed_batch)  # Collect processed batch results

# Convert all processed results to a DataFrame at once
df_table = json_to_table(processed_results)

# Save the final JSON table
save_df_as_json(df_table, path_db_embedded)
logger.info("Embedding and conversion to table format completed.")
# Out:
# C:\Users\fbohm\Documents\Venvironments\Lib\site-packages\torchvision\io\image.py:14: UserWarning: Failed to load image Python extension: '[WinError 127] The specified procedure could not be found'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# 2024-12-13 15:10:40,596 - INFO - PyTorch version 2.5.1+cu124 available.
# 2024-12-13 15:10:40,598 - INFO - Polars version 1.12.0 available.
# 2024-12-13 15:10:40,598 - INFO - Duckdb version 1.1.2 available.
# 2024-12-13 15:10:42,356 - INFO - Use pytorch device_name: cuda
# 2024-12-13 15:10:42,357 - INFO - Load pretrained SentenceTransformer: dunzhang/stella_en_400M_v5
# Some weights of the model checkpoint at dunzhang/stella_en_400M_v5 were not used when initializing NewModel: ['new.pooler.dense.bias', 'new.pooler.dense.weight']
# - This IS expected if you are initializing NewModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing NewModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# tokenizer_config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# C:\Users\fbohm\Documents\Venvironments\Lib\site-packages\huggingface_hub\file_download.py:139: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\fbohm\.cache\huggingface\hub\models--dunzhang--stella_en_400M_v5. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/712k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/695 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/186 [00:00<?, ?B/s]
# 2_Dense_1024/config.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/4.20M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/4.20M [00:00<?, ?B/s]
# 2024-12-13 15:10:59,477 - INFO - 2 prompts are loaded, with the keys: ['s2p_query', 's2s_query']
# 2024-12-13 15:10:59,477 - INFO - Processing batch 1 (0 to 50)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 28
#      26     batch = data[batch_start:batch_end]
#      27     logger.info(f"Processing batch {batch_start // batch_size + 1} ({batch_start} to {batch_end})")
# ---> 28     processed_batch = process_batch(batch, embed_model, b_override, embed_key=embed_key)
#      29     processed_results.extend(processed_batch)  # Collect processed batch results
#      31 # Convert all processed results to a DataFrame at once
#
# File ~\Desktop\Projects\DataScience\cluster_analysis\helper\embedding.py:55, in process_batch(batch, embed_model, b_override, embed_key)
#      52     if isinstance(d_topic, dict):
#      53         # Check if the key exists and embedding should be created or overridden
#      54         if embed_key in d_topic and ("embedding" not in d_topic or b_override):
# ---> 55             d_topic["embedding"] = embed_text(d_topic[embed_key], embed_model)
#      56 processed_batch.append(review_entry)  # Append the processed entry
#      57 gc.collect()
#
# File ~\Desktop\Projects\DataScience\cluster_analysis\helper\embedding.py:35, in embed_text(text, embed_model)
#      26 """
#      27 Generates embeddings for the provided text.
#      28 Args:
#    (...)
#      32     list: The embedding vector.
#      33 """
#      34 text = text.encode(encoding="ASCII", errors="ignore").decode()
# ---> 35 return embed_model.get_text_embedding(text)
#
# File ~\Documents\Venvironments\Lib\site-packages\torch\nn\modules\module.py:1931, in Module.__getattr__(self, name)
#    1929     if name in modules:
#    1930         return modules[name]
# -> 1931 raise AttributeError(
#    1932     f"'{type(self).__name__}' object has no attribute '{name}'"
#    1933 )
#
# AttributeError: 'SentenceTransformer' object has no attribute 'get_text_embedding'

# %%
batch_size = 50
b_override = False  # Change to True if embeddings should be overwritten
embed_key = "sentence"  # topic or "sentence"

# embed_model_name = 'sentence-transformers/all-mpnet-base-v2'
# embed_model_name = 'dunzhang/stella_en_1.5B_v5'
embed_model_name = 'dunzhang/stella_en_400M_v5'

# Load the JSON data 
data = read_json(path_db_analysed)

# Initialize the embedding model once
# embed_model = initialize_embedding_model(model_name=embed_model_name)


from sentence_transformers import SentenceTransformer

embed_model = SentenceTransformer("dunzhang/stella_en_400M_v5", trust_remote_code=True)
# Out:
# 2024-12-13 15:12:15,215 - INFO - Use pytorch device_name: cuda
# 2024-12-13 15:12:15,215 - INFO - Load pretrained SentenceTransformer: dunzhang/stella_en_400M_v5
# Some weights of the model checkpoint at dunzhang/stella_en_400M_v5 were not used when initializing NewModel: ['new.pooler.dense.bias', 'new.pooler.dense.weight']
# - This IS expected if you are initializing NewModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing NewModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 2024-12-13 15:12:25,145 - INFO - 2 prompts are loaded, with the keys: ['s2p_query', 's2s_query']

# %% [markdown]
# # Stella

# %%
processed_batch = []  # Collect processed results
batch_size = 10
counter = 0
for review_entry in data:
    if isinstance(review_entry, dict) and "topics" in review_entry and isinstance(review_entry["topics"], list):
        for d_topic in review_entry["topics"]:
            if isinstance(d_topic, dict):
                # Check if the key exists and embedding should be created or overridden
                if embed_key in d_topic and ("embedding" not in d_topic or b_override):
                    d_topic["embedding"] = embed_model.encode(d_topic[embed_key])
        processed_batch.append(review_entry)  # Append the processed entry
        gc.collect()
    counter += 1
    if counter % batch_size == 0:
        logger.info(f"Processed {counter} entries")

# %% [markdown]
# # OPENAI ADA

# %%
import openai
import logging
from helper.utils import *

# Configure logging
logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")
logger = logging.getLogger(__name__)


def get_embedding(text, model="text-embedding-3-small"):
   text = text.replace("\n", " ")
   embedding = client.embeddings.create(input = [text], model=model).data[0].embedding
   return embedding


def flatten_and_embed(json_data, embed_model_name="text-embedding-3-large", embed_key="sentence"):
    """
    Flattens the topics in the JSON data and embeds the sentences.
    Args:
        json_data (list): List of JSON entries with nested topics.
        embed_model_name (str): The OpenAI embedding model name.
    Returns:
        list: A flattened list of JSON entries with embeddings.
    """
    flattened_data = []
    counter = 0
    
    for entry in json_data:
        # Extract common fields
        common_fields = {key: value for key, value in entry.items() if key != "topics"}
        
        if "topics" in entry and isinstance(entry["topics"], list):
            for topic in entry["topics"]:
                # Combine common fields with topic-specific fields
                flattened_entry = {**common_fields, **topic}
                #print(flattened_entry)
                # Generate embedding for the sentence
                if embed_key in topic:
                    flattened_entry["embedding"] = get_embedding(topic[embed_key], model=embed_model_name)
                    counter += 1
                    if counter % 10 == 0:
                        logger.info(f"Processed {counter} entries")
                else:
                    flattened_entry["embedding"] = None
                    logger.info(f"No sentence found in entry: {entry.get('recommendationid', 'Unknown')}")
                # Append the flattened entry to the list
                flattened_data.append(flattened_entry)
        else:
            logger.warning(f"No topics found in entry: {entry.get('recommendationid', 'Unknown')}")
    
    return flattened_data


data = read_json(sample_for_embedding)

# Process the data
logger.info("Flattening and embedding data...")
processed_data = flatten_and_embed(data)

# Save the processed data

output_file = os.path.join(root_dir, steam_title, "openai_embedding.json")


save_df_as_json(processed_data, output_file)

logger.info("Data flattening and embedding completed successfully.")
# Out:
# 2024-12-13 15:30:10,443 - INFO - Flattening and embedding data...
# 2024-12-13 15:30:20,361 - INFO - Processed 10 entries
# 2024-12-13 15:30:26,732 - INFO - Processed 20 entries
# 2024-12-13 15:30:32,926 - INFO - Processed 30 entries
# 2024-12-13 15:30:39,858 - INFO - Processed 40 entries
# 2024-12-13 15:30:46,010 - INFO - Processed 50 entries
# 2024-12-13 15:30:52,118 - INFO - Processed 60 entries
# 2024-12-13 15:30:59,832 - INFO - Processed 70 entries
# 2024-12-13 15:31:06,129 - INFO - Processed 80 entries
# 2024-12-13 15:31:11,351 - INFO - Processed 90 entries
# 2024-12-13 15:31:16,442 - INFO - Processed 100 entries
# 2024-12-13 15:31:22,489 - INFO - Processed 110 entries
# 2024-12-13 15:31:28,918 - INFO - Processed 120 entries
# 2024-12-13 15:31:34,912 - INFO - Processed 130 entries
# 2024-12-13 15:31:40,904 - INFO - Processed 140 entries
# 2024-12-13 15:31:46,432 - INFO - Processed 150 entries
# 2024-12-13 15:31:56,416 - INFO - Processed 160 entries
# 2024-12-13 15:32:02,537 - INFO - Processed 170 entries
# 2024-12-13 15:32:09,838 - INFO - Processed 180 entries
# 2024-12-13 15:32:15,621 - INFO - Processed 190 entries
# 2024-12-13 15:32:20,968 - INFO - Processed 200 entries
# 2024-12-13 15:32:27,229 - INFO - Processed 210 entries
# 2024-12-13 15:32:33,013 - INFO - Processed 220 entries
# 2024-12-13 15:32:39,919 - INFO - Processed 230 entries
# 2024-12-13 15:32:45,985 - INFO - Processed 240 entries
# 2024-12-13 15:32:51,561 - INFO - Saving data to C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\Steamapps\Market\openai_embedding.json
# 2024-12-13 15:32:52,689 - INFO - Data flattening and embedding completed successfully.

# %% [markdown]
# # Optional Data transofrmation operations
# ##### - maybe just filter out all reviews that have category = 'bugs'
# ##### - Remove embedding key (reduce size)

# %%
data = read_json(path_db_analysed)

# Filter out all reviews that have category = 'bugs'
bug_entries = [entry for entry in data if entry.get('category') == 'bug']
filtered_entries = [entry for entry in data if entry.get('category') != 'bug']

# %%
# Save the entries with "category": "bug" to a separate file
output_path = os.path.join(root_dir, steam_title, "bugs.json")
save_to_json(bug_entries, output_path)

output_path = os.path.join(root_dir, steam_title, "no_bugs.json")
# Save the filtered JSON back to the original file or a new file
save_to_json(filtered_entries, output_path)
# Out:
# 2024-12-04 12:17:25,345 - INFO - Data successfully saved to C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\Steamapps\Days Gone\bugs.json
# 2024-12-04 12:17:33,747 - INFO - Data successfully saved to C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\Steamapps\Days Gone\no_bugs.json

# %%
len(bug_entries)
# Out:
# 0

# %% [markdown]
# # Cluster Analysis

# %%
# Adjustable parameters
dimensionality_methods = ['UMAP', 'tSNE']
hdbscan_params = {"min_cluster_size": 50, "min_samples": 30, "cluster_selection_epsilon": 0.2}

# Load data
input_path = os.path.join(root_dir, steam_title, "no_bugs.json")
df_total = load_embedded_data(input_path)
mat = np.array(df_total['embedding'].tolist())

# Apply HDBSCAN
df_total = apply_hdbscan(
    df_total,
    mat,
    dimensionality_methods,
    hdbscan_params=hdbscan_params,
    include_2d=True,
    include_3d=True
)

output_path = path_db_clustered = os.path.join(root_dir, steam_title, "no_bugs.json")
# Save results
save_df_as_json(df_total, output_path)
logger.info(f"Results saved to {output_path}")

# how many unique cluster ids are in the data?
length = len(df_total['hdbscan_UMAP_2D'].unique())
print(f'Number of unique clusters: {length}')
# Out:
# 2024-12-04 13:23:21,545 - INFO - Loading data from C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\Steamapps\Days Gone\no_bugs.json
# 2024-12-04 13:23:27,481 - INFO - Loaded 13091 valid entries with embeddings.
# 2024-12-04 13:23:27,886 - INFO - Applying HDBSCAN in the original high-dimensional space with params: {'min_cluster_size': 50, 'min_samples': 30, 'cluster_selection_epsilon': 0.2}
# 2024-12-04 13:24:51,641 - INFO - Applying UMAP for 2D visualization.
# 2024-12-04 13:24:51,643 - INFO - Applying UMAP with 2 components.
# C:\Users\fbohm\Documents\Venvironments\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# 2024-12-04 13:25:11,421 - INFO - Applying UMAP for 3D visualization.
# 2024-12-04 13:25:11,423 - INFO - Applying UMAP with 3 components.
# C:\Users\fbohm\Documents\Venvironments\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# 2024-12-04 13:25:30,270 - INFO - Applying tSNE for 2D visualization.
# 2024-12-04 13:25:30,271 - INFO - Applying tSNE with 2 components.
# 2024-12-04 13:25:30,271 - INFO - Perplexity not provided, setting to 30 based on sample size.
# 2024-12-04 13:26:26,232 - INFO - Applying tSNE for 3D visualization.
# 2024-12-04 13:26:26,233 - INFO - Applying tSNE with 3 components.
# 2024-12-04 13:26:26,234 - INFO - Perplexity not provided, setting to 30 based on sample size.
# 2024-12-04 13:28:36,468 - INFO - HDBSCAN clustering and dimensionality reduction completed.
# 2024-12-04 13:28:36,474 - INFO - Saving data to C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\Steamapps\Days Gone\no_bugs.json
# C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\helper\utils.py:81: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   data = data.to_dict(orient="records")
# 2024-12-04 13:28:47,338 - INFO - Results saved to C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\Steamapps\Days Gone\no_bugs.json
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15552\3292684919.py in ?()
#      22 save_df_as_json(df_total, output_path)
#      23 logger.info(f"Results saved to {output_path}")
#      24
#      25 # how many unique cluster ids are in the data?
# ---> 26 length = len(df_total['hdbscan_UMAP_2D'].unique())
#      27 print(f'Number of unique clusters: {length}')
#
# ~\Documents\Venvironments\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
length = len(df_total['hdbscan_UMAP_2D'].unique())
length
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15552\1584187010.py in ?()
# ----> 1 length = len(df_total['hdbscan_UMAP_2D'].unique())
#       2 length
#
# ~\Documents\Venvironments\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %% [markdown]
# # Improve HDBSCAN
# ##### - Reduce the sample size
# ##### - build a sklearn loop to optimize the hdbscan parameters
# ##### -  benchmark: reduce noise (smaller Unknown cluster) and improve cluster assignment (big topics are not split while preserving small topics)

# %%
# Sample paths
sample_db_embedded = os.path.join(root_dir, steam_title, "sample_db_embedded.json")
sample_db_clustered = os.path.join(root_dir, steam_title, "sample_db_clustered.json")

# %%
# Get a random sample
n = 400
seed = 42
df_total = load_embedded_data(path_db_embedded)
df_sample = df_total.sample(n, random_state=seed)

# Save the sample
save_df_as_json(df_sample, sample_db_embedded)
len(df_sample)
# Out:
# 2024-12-12 09:01:41,745 - INFO - Loading data from C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\Steamapps\Market\db_embedded.json
# 2024-12-12 09:01:45,307 - INFO - Loaded 7168 valid entries with embeddings.
# 2024-12-12 09:01:45,319 - INFO - Saving data to C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\Steamapps\Market\sample_db_embedded.json
# 400

# %%
# Build matrix
from sklearn.model_selection import ParameterGrid

param_grid = {
    'min_cluster_size': [3, 5, 7, 10, 15],
    'min_samples': [1, 2, 3, 4, 5, 7, 10],
    'cluster_selection_epsilon': [0.1, 0.3, 0.5, 0.7, 0.9]
}
grid = ParameterGrid(param_grid)

# %%
sample_df = read_json(sample_db_embedded)

# %%
sampled_mat = np.array([entry['embedding'] for entry in sample_df])

# %%
# Reduce dimensions

# Step 3: Reduce Dimensionality with UMAP
# Reduce the original 3075 dimensions to 20 dimensions
reducer = umap.UMAP(n_components=20, random_state=42)
mat_reduced = reducer.fit_transform(sampled_mat)
# Out:
# C:\Users\fbohm\Documents\Venvironments\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %%
mat_reduced.shape
# Out:
# (400, 20)

# %%
# Build matrix
from sklearn.model_selection import ParameterGrid

param_grid = {
    'min_cluster_size': [3, 5, 7, 10, 15],
    'min_samples': [1, 2, 3, 4, 5, 7, 10],
    'cluster_selection_epsilon': [0.1, 0.3, 0.5, 0.7, 0.9]
}
grid = ParameterGrid(param_grid)

# %%
# Step 4: Define Hyperparameter Grid
param_grid = {
    'min_cluster_size': [5, 10, 15, 20],
    'min_samples': [1, 5, 10],
    'cluster_selection_epsilon': [0.1, 0.3, 0.5, 0.7]
}
grid = ParameterGrid(param_grid)

# Step 5: Apply HDBSCAN to Each Parameter Combination and Evaluate Results
results = []

for params in grid:
    clusterer = hdbscan.HDBSCAN(
        min_cluster_size=params['min_cluster_size'],
        min_samples=params['min_samples'],
        cluster_selection_epsilon=params['cluster_selection_epsilon']
    )
    labels = clusterer.fit_predict(mat_reduced)
    #print(labels)

    # Number of clusters (excluding noise, which is labeled as -1)
    n_clusters = len(set(labels)) - (1 if -1 in labels else 0)
    # Proportion of noise points
    noise_ratio = sum(labels == -1) / len(labels)

    # Store the results for analysis
    results.append({
        'params': params,
        'n_clusters': n_clusters,
        'noise_ratio': noise_ratio
    })

# Convert results to DataFrame for easier analysis
results_df = pd.DataFrame(results)

# %%
# Step 6: Analyze the Results
# Sort by noise ratio (ascending) and number of clusters (descending)
optimal_results = results_df.sort_values(by=['noise_ratio', 'n_clusters'], ascending=[True, False])
print(optimal_results)  # Print the top parameter combinations
# Out:
#                                                params  n_clusters  noise_ratio
# 36  {'cluster_selection_epsilon': 0.7, 'min_cluste...          15       0.0125
# 24  {'cluster_selection_epsilon': 0.5, 'min_cluste...          22       0.0375
# 37  {'cluster_selection_epsilon': 0.7, 'min_cluste...          13       0.0525
# 12  {'cluster_selection_epsilon': 0.3, 'min_cluste...          33       0.0675
# 0   {'cluster_selection_epsilon': 0.1, 'min_cluste...          36       0.0900
# 39  {'cluster_selection_epsilon': 0.7, 'min_cluste...          10       0.0975
# 40  {'cluster_selection_epsilon': 0.7, 'min_cluste...          10       0.1125
# 25  {'cluster_selection_epsilon': 0.5, 'min_cluste...          21       0.1175
# 10  {'cluster_selection_epsilon': 0.1, 'min_cluste...           3       0.1175
# 22  {'cluster_selection_epsilon': 0.3, 'min_cluste...           3       0.1175
# 34  {'cluster_selection_epsilon': 0.5, 'min_cluste...           3       0.1175
# 46  {'cluster_selection_epsilon': 0.7, 'min_cluste...           3       0.1175
# 27  {'cluster_selection_epsilon': 0.5, 'min_cluste...          15       0.1225
# 7   {'cluster_selection_epsilon': 0.1, 'min_cluste...           6       0.1250
# 19  {'cluster_selection_epsilon': 0.3, 'min_cluste...           6       0.1250
# 31  {'cluster_selection_epsilon': 0.5, 'min_cluste...           6       0.1250
# 43  {'cluster_selection_epsilon': 0.7, 'min_cluste...           6       0.1250
# 3   {'cluster_selection_epsilon': 0.1, 'min_cluste...          18       0.1525
# 15  {'cluster_selection_epsilon': 0.3, 'min_cluste...          18       0.1525
# 42  {'cluster_selection_epsilon': 0.7, 'min_cluste...           7       0.1525
# 9   {'cluster_selection_epsilon': 0.1, 'min_cluste...           4       0.1725
# 21  {'cluster_selection_epsilon': 0.3, 'min_cluste...           4       0.1725
# 33  {'cluster_selection_epsilon': 0.5, 'min_cluste...           4       0.1725
# 45  {'cluster_selection_epsilon': 0.7, 'min_cluste...           4       0.1725
# 1   {'cluster_selection_epsilon': 0.1, 'min_cluste...          25       0.1775
# 13  {'cluster_selection_epsilon': 0.3, 'min_cluste...          25       0.1775
# 28  {'cluster_selection_epsilon': 0.5, 'min_cluste...          18       0.1775
# 6   {'cluster_selection_epsilon': 0.1, 'min_cluste...          11       0.1775
# 18  {'cluster_selection_epsilon': 0.3, 'min_cluste...          11       0.1775
# 30  {'cluster_selection_epsilon': 0.5, 'min_cluste...          11       0.1775
# 5   {'cluster_selection_epsilon': 0.1, 'min_cluste...           7       0.1775
# 8   {'cluster_selection_epsilon': 0.1, 'min_cluste...           7       0.1775
# 17  {'cluster_selection_epsilon': 0.3, 'min_cluste...           7       0.1775
# 20  {'cluster_selection_epsilon': 0.3, 'min_cluste...           7       0.1775
# 29  {'cluster_selection_epsilon': 0.5, 'min_cluste...           7       0.1775
# 32  {'cluster_selection_epsilon': 0.5, 'min_cluste...           7       0.1775
# 41  {'cluster_selection_epsilon': 0.7, 'min_cluste...           7       0.1775
# 44  {'cluster_selection_epsilon': 0.7, 'min_cluste...           7       0.1775
# 2   {'cluster_selection_epsilon': 0.1, 'min_cluste...           9       0.1825
# 14  {'cluster_selection_epsilon': 0.3, 'min_cluste...           9       0.1825
# 26  {'cluster_selection_epsilon': 0.5, 'min_cluste...           9       0.1825
# 38  {'cluster_selection_epsilon': 0.7, 'min_cluste...           8       0.1825
# 4   {'cluster_selection_epsilon': 0.1, 'min_cluste...          19       0.1900
# 16  {'cluster_selection_epsilon': 0.3, 'min_cluste...          19       0.1900
# 11  {'cluster_selection_epsilon': 0.1, 'min_cluste...           4       0.2075
# 23  {'cluster_selection_epsilon': 0.3, 'min_cluste...           4       0.2075
# 35  {'cluster_selection_epsilon': 0.5, 'min_cluste...           4       0.2075
# 47  {'cluster_selection_epsilon': 0.7, 'min_cluste...           4       0.2075

# %%
# Step 7: Choose Optimal Parameters and Apply to Full Dataset
# Assuming the optimal parameters are in the first row of optimal_results
best_params = optimal_results.iloc[0]
print(f"Best Parameters: {best_params}")
# Out:
# Best Parameters: params         {'cluster_selection_epsilon': 0.7, 'min_cluste...
# n_clusters                                                    15
# noise_ratio                                               0.0125
# Name: 36, dtype: object

# %%
# Adjustable parameters
dimensionality_methods = ['UMAP','PCA', 'tSNE']
hdbscan_params = {"min_cluster_size": 5, "min_samples": 1, "cluster_selection_epsilon": 0.7}

# Load data
df_total = load_embedded_data(sample_db_embedded)
mat = np.array(df_total['embedding'].tolist())

# Apply HDBSCAN
df_total = apply_hdbscan(
    df_total,
    mat_reduced,
    dimensionality_methods,
    hdbscan_params=hdbscan_params,
    include_2d=True,
    include_3d=True
)

# Save results
save_df_as_json(df_total, sample_db_clustered)
logger.info(f"Results saved to {sample_db_clustered}")

# how many unique cluster ids are in the data?
length = len(df_total['hdbscan_UMAP_2D'].unique())
print(f'Number of unique clusters: {length}')

# %% [markdown]
# # Clustering

# %%
db_embedded = read_json(path_db_embedded)
mat = np.array([entry['embedding'] for entry in db_embedded])

# Reduce the original 3075 dimensions to 20 dimensions
reducer = umap.UMAP(n_components=20, random_state=42)
mat_reduced = reducer.fit_transform(mat)
# Out:
# C:\Users\fbohm\Documents\Venvironments\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %%
# Adjustable parameters
dimensionality_methods = ['UMAP','PCA', 'tSNE']
hdbscan_params = {"min_cluster_size": 10, "min_samples": 6, "cluster_selection_epsilon": 0.4}

# Load data
df_total = load_embedded_data(path_db_embedded)
mat = np.array(df_total['embedding'].tolist())

# Apply HDBSCAN
df_total = apply_hdbscan(
    df_total,
    mat,
    dimensionality_methods,
    hdbscan_params=hdbscan_params,
    include_2d=True,
    include_3d=True
)

# Save results
save_df_as_json(df_total, path_db_clustered)
logger.info(f"Results saved to {path_db_clustered}")

# how many unique cluster ids are in the data?
length = len(df_total['hdbscan_UMAP_2D'].unique())
print(f'Number of unique clusters: {length}')
# Out:
# 2024-12-13 09:15:57,500 - INFO - Loading data from C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\Steamapps\Market\db_embedded.json
# 2024-12-13 09:16:00,215 - INFO - Loaded 7168 valid entries with embeddings.
# 2024-12-13 09:16:00,356 - INFO - Applying HDBSCAN in the original high-dimensional space with params: {'min_cluster_size': 10, 'min_samples': 6, 'cluster_selection_epsilon': 0.4}
# 2024-12-13 09:16:24,697 - INFO - Applying UMAP for 2D visualization.
# 2024-12-13 09:16:24,697 - INFO - Applying UMAP with 2 components.
# C:\Users\fbohm\Documents\Venvironments\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# 2024-12-13 09:16:39,230 - INFO - Applying UMAP for 3D visualization.
# 2024-12-13 09:16:39,230 - INFO - Applying UMAP with 3 components.
# C:\Users\fbohm\Documents\Venvironments\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# 2024-12-13 09:16:54,508 - INFO - Applying PCA for 2D visualization.
# 2024-12-13 09:16:54,508 - INFO - Applying PCA with 2 components.
# 2024-12-13 09:16:54,642 - INFO - Applying PCA for 3D visualization.
# 2024-12-13 09:16:54,642 - INFO - Applying PCA with 3 components.
# 2024-12-13 09:16:54,766 - INFO - Applying tSNE for 2D visualization.
# 2024-12-13 09:16:54,766 - INFO - Applying tSNE with 2 components.
# 2024-12-13 09:16:54,766 - INFO - Perplexity not provided, setting to 30 based on sample size.
# 2024-12-13 09:17:24,531 - INFO - Applying tSNE for 3D visualization.
# 2024-12-13 09:17:24,531 - INFO - Applying tSNE with 3 components.
# 2024-12-13 09:17:24,531 - INFO - Perplexity not provided, setting to 30 based on sample size.
# 2024-12-13 09:18:35,769 - INFO - HDBSCAN clustering and dimensionality reduction completed.
# 2024-12-13 09:18:35,785 - INFO - Saving data to C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\Steamapps\Market\db_clustered.json
# 2024-12-13 09:18:40,661 - INFO - Results saved to C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\Steamapps\Market\db_clustered.json
# Number of unique clusters: 162

# %%
# Apply KMeans (if needed)
dimensionality_methods = ['UMAP', 'tSNE']
kmeans_clusters = [14, 35, 50]

df_total = load_embedded_data(path_db_clustered)
df_total = apply_kmeans(
    df_total,
    mat,
    dimensionality_methods,
    kmeans_clusters,
    include_2d=True,
    include_3d=True
)

# Save results
save_df_as_json(df_total, path_db_clustered)
logger.info(f"Results saved to {path_db_clustered}")
# Out:
# 2024-12-05 16:46:58,076 - INFO - Loading data from C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\Steamapps\Days Gone\db_clustered.json
# 2024-12-05 16:47:55,407 - INFO - Loaded 13767 valid entries with embeddings.
# 2024-12-05 16:47:58,663 - INFO - Applying KMeans with 14 clusters in high-dimensional space.
# 2024-12-05 16:48:03,127 - INFO - Applying UMAP in 2D.
# 2024-12-05 16:48:03,129 - INFO - Applying UMAP with 2 components.
# C:\Users\fbohm\Documents\Venvironments\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# 2024-12-05 16:48:16,022 - INFO - Applying UMAP in 3D.
# 2024-12-05 16:48:16,022 - INFO - Applying UMAP with 3 components.
# C:\Users\fbohm\Documents\Venvironments\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# 2024-12-05 16:48:28,508 - INFO - Applying tSNE in 2D.
# 2024-12-05 16:48:28,508 - INFO - Applying tSNE with 2 components.
# 2024-12-05 16:48:28,508 - INFO - Perplexity not provided, setting to 30 based on sample size.
# 2024-12-05 16:49:31,796 - INFO - Applying tSNE in 3D.
# 2024-12-05 16:49:31,796 - INFO - Applying tSNE with 3 components.
# 2024-12-05 16:49:31,798 - INFO - Perplexity not provided, setting to 30 based on sample size.
# 2024-12-05 16:51:52,369 - INFO - Applying KMeans with 35 clusters in high-dimensional space.
# 2024-12-05 16:51:56,496 - INFO - Applying UMAP in 2D.
# 2024-12-05 16:51:56,496 - INFO - Applying UMAP with 2 components.
# C:\Users\fbohm\Documents\Venvironments\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# 2024-12-05 16:52:09,208 - INFO - Applying UMAP in 3D.
# 2024-12-05 16:52:09,208 - INFO - Applying UMAP with 3 components.
# C:\Users\fbohm\Documents\Venvironments\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# 2024-12-05 16:52:23,285 - INFO - Applying tSNE in 2D.
# 2024-12-05 16:52:23,285 - INFO - Applying tSNE with 2 components.
# 2024-12-05 16:52:23,285 - INFO - Perplexity not provided, setting to 30 based on sample size.
# 2024-12-05 16:53:33,040 - INFO - Applying tSNE in 3D.
# 2024-12-05 16:53:33,042 - INFO - Applying tSNE with 3 components.
# 2024-12-05 16:53:33,042 - INFO - Perplexity not provided, setting to 30 based on sample size.
# 2024-12-05 16:56:04,713 - INFO - Applying KMeans with 50 clusters in high-dimensional space.
# 2024-12-05 16:56:10,980 - INFO - Applying UMAP in 2D.
# 2024-12-05 16:56:10,980 - INFO - Applying UMAP with 2 components.
# C:\Users\fbohm\Documents\Venvironments\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# 2024-12-05 16:56:23,858 - INFO - Applying UMAP in 3D.
# 2024-12-05 16:56:23,858 - INFO - Applying UMAP with 3 components.
# C:\Users\fbohm\Documents\Venvironments\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# 2024-12-05 16:56:36,754 - INFO - Applying tSNE in 2D.
# 2024-12-05 16:56:36,754 - INFO - Applying tSNE with 2 components.
# 2024-12-05 16:56:36,754 - INFO - Perplexity not provided, setting to 30 based on sample size.
# 2024-12-05 16:57:43,617 - INFO - Applying tSNE in 3D.
# 2024-12-05 16:57:43,618 - INFO - Applying tSNE with 3 components.
# 2024-12-05 16:57:43,619 - INFO - Perplexity not provided, setting to 30 based on sample size.
# 2024-12-05 17:00:05,026 - INFO - KMeans clustering and dimensionality reduction completed.
# 2024-12-05 17:00:05,026 - INFO - Saving data to C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\Steamapps\Days Gone\db_clustered.json
# 2024-12-05 17:01:11,949 - INFO - Results saved to C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\Steamapps\Days Gone\db_clustered.json

# %% [markdown]
# # Cluster naming

# %%
# Parameters
dimensionality_methods = ["UMAP",'PCA', "tSNE"]
clustering_algorithms = ["hdbscan"]  # No KMeans here
max_centers = 10

#kmeans_clusters = [15, 20, 25, 50]  # Number of clusters for KMeans

# Load data
df_total = load_json_into_df(path_db_clustered)

# Process clusters and generate names
df_total = process_clusters(
    df_total, 
    dimensionality_methods, 
    clustering_algorithms, 
    max_centers, 
    api_settings) # insert kmeans_clusters in the function when needed


# Save results
save_data_for_streamlit(df_total, path_db_final)
# Out:
# 2024-12-13 09:18:55,676 - INFO - Loading data from C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\Steamapps\Market\db_clustered.json
# 2024-12-13 09:18:57,213 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 99
# 2024-12-13 09:18:58,049 - INFO - Generated cluster name: Balanced Challenge Gaming Experience
# 2024-12-13 09:18:58,049 - INFO -  Tokens used so far: Prompt Tokens: 36303, Completion Tokens: 931
# 2024-12-13 09:18:58,049 - INFO - HDBSCAN Cluster ID 99 (UMAP 2D): Balanced Challenge Gaming Experience
# 2024-12-13 09:18:58,084 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 159
# 2024-12-13 09:18:58,621 - INFO - Generated cluster name: Gameplay Enjoyment vs. Frustration
# 2024-12-13 09:18:58,637 - INFO -  Tokens used so far: Prompt Tokens: 36485, Completion Tokens: 939
# 2024-12-13 09:18:58,637 - INFO - HDBSCAN Cluster ID 159 (UMAP 2D): Gameplay Enjoyment vs. Frustration
# 2024-12-13 09:18:58,669 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 120
# 2024-12-13 09:18:59,136 - INFO - Generated cluster name: Crafting Mechanics and Experiences
# 2024-12-13 09:18:59,141 - INFO -  Tokens used so far: Prompt Tokens: 36682, Completion Tokens: 944
# 2024-12-13 09:18:59,141 - INFO - HDBSCAN Cluster ID 120 (UMAP 2D): Crafting Mechanics and Experiences
# 2024-12-13 09:18:59,167 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 113
# 2024-12-13 09:18:59,728 - INFO - Generated cluster name: Fae Adventure Gameplay Experience
# 2024-12-13 09:18:59,728 - INFO -  Tokens used so far: Prompt Tokens: 36823, Completion Tokens: 949
# 2024-12-13 09:18:59,728 - INFO - HDBSCAN Cluster ID 113 (UMAP 2D): Fae Adventure Gameplay Experience
# 2024-12-13 09:18:59,747 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 137
# 2024-12-13 09:19:00,178 - INFO - Generated cluster name: Visual Appeal in Gaming
# 2024-12-13 09:19:00,178 - INFO -  Tokens used so far: Prompt Tokens: 36951, Completion Tokens: 953
# 2024-12-13 09:19:00,188 - INFO - HDBSCAN Cluster ID 137 (UMAP 2D): Visual Appeal in Gaming
# 2024-12-13 09:19:00,222 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 116
# 2024-12-13 09:19:00,713 - INFO - Generated cluster name: Base Building and Exploration Adventure
# 2024-12-13 09:19:00,715 - INFO -  Tokens used so far: Prompt Tokens: 37143, Completion Tokens: 958
# 2024-12-13 09:19:00,719 - INFO - HDBSCAN Cluster ID 116 (UMAP 2D): Base Building and Exploration Adventure
# 2024-12-13 09:19:00,738 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 20
# 2024-12-13 09:19:01,271 - INFO - Generated cluster name: Voice Acting Experience in Gaming
# 2024-12-13 09:19:01,271 - INFO -  Tokens used so far: Prompt Tokens: 37371, Completion Tokens: 963
# 2024-12-13 09:19:01,286 - INFO - HDBSCAN Cluster ID 20 (UMAP 2D): Voice Acting Experience in Gaming
# 2024-12-13 09:19:01,319 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 124
# 2024-12-13 09:19:01,938 - INFO - Generated cluster name: Enchanting and Unique Game Settings
# 2024-12-13 09:19:01,938 - INFO -  Tokens used so far: Prompt Tokens: 37542, Completion Tokens: 969
# 2024-12-13 09:19:01,938 - INFO - HDBSCAN Cluster ID 124 (UMAP 2D): Enchanting and Unique Game Settings
# 2024-12-13 09:19:01,944 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 21
# 2024-12-13 09:19:02,451 - INFO - Generated cluster name: Value and Pricing Opinions
# 2024-12-13 09:19:02,451 - INFO -  Tokens used so far: Prompt Tokens: 37768, Completion Tokens: 973
# 2024-12-13 09:19:02,451 - INFO - HDBSCAN Cluster ID 21 (UMAP 2D): Value and Pricing Opinions
# 2024-12-13 09:19:02,467 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 45
# 2024-12-13 09:19:02,927 - INFO - Generated cluster name: Developer-Community Engagement and Commitment
# 2024-12-13 09:19:02,927 - INFO -  Tokens used so far: Prompt Tokens: 37979, Completion Tokens: 979
# 2024-12-13 09:19:02,927 - INFO - HDBSCAN Cluster ID 45 (UMAP 2D): Developer-Community Engagement and Commitment
# 2024-12-13 09:19:02,942 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 142
# 2024-12-13 09:19:03,388 - INFO - Generated cluster name: Early Access Expectations and Realities
# 2024-12-13 09:19:03,389 - INFO -  Tokens used so far: Prompt Tokens: 38173, Completion Tokens: 985
# 2024-12-13 09:19:03,390 - INFO - HDBSCAN Cluster ID 142 (UMAP 2D): Early Access Expectations and Realities
# 2024-12-13 09:19:03,406 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 153
# 2024-12-13 09:19:03,836 - INFO - Generated cluster name: Game Improvement Insights
# 2024-12-13 09:19:03,839 - INFO -  Tokens used so far: Prompt Tokens: 38383, Completion Tokens: 988
# 2024-12-13 09:19:03,840 - INFO - HDBSCAN Cluster ID 153 (UMAP 2D): Game Improvement Insights
# 2024-12-13 09:19:03,859 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 129
# 2024-12-13 09:19:04,529 - INFO - Generated cluster name: Diverse Gameplay in Survival Games
# 2024-12-13 09:19:04,529 - INFO -  Tokens used so far: Prompt Tokens: 38585, Completion Tokens: 994
# 2024-12-13 09:19:04,529 - INFO - HDBSCAN Cluster ID 129 (UMAP 2D): Diverse Gameplay in Survival Games
# 2024-12-13 09:19:04,588 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 106
# 2024-12-13 09:19:05,251 - INFO - Generated cluster name: Combat Quality and Player Experience
# 2024-12-13 09:19:05,253 - INFO -  Tokens used so far: Prompt Tokens: 38709, Completion Tokens: 999
# 2024-12-13 09:19:05,253 - INFO - HDBSCAN Cluster ID 106 (UMAP 2D): Combat Quality and Player Experience
# 2024-12-13 09:19:05,263 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 50
# 2024-12-13 09:19:05,734 - INFO - Generated cluster name: Survival Game Recommendations and Reviews
# 2024-12-13 09:19:05,737 - INFO -  Tokens used so far: Prompt Tokens: 38922, Completion Tokens: 1005
# 2024-12-13 09:19:05,737 - INFO - HDBSCAN Cluster ID 50 (UMAP 2D): Survival Game Recommendations and Reviews
# 2024-12-13 09:19:05,748 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 90
# 2024-12-13 09:19:06,229 - INFO - Generated cluster name: Repetitive Gameplay Loops
# 2024-12-13 09:19:06,231 - INFO -  Tokens used so far: Prompt Tokens: 39184, Completion Tokens: 1011
# 2024-12-13 09:19:06,233 - INFO - HDBSCAN Cluster ID 90 (UMAP 2D): Repetitive Gameplay Loops
# 2024-12-13 09:19:06,243 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 54
# 2024-12-13 09:19:06,787 - INFO - Generated cluster name: Game Stability and Performance Feedback
# 2024-12-13 09:19:06,788 - INFO -  Tokens used so far: Prompt Tokens: 39397, Completion Tokens: 1016
# 2024-12-13 09:19:06,789 - INFO - HDBSCAN Cluster ID 54 (UMAP 2D): Game Stability and Performance Feedback
# 2024-12-13 09:19:06,789 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 139
# 2024-12-13 09:19:07,310 - INFO - Generated cluster name: Easy Multiplayer Fun with Friends
# 2024-12-13 09:19:07,310 - INFO -  Tokens used so far: Prompt Tokens: 39600, Completion Tokens: 1021
# 2024-12-13 09:19:07,310 - INFO - HDBSCAN Cluster ID 139 (UMAP 2D): Easy Multiplayer Fun with Friends
# 2024-12-13 09:19:07,310 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 117
# 2024-12-13 09:19:07,825 - INFO - Generated cluster name: Building Mechanics Experience
# 2024-12-13 09:19:07,825 - INFO -  Tokens used so far: Prompt Tokens: 39794, Completion Tokens: 1024
# 2024-12-13 09:19:07,834 - INFO - HDBSCAN Cluster ID 117 (UMAP 2D): Building Mechanics Experience
# 2024-12-13 09:19:07,863 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 49
# 2024-12-13 09:19:08,367 - INFO - Generated cluster name: Building Limitations and Frustrations
# 2024-12-13 09:19:08,368 - INFO -  Tokens used so far: Prompt Tokens: 40046, Completion Tokens: 1031
# 2024-12-13 09:19:08,368 - INFO - HDBSCAN Cluster ID 49 (UMAP 2D): Building Limitations and Frustrations
# 2024-12-13 09:19:08,378 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 158
# 2024-12-13 09:19:08,823 - INFO - Generated cluster name: Positive Game Enjoyment Feedback
# 2024-12-13 09:19:08,824 - INFO -  Tokens used so far: Prompt Tokens: 40191, Completion Tokens: 1036
# 2024-12-13 09:19:08,825 - INFO - HDBSCAN Cluster ID 158 (UMAP 2D): Positive Game Enjoyment Feedback
# 2024-12-13 09:19:08,840 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 150
# 2024-12-13 09:19:09,361 - INFO - Generated cluster name: Stunning Visuals in Gaming
# 2024-12-13 09:19:09,361 - INFO -  Tokens used so far: Prompt Tokens: 40327, Completion Tokens: 1042
# 2024-12-13 09:19:09,361 - INFO - HDBSCAN Cluster ID 150 (UMAP 2D): Stunning Visuals in Gaming
# 2024-12-13 09:19:09,381 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 34
# 2024-12-13 09:19:09,793 - INFO - Generated cluster name: Innovative Realm Creation Mechanics
# 2024-12-13 09:19:09,809 - INFO -  Tokens used so far: Prompt Tokens: 40558, Completion Tokens: 1047
# 2024-12-13 09:19:09,809 - INFO - HDBSCAN Cluster ID 34 (UMAP 2D): Innovative Realm Creation Mechanics
# 2024-12-13 09:19:09,853 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 126
# 2024-12-13 09:19:10,343 - INFO - Generated cluster name: Complex Yet Intuitive Crafting Systems
# 2024-12-13 09:19:10,345 - INFO -  Tokens used so far: Prompt Tokens: 40770, Completion Tokens: 1054
# 2024-12-13 09:19:10,348 - INFO - HDBSCAN Cluster ID 126 (UMAP 2D): Complex Yet Intuitive Crafting Systems
# 2024-12-13 09:19:10,375 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 12
# 2024-12-13 09:19:10,808 - INFO - Generated cluster name: Developer Community Engagement
# 2024-12-13 09:19:10,809 - INFO -  Tokens used so far: Prompt Tokens: 40959, Completion Tokens: 1057
# 2024-12-13 09:19:10,809 - INFO - HDBSCAN Cluster ID 12 (UMAP 2D): Developer Community Engagement
# 2024-12-13 09:19:10,809 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 115
# 2024-12-13 09:19:12,241 - INFO - Generated cluster name: Building System Feedback and Improvements
# 2024-12-13 09:19:12,243 - INFO -  Tokens used so far: Prompt Tokens: 41182, Completion Tokens: 1062
# 2024-12-13 09:19:12,251 - INFO - HDBSCAN Cluster ID 115 (UMAP 2D): Building System Feedback and Improvements
# 2024-12-13 09:19:12,274 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 155
# 2024-12-13 09:19:12,773 - INFO - Generated cluster name: Survival Crafting Game Experience
# 2024-12-13 09:19:12,776 - INFO -  Tokens used so far: Prompt Tokens: 41375, Completion Tokens: 1068
# 2024-12-13 09:19:12,776 - INFO - HDBSCAN Cluster ID 155 (UMAP 2D): Survival Crafting Game Experience
# 2024-12-13 09:19:12,802 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 93
# 2024-12-13 09:19:13,240 - INFO - Generated cluster name: Engaging Exploration Experiences
# 2024-12-13 09:19:13,240 - INFO -  Tokens used so far: Prompt Tokens: 41590, Completion Tokens: 1072
# 2024-12-13 09:19:13,241 - INFO - HDBSCAN Cluster ID 93 (UMAP 2D): Engaging Exploration Experiences
# 2024-12-13 09:19:13,243 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 125
# 2024-12-13 09:19:13,709 - INFO - Generated cluster name: Crafting and Building Enthusiasm
# 2024-12-13 09:19:13,709 - INFO -  Tokens used so far: Prompt Tokens: 41775, Completion Tokens: 1078
# 2024-12-13 09:19:13,709 - INFO - HDBSCAN Cluster ID 125 (UMAP 2D): Crafting and Building Enthusiasm
# 2024-12-13 09:19:13,724 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 35
# 2024-12-13 09:19:14,181 - INFO - Generated cluster name: Realms Rebuilt Impact on Gameplay
# 2024-12-13 09:19:14,182 - INFO -  Tokens used so far: Prompt Tokens: 41998, Completion Tokens: 1085
# 2024-12-13 09:19:14,183 - INFO - HDBSCAN Cluster ID 35 (UMAP 2D): Realms Rebuilt Impact on Gameplay
# 2024-12-13 09:19:14,196 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 157
# 2024-12-13 09:19:14,596 - INFO - Generated cluster name: Game Enjoyment and Recommendations
# 2024-12-13 09:19:14,598 - INFO -  Tokens used so far: Prompt Tokens: 42124, Completion Tokens: 1090
# 2024-12-13 09:19:14,599 - INFO - HDBSCAN Cluster ID 157 (UMAP 2D): Game Enjoyment and Recommendations
# 2024-12-13 09:19:14,609 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 11
# 2024-12-13 09:19:15,127 - INFO - Generated cluster name: Inventory Management Frustrations
# 2024-12-13 09:19:15,130 - INFO -  Tokens used so far: Prompt Tokens: 42379, Completion Tokens: 1095
# 2024-12-13 09:19:15,130 - INFO - HDBSCAN Cluster ID 11 (UMAP 2D): Inventory Management Frustrations
# 2024-12-13 09:19:15,166 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 28
# 2024-12-13 09:19:16,635 - INFO - Generated cluster name: "Enemy AI Critique and Suggestions"
# 2024-12-13 09:19:16,635 - INFO -  Tokens used so far: Prompt Tokens: 42575, Completion Tokens: 1103
# 2024-12-13 09:19:16,636 - INFO - HDBSCAN Cluster ID 28 (UMAP 2D): "Enemy AI Critique and Suggestions"
# 2024-12-13 09:19:16,644 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 95
# 2024-12-13 09:19:17,135 - INFO - Generated cluster name: Combat Experience Feedback
# 2024-12-13 09:19:17,135 - INFO -  Tokens used so far: Prompt Tokens: 42769, Completion Tokens: 1106
# 2024-12-13 09:19:17,136 - INFO - HDBSCAN Cluster ID 95 (UMAP 2D): Combat Experience Feedback
# 2024-12-13 09:19:17,146 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 82
# 2024-12-13 09:19:17,856 - INFO - Generated cluster name: Server Issues and Gameplay Woes
# 2024-12-13 09:19:17,859 - INFO -  Tokens used so far: Prompt Tokens: 42972, Completion Tokens: 1112
# 2024-12-13 09:19:17,862 - INFO - HDBSCAN Cluster ID 82 (UMAP 2D): Server Issues and Gameplay Woes
# 2024-12-13 09:19:17,888 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 110
# 2024-12-13 09:19:18,410 - INFO - Generated cluster name: Survival Crafting Game Insights
# 2024-12-13 09:19:18,413 - INFO -  Tokens used so far: Prompt Tokens: 43188, Completion Tokens: 1118
# 2024-12-13 09:19:18,416 - INFO - HDBSCAN Cluster ID 110 (UMAP 2D): Survival Crafting Game Insights
# 2024-12-13 09:19:18,451 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 57
# 2024-12-13 09:19:18,926 - INFO - Generated cluster name: Graphic Quality Assessment
# 2024-12-13 09:19:18,927 - INFO -  Tokens used so far: Prompt Tokens: 43371, Completion Tokens: 1121
# 2024-12-13 09:19:18,927 - INFO - HDBSCAN Cluster ID 57 (UMAP 2D): Graphic Quality Assessment
# 2024-12-13 09:19:18,934 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 149
# 2024-12-13 09:19:19,481 - INFO - Generated cluster name: Stunning Game Visuals and Aesthetics
# 2024-12-13 09:19:19,481 - INFO -  Tokens used so far: Prompt Tokens: 43541, Completion Tokens: 1130
# 2024-12-13 09:19:19,483 - INFO - HDBSCAN Cluster ID 149 (UMAP 2D): Stunning Game Visuals and Aesthetics
# 2024-12-13 09:19:19,495 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 88
# 2024-12-13 09:19:19,950 - INFO - Generated cluster name: Character Creation Opinions and Diversity
# 2024-12-13 09:19:19,951 - INFO -  Tokens used so far: Prompt Tokens: 43765, Completion Tokens: 1135
# 2024-12-13 09:19:19,952 - INFO - HDBSCAN Cluster ID 88 (UMAP 2D): Character Creation Opinions and Diversity
# 2024-12-13 09:19:19,969 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 107
# 2024-12-13 09:19:20,414 - INFO - Generated cluster name: Combat Feedback and Mechanics Evaluation
# 2024-12-13 09:19:20,416 - INFO -  Tokens used so far: Prompt Tokens: 44025, Completion Tokens: 1140
# 2024-12-13 09:19:20,418 - INFO - HDBSCAN Cluster ID 107 (UMAP 2D): Combat Feedback and Mechanics Evaluation
# 2024-12-13 09:19:20,466 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 80
# 2024-12-13 09:19:20,944 - INFO - Generated cluster name: Always Online Gameplay Frustrations
# 2024-12-13 09:19:20,944 - INFO -  Tokens used so far: Prompt Tokens: 44301, Completion Tokens: 1146
# 2024-12-13 09:19:20,944 - INFO - HDBSCAN Cluster ID 80 (UMAP 2D): Always Online Gameplay Frustrations
# 2024-12-13 09:19:20,961 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 96
# 2024-12-13 09:19:21,435 - INFO - Generated cluster name: Complex Crafting Mechanics in Games
# 2024-12-13 09:19:21,439 - INFO -  Tokens used so far: Prompt Tokens: 44538, Completion Tokens: 1152
# 2024-12-13 09:19:21,439 - INFO - HDBSCAN Cluster ID 96 (UMAP 2D): Complex Crafting Mechanics in Games
# 2024-12-13 09:19:21,464 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 132
# 2024-12-13 09:19:22,073 - INFO - Generated cluster name: Aesthetic Appeal of Gaming
# 2024-12-13 09:19:22,073 - INFO -  Tokens used so far: Prompt Tokens: 44682, Completion Tokens: 1157
# 2024-12-13 09:19:22,073 - INFO - HDBSCAN Cluster ID 132 (UMAP 2D): Aesthetic Appeal of Gaming
# 2024-12-13 09:19:22,081 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 6
# 2024-12-13 09:19:22,550 - INFO - Generated cluster name: Menu Navigation Challenges
# 2024-12-13 09:19:22,550 - INFO -  Tokens used so far: Prompt Tokens: 44937, Completion Tokens: 1160
# 2024-12-13 09:19:22,551 - INFO - HDBSCAN Cluster ID 6 (UMAP 2D): Menu Navigation Challenges
# 2024-12-13 09:19:22,568 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 92
# 2024-12-13 09:19:23,077 - INFO - Generated cluster name: Anticipation and Disappointment in Gaming
# 2024-12-13 09:19:23,079 - INFO -  Tokens used so far: Prompt Tokens: 45126, Completion Tokens: 1168
# 2024-12-13 09:19:23,080 - INFO - HDBSCAN Cluster ID 92 (UMAP 2D): Anticipation and Disappointment in Gaming
# 2024-12-13 09:19:23,103 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 37
# 2024-12-13 09:19:23,617 - INFO - Generated cluster name: "Enjoyment in Gaming"
# 2024-12-13 09:19:23,617 - INFO -  Tokens used so far: Prompt Tokens: 45280, Completion Tokens: 1174
# 2024-12-13 09:19:23,626 - INFO - HDBSCAN Cluster ID 37 (UMAP 2D): "Enjoyment in Gaming"
# 2024-12-13 09:19:23,686 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 136
# 2024-12-13 09:19:24,094 - INFO - Generated cluster name: Early Access Bug Experiences
# 2024-12-13 09:19:24,109 - INFO -  Tokens used so far: Prompt Tokens: 45487, Completion Tokens: 1178
# 2024-12-13 09:19:24,111 - INFO - HDBSCAN Cluster ID 136 (UMAP 2D): Early Access Bug Experiences
# 2024-12-13 09:19:24,161 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 127
# 2024-12-13 09:19:24,693 - INFO - Generated cluster name: Anticipation for Future Updates
# 2024-12-13 09:19:24,693 - INFO -  Tokens used so far: Prompt Tokens: 45677, Completion Tokens: 1184
# 2024-12-13 09:19:24,693 - INFO - HDBSCAN Cluster ID 127 (UMAP 2D): Anticipation for Future Updates
# 2024-12-13 09:19:24,704 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 42
# 2024-12-13 09:19:25,293 - INFO - Generated cluster name: Devotion to Game Improvement
# 2024-12-13 09:19:25,293 - INFO -  Tokens used so far: Prompt Tokens: 45917, Completion Tokens: 1189
# 2024-12-13 09:19:25,308 - INFO - HDBSCAN Cluster ID 42 (UMAP 2D): Devotion to Game Improvement
# 2024-12-13 09:19:25,317 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 84
# 2024-12-13 09:19:25,909 - INFO - Generated cluster name: Engagement vs. Boredom in Gaming
# 2024-12-13 09:19:25,909 - INFO -  Tokens used so far: Prompt Tokens: 46119, Completion Tokens: 1198
# 2024-12-13 09:19:25,909 - INFO - HDBSCAN Cluster ID 84 (UMAP 2D): Engagement vs. Boredom in Gaming
# 2024-12-13 09:19:25,921 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 111
# 2024-12-13 09:19:26,404 - INFO - Generated cluster name: Narrative-Driven Survival Mechanics
# 2024-12-13 09:19:26,404 - INFO -  Tokens used so far: Prompt Tokens: 46326, Completion Tokens: 1204
# 2024-12-13 09:19:26,404 - INFO - HDBSCAN Cluster ID 111 (UMAP 2D): Narrative-Driven Survival Mechanics
# 2024-12-13 09:19:26,421 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 160
# 2024-12-13 09:19:26,872 - INFO - Generated cluster name: Game Experience Evaluations
# 2024-12-13 09:19:26,873 - INFO -  Tokens used so far: Prompt Tokens: 46492, Completion Tokens: 1208
# 2024-12-13 09:19:26,874 - INFO - HDBSCAN Cluster ID 160 (UMAP 2D): Game Experience Evaluations
# 2024-12-13 09:19:26,896 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 85
# 2024-12-13 09:19:27,478 - INFO - Generated cluster name: Immersive Lore and Storytelling
# 2024-12-13 09:19:27,478 - INFO -  Tokens used so far: Prompt Tokens: 46682, Completion Tokens: 1215
# 2024-12-13 09:19:27,479 - INFO - HDBSCAN Cluster ID 85 (UMAP 2D): Immersive Lore and Storytelling
# 2024-12-13 09:19:27,488 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 100
# 2024-12-13 09:19:27,967 - INFO - Generated cluster name: Combat Difficulty and Mechanics Feedback
# 2024-12-13 09:19:27,967 - INFO -  Tokens used so far: Prompt Tokens: 46901, Completion Tokens: 1220
# 2024-12-13 09:19:27,968 - INFO - HDBSCAN Cluster ID 100 (UMAP 2D): Combat Difficulty and Mechanics Feedback
# 2024-12-13 09:19:27,978 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 73
# 2024-12-13 09:19:28,377 - INFO - Generated cluster name: First Impressions of Gaming Experiences
# 2024-12-13 09:19:28,377 - INFO -  Tokens used so far: Prompt Tokens: 47099, Completion Tokens: 1226
# 2024-12-13 09:19:28,377 - INFO - HDBSCAN Cluster ID 73 (UMAP 2D): First Impressions of Gaming Experiences
# 2024-12-13 09:19:28,395 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 121
# 2024-12-13 09:19:28,823 - INFO - Generated cluster name: Game Depth and Engagement Perspectives
# 2024-12-13 09:19:28,826 - INFO -  Tokens used so far: Prompt Tokens: 47314, Completion Tokens: 1231
# 2024-12-13 09:19:28,827 - INFO - HDBSCAN Cluster ID 121 (UMAP 2D): Game Depth and Engagement Perspectives
# 2024-12-13 09:19:28,843 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 72
# 2024-12-13 09:19:29,257 - INFO - Generated cluster name: Online-Only Game Reception Analysis
# 2024-12-13 09:19:29,257 - INFO -  Tokens used so far: Prompt Tokens: 47526, Completion Tokens: 1237
# 2024-12-13 09:19:29,273 - INFO - HDBSCAN Cluster ID 72 (UMAP 2D): Online-Only Game Reception Analysis
# 2024-12-13 09:19:29,300 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 39
# 2024-12-13 09:19:29,728 - INFO - Generated cluster name: Limited Enemy Variety and Design
# 2024-12-13 09:19:29,728 - INFO -  Tokens used so far: Prompt Tokens: 47748, Completion Tokens: 1242
# 2024-12-13 09:19:29,733 - INFO - HDBSCAN Cluster ID 39 (UMAP 2D): Limited Enemy Variety and Design
# 2024-12-13 09:19:29,743 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 140
# 2024-12-13 09:19:30,425 - INFO - Generated cluster name: Survival Game Comparisons and Critiques
# 2024-12-13 09:19:30,426 - INFO -  Tokens used so far: Prompt Tokens: 47981, Completion Tokens: 1250
# 2024-12-13 09:19:30,426 - INFO - HDBSCAN Cluster ID 140 (UMAP 2D): Survival Game Comparisons and Critiques
# 2024-12-13 09:19:30,444 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 52
# 2024-12-13 09:19:31,102 - INFO - Generated cluster name: Game Recommendations and Evaluations
# 2024-12-13 09:19:31,109 - INFO -  Tokens used so far: Prompt Tokens: 48175, Completion Tokens: 1255
# 2024-12-13 09:19:31,112 - INFO - HDBSCAN Cluster ID 52 (UMAP 2D): Game Recommendations and Evaluations
# 2024-12-13 09:19:31,148 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 138
# 2024-12-13 09:19:31,617 - INFO - Generated cluster name: Early Access Player Experiences
# 2024-12-13 09:19:31,619 - INFO -  Tokens used so far: Prompt Tokens: 48401, Completion Tokens: 1259
# 2024-12-13 09:19:31,619 - INFO - HDBSCAN Cluster ID 138 (UMAP 2D): Early Access Player Experiences
# 2024-12-13 09:19:31,678 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 46
# 2024-12-13 09:19:32,805 - INFO - Generated cluster name: Dedicated Game Developer Support
# 2024-12-13 09:19:32,811 - INFO -  Tokens used so far: Prompt Tokens: 48588, Completion Tokens: 1263
# 2024-12-13 09:19:32,811 - INFO - HDBSCAN Cluster ID 46 (UMAP 2D): Dedicated Game Developer Support
# 2024-12-13 09:19:32,862 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 64
# 2024-12-13 09:19:33,276 - INFO - Generated cluster name: Game Optimization Issues
# 2024-12-13 09:19:33,293 - INFO -  Tokens used so far: Prompt Tokens: 48744, Completion Tokens: 1266
# 2024-12-13 09:19:33,295 - INFO - HDBSCAN Cluster ID 64 (UMAP 2D): Game Optimization Issues
# 2024-12-13 09:19:33,311 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 141
# 2024-12-13 09:19:33,860 - INFO - Generated cluster name: Fantasy Survival Game Mashups
# 2024-12-13 09:19:33,860 - INFO -  Tokens used so far: Prompt Tokens: 48950, Completion Tokens: 1271
# 2024-12-13 09:19:33,860 - INFO - HDBSCAN Cluster ID 141 (UMAP 2D): Fantasy Survival Game Mashups
# 2024-12-13 09:19:33,876 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 51
# 2024-12-13 09:19:34,343 - INFO - Generated cluster name: Game Recommendation Enthusiasm
# 2024-12-13 09:19:34,344 - INFO -  Tokens used so far: Prompt Tokens: 49107, Completion Tokens: 1275
# 2024-12-13 09:19:34,344 - INFO - HDBSCAN Cluster ID 51 (UMAP 2D): Game Recommendation Enthusiasm
# 2024-12-13 09:19:34,400 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 68
# 2024-12-13 09:19:34,854 - INFO - Generated cluster name: Early Access Bug Reports
# 2024-12-13 09:19:34,856 - INFO -  Tokens used so far: Prompt Tokens: 49269, Completion Tokens: 1279
# 2024-12-13 09:19:34,859 - INFO - HDBSCAN Cluster ID 68 (UMAP 2D): Early Access Bug Reports
# 2024-12-13 09:19:34,898 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 89
# 2024-12-13 09:19:35,802 - INFO - Generated cluster name: "Promising Yet Underwhelming Games"
# 2024-12-13 09:19:35,803 - INFO -  Tokens used so far: Prompt Tokens: 49446, Completion Tokens: 1288
# 2024-12-13 09:19:35,804 - INFO - HDBSCAN Cluster ID 89 (UMAP 2D): "Promising Yet Underwhelming Games"
# 2024-12-13 09:19:35,817 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 29
# 2024-12-13 09:19:41,231 - INFO - Generated cluster name: Companion AI Critiques and Frustrations
# 2024-12-13 09:19:41,232 - INFO -  Tokens used so far: Prompt Tokens: 49676, Completion Tokens: 1297
# 2024-12-13 09:19:41,233 - INFO - HDBSCAN Cluster ID 29 (UMAP 2D): Companion AI Critiques and Frustrations
# 2024-12-13 09:19:41,242 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 97
# 2024-12-13 09:19:41,745 - INFO - Generated cluster name: Progression Systems in Gaming
# 2024-12-13 09:19:41,745 - INFO -  Tokens used so far: Prompt Tokens: 49894, Completion Tokens: 1302
# 2024-12-13 09:19:41,745 - INFO - HDBSCAN Cluster ID 97 (UMAP 2D): Progression Systems in Gaming
# 2024-12-13 09:19:41,773 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 69
# 2024-12-13 09:19:42,308 - INFO - Generated cluster name: Offline Mode Development and Reception
# 2024-12-13 09:19:42,308 - INFO -  Tokens used so far: Prompt Tokens: 50093, Completion Tokens: 1307
# 2024-12-13 09:19:42,308 - INFO - HDBSCAN Cluster ID 69 (UMAP 2D): Offline Mode Development and Reception
# 2024-12-13 09:19:42,352 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 47
# 2024-12-13 09:19:42,893 - INFO - Generated cluster name: Frustrations with Game Tutorials
# 2024-12-13 09:19:42,893 - INFO -  Tokens used so far: Prompt Tokens: 50353, Completion Tokens: 1313
# 2024-12-13 09:19:42,893 - INFO - HDBSCAN Cluster ID 47 (UMAP 2D): Frustrations with Game Tutorials
# 2024-12-13 09:19:42,915 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 18
# 2024-12-13 09:19:43,508 - INFO - Generated cluster name: PvE Focus Overlooked PvP Potential
# 2024-12-13 09:19:43,509 - INFO -  Tokens used so far: Prompt Tokens: 50557, Completion Tokens: 1322
# 2024-12-13 09:19:43,509 - INFO - HDBSCAN Cluster ID 18 (UMAP 2D): PvE Focus Overlooked PvP Potential
# 2024-12-13 09:19:43,525 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 43
# 2024-12-13 09:19:43,985 - INFO - Generated cluster name: Lag and Connectivity Issues
# 2024-12-13 09:19:43,986 - INFO -  Tokens used so far: Prompt Tokens: 50737, Completion Tokens: 1326
# 2024-12-13 09:19:43,986 - INFO - HDBSCAN Cluster ID 43 (UMAP 2D): Lag and Connectivity Issues
# 2024-12-13 09:19:43,996 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 44
# 2024-12-13 09:19:44,584 - INFO - Generated cluster name: Poor User Interface Design
# 2024-12-13 09:19:44,594 - INFO -  Tokens used so far: Prompt Tokens: 50910, Completion Tokens: 1330
# 2024-12-13 09:19:44,597 - INFO - HDBSCAN Cluster ID 44 (UMAP 2D): Poor User Interface Design
# 2024-12-13 09:19:44,607 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 119
# 2024-12-13 09:19:45,134 - INFO - Generated cluster name: Future Improvement Anticipation
# 2024-12-13 09:19:45,137 - INFO -  Tokens used so far: Prompt Tokens: 51134, Completion Tokens: 1335
# 2024-12-13 09:19:45,139 - INFO - HDBSCAN Cluster ID 119 (UMAP 2D): Future Improvement Anticipation
# 2024-12-13 09:19:45,162 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 1
# 2024-12-13 09:19:45,701 - INFO - Generated cluster name: Refund Requests and Experiences
# 2024-12-13 09:19:45,702 - INFO -  Tokens used so far: Prompt Tokens: 51301, Completion Tokens: 1339
# 2024-12-13 09:19:45,702 - INFO - HDBSCAN Cluster ID 1 (UMAP 2D): Refund Requests and Experiences
# 2024-12-13 09:19:45,710 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 24
# 2024-12-13 09:19:46,232 - INFO - Generated cluster name: Value-Focused Gaming Experiences
# 2024-12-13 09:19:46,233 - INFO -  Tokens used so far: Prompt Tokens: 51552, Completion Tokens: 1344
# 2024-12-13 09:19:46,233 - INFO - HDBSCAN Cluster ID 24 (UMAP 2D): Value-Focused Gaming Experiences
# 2024-12-13 09:19:46,242 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 79
# 2024-12-13 09:19:46,727 - INFO - Generated cluster name: Online Only Gaming Frustrations
# 2024-12-13 09:19:46,727 - INFO -  Tokens used so far: Prompt Tokens: 51788, Completion Tokens: 1350
# 2024-12-13 09:19:46,727 - INFO - HDBSCAN Cluster ID 79 (UMAP 2D): Online Only Gaming Frustrations
# 2024-12-13 09:19:46,778 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 9
# 2024-12-13 09:19:47,414 - INFO - Generated cluster name: Quality of Life Enhancements Needed
# 2024-12-13 09:19:47,415 - INFO -  Tokens used so far: Prompt Tokens: 52004, Completion Tokens: 1356
# 2024-12-13 09:19:47,416 - INFO - HDBSCAN Cluster ID 9 (UMAP 2D): Quality of Life Enhancements Needed
# 2024-12-13 09:19:47,426 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 152
# 2024-12-13 09:19:47,821 - INFO - Generated cluster name: Game Quality Divergence
# 2024-12-13 09:19:47,822 - INFO -  Tokens used so far: Prompt Tokens: 52149, Completion Tokens: 1360
# 2024-12-13 09:19:47,822 - INFO - HDBSCAN Cluster ID 152 (UMAP 2D): Game Quality Divergence
# 2024-12-13 09:19:47,833 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 16
# 2024-12-13 09:19:48,310 - INFO - Generated cluster name: Early Access Critiques and Expectations
# 2024-12-13 09:19:48,310 - INFO -  Tokens used so far: Prompt Tokens: 52332, Completion Tokens: 1366
# 2024-12-13 09:19:48,310 - INFO - HDBSCAN Cluster ID 16 (UMAP 2D): Early Access Critiques and Expectations
# 2024-12-13 09:19:48,344 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 81
# 2024-12-13 09:19:49,323 - INFO - Generated cluster name: Anticipation for Future Game Improvements
# 2024-12-13 09:19:49,323 - INFO -  Tokens used so far: Prompt Tokens: 52508, Completion Tokens: 1373
# 2024-12-13 09:19:49,323 - INFO - HDBSCAN Cluster ID 81 (UMAP 2D): Anticipation for Future Game Improvements
# 2024-12-13 09:19:49,339 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 7
# 2024-12-13 09:19:49,775 - INFO - Generated cluster name: Map Design Quality and Variety
# 2024-12-13 09:19:49,775 - INFO -  Tokens used so far: Prompt Tokens: 52711, Completion Tokens: 1378
# 2024-12-13 09:19:49,791 - INFO - HDBSCAN Cluster ID 7 (UMAP 2D): Map Design Quality and Variety
# 2024-12-13 09:19:49,822 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 67
# 2024-12-13 09:19:50,296 - INFO - Generated cluster name: Game-Breaking Bugs in Early Access
# 2024-12-13 09:19:50,311 - INFO -  Tokens used so far: Prompt Tokens: 52928, Completion Tokens: 1386
# 2024-12-13 09:19:50,311 - INFO - HDBSCAN Cluster ID 67 (UMAP 2D): Game-Breaking Bugs in Early Access
# 2024-12-13 09:19:50,339 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 75
# 2024-12-13 09:19:50,873 - INFO - Generated cluster name: Engaging Story-Driven Game Experience
# 2024-12-13 09:19:50,889 - INFO -  Tokens used so far: Prompt Tokens: 53083, Completion Tokens: 1393
# 2024-12-13 09:19:50,889 - INFO - HDBSCAN Cluster ID 75 (UMAP 2D): Engaging Story-Driven Game Experience
# 2024-12-13 09:19:50,896 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 15
# 2024-12-13 09:19:51,360 - INFO - Generated cluster name: "Limited Biome Variation in Exploration"
# 2024-12-13 09:19:51,364 - INFO -  Tokens used so far: Prompt Tokens: 53317, Completion Tokens: 1401
# 2024-12-13 09:19:51,368 - INFO - HDBSCAN Cluster ID 15 (UMAP 2D): "Limited Biome Variation in Exploration"
# 2024-12-13 09:19:51,387 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 17
# 2024-12-13 09:19:56,875 - INFO - Generated cluster name: Constant Game Crashing Issues
# 2024-12-13 09:19:56,883 - INFO -  Tokens used so far: Prompt Tokens: 53515, Completion Tokens: 1406
# 2024-12-13 09:19:56,885 - INFO - HDBSCAN Cluster ID 17 (UMAP 2D): Constant Game Crashing Issues
# 2024-12-13 09:19:56,907 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 104
# 2024-12-13 09:19:57,453 - INFO - Generated cluster name: Game Progression Experiences
# 2024-12-13 09:19:57,453 - INFO -  Tokens used so far: Prompt Tokens: 53754, Completion Tokens: 1410
# 2024-12-13 09:19:57,453 - INFO - HDBSCAN Cluster ID 104 (UMAP 2D): Game Progression Experiences
# 2024-12-13 09:19:57,505 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 30
# 2024-12-13 09:19:57,985 - INFO - Generated cluster name: Boss Fight Quality Concerns
# 2024-12-13 09:19:57,987 - INFO -  Tokens used so far: Prompt Tokens: 53962, Completion Tokens: 1415
# 2024-12-13 09:19:57,988 - INFO - HDBSCAN Cluster ID 30 (UMAP 2D): Boss Fight Quality Concerns
# 2024-12-13 09:19:58,003 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 56
# 2024-12-13 09:19:58,472 - INFO - Generated cluster name: Puzzle Enjoyment and Frustration
# 2024-12-13 09:19:58,475 - INFO -  Tokens used so far: Prompt Tokens: 54127, Completion Tokens: 1422
# 2024-12-13 09:19:58,478 - INFO - HDBSCAN Cluster ID 56 (UMAP 2D): Puzzle Enjoyment and Frustration
# 2024-12-13 09:19:58,510 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 19
# 2024-12-13 09:20:00,648 - INFO - Generated cluster name: Gameplay Balance and Community Feedback
# 2024-12-13 09:20:00,653 - INFO -  Tokens used so far: Prompt Tokens: 54332, Completion Tokens: 1427
# 2024-12-13 09:20:00,656 - INFO - HDBSCAN Cluster ID 19 (UMAP 2D): Gameplay Balance and Community Feedback
# 2024-12-13 09:20:00,693 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 22
# 2024-12-13 09:20:01,210 - INFO - Generated cluster name: Value for Money Assessment
# 2024-12-13 09:20:01,210 - INFO -  Tokens used so far: Prompt Tokens: 54539, Completion Tokens: 1431
# 2024-12-13 09:20:01,210 - INFO - HDBSCAN Cluster ID 22 (UMAP 2D): Value for Money Assessment
# 2024-12-13 09:20:01,243 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 71
# 2024-12-13 09:20:01,699 - INFO - Generated cluster name: Offline Play Options Debate
# 2024-12-13 09:20:01,699 - INFO -  Tokens used so far: Prompt Tokens: 54748, Completion Tokens: 1435
# 2024-12-13 09:20:01,699 - INFO - HDBSCAN Cluster ID 71 (UMAP 2D): Offline Play Options Debate
# 2024-12-13 09:20:01,727 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 94
# 2024-12-13 09:20:02,209 - INFO - Generated cluster name: Grinding Game Experience
# 2024-12-13 09:20:02,211 - INFO -  Tokens used so far: Prompt Tokens: 54933, Completion Tokens: 1438
# 2024-12-13 09:20:02,211 - INFO - HDBSCAN Cluster ID 94 (UMAP 2D): Grinding Game Experience
# 2024-12-13 09:20:02,261 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 0
# 2024-12-13 09:20:02,959 - INFO - Generated cluster name: Stamina System Concerns and Frustrations
# 2024-12-13 09:20:02,962 - INFO -  Tokens used so far: Prompt Tokens: 55195, Completion Tokens: 1447
# 2024-12-13 09:20:02,962 - INFO - HDBSCAN Cluster ID 0 (UMAP 2D): Stamina System Concerns and Frustrations
# 2024-12-13 09:20:03,031 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 59
# 2024-12-13 09:20:03,629 - INFO - Generated cluster name: Early Access Game Quality Debate
# 2024-12-13 09:20:03,629 - INFO -  Tokens used so far: Prompt Tokens: 55388, Completion Tokens: 1452
# 2024-12-13 09:20:03,629 - INFO - HDBSCAN Cluster ID 59 (UMAP 2D): Early Access Game Quality Debate
# 2024-12-13 09:20:03,678 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 105
# 2024-12-13 09:20:04,193 - INFO - Generated cluster name: Endless Survival Game Engagement
# 2024-12-13 09:20:04,193 - INFO -  Tokens used so far: Prompt Tokens: 55591, Completion Tokens: 1457
# 2024-12-13 09:20:04,209 - INFO - HDBSCAN Cluster ID 105 (UMAP 2D): Endless Survival Game Engagement
# 2024-12-13 09:20:04,211 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 74
# 2024-12-13 09:20:04,712 - INFO - Generated cluster name: Game Development Anticipation and Improvement
# 2024-12-13 09:20:04,712 - INFO -  Tokens used so far: Prompt Tokens: 55792, Completion Tokens: 1464
# 2024-12-13 09:20:04,712 - INFO - HDBSCAN Cluster ID 74 (UMAP 2D): Game Development Anticipation and Improvement
# 2024-12-13 09:20:04,712 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 5
# 2024-12-13 09:20:06,043 - INFO - Generated cluster name: Defending the Game Against Criticism
# 2024-12-13 09:20:06,059 - INFO -  Tokens used so far: Prompt Tokens: 56018, Completion Tokens: 1471
# 2024-12-13 09:20:06,059 - INFO - HDBSCAN Cluster ID 5 (UMAP 2D): Defending the Game Against Criticism
# 2024-12-13 09:20:06,076 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 91
# 2024-12-13 09:20:06,460 - INFO - Generated cluster name: Game Quality Reviews
# 2024-12-13 09:20:06,460 - INFO -  Tokens used so far: Prompt Tokens: 56124, Completion Tokens: 1474
# 2024-12-13 09:20:06,460 - INFO - HDBSCAN Cluster ID 91 (UMAP 2D): Game Quality Reviews
# 2024-12-13 09:20:06,477 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 122
# 2024-12-13 09:20:06,926 - INFO - Generated cluster name: Complexity in Gaming Challenges
# 2024-12-13 09:20:06,927 - INFO -  Tokens used so far: Prompt Tokens: 56299, Completion Tokens: 1479
# 2024-12-13 09:20:06,927 - INFO - HDBSCAN Cluster ID 122 (UMAP 2D): Complexity in Gaming Challenges
# 2024-12-13 09:20:06,949 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 98
# 2024-12-13 09:20:07,377 - INFO - Generated cluster name: Gaming Time Commitment
# 2024-12-13 09:20:07,377 - INFO -  Tokens used so far: Prompt Tokens: 56512, Completion Tokens: 1482
# 2024-12-13 09:20:07,377 - INFO - HDBSCAN Cluster ID 98 (UMAP 2D): Gaming Time Commitment
# 2024-12-13 09:20:07,414 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 134
# 2024-12-13 09:20:07,944 - INFO - Generated cluster name: Vibrant Worlds and Engaging Exploration
# 2024-12-13 09:20:07,944 - INFO -  Tokens used so far: Prompt Tokens: 56682, Completion Tokens: 1490
# 2024-12-13 09:20:07,944 - INFO - HDBSCAN Cluster ID 134 (UMAP 2D): Vibrant Worlds and Engaging Exploration
# 2024-12-13 09:20:07,960 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 61
# 2024-12-13 09:20:08,343 - INFO - Generated cluster name: Gameplay Performance Issues
# 2024-12-13 09:20:08,343 - INFO -  Tokens used so far: Prompt Tokens: 56981, Completion Tokens: 1493
# 2024-12-13 09:20:08,343 - INFO - HDBSCAN Cluster ID 61 (UMAP 2D): Gameplay Performance Issues
# 2024-12-13 09:20:08,359 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 27
# 2024-12-13 09:20:08,899 - INFO - Generated cluster name: Loot and Reward Frustrations
# 2024-12-13 09:20:08,899 - INFO -  Tokens used so far: Prompt Tokens: 57189, Completion Tokens: 1499
# 2024-12-13 09:20:08,899 - INFO - HDBSCAN Cluster ID 27 (UMAP 2D): Loot and Reward Frustrations
# 2024-12-13 09:20:08,917 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 23
# 2024-12-13 09:20:09,410 - INFO - Generated cluster name: Learning Curve in Gameplay
# 2024-12-13 09:20:09,410 - INFO -  Tokens used so far: Prompt Tokens: 57435, Completion Tokens: 1503
# 2024-12-13 09:20:09,410 - INFO - HDBSCAN Cluster ID 23 (UMAP 2D): Learning Curve in Gameplay
# 2024-12-13 09:20:09,426 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 2
# 2024-12-13 09:20:09,877 - INFO - Generated cluster name: Controller Support Improvements Needed
# 2024-12-13 09:20:09,877 - INFO -  Tokens used so far: Prompt Tokens: 57611, Completion Tokens: 1507
# 2024-12-13 09:20:09,877 - INFO - HDBSCAN Cluster ID 2 (UMAP 2D): Controller Support Improvements Needed
# 2024-12-13 09:20:09,895 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 128
# 2024-12-13 09:20:10,393 - INFO - Generated cluster name: Future Content Excitement
# 2024-12-13 09:20:10,393 - INFO -  Tokens used so far: Prompt Tokens: 57797, Completion Tokens: 1512
# 2024-12-13 09:20:10,393 - INFO - HDBSCAN Cluster ID 128 (UMAP 2D): Future Content Excitement
# 2024-12-13 09:20:10,409 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 63
# 2024-12-13 09:20:10,860 - INFO - Generated cluster name: Game Performance Feedback
# 2024-12-13 09:20:10,860 - INFO -  Tokens used so far: Prompt Tokens: 57965, Completion Tokens: 1515
# 2024-12-13 09:20:10,860 - INFO - HDBSCAN Cluster ID 63 (UMAP 2D): Game Performance Feedback
# 2024-12-13 09:20:10,880 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 58
# 2024-12-13 09:20:11,260 - INFO - Generated cluster name: Slow-Paced Gaming Experience
# 2024-12-13 09:20:11,260 - INFO -  Tokens used so far: Prompt Tokens: 58189, Completion Tokens: 1520
# 2024-12-13 09:20:11,260 - INFO - HDBSCAN Cluster ID 58 (UMAP 2D): Slow-Paced Gaming Experience
# 2024-12-13 09:20:11,260 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 87
# 2024-12-13 09:20:11,811 - INFO - Generated cluster name: Network Connectivity Problems
# 2024-12-13 09:20:11,811 - INFO -  Tokens used so far: Prompt Tokens: 58419, Completion Tokens: 1523
# 2024-12-13 09:20:11,811 - INFO - HDBSCAN Cluster ID 87 (UMAP 2D): Network Connectivity Problems
# 2024-12-13 09:20:11,827 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 55
# 2024-12-13 09:20:12,243 - INFO - Generated cluster name: Quest Clarity and Design Issues
# 2024-12-13 09:20:12,243 - INFO -  Tokens used so far: Prompt Tokens: 58642, Completion Tokens: 1529
# 2024-12-13 09:20:12,243 - INFO - HDBSCAN Cluster ID 55 (UMAP 2D): Quest Clarity and Design Issues
# 2024-12-13 09:20:12,259 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 148
# 2024-12-13 09:20:12,760 - INFO - Generated cluster name: Aesthetic Appeal in Gaming
# 2024-12-13 09:20:12,760 - INFO -  Tokens used so far: Prompt Tokens: 58838, Completion Tokens: 1534
# 2024-12-13 09:20:12,760 - INFO - HDBSCAN Cluster ID 148 (UMAP 2D): Aesthetic Appeal in Gaming
# 2024-12-13 09:20:12,777 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 41
# 2024-12-13 09:20:13,211 - INFO - Generated cluster name: Character Customization Experiences
# 2024-12-13 09:20:13,211 - INFO -  Tokens used so far: Prompt Tokens: 58999, Completion Tokens: 1538
# 2024-12-13 09:20:13,211 - INFO - HDBSCAN Cluster ID 41 (UMAP 2D): Character Customization Experiences
# 2024-12-13 09:20:13,227 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 31
# 2024-12-13 09:20:14,260 - INFO - Generated cluster name: Portal System Experience in Nightingale
# 2024-12-13 09:20:14,260 - INFO -  Tokens used so far: Prompt Tokens: 59218, Completion Tokens: 1544
# 2024-12-13 09:20:14,260 - INFO - HDBSCAN Cluster ID 31 (UMAP 2D): Portal System Experience in Nightingale
# 2024-12-13 09:20:14,274 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 70
# 2024-12-13 09:20:14,710 - INFO - Generated cluster name: Repetitive Gameplay Experience
# 2024-12-13 09:20:14,710 - INFO -  Tokens used so far: Prompt Tokens: 59411, Completion Tokens: 1549
# 2024-12-13 09:20:14,710 - INFO - HDBSCAN Cluster ID 70 (UMAP 2D): Repetitive Gameplay Experience
# 2024-12-13 09:20:14,728 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 133
# 2024-12-13 09:20:15,329 - INFO - Generated cluster name: Game Design and Aesthetic Quality
# 2024-12-13 09:20:15,329 - INFO -  Tokens used so far: Prompt Tokens: 59600, Completion Tokens: 1555
# 2024-12-13 09:20:15,342 - INFO - HDBSCAN Cluster ID 133 (UMAP 2D): Game Design and Aesthetic Quality
# 2024-12-13 09:20:15,344 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 108
# 2024-12-13 09:20:15,836 - INFO - Generated cluster name: Anticipating Game Development Progress
# 2024-12-13 09:20:15,836 - INFO -  Tokens used so far: Prompt Tokens: 59769, Completion Tokens: 1561
# 2024-12-13 09:20:15,836 - INFO - HDBSCAN Cluster ID 108 (UMAP 2D): Anticipating Game Development Progress
# 2024-12-13 09:20:15,860 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 112
# 2024-12-13 09:20:16,443 - INFO - Generated cluster name: Survival Game Enthusiasm
# 2024-12-13 09:20:16,443 - INFO -  Tokens used so far: Prompt Tokens: 59966, Completion Tokens: 1566
# 2024-12-13 09:20:16,443 - INFO - HDBSCAN Cluster ID 112 (UMAP 2D): Survival Game Enthusiasm
# 2024-12-13 09:20:16,460 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 154
# 2024-12-13 09:20:16,961 - INFO - Generated cluster name: Unique Survival Game Innovations
# 2024-12-13 09:20:16,961 - INFO -  Tokens used so far: Prompt Tokens: 60134, Completion Tokens: 1570
# 2024-12-13 09:20:16,961 - INFO - HDBSCAN Cluster ID 154 (UMAP 2D): Unique Survival Game Innovations
# 2024-12-13 09:20:16,994 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 86
# 2024-12-13 09:20:17,693 - INFO - Generated cluster name: Connection Issues and Disruptions
# 2024-12-13 09:20:17,693 - INFO -  Tokens used so far: Prompt Tokens: 60354, Completion Tokens: 1576
# 2024-12-13 09:20:17,693 - INFO - HDBSCAN Cluster ID 86 (UMAP 2D): Connection Issues and Disruptions
# 2024-12-13 09:20:17,693 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 156
# 2024-12-13 09:20:18,227 - INFO - Generated cluster name: Engaging Gameplay Experiences
# 2024-12-13 09:20:18,233 - INFO -  Tokens used so far: Prompt Tokens: 60476, Completion Tokens: 1580
# 2024-12-13 09:20:18,236 - INFO - HDBSCAN Cluster ID 156 (UMAP 2D): Engaging Gameplay Experiences
# 2024-12-13 09:20:18,310 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 146
# 2024-12-13 09:20:19,011 - INFO - Generated cluster name: Game Concept Praise and Critique
# 2024-12-13 09:20:19,011 - INFO -  Tokens used so far: Prompt Tokens: 60619, Completion Tokens: 1586
# 2024-12-13 09:20:19,011 - INFO - HDBSCAN Cluster ID 146 (UMAP 2D): Game Concept Praise and Critique
# 2024-12-13 09:20:19,061 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 66
# 2024-12-13 09:20:19,692 - INFO - Generated cluster name: Early Access Glitches Experience
# 2024-12-13 09:20:19,693 - INFO -  Tokens used so far: Prompt Tokens: 60811, Completion Tokens: 1591
# 2024-12-13 09:20:19,694 - INFO - HDBSCAN Cluster ID 66 (UMAP 2D): Early Access Glitches Experience
# 2024-12-13 09:20:19,707 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 25
# 2024-12-13 09:20:20,228 - INFO - Generated cluster name: Pricing Perceptions of Video Games
# 2024-12-13 09:20:20,239 - INFO -  Tokens used so far: Prompt Tokens: 61016, Completion Tokens: 1597
# 2024-12-13 09:20:20,248 - INFO - HDBSCAN Cluster ID 25 (UMAP 2D): Pricing Perceptions of Video Games
# 2024-12-13 09:20:20,279 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 83
# 2024-12-13 09:20:20,778 - INFO - Generated cluster name: Persistent Network Errors
# 2024-12-13 09:20:20,778 - INFO -  Tokens used so far: Prompt Tokens: 61255, Completion Tokens: 1600
# 2024-12-13 09:20:20,778 - INFO - HDBSCAN Cluster ID 83 (UMAP 2D): Persistent Network Errors
# 2024-12-13 09:20:20,849 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 60
# 2024-12-13 09:20:21,284 - INFO - Generated cluster name: Server Experiences and Performance Review
# 2024-12-13 09:20:21,289 - INFO -  Tokens used so far: Prompt Tokens: 61415, Completion Tokens: 1605
# 2024-12-13 09:20:21,292 - INFO - HDBSCAN Cluster ID 60 (UMAP 2D): Server Experiences and Performance Review
# 2024-12-13 09:20:21,347 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 32
# 2024-12-13 09:20:22,227 - INFO - Generated cluster name: Loading Screen Frustrations
# 2024-12-13 09:20:22,227 - INFO -  Tokens used so far: Prompt Tokens: 61642, Completion Tokens: 1610
# 2024-12-13 09:20:22,243 - INFO - HDBSCAN Cluster ID 32 (UMAP 2D): Loading Screen Frustrations
# 2024-12-13 09:20:22,259 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 77
# 2024-12-13 09:20:22,714 - INFO - Generated cluster name: Augmentation System Critique
# 2024-12-13 09:20:22,714 - INFO -  Tokens used so far: Prompt Tokens: 61854, Completion Tokens: 1615
# 2024-12-13 09:20:22,714 - INFO - HDBSCAN Cluster ID 77 (UMAP 2D): Augmentation System Critique
# 2024-12-13 09:20:22,726 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 135
# 2024-12-13 09:20:23,160 - INFO - Generated cluster name: Early Access Game Reviews
# 2024-12-13 09:20:23,160 - INFO -  Tokens used so far: Prompt Tokens: 62044, Completion Tokens: 1619
# 2024-12-13 09:20:23,160 - INFO - HDBSCAN Cluster ID 135 (UMAP 2D): Early Access Game Reviews
# 2024-12-13 09:20:23,180 - INFO - Found 10 Topics for hdbscan_UMAP_2D ID: 131
# 2024-12-13 09:20:23,660 - INFO - Generated cluster name: Early Access Game Expectations
# 2024-12-13 09:20:23,660 - INFO -  Tokens used so far: Prompt Tokens: 62277, Completion Tokens: 1623
# ...
# 2024-12-13 09:40:04,627 - INFO - HDBSCAN Cluster ID 95 (tSNE 3D): Reused 2D cluster name: Combat Experience in Games
# 2024-12-13 09:40:04,643 - INFO - HDBSCAN Cluster ID 82 (tSNE 3D): Reused 2D cluster name: Server Stability and Gameplay Issues
# 2024-12-13 09:40:04,643 - INFO - HDBSCAN Cluster ID 110 (tSNE 3D): Reused 2D cluster name: Survival Crafting Game Enthusiasts
# 2024-12-13 09:40:04,659 - INFO - HDBSCAN Cluster ID 57 (tSNE 3D): Reused 2D cluster name: Graphics Quality Perception
# 2024-12-13 09:40:04,659 - INFO - HDBSCAN Cluster ID 149 (tSNE 3D): Reused 2D cluster name: Stunning Game Graphics and Aesthetics
# 2024-12-13 09:40:04,659 - INFO - HDBSCAN Cluster ID 88 (tSNE 3D): Reused 2D cluster name: Character Creation Perspectives and Critiques
# 2024-12-13 09:40:04,674 - INFO - HDBSCAN Cluster ID 107 (tSNE 3D): Reused 2D cluster name: Combat Experience Evaluation
# 2024-12-13 09:40:04,674 - INFO - HDBSCAN Cluster ID 80 (tSNE 3D): Reused 2D cluster name: Always Online Game Frustrations
# 2024-12-13 09:40:04,674 - INFO - HDBSCAN Cluster ID 96 (tSNE 3D): Reused 2D cluster name: Complex Crafting Mechanics in Gaming
# 2024-12-13 09:40:04,690 - INFO - HDBSCAN Cluster ID 132 (tSNE 3D): Reused 2D cluster name: Beautiful Game Aesthetics and Atmosphere
# 2024-12-13 09:40:04,690 - INFO - HDBSCAN Cluster ID 6 (tSNE 3D): Reused 2D cluster name: Menu Navigation Challenges
# 2024-12-13 09:40:04,706 - INFO - HDBSCAN Cluster ID 92 (tSNE 3D): Reused 2D cluster name: Unfulfilled Hopes for Game Future
# 2024-12-13 09:40:04,706 - INFO - HDBSCAN Cluster ID 37 (tSNE 3D): Reused 2D cluster name: Ultimate Fun Gaming Experience
# 2024-12-13 09:40:04,706 - INFO - HDBSCAN Cluster ID 136 (tSNE 3D): Reused 2D cluster name: Early Access Bug Experiences
# 2024-12-13 09:40:04,722 - INFO - HDBSCAN Cluster ID 127 (tSNE 3D): Reused 2D cluster name: Anticipation for Future Updates
# 2024-12-13 09:40:04,727 - INFO - HDBSCAN Cluster ID 42 (tSNE 3D): Reused 2D cluster name: Developer Dedication and Commitment
# 2024-12-13 09:40:04,727 - INFO - HDBSCAN Cluster ID 84 (tSNE 3D): Reused 2D cluster name: Engagement in Gaming Experience
# 2024-12-13 09:40:04,738 - INFO - HDBSCAN Cluster ID 111 (tSNE 3D): Reused 2D cluster name: Story-Driven Survival Mechanics
# 2024-12-13 09:40:04,738 - INFO - HDBSCAN Cluster ID 160 (tSNE 3D): Reused 2D cluster name: Game Experience Reviews and Opinions
# 2024-12-13 09:40:04,738 - INFO - HDBSCAN Cluster ID 85 (tSNE 3D): Reused 2D cluster name: Rich Lore and Storytelling Experience
# 2024-12-13 09:40:04,754 - INFO - HDBSCAN Cluster ID 100 (tSNE 3D): Reused 2D cluster name: Combat Difficulty and Balance Issues
# 2024-12-13 09:40:04,766 - INFO - HDBSCAN Cluster ID 73 (tSNE 3D): Reused 2D cluster name: Mixed Initial Impressions on Game
# 2024-12-13 09:40:04,772 - INFO - HDBSCAN Cluster ID 121 (tSNE 3D): Reused 2D cluster name: Game Depth and Player Perception
# 2024-12-13 09:40:04,778 - INFO - HDBSCAN Cluster ID 72 (tSNE 3D): Reused 2D cluster name: Online-Only Game Experience Perspectives
# 2024-12-13 09:40:04,782 - INFO - HDBSCAN Cluster ID 39 (tSNE 3D): Reused 2D cluster name: Enemy Variety Limitations
# 2024-12-13 09:40:04,788 - INFO - HDBSCAN Cluster ID 140 (tSNE 3D): Reused 2D cluster name: Survival Game Comparisons and Critiques
# 2024-12-13 09:40:04,790 - INFO - HDBSCAN Cluster ID 52 (tSNE 3D): Reused 2D cluster name: Game Recommendations and Opinions
# 2024-12-13 09:40:04,802 - INFO - HDBSCAN Cluster ID 138 (tSNE 3D): Reused 2D cluster name: Early Access Gaming Experience
# 2024-12-13 09:40:04,802 - INFO - HDBSCAN Cluster ID 46 (tSNE 3D): Reused 2D cluster name: Dedicated Developer Support
# 2024-12-13 09:40:04,813 - INFO - HDBSCAN Cluster ID 64 (tSNE 3D): Reused 2D cluster name: Game Optimization Complaints
# 2024-12-13 09:40:04,817 - INFO - HDBSCAN Cluster ID 141 (tSNE 3D): Reused 2D cluster name: Fantasy Survival Game Mashups
# 2024-12-13 09:40:04,817 - INFO - HDBSCAN Cluster ID 51 (tSNE 3D): Reused 2D cluster name: Game Recommendations and Advice
# 2024-12-13 09:40:04,832 - INFO - HDBSCAN Cluster ID 68 (tSNE 3D): Reused 2D cluster name: Early Access Bug Experience
# 2024-12-13 09:40:04,837 - INFO - HDBSCAN Cluster ID 89 (tSNE 3D): Reused 2D cluster name: Game Potential and Expectations
# 2024-12-13 09:40:04,843 - INFO - HDBSCAN Cluster ID 29 (tSNE 3D): Reused 2D cluster name: Companion AI Frustrations
# 2024-12-13 09:40:04,849 - INFO - HDBSCAN Cluster ID 97 (tSNE 3D): Reused 2D cluster name: Progression System Feedback
# 2024-12-13 09:40:04,855 - INFO - HDBSCAN Cluster ID 69 (tSNE 3D): Reused 2D cluster name: Offline Mode Development and Feedback
# 2024-12-13 09:40:04,857 - INFO - HDBSCAN Cluster ID 47 (tSNE 3D): Reused 2D cluster name: Frustrating Tutorial Experiences
# 2024-12-13 09:40:04,865 - INFO - HDBSCAN Cluster ID 18 (tSNE 3D): Reused 2D cluster name: Triforcing and PvE Focus
# 2024-12-13 09:40:04,874 - INFO - HDBSCAN Cluster ID 43 (tSNE 3D): Reused 2D cluster name: Lag and Connectivity Issues
# 2024-12-13 09:40:04,874 - INFO - HDBSCAN Cluster ID 44 (tSNE 3D): Reused 2D cluster name: Dysfunctional User Interface Critiques
# 2024-12-13 09:40:04,881 - INFO - HDBSCAN Cluster ID 119 (tSNE 3D): Reused 2D cluster name: Future Improvement Hopes
# 2024-12-13 09:40:04,881 - INFO - HDBSCAN Cluster ID 1 (tSNE 3D): Reused 2D cluster name: Refund Request Frustrations
# 2024-12-13 09:40:04,896 - INFO - HDBSCAN Cluster ID 24 (tSNE 3D): Reused 2D cluster name: Value for Money in Gaming
# 2024-12-13 09:40:04,896 - INFO - HDBSCAN Cluster ID 79 (tSNE 3D): Reused 2D cluster name: "Online-Only Gameplay Frustrations"
# 2024-12-13 09:40:04,912 - INFO - HDBSCAN Cluster ID 9 (tSNE 3D): Reused 2D cluster name: Quality of Life Enhancements Needed
# 2024-12-13 09:40:04,912 - INFO - HDBSCAN Cluster ID 152 (tSNE 3D): Reused 2D cluster name: Game Quality Debate
# 2024-12-13 09:40:04,912 - INFO - HDBSCAN Cluster ID 16 (tSNE 3D): Reused 2D cluster name: Early Access Game Impressions
# 2024-12-13 09:40:04,928 - INFO - HDBSCAN Cluster ID 81 (tSNE 3D): Reused 2D cluster name: Promising Future for Game Development
# 2024-12-13 09:40:04,928 - INFO - HDBSCAN Cluster ID 7 (tSNE 3D): Reused 2D cluster name: Map Design Quality Assessment
# 2024-12-13 09:40:04,928 - INFO - HDBSCAN Cluster ID 67 (tSNE 3D): Reused 2D cluster name: Game Bugs and Early Access Issues
# 2024-12-13 09:40:04,944 - INFO - HDBSCAN Cluster ID 75 (tSNE 3D): Reused 2D cluster name: Engaging Narrative in Expansive Worlds
# 2024-12-13 09:40:04,944 - INFO - HDBSCAN Cluster ID 15 (tSNE 3D): Reused 2D cluster name: Biome Variation Limitations
# 2024-12-13 09:40:04,959 - INFO - HDBSCAN Cluster ID 17 (tSNE 3D): Reused 2D cluster name: Frequent Game Crashes and Issues
# 2024-12-13 09:40:04,959 - INFO - HDBSCAN Cluster ID 104 (tSNE 3D): Reused 2D cluster name: Game Progression Experiences
# 2024-12-13 09:40:04,959 - INFO - HDBSCAN Cluster ID 30 (tSNE 3D): Reused 2D cluster name: Boss Fight Critiques and Concerns
# 2024-12-13 09:40:04,975 - INFO - HDBSCAN Cluster ID 56 (tSNE 3D): Reused 2D cluster name: Engaging Puzzle Experiences
# 2024-12-13 09:40:04,975 - INFO - HDBSCAN Cluster ID 19 (tSNE 3D): Reused 2D cluster name: Gameplay Balance and Player Experience
# 2024-12-13 09:40:04,975 - INFO - HDBSCAN Cluster ID 22 (tSNE 3D): Reused 2D cluster name: Value for Money in Gaming
# 2024-12-13 09:40:04,991 - INFO - HDBSCAN Cluster ID 71 (tSNE 3D): Reused 2D cluster name: Offline Play Concerns
# 2024-12-13 09:40:04,991 - INFO - HDBSCAN Cluster ID 94 (tSNE 3D): Reused 2D cluster name: "Game Grinding Experiences and Perceptions"
# 2024-12-13 09:40:05,007 - INFO - HDBSCAN Cluster ID 0 (tSNE 3D): Reused 2D cluster name: Stamina System Critique
# 2024-12-13 09:40:05,007 - INFO - HDBSCAN Cluster ID 59 (tSNE 3D): Reused 2D cluster name: Early Access Game Polish Issues
# 2024-12-13 09:40:05,025 - INFO - HDBSCAN Cluster ID 105 (tSNE 3D): Reused 2D cluster name: Extensive Gameplay and Learning Curve
# 2024-12-13 09:40:05,028 - INFO - HDBSCAN Cluster ID 74 (tSNE 3D): Reused 2D cluster name: Game Development Anticipation and Optimism
# 2024-12-13 09:40:05,028 - INFO - HDBSCAN Cluster ID 5 (tSNE 3D): Reused 2D cluster name: Defending Against Negative Reviews
# 2024-12-13 09:40:05,039 - INFO - HDBSCAN Cluster ID 91 (tSNE 3D): Reused 2D cluster name: Game Quality Impressions
# 2024-12-13 09:40:05,039 - INFO - HDBSCAN Cluster ID 122 (tSNE 3D): Reused 2D cluster name: Complexity in Gaming Experience
# 2024-12-13 09:40:05,039 - INFO - HDBSCAN Cluster ID 98 (tSNE 3D): Reused 2D cluster name: Extensive Gaming Experience
# 2024-12-13 09:40:05,055 - INFO - HDBSCAN Cluster ID 134 (tSNE 3D): Reused 2D cluster name: Enchanting Worlds and Exploration
# 2024-12-13 09:40:05,055 - INFO - HDBSCAN Cluster ID 61 (tSNE 3D): Reused 2D cluster name: Performance Issues and Optimization Challenges
# 2024-12-13 09:40:05,071 - INFO - HDBSCAN Cluster ID 27 (tSNE 3D): Reused 2D cluster name: Loot Quality and Accessibility Issues
# 2024-12-13 09:40:05,071 - INFO - HDBSCAN Cluster ID 23 (tSNE 3D): Reused 2D cluster name: Learning Curve in Gaming
# 2024-12-13 09:40:05,071 - INFO - HDBSCAN Cluster ID 2 (tSNE 3D): Reused 2D cluster name: Controller Support Improvement Needed
# 2024-12-13 09:40:05,087 - INFO - HDBSCAN Cluster ID 128 (tSNE 3D): Reused 2D cluster name: Future Game Content Excitement
# 2024-12-13 09:40:05,087 - INFO - HDBSCAN Cluster ID 63 (tSNE 3D): Reused 2D cluster name: Game Performance and User Experience
# 2024-12-13 09:40:05,103 - INFO - HDBSCAN Cluster ID 58 (tSNE 3D): Reused 2D cluster name: Slow-Paced Gaming Experience
# 2024-12-13 09:40:05,103 - INFO - HDBSCAN Cluster ID 87 (tSNE 3D): Reused 2D cluster name: Network Connectivity Problems
# 2024-12-13 09:40:05,119 - INFO - HDBSCAN Cluster ID 55 (tSNE 3D): Reused 2D cluster name: Quest Design Frustrations
# 2024-12-13 09:40:05,119 - INFO - HDBSCAN Cluster ID 148 (tSNE 3D): Reused 2D cluster name: Aesthetic Beauty in Gaming
# 2024-12-13 09:40:05,128 - INFO - HDBSCAN Cluster ID 41 (tSNE 3D): Reused 2D cluster name: Character Customization Experiences
# 2024-12-13 09:40:05,135 - INFO - HDBSCAN Cluster ID 31 (tSNE 3D): Reused 2D cluster name: Portal System Impressions and Issues
# 2024-12-13 09:40:05,135 - INFO - HDBSCAN Cluster ID 70 (tSNE 3D): Reused 2D cluster name: Repetitive Gameplay Experience
# 2024-12-13 09:40:05,148 - INFO - HDBSCAN Cluster ID 133 (tSNE 3D): Reused 2D cluster name: Game Design Quality and Innovation
# 2024-12-13 09:40:05,154 - INFO - HDBSCAN Cluster ID 108 (tSNE 3D): Reused 2D cluster name: Anticipation for Game Development
# 2024-12-13 09:40:05,160 - INFO - HDBSCAN Cluster ID 112 (tSNE 3D): Reused 2D cluster name: Survival Game Enthusiasm and Opinions
# 2024-12-13 09:40:05,166 - INFO - HDBSCAN Cluster ID 154 (tSNE 3D): Reused 2D cluster name: Unique Survival Game Concepts
# 2024-12-13 09:40:05,166 - INFO - HDBSCAN Cluster ID 86 (tSNE 3D): Reused 2D cluster name: Connection Issues and Server Stability
# 2024-12-13 09:40:05,166 - INFO - HDBSCAN Cluster ID 156 (tSNE 3D): Reused 2D cluster name: Engaging and Fun Gameplay
# 2024-12-13 09:40:05,182 - INFO - HDBSCAN Cluster ID 146 (tSNE 3D): Reused 2D cluster name: Game Concept Praise and Critique
# 2024-12-13 09:40:05,182 - INFO - HDBSCAN Cluster ID 66 (tSNE 3D): Reused 2D cluster name: Early Access Glitches and Stability
# 2024-12-13 09:40:05,182 - INFO - HDBSCAN Cluster ID 25 (tSNE 3D): Reused 2D cluster name: Game Pricing and Value Perception
# 2024-12-13 09:40:05,198 - INFO - HDBSCAN Cluster ID 83 (tSNE 3D): Reused 2D cluster name: Severe Network Issues
# 2024-12-13 09:40:05,198 - INFO - HDBSCAN Cluster ID 60 (tSNE 3D): Reused 2D cluster name: Server Stability Feedback
# 2024-12-13 09:40:05,198 - INFO - HDBSCAN Cluster ID 32 (tSNE 3D): Reused 2D cluster name: Loading Time Frustrations
# 2024-12-13 09:40:05,218 - INFO - HDBSCAN Cluster ID 77 (tSNE 3D): Reused 2D cluster name: Augmentation System Challenges
# 2024-12-13 09:40:05,218 - INFO - HDBSCAN Cluster ID 135 (tSNE 3D): Reused 2D cluster name: Quality of Early Access Games
# 2024-12-13 09:40:05,228 - INFO - HDBSCAN Cluster ID 131 (tSNE 3D): Reused 2D cluster name: Early Access Feedback and Expectations
# 2024-12-13 09:40:05,233 - INFO - HDBSCAN Cluster ID 130 (tSNE 3D): Reused 2D cluster name: Early Access Potential and Growth
# 2024-12-13 09:40:05,233 - INFO - HDBSCAN Cluster ID 101 (tSNE 3D): Reused 2D cluster name: Mixed Reviews on Combat Systems
# 2024-12-13 09:40:05,244 - INFO - HDBSCAN Cluster ID 33 (tSNE 3D): Reused 2D cluster name: Procedural Generation in Game Design
# 2024-12-13 09:40:05,244 - INFO - HDBSCAN Cluster ID 38 (tSNE 3D): Reused 2D cluster name: Immersive Gameplay Experiences
# 2024-12-13 09:40:05,260 - INFO - HDBSCAN Cluster ID 147 (tSNE 3D): Reused 2D cluster name: Charming and Unique Art Styles
# 2024-12-13 09:40:05,267 - INFO - HDBSCAN Cluster ID 102 (tSNE 3D): Reused 2D cluster name: End Game Experience and Critique
# 2024-12-13 09:40:05,273 - INFO - HDBSCAN Cluster ID 78 (tSNE 3D): Reused 2D cluster name: Server Disconnection Challenges
# 2024-12-13 09:40:05,276 - INFO - HDBSCAN Cluster ID 114 (tSNE 3D): Reused 2D cluster name: Resource Gathering Dynamics
# 2024-12-13 09:40:05,276 - INFO - HDBSCAN Cluster ID 40 (tSNE 3D): Reused 2D cluster name: Game Reception and Player Sentiment
# 2024-12-13 09:40:05,292 - INFO - HDBSCAN Cluster ID 48 (tSNE 3D): Reused 2D cluster name: Lengthy and Ineffective Tutorials
# 2024-12-13 09:40:05,292 - INFO - HDBSCAN Cluster ID 76 (tSNE 3D): Reused 2D cluster name: Engaging Storyline Experiences
# 2024-12-13 09:40:05,303 - INFO - HDBSCAN Cluster ID 36 (tSNE 3D): Reused 2D cluster name: Immersive Game Atmosphere Appreciation
# 2024-12-13 09:40:05,309 - INFO - HDBSCAN Cluster ID 65 (tSNE 3D): Reused 2D cluster name: Optimization Concerns in Gaming
# 2024-12-13 09:40:05,309 - INFO - HDBSCAN Cluster ID 62 (tSNE 3D): Reused 2D cluster name: Game Performance Insights
# 2024-12-13 09:40:05,309 - INFO - HDBSCAN Cluster ID 145 (tSNE 3D): Reused 2D cluster name: Cooperative Gaming Experiences
# 2024-12-13 09:40:05,323 - INFO - HDBSCAN Cluster ID 53 (tSNE 3D): Reused 2D cluster name: Server Stability Feedback and Improvement
# 2024-12-13 09:40:05,333 - INFO - HDBSCAN Cluster ID 144 (tSNE 3D): Reused 2D cluster name: Multiplayer Gaming Experiences
# 2024-12-13 09:40:05,333 - INFO - HDBSCAN Cluster ID 103 (tSNE 3D): Reused 2D cluster name: Endgame Experience Evaluation
# 2024-12-13 09:40:05,339 - INFO - HDBSCAN Cluster ID 10 (tSNE 3D): Reused 2D cluster name: Quality of Life in Gaming
# 2024-12-13 09:40:05,339 - INFO - HDBSCAN Cluster ID 8 (tSNE 3D): Reused 2D cluster name: Card System Reception in Gameplay
# 2024-12-13 09:40:05,339 - INFO - HDBSCAN Cluster ID 26 (tSNE 3D): Reused 2D cluster name: NPC Engagement and Interaction Issues
# 2024-12-13 09:40:05,355 - INFO - HDBSCAN Cluster ID 14 (tSNE 3D): Reused 2D cluster name: Game Rating Opinions
# 2024-12-13 09:40:05,355 - INFO - HDBSCAN Cluster ID 13 (tSNE 3D): Reused 2D cluster name: Enduring Survival Game Experiences
# 2024-12-13 09:40:05,371 - INFO - HDBSCAN Cluster ID 118 (tSNE 3D): Reused 2D cluster name: Unrealized Potential in Development
# 2024-12-13 09:40:05,371 - INFO - HDBSCAN Cluster ID 109 (tSNE 3D): Reused 2D cluster name: Solo Play Experience
# 2024-12-13 09:40:05,371 - INFO - HDBSCAN Cluster ID 151 (tSNE 3D): Reused 2D cluster name: Active Game Development and Updates
# 2024-12-13 09:40:05,387 - INFO - HDBSCAN Cluster ID 143 (tSNE 3D): Reused 2D cluster name: Early Access Issues and Concerns
# 2024-12-13 09:40:05,387 - INFO - HDBSCAN Cluster ID 4 (tSNE 3D): Reused 2D cluster name: Captivating Stories in Gaming
# 2024-12-13 09:40:05,387 - INFO - HDBSCAN Cluster ID 123 (tSNE 3D): Reused 2D cluster name: Exploration and Crafting Adventure
# 2024-12-13 09:40:05,403 - INFO - HDBSCAN Cluster ID 3 (tSNE 3D): Reused 2D cluster name: Irrelevant or Typos Cluster
# 2024-12-13 09:40:05,403 - INFO - Cluster naming process completed.
# 2024-12-13 09:40:05,403 - INFO - Saving updated data to C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\Steamapps\Market\db_final.json
# 2024-12-13 09:40:06,074 - INFO - Data saved successfully.

# %%
len_topic = len(df_total['topic'].unique())
print(f'Number of unique topics: {len_topic}')

len_clusters = len(df_total['hdbscan_UMAP_2D'].unique())
print(f'Number of unique clusters: {len_clusters}')

# %%
# remove embedding key again to save space

def remove_embeddings(data):
    """
    Removes the 'embedding' key from each entry in the dataset.
    Args:
        data (list): List of JSON entries.
    Returns:
        list: Dataset with 'embedding' key removed.
    """
    for entry in data:
        if "embedding" in entry:
            del entry["embedding"]
    return data

data = read_json(path_db_final)
data = remove_embeddings(data)
# transform to df
df = pd.DataFrame(data)
save_data_for_streamlit(df, path_db_final)
# Out:
# 2024-12-12 09:45:52,508 - INFO - Saving updated data to C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\Steamapps\Market\db_final.json
# 2024-12-12 09:45:52,666 - INFO - Data saved successfully.
