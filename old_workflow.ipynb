# %%
# General modules
import os
import openai
import pandas as pd
from dotenv import load_dotenv
from helper.utils import *

# Setup API keys
load_dotenv()
openai_api_key = os.getenv("OPENAI_API_KEY")
openai.api_key = openai_api_key
client = openai.Client()

# Specify models
chat_model_name = 'gpt-4o-mini'
openai_embedding_model = "text-embedding-3-small"
local_embedding_model = "all-MiniLM-L6-v2"

configure_api(client, chat_model_name)

# Specify paths for storing (backup) data
root_dir = r'S:\SID\Analytics\Working Files\Individual\Florian\Projects\DataScience\cluster_analysis\Data\RivalStars'
data_source = 'Steam'

path_db_prepared = os.path.join(root_dir, data_source, "db_prepared.json")          #backup
path_db_translated = os.path.join(root_dir, data_source, "db_translated.json")      #backup
path_db_analysed = os.path.join(root_dir, data_source, "db_analysed.json")          #backup
path_db_embedded = os.path.join(root_dir, data_source, "db_embedded.json")          #backup
path_db_clustered = os.path.join(root_dir, data_source, "db_clustered.json")        #backup
path_db_final = os.path.join(root_dir, data_source, "db_final.json")                #final file

# %% [markdown]
# This Jupyter notebook guides you through the process of generating the sentiment ant topic data for the Rival Stars Desktop edition steam comments.
# The process is as follows:
# 1. Gather Data (Redshift)
# 2. Translate Data (Optional)
# 3. Analyse Data
# 4. Embed Data
# 5. Cluster Analysis
# 6. Cluster Naming
# 7. Upload to Streamlit

# %% [markdown]
# # Gather Data (Redshift)
#
#  Currently, we did not automate the process of getting the steam reviews into our Redshift Database. Eventually this will be done so this script already builds on the assumption that the data is already in the database.

# %%
# My imports
from helper.redshift_conector_standalone import *

# https://store.steampowered.com/app/1166860/Rival_Stars_Horse_Racing_Desktop_Edition/

# SQL Query Redshift
sql_query = """
SELECT *
FROM steam_review
where app_id_name = '1166860_Rival_Stars_Horse_Racing_Desktop_Edition'
"""
logger.info(f"Query Redshift with: {sql_query}")

try:
    results_json, results_df = fetch_query_results(sql_query)
    # Print the first row of the DataFrame
    logger.info("Successfully fetched query results, with shape: %s", results_df.shape)
except Exception as e:
    logger.error(f"Error fetching query results: {e}")
    raise

# Save the json
parsed_json = json.loads(results_json)

# 2) Then pretty-print with indentation
save_to_json(parsed_json, path_db_prepared)
# Out:
# 2025-02-11 16:42:05,728 - INFO - Query Redshift with:
# SELECT *
# FROM steam_review
# where app_id_name = '1166860_Rival_Stars_Horse_Racing_Desktop_Edition'
#
# 2025-02-11 16:42:07,828 - INFO - Successfully fetched query results, with shape: (3235, 14)
# 2025-02-11 16:42:08,014 - INFO - Data successfully saved to S:\SID\Analytics\Working Files\Individual\Florian\Projects\DataScience\cluster_analysis\Data\RivalStars\Steam\db_prepared.json

# %% [markdown]
# # Translate Data (Optional)
#
# Since not all reviews will be in english, we will use a local model to analyse the user review and assign it a language tag.
# For the Steam data this step is obsolete, since the data has already a language tag. The function will simply tell you that there is already a language tag.
#
# After this the specified OpenAI model will be used to translate all reviews into english that currently have a different language tag.
# The translated review will overwrite the original review in the data, the original tag though will be kept.
# Therefore we know the review was translated to check later if the translation caused problems when observing unexpected results.

# %%
from helper.data_analysis import *

# Get Language Tag
data = read_json(path_db_prepared)
id_column = "recommendationid"              # The column that contains unique identifiers
columns_of_interest = ["review_text"]       # The column(s) that are going to be analyzed
all_entries = []
processed_ids = set()

# If the analyzed file already exists, load it
if os.path.exists(path_db_analysed):
    all_entries = read_json(path_db_analysed)
    processed_ids = {entry[id_column] for entry in all_entries}  # set for O(1) membership checks

# Process all unprocessed entries
for i, entry in enumerate(data_prepared):
    current_id = entry[id_column]

    # If we've already processed this entry, skip it
    if current_id in processed_ids:
        logger.info(f"Skipping entry {i} (ID: {current_id}) - already processed.")
        continue

    # Otherwise, process and append
    process_entry(
        entry,
        id_column,
        prompt_template_topic,
        prompt_template_sentiment,
        api_settings,
        columns_of_interest
    )
    all_entries.append(entry)
    processed_ids.add(current_id)  # mark as processed

    # Save intermediate progress every 10 entries
    if (i % 10) == 0 and i != 0:
        save_to_json(all_entries, path_db_analysed)
        logger.info(f"Progress saved at index {i}.")

# Final save after the loop
save_to_json(all_entries, path_db_analysed)
logger.info("All entries processed and final results saved.")
# Out:
# 2025-02-12 10:52:08,088 - INFO - Tokens used so far: Prompt Tokens: 0, Completion Tokens: 0
# 2025-02-12 10:52:08,088 - INFO - Extracting topics for entry ID 183945829
# 2025-02-12 10:52:09,335 - INFO - Analyzing sentiment for topic 'Visual Appeal' (Entry ID 183945829)
# 2025-02-12 10:52:09,856 - INFO - Tokens used so far: Prompt Tokens: 749, Completion Tokens: 41
# 2025-02-12 10:52:09,856 - INFO - Extracting topics for entry ID 183559149
# 2025-02-12 10:52:11,055 - INFO - Analyzing sentiment for topic 'Overall Enjoyment' (Entry ID 183559149)
# 2025-02-12 10:52:11,558 - INFO - Tokens used so far: Prompt Tokens: 1507, Completion Tokens: 87
# 2025-02-12 10:52:11,558 - INFO - Extracting topics for entry ID 183529438
# 2025-02-12 10:52:12,825 - INFO - Analyzing sentiment for topic 'Overall Enjoyment' (Entry ID 183529438)
# 2025-02-12 10:52:13,306 - INFO - Tokens used so far: Prompt Tokens: 2258, Completion Tokens: 129
# 2025-02-12 10:52:13,306 - INFO - Extracting topics for entry ID 180957113
# 2025-02-12 10:52:16,186 - INFO - Analyzing sentiment for topic 'Game Enjoyment' (Entry ID 180957113)
# 2025-02-12 10:52:16,680 - INFO - Analyzing sentiment for topic 'Competitions' (Entry ID 180957113)
# 2025-02-12 10:52:17,266 - INFO - Analyzing sentiment for topic 'Customization Options' (Entry ID 180957113)
# 2025-02-12 10:52:17,680 - INFO - Analyzing sentiment for topic 'Replayability' (Entry ID 180957113)
# 2025-02-12 10:52:18,199 - INFO - Analyzing sentiment for topic 'Value for Money' (Entry ID 180957113)
# 2025-02-12 10:52:18,655 - INFO - Tokens used so far: Prompt Tokens: 3671, Completion Tokens: 329
# 2025-02-12 10:52:18,655 - INFO - Extracting topics for entry ID 180935441
# 2025-02-12 10:52:20,746 - INFO - Analyzing sentiment for topic 'Game Enjoyment' (Entry ID 180935441)
# 2025-02-12 10:52:21,404 - INFO - Analyzing sentiment for topic 'Cross-Platform Experience' (Entry ID 180935441)
# 2025-02-12 10:52:22,400 - INFO - Tokens used so far: Prompt Tokens: 4671, Completion Tokens: 454
# 2025-02-12 10:52:22,400 - INFO - Extracting topics for entry ID 179001240
# 2025-02-12 10:52:25,715 - INFO - Analyzing sentiment for topic 'Mobile Version Frustrations' (Entry ID 179001240)
# 2025-02-12 10:52:26,330 - INFO - Analyzing sentiment for topic 'PC Version Satisfaction' (Entry ID 179001240)
# 2025-02-12 10:52:31,529 - INFO - Analyzing sentiment for topic 'Customization Options' (Entry ID 179001240)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 34
#      31     continue
#      33 # Otherwise, process and append
# ---> 34 process_entry(
#      35     entry,
#      36     id_column,
#      37     prompt_template_topic,
#      38     prompt_template_sentiment,
#      39     api_settings,
#      40     columns_of_interest
#      41 )
#      42 all_entries.append(entry)
#      43 processed_ids.add(current_id)  # mark as processed
#
# File S:\SID\Analytics\Working Files\Individual\Florian\Projects\DataScience\cluster_analysis\helper\data_analysis.py:304, in process_entry(entry, id_column, prompt_template_topic, prompt_template_sentiment, api_settings, columns_of_interest)
#     302     entry_id = entry.get(id_column, "unknown")
#     303     topics = extract_topics(entry, entry_id, prompt_template_topic, api_settings, columns_of_interest)
# --> 304     analyze_sentiments(entry, entry_id, topics, prompt_template_sentiment, api_settings)
#     305 except Exception as e:
#     306     logger.error(f"Error processing entry ID {entry[{id_column}]}: {e}")
#
# File S:\SID\Analytics\Working Files\Individual\Florian\Projects\DataScience\cluster_analysis\helper\data_analysis.py:260, in analyze_sentiments(entry, entry_id, topics, prompt_template_sentiment, api_settings)
#     256 try:
#     257     prompt_sentiment = prompt_template_sentiment.format(
#     258         review=topic["Context"], topic=topic["Topic"]
#     259     )
# --> 260     response = api_settings["client"].chat.completions.create(
#     261         model=api_settings["model"],
#     262         messages=[
#     263             {"role": "system", "content": "You are a helpful assistant for sentiment analysis."},
#     264             {"role": "user", "content": prompt_sentiment},
#     265         ],
#     266         max_tokens=1024,
#     267     )
#     268     track_tokens(response)
#     269     sentiment = response.choices[0].message.content.strip()
#
# File ~\Documents\Venvironments\.venv\Lib\site-packages\openai\_utils\_utils.py:279, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     277             msg = f"Missing required argument: {quote(missing[0])}"
#     278     raise TypeError(msg)
# --> 279 return func(*args, **kwargs)
#
# File ~\Documents\Venvironments\.venv\Lib\site-packages\openai\resources\chat\completions.py:859, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     817 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     818 def create(
#     819     self,
#    (...)
#     856     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     857 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     858     validate_response_format(response_format)
# --> 859     return self._post(
#     860         "/chat/completions",
#     861         body=maybe_transform(
#     862             {
#     863                 "messages": messages,
#     864                 "model": model,
#     865                 "audio": audio,
#     866                 "frequency_penalty": frequency_penalty,
#     867                 "function_call": function_call,
#     868                 "functions": functions,
#     869                 "logit_bias": logit_bias,
#     870                 "logprobs": logprobs,
#     871                 "max_completion_tokens": max_completion_tokens,
#     872                 "max_tokens": max_tokens,
#     873                 "metadata": metadata,
#     874                 "modalities": modalities,
#     875                 "n": n,
#     876                 "parallel_tool_calls": parallel_tool_calls,
#     877                 "prediction": prediction,
#     878                 "presence_penalty": presence_penalty,
#     879                 "reasoning_effort": reasoning_effort,
#     880                 "response_format": response_format,
#     881                 "seed": seed,
#     882                 "service_tier": service_tier,
#     883                 "stop": stop,
#     884                 "store": store,
#     885                 "stream": stream,
#     886                 "stream_options": stream_options,
#     887                 "temperature": temperature,
#     888                 "tool_choice": tool_choice,
#     889                 "tools": tools,
#     890                 "top_logprobs": top_logprobs,
#     891                 "top_p": top_p,
#     892                 "user": user,
#     893             },
#     894             completion_create_params.CompletionCreateParams,
#     895         ),
#     896         options=make_request_options(
#     897             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     898         ),
#     899         cast_to=ChatCompletion,
#     900         stream=stream or False,
#     901         stream_cls=Stream[ChatCompletionChunk],
#     902     )
#
# File ~\Documents\Venvironments\.venv\Lib\site-packages\openai\_base_client.py:1283, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1269 def post(
#    1270     self,
#    1271     path: str,
#    (...)
#    1278     stream_cls: type[_StreamT] | None = None,
#    1279 ) -> ResponseT | _StreamT:
#    1280     opts = FinalRequestOptions.construct(
#    1281         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1282     )
# -> 1283     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\Documents\Venvironments\.venv\Lib\site-packages\openai\_base_client.py:960, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     957 else:
#     958     retries_taken = 0
# --> 960 return self._request(
#     961     cast_to=cast_to,
#     962     options=options,
#     963     stream=stream,
#     964     stream_cls=stream_cls,
#     965     retries_taken=retries_taken,
#     966 )
#
# File ~\Documents\Venvironments\.venv\Lib\site-packages\openai\_base_client.py:996, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     993 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     995 try:
# --> 996     response = self._client.send(
#     997         request,
#     998         stream=stream or self._should_stream_response_body(request=request),
#     999         **kwargs,
#    1000     )
#    1001 except httpx.TimeoutException as err:
#    1002     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~\Documents\Venvironments\.venv\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~\Documents\Venvironments\.venv\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~\Documents\Venvironments\.venv\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~\Documents\Venvironments\.venv\Lib\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~\Documents\Venvironments\.venv\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~\Documents\Venvironments\.venv\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~\Documents\Venvironments\.venv\Lib\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~\Documents\Venvironments\.venv\Lib\site-packages\httpcore\_sync\connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~\Documents\Venvironments\.venv\Lib\site-packages\httpcore\_sync\http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~\Documents\Venvironments\.venv\Lib\site-packages\httpcore\_sync\http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~\Documents\Venvironments\.venv\Lib\site-packages\httpcore\_sync\http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~\Documents\Venvironments\.venv\Lib\site-packages\httpcore\_sync\http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~\Documents\Venvironments\.venv\Lib\site-packages\httpcore\_backends\sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1295, in SSLSocket.recv(self, buflen, flags)
#    1291     if flags != 0:
#    1292         raise ValueError(
#    1293             "non-zero flags not allowed in calls to recv() on %s" %
#    1294             self.__class__)
# -> 1295     return self.read(buflen)
#    1296 else:
#    1297     return super().recv(buflen, flags)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1168, in SSLSocket.read(self, len, buffer)
#    1166         return self._sslobj.read(len, buffer)
#    1167     else:
# -> 1168         return self._sslobj.read(len)
#    1169 except SSLError as x:
#    1170     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %% [markdown]
# # Embed Data
# There are two main ways to embed the data that have been explored here so far. One is a fast local embeding on the generate topic names. It is ~350 dims and can be computed fast. The way slower approch is to use openAI embeddings for not the topics but the actual sentences. This will increase computation time since it is roughly 3500 dimensions per user statement. Especially the API calls will be much slower than the local embedding. The OpenAI embedding though allows for a much mor nuanced semantic representation in the vector which generally improves the results in the clustering step.

# %% [markdown]
# ### OpenAI Embedding

# %%
def get_embedding(text, model="text-embedding-3-small"):
   text = text.replace("\n", " ")
   embedding = client.embeddings.create(input = [text], model=model).data[0].embedding
   return embedding



embed_key = "sentence"  # "topic" or "sentence"
data = read_json(path_db_analysed)

def process_embedding(data, embed_key):
    for i in range(0, len(data)):
        if i % 10 == 0:
            logger.info(f"Processing entry {i}")

        for d_topic in data[i]["topics"]:
            if isinstance(d_topic, dict):
                d_topic["embedding"] = get_embedding(d_topic[embed_key], model="text-embedding-3-small")
    return data


data_embedded = process_embedding(data, embed_key)


# Flatten
def flatten_data(data):
    flattened = []
    for entry in data:
        base_copy = dict(entry)
        topics = base_copy.pop("topics", [])

        for topic in topics:
            new_entry = dict(base_copy)
            new_entry.update(topic)
            flattened.append(new_entry)
    return flattened


data_flattened = flatten_data(data_embedded)

# Save the embedded data
save_to_json(data_flattened, path_db_embedded)

# %% [markdown]
# ### Local Embedding

# %%
from helper.embedding import *

embed_key = "topic"  # "topic" or "sentence"

data = read_json(path_db_analysed)
embed_model = initialize_embedding_model(local_embedding_model)


def process_embedding(data, embed_key):
    for i in range(0, len(data)):
        if i % 10 == 0:
            logger.info(f"Processing entry {i}")

        for d_topic in data[i]["topics"]:
            if isinstance(d_topic, dict):
                d_topic["embedding"] = embed_text(d_topic[embed_key], embed_model)
    return data


data_embedded = process_embedding(data, embed_key)


# Flatten
def flatten_data(data):
    flattened = []
    for entry in data:
        base_copy = dict(entry)
        topics = base_copy.pop("topics", [])

        for topic in topics:
            new_entry = dict(base_copy)
            new_entry.update(topic)
            flattened.append(new_entry)
    return flattened


data_flattened = flatten_data(data_embedded)

# Save the embedded data
save_to_json(data_flattened, path_db_embedded)
# Out:
# 2025-02-12 12:18:42,512 - INFO - Loading embedding model: all-MiniLM-L6-v2
# S:\SID\Analytics\Working Files\Individual\Florian\Projects\DataScience\cluster_analysis\helper\embedding.py:22: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   
# 2025-02-12 12:20:02,608 - INFO - Processing entry 2950
# 2025-02-12 12:20:02,844 - INFO - Processing entry 2960
# 2025-02-12 12:20:03,001 - INFO - Processing entry 2970
# 2025-02-12 12:20:03,174 - INFO - Processing entry 2980
# 2025-02-12 12:20:03,523 - INFO - Processing entry 2990
# 2025-02-12 12:20:03,681 - INFO - Processing entry 3000
# 2025-02-12 12:20:03,999 - INFO - Processing entry 3010
# 2025-02-12 12:20:04,286 - INFO - Processing entry 3020
# 2025-02-12 12:20:04,543 - INFO - Processing entry 3030
# 2025-02-12 12:20:04,893 - INFO - Processing entry 3040
# 2025-02-12 12:20:05,242 - INFO - Processing entry 3050
# 2025-02-12 12:20:05,497 - INFO - Processing entry 3060
# 2025-02-12 12:20:05,712 - INFO - Processing entry 3070
# 2025-02-12 12:20:05,894 - INFO - Processing entry 3080
# 2025-02-12 12:20:06,110 - INFO - Processing entry 3090
# 2025-02-12 12:20:06,491 - INFO - Processing entry 3100
# 2025-02-12 12:20:06,717 - INFO - Processing entry 3110
# 2025-02-12 12:20:06,981 - INFO - Processing entry 3120
# 2025-02-12 12:20:07,193 - INFO - Processing entry 3130
# 2025-02-12 12:20:07,394 - INFO - Processing entry 3140
# 2025-02-12 12:20:07,582 - INFO - Processing entry 3150
# 2025-02-12 12:20:07,795 - INFO - Processing entry 3160
# 2025-02-12 12:20:07,971 - INFO - Processing entry 3170
# 2025-02-12 12:20:08,304 - INFO - Processing entry 3180
# 2025-02-12 12:20:08,534 - INFO - Processing entry 3190
# 2025-02-12 12:20:08,760 - INFO - Processing entry 3200
# 2025-02-12 12:20:08,974 - INFO - Processing entry 3210
# 2025-02-12 12:20:09,391 - INFO - Processing entry 3220
# 2025-02-12 12:20:09,661 - INFO - Processing entry 3230
# 2025-02-12 12:20:19,648 - INFO - Data successfully saved to S:\SID\Analytics\Working Files\Individual\Florian\Projects\DataScience\cluster_analysis\Data\RivalStars\Steam\db_embedded.json

# %% [markdown]
# # Cluster Analysis
#
# The main approach here is to use HDBSCAN to cluster the embeddings. kmeans can additionally be used if the user has a rough idea about the number of topics in the data set. If the openAI embedding was used in the previous step it is generally advised to perform a dimension reduction before clustering. The UMAP algorithm is used for this purpose.
# This is because HDBSCAN is dense based. And in a high dimensional space the data is generally sparse, which leads to less meaningful clusters and vastly greater computation time.

# %% [markdown]
# ### Dimensionality Reduction (Optional)

# %%
# Reduce dimensions a priori
# The clustering does not perform to good. Some datapoints that clearly should be in a cluster based on eyeballing and their topic name but they are not. Rather often some points in a dense cluster are categorized as noise.
# I will try to improve this by first perform a dimension reduction and then perform clustering. Reason being, that in high dimensions the data might be too sparse for the clustering algorithm to work properly.


import umap

data = read_json(path_db_embedded)
# Gather all embeddings
embeddings = [entry['embedding'] for entry in data]

# Convert to numpy array
X = np.array(embeddings)

# Perform UMAP
X_embedded = umap.UMAP(n_components=40).fit_transform(X) # 40 dimensions

# Store the updated embeddings in the data
for i, entry in enumerate(data):
    entry['embedding'] = X_embedded[i].tolist()

# %% [markdown]
# ### HDBSCAN

# %%
from helper.cluster_analysis import *
from helper.utils import *

# Adjustable parameters
dimensionality_methods = ['UMAP', 'PCA', 'tSNE']
hdbscan_params = {"min_cluster_size": 50, "min_samples": 2, "cluster_selection_epsilon": 0.15}

data = read_json(path_db_embedded)
df = pd.DataFrame(data)
df = df[df['embedding'].apply(lambda x: isinstance(x, list) and len(x) > 0)]
print(f"Loaded {len(df)} valid entries with embeddings.")

# Extract embeddings
mat = np.array(df['embedding'].tolist())

hdbscan_clusterer = hdbscan.HDBSCAN(**hdbscan_params)
cluster_labels = hdbscan_clusterer.fit_predict(mat)

reduction_results = {}

for method in dimensionality_methods:
    coords_2d = dimensionality_reduction(mat, method, n_components=2)
    reduction_results[f'hdbscan_{method}_2D'] = {
        'x': coords_2d[:, 0],
        'y': coords_2d[:, 1]
    }

# 3D Reduction
    coords_3d = dimensionality_reduction(mat, method, n_components=3)
    reduction_results[f'hdbscan_{method}_3D'] = {
        'x': coords_3d[:, 0],
        'y': coords_3d[:, 1],
        'z': coords_3d[:, 2]
    }

# Add dimensional coordinates to DataFrame
for method_dim, coords in reduction_results.items():
    for axis, values in coords.items():
        df[f'{method_dim}_{axis}'] = values

# Add the cluster labels to the DataFrame
df['hdbscan_id'] = cluster_labels
# Out:
# Loaded 9501 valid entries with embeddings.
# C:\Users\fbohm\Documents\Venvironments\.venv\Lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\fbohm\Documents\Venvironments\.venv\Lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2025-02-12 12:26:39,206 - INFO - Applying UMAP with 2 components.
# C:\Users\fbohm\Documents\Venvironments\.venv\Lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2025-02-12 12:26:41,260 - INFO - Applying UMAP with 3 components.
# C:\Users\fbohm\Documents\Venvironments\.venv\Lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2025-02-12 12:26:43,306 - INFO - Applying PCA with 2 components.
# 2025-02-12 12:26:43,386 - INFO - Applying PCA with 3 components.
# 2025-02-12 12:26:43,441 - INFO - Applying tSNE with 2 components.
# 2025-02-12 12:26:43,441 - INFO - Perplexity not provided, setting to 30 based on sample size.
# 2025-02-12 12:27:00,048 - INFO - Applying tSNE with 3 components.
# 2025-02-12 12:27:00,048 - INFO - Perplexity not provided, setting to 30 based on sample size.

# %% [markdown]
# ### KMeans (Optional)

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans

from helper.cluster_analysis import dimensionality_reduction


# Adjustable parameters
dimensionality_methods = ['UMAP', 'PCA', 'tSNE']
kmeans_clusters = [15, 21, 25, 50]


df = df[df['embedding'].apply(lambda x: isinstance(x, list) and len(x) > 0)]
print(f"Loaded {len(df)} valid entries with embeddings.")

# Extract embeddings
mat = np.array(df['embedding'].tolist())  # shape (n_samples, n_dimensions)

# --- KMeans Clustering (High-Dimensional) ---
for n_clusters in kmeans_clusters:
    kmeans_model = KMeans(n_clusters=n_clusters, random_state=42)
    cluster_labels = kmeans_model.fit_predict(mat)

    logger.info(f"Found {len(np.unique(cluster_labels))} clusters for KMeans with {n_clusters} clusters.")

    # Store the labels in a column named by cluster count
    df[f'kmeans_{n_clusters}_id'] = cluster_labels

# --- Dimensionality Reduction ---
# We do each method in 2D and 3D exactly once
reduction_results = {}

for method in dimensionality_methods:
    # 2D
    coords_2d = dimensionality_reduction(mat, method, n_components=2)
    reduction_results[f'kmeans_{method}_2D'] = {
        'x': coords_2d[:, 0],
        'y': coords_2d[:, 1]
    }

    # 3D
    coords_3d = dimensionality_reduction(mat, method, n_components=3)
    reduction_results[f'kmeans_{method}_3D'] = {
        'x': coords_3d[:, 0],
        'y': coords_3d[:, 1],
        'z': coords_3d[:, 2]
    }

# --- Add Dimensional Coordinates to DataFrame ---
for method_dim, coords in reduction_results.items():
    for axis, values in coords.items():
        df[f'{method_dim}_{axis}'] = values
# Out:
# Loaded 9501 valid entries with embeddings.
# 2025-02-12 12:27:37,951 - INFO - Found 15 clusters for KMeans with 15 clusters.
# 2025-02-12 12:27:38,093 - INFO - Found 21 clusters for KMeans with 21 clusters.
# 2025-02-12 12:27:38,292 - INFO - Found 25 clusters for KMeans with 25 clusters.
# 2025-02-12 12:27:38,476 - INFO - Found 50 clusters for KMeans with 50 clusters.
# 2025-02-12 12:27:38,478 - INFO - Applying UMAP with 2 components.
# C:\Users\fbohm\Documents\Venvironments\.venv\Lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2025-02-12 12:27:41,032 - INFO - Applying UMAP with 3 components.
# C:\Users\fbohm\Documents\Venvironments\.venv\Lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2025-02-12 12:27:43,514 - INFO - Applying PCA with 2 components.
# 2025-02-12 12:27:43,600 - INFO - Applying PCA with 3 components.
# 2025-02-12 12:27:43,666 - INFO - Applying tSNE with 2 components.
# 2025-02-12 12:27:43,666 - INFO - Perplexity not provided, setting to 30 based on sample size.
# 2025-02-12 12:28:02,266 - INFO - Applying tSNE with 3 components.
# 2025-02-12 12:28:02,266 - INFO - Perplexity not provided, setting to 30 based on sample size.

# %%
# Save the clustered data
# NOTE: either cluster algorithm is optional as well as the dimension reduction. Generally you want to perform HDBSCAN though with reduced dimensions and use kmeans only if you have an idea of the number of clusters up front.
save_df_as_json(df, path_db_clustered)
# Out:
# 2025-02-12 12:28:41,123 - INFO - Saving data to S:\SID\Analytics\Working Files\Individual\Florian\Projects\DataScience\cluster_analysis\Data\RivalStars\Steam\db_clustered.json

# %% [markdown]
# # Cluster Naming
# Lastly to make the clusters more meaningful on first sight, they will be named. Again OpenAIs models will be used to perfomr that. The k most centric points will be computed and the model will generate a name for the cluster based on these points.

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_distances

from helper.cluster_naming import *

api_settings = {"client": client, "model": chat_model_name}

def name_clusters(
    df,
    cluster_columns,
    embedding_col="embedding",
    text_col="sentence",
    top_k=25,
    skip_noise_label=-1
):
    for col in cluster_columns:
        # Prepare a dict to store {cluster_id -> cluster_name}
        cluster_id_to_name = {}
        logger.info((f'Preparing to name clusters in column "{col}"'))

        # Get unique cluster IDs from this column
        cluster_ids = df[col].unique()

        for cluster_id in cluster_ids:

            if skip_noise_label is not None and cluster_id == skip_noise_label:
                continue

            # Select rows belonging to this cluster
            cluster_data = df[df[col] == cluster_id]
            if cluster_data.empty:
                continue

            # Compute centroid of embeddings
            embeddings = np.array(cluster_data[embedding_col].tolist())
            centroid = embeddings.mean(axis=0, dtype=np.float32, keepdims=True)

            # Find top_k closest points to centroid
            distances = cosine_distances(centroid, embeddings).flatten()
            closest_indices = np.argsort(distances)[:top_k]
            representative_texts = cluster_data.iloc[closest_indices][text_col].tolist()

            # Call your naming function
            cluster_name = generate_cluster_name(representative_texts, api_settings)
            cluster_id_to_name[cluster_id] = cluster_name

        # Create a new column with the cluster name for each row
        name_col = f"{col}_name"
        df[name_col] = df[col].apply(lambda cid: cluster_id_to_name.get(cid, "Noise"))

    return df


data = read_json(path_db_clustered)  # data is probably a list of dicts
df = pd.DataFrame(data)              # Convert to DataFrame

cluster_columns = ['hdbscan_id', 'kmeans_15_id', 'kmeans_21_id', 'kmeans_25_id', 'kmeans_50_id']

df_named = name_clusters(
    df,
    cluster_columns,
    embedding_col="embedding",
    text_col="sentence",
    top_k=10,
    skip_noise_label=-1  # for HDBSCAN noise
)
# Out:
# 2025-02-12 12:30:39,139 - INFO - Preparing to name clusters in column "hdbscan_id"
# 2025-02-12 12:30:39,718 - INFO - Generated cluster name: Game Love and Enthusiasm
# 2025-02-12 12:30:39,718 - INFO - Tokens used so far: Prompt Tokens: 162, Completion Tokens: 6
# 2025-02-12 12:30:40,286 - INFO - Generated cluster name: Evening Gaming Enjoyment
# 2025-02-12 12:30:40,286 - INFO - Tokens used so far: Prompt Tokens: 324, Completion Tokens: 12
# 2025-02-12 12:30:40,949 - INFO - Generated cluster name: Engaging Horse Management Experience
# 2025-02-12 12:30:40,964 - INFO - Tokens used so far: Prompt Tokens: 519, Completion Tokens: 18
# 2025-02-12 12:30:41,633 - INFO - Generated cluster name: Horse Customization and Personalization
# 2025-02-12 12:30:41,633 - INFO - Tokens used so far: Prompt Tokens: 738, Completion Tokens: 25
# 2025-02-12 12:30:42,146 - INFO - Generated cluster name: Game Enthusiasm and Praise
# 2025-02-12 12:30:42,146 - INFO - Tokens used so far: Prompt Tokens: 923, Completion Tokens: 31
# 2025-02-12 12:30:42,699 - INFO - Generated cluster name: Stunning Graphics and Gameplay Quality
# 2025-02-12 12:30:42,702 - INFO - Tokens used so far: Prompt Tokens: 1055, Completion Tokens: 38
# 2025-02-12 12:30:43,295 - INFO - Generated cluster name: Desktop vs. Mobile Experience Comparison
# 2025-02-12 12:30:43,295 - INFO - Tokens used so far: Prompt Tokens: 1258, Completion Tokens: 45
# 2025-02-12 12:30:43,833 - INFO - Generated cluster name: "Superior Alternative to Mobile Games"
# 2025-02-12 12:30:43,833 - INFO - Tokens used so far: Prompt Tokens: 1471, Completion Tokens: 53
# 2025-02-12 12:30:44,289 - INFO - Generated cluster name: Game Performance Issues
# 2025-02-12 12:30:44,294 - INFO - Tokens used so far: Prompt Tokens: 1658, Completion Tokens: 57
# 2025-02-12 12:30:44,769 - INFO - Generated cluster name: Horse Racing and Breeding Enthusiasts
# 2025-02-12 12:30:44,769 - INFO - Tokens used so far: Prompt Tokens: 1848, Completion Tokens: 66
# 2025-02-12 12:30:45,338 - INFO - Generated cluster name: Cross Country Equestrian Gameplay
# 2025-02-12 12:30:45,353 - INFO - Tokens used so far: Prompt Tokens: 2031, Completion Tokens: 73
# 2025-02-12 12:30:45,881 - INFO - Generated cluster name: Horse Breeding Enthusiasm
# 2025-02-12 12:30:45,881 - INFO - Tokens used so far: Prompt Tokens: 2200, Completion Tokens: 79
# 2025-02-12 12:30:46,399 - INFO - Generated cluster name: Engaging Farm Quest Narrative
# 2025-02-12 12:30:46,399 - INFO - Tokens used so far: Prompt Tokens: 2438, Completion Tokens: 85
# 2025-02-12 12:30:46,927 - INFO - Generated cluster name: Top Equestrian Game Praise
# 2025-02-12 12:30:46,927 - INFO - Tokens used so far: Prompt Tokens: 2613, Completion Tokens: 92
# 2025-02-12 12:30:47,674 - INFO - Generated cluster name: Highly Realistic Horse Racing Games
# 2025-02-12 12:30:47,674 - INFO - Tokens used so far: Prompt Tokens: 2772, Completion Tokens: 99
# 2025-02-12 12:30:48,297 - INFO - Generated cluster name: Exceptional Horse Racing Experiences
# 2025-02-12 12:30:48,297 - INFO - Tokens used so far: Prompt Tokens: 2923, Completion Tokens: 104
# 2025-02-12 12:30:49,071 - INFO - Generated cluster name: Horse Breeding and Genetics Dynamics
# 2025-02-12 12:30:49,071 - INFO - Tokens used so far: Prompt Tokens: 3152, Completion Tokens: 111
# 2025-02-12 12:30:49,650 - INFO - Generated cluster name: Horse Aesthetics Appreciation
# 2025-02-12 12:30:49,666 - INFO - Tokens used so far: Prompt Tokens: 3314, Completion Tokens: 117
# 2025-02-12 12:30:50,168 - INFO - Generated cluster name: Balanced Game Difficulty Opinions
# 2025-02-12 12:30:50,168 - INFO - Tokens used so far: Prompt Tokens: 3514, Completion Tokens: 122
# 2025-02-12 12:30:50,685 - INFO - Generated cluster name: Strong Recommendations for Horse Games
# 2025-02-12 12:30:50,685 - INFO - Tokens used so far: Prompt Tokens: 3668, Completion Tokens: 128
# 2025-02-12 12:30:51,200 - INFO - Generated cluster name: Addictive Fun and Time Wasting
# 2025-02-12 12:30:51,200 - INFO - Tokens used so far: Prompt Tokens: 3809, Completion Tokens: 136
# 2025-02-12 12:30:51,782 - INFO - Generated cluster name: Value Perception of RSHR Desktop
# 2025-02-12 12:30:51,782 - INFO - Tokens used so far: Prompt Tokens: 4023, Completion Tokens: 145
# 2025-02-12 12:30:52,302 - INFO - Generated cluster name: Multiplayer Racing Experience Feedback
# 2025-02-12 12:30:52,302 - INFO - Tokens used so far: Prompt Tokens: 4212, Completion Tokens: 151
# 2025-02-12 12:30:52,807 - INFO - Generated cluster name: Value Assessment of Game Prices
# 2025-02-12 12:30:52,807 - INFO - Tokens used so far: Prompt Tokens: 4427, Completion Tokens: 157
# 2025-02-12 12:30:53,294 - INFO - Generated cluster name: Addictive Gaming Experience
# 2025-02-12 12:30:53,294 - INFO - Tokens used so far: Prompt Tokens: 4623, Completion Tokens: 162
# 2025-02-12 12:30:53,818 - INFO - Generated cluster name: Enjoyable and Engaging Gameplay
# 2025-02-12 12:30:53,818 - INFO - Tokens used so far: Prompt Tokens: 4803, Completion Tokens: 169
# 2025-02-12 12:30:54,871 - INFO - Generated cluster name: Game Update Optimization
# 2025-02-12 12:30:54,871 - INFO - Tokens used so far: Prompt Tokens: 4976, Completion Tokens: 173
# 2025-02-12 12:30:55,373 - INFO - Generated cluster name: Game Value Opinions
# 2025-02-12 12:30:55,373 - INFO - Tokens used so far: Prompt Tokens: 5186, Completion Tokens: 177
# 2025-02-12 12:30:55,914 - INFO - Generated cluster name: Repetitive Gameplay Feedback
# 2025-02-12 12:30:55,916 - INFO - Tokens used so far: Prompt Tokens: 5427, Completion Tokens: 183
# 2025-02-12 12:30:56,508 - INFO - Generated cluster name: Horse Breeding and Racing Enthusiasm
# 2025-02-12 12:30:56,508 - INFO - Tokens used so far: Prompt Tokens: 5634, Completion Tokens: 191
# 2025-02-12 12:30:57,019 - INFO - Generated cluster name: Highly Recommended Horse Racing Game
# 2025-02-12 12:30:57,019 - INFO - Tokens used so far: Prompt Tokens: 5809, Completion Tokens: 197
# 2025-02-12 12:30:57,533 - INFO - Generated cluster name: Accessible Family-Friendly Horse Racing Game
# 2025-02-12 12:30:57,533 - INFO - Tokens used so far: Prompt Tokens: 6027, Completion Tokens: 204
# 2025-02-12 12:30:57,976 - INFO - Generated cluster name: Desktop Versus Mobile Gaming Experience
# 2025-02-12 12:30:57,976 - INFO - Tokens used so far: Prompt Tokens: 6247, Completion Tokens: 211
# 2025-02-12 12:30:58,704 - INFO - Generated cluster name: "Enjoyment of Horse Racing"
# 2025-02-12 12:30:58,710 - INFO - Tokens used so far: Prompt Tokens: 6417, Completion Tokens: 219
# 2025-02-12 12:30:59,202 - INFO - Generated cluster name: Horse Breeding System Insights
# 2025-02-12 12:30:59,204 - INFO - Tokens used so far: Prompt Tokens: 6628, Completion Tokens: 225
# 2025-02-12 12:30:59,858 - INFO - Generated cluster name: Addictive and Engaging Gameplay
# 2025-02-12 12:30:59,858 - INFO - Tokens used so far: Prompt Tokens: 6811, Completion Tokens: 232
# 2025-02-12 12:31:00,394 - INFO - Generated cluster name: Microtransaction Frustrations in Gaming
# 2025-02-12 12:31:00,394 - INFO - Tokens used so far: Prompt Tokens: 7057, Completion Tokens: 240
# 2025-02-12 12:31:00,409 - INFO - Preparing to name clusters in column "kmeans_15_id"
# 2025-02-12 12:31:01,137 - INFO - Generated cluster name: Game Love and Enjoyment
# 2025-02-12 12:31:01,137 - INFO - Tokens used so far: Prompt Tokens: 7231, Completion Tokens: 246
# 2025-02-12 12:31:01,812 - INFO - Generated cluster name: Beautifully Designed Horses
# 2025-02-12 12:31:01,828 - INFO - Tokens used so far: Prompt Tokens: 7393, Completion Tokens: 251
# 2025-02-12 12:31:02,384 - INFO - Generated cluster name: Desktop vs. Mobile Game Comparison
# 2025-02-12 12:31:02,384 - INFO - Tokens used so far: Prompt Tokens: 7634, Completion Tokens: 258
# 2025-02-12 12:31:02,961 - INFO - Generated cluster name: Endless Horse Racing Adventures
# 2025-02-12 12:31:02,961 - INFO - Tokens used so far: Prompt Tokens: 7847, Completion Tokens: 264
# 2025-02-12 12:31:03,487 - INFO - Generated cluster name: Horse Customization Features
# 2025-02-12 12:31:03,487 - INFO - Tokens used so far: Prompt Tokens: 8054, Completion Tokens: 269
# 2025-02-12 12:31:03,982 - INFO - Generated cluster name: Pricing Concerns and Valuation Opinions
# 2025-02-12 12:31:03,982 - INFO - Tokens used so far: Prompt Tokens: 8257, Completion Tokens: 277
# 2025-02-12 12:31:04,527 - INFO - Generated cluster name: Horse Racing Game Appreciation
# 2025-02-12 12:31:04,527 - INFO - Tokens used so far: Prompt Tokens: 8413, Completion Tokens: 282
# 2025-02-12 12:31:04,992 - INFO - Generated cluster name: Graphics and Gameplay Excellence
# 2025-02-12 12:31:04,992 - INFO - Tokens used so far: Prompt Tokens: 8554, Completion Tokens: 287
# 2025-02-12 12:31:05,491 - INFO - Generated cluster name: Progress and Playability in Gaming
# 2025-02-12 12:31:05,491 - INFO - Tokens used so far: Prompt Tokens: 8797, Completion Tokens: 294
# 2025-02-12 12:31:06,082 - INFO - Generated cluster name: Horse Racing Enthusiasts' Game
# 2025-02-12 12:31:06,090 - INFO - Tokens used so far: Prompt Tokens: 9016, Completion Tokens: 302
# 2025-02-12 12:31:06,626 - INFO - Generated cluster name: Horse Breeding and Racing Dynamics
# 2025-02-12 12:31:06,626 - INFO - Tokens used so far: Prompt Tokens: 9245, Completion Tokens: 309
# 2025-02-12 12:31:07,845 - INFO - Generated cluster name: Storyline Quality and Engagement
# 2025-02-12 12:31:07,845 - INFO - Tokens used so far: Prompt Tokens: 9475, Completion Tokens: 315
# 2025-02-12 12:31:08,445 - INFO - Generated cluster name: Passion for Horse Racing
# 2025-02-12 12:31:08,445 - INFO - Tokens used so far: Prompt Tokens: 9629, Completion Tokens: 321
# 2025-02-12 12:31:08,867 - INFO - Generated cluster name: Continuous Game Updates
# 2025-02-12 12:31:08,867 - INFO - Tokens used so far: Prompt Tokens: 9821, Completion Tokens: 325
# 2025-02-12 12:31:09,310 - INFO - Generated cluster name: Highly Recommended Horse Game
# 2025-02-12 12:31:09,310 - INFO - Tokens used so far: Prompt Tokens: 9964, Completion Tokens: 330
# 2025-02-12 12:31:09,331 - INFO - Preparing to name clusters in column "kmeans_21_id"
# 2025-02-12 12:31:09,974 - INFO - Generated cluster name: Game Enjoyment and Recommendations
# 2025-02-12 12:31:09,974 - INFO - Tokens used so far: Prompt Tokens: 10105, Completion Tokens: 336
# 2025-02-12 12:31:10,463 - INFO - Generated cluster name: Adorable and Artistic Horses
# 2025-02-12 12:31:10,463 - INFO - Tokens used so far: Prompt Tokens: 10267, Completion Tokens: 342
# 2025-02-12 12:31:11,075 - INFO - Generated cluster name: Ultimate Horse Racing Fun
# 2025-02-12 12:31:11,075 - INFO - Tokens used so far: Prompt Tokens: 10470, Completion Tokens: 347
# 2025-02-12 12:31:11,609 - INFO - Generated cluster name: Mobile vs. Desktop Game Experience
# 2025-02-12 12:31:11,609 - INFO - Tokens used so far: Prompt Tokens: 10687, Completion Tokens: 354
# 2025-02-12 12:31:12,239 - INFO - Generated cluster name: Horse Racing Management Experience
# 2025-02-12 12:31:12,255 - INFO - Tokens used so far: Prompt Tokens: 10927, Completion Tokens: 359
# 2025-02-12 12:31:12,830 - INFO - Generated cluster name: Custom Horse Aesthetics and Options
# 2025-02-12 12:31:12,830 - INFO - Tokens used so far: Prompt Tokens: 11132, Completion Tokens: 367
# 2025-02-12 12:31:13,361 - INFO - Generated cluster name: Value for Money in Gaming
# 2025-02-12 12:31:13,372 - INFO - Tokens used so far: Prompt Tokens: 11309, Completion Tokens: 373
# 2025-02-12 12:31:13,912 - INFO - Generated cluster name: Stunning Graphics and Gameplay Experience
# 2025-02-12 12:31:13,912 - INFO - Tokens used so far: Prompt Tokens: 11462, Completion Tokens: 380
# 2025-02-12 12:31:14,703 - INFO - Generated cluster name: Visually Stunning Horse Racing Game
# 2025-02-12 12:31:14,703 - INFO - Tokens used so far: Prompt Tokens: 11630, Completion Tokens: 387
# 2025-02-12 12:31:15,434 - INFO - Generated cluster name: Gaming Bugs and Content Issues
# 2025-02-12 12:31:15,441 - INFO - Tokens used so far: Prompt Tokens: 11908, Completion Tokens: 393
# 2025-02-12 12:31:16,174 - INFO - Generated cluster name: Horse Breeding Mechanics and Features
# 2025-02-12 12:31:16,174 - INFO - Tokens used so far: Prompt Tokens: 12124, Completion Tokens: 400
# 2025-02-12 12:31:16,729 - INFO - Generated cluster name: Story-Driven Farm Game Experience
# 2025-02-12 12:31:16,729 - INFO - Tokens used so far: Prompt Tokens: 12398, Completion Tokens: 407
# 2025-02-12 12:31:17,280 - INFO - Generated cluster name: Horse Racing Game Reviews
# 2025-02-12 12:31:17,287 - INFO - Tokens used so far: Prompt Tokens: 12555, Completion Tokens: 412
# 2025-02-12 12:31:17,841 - INFO - Generated cluster name: Gameplay Difficulty and Engagement
# 2025-02-12 12:31:17,841 - INFO - Tokens used so far: Prompt Tokens: 12734, Completion Tokens: 417
# 2025-02-12 12:31:18,587 - INFO - Generated cluster name: Realistic Horse Racing Experience
# 2025-02-12 12:31:18,587 - INFO - Tokens used so far: Prompt Tokens: 12884, Completion Tokens: 423
# 2025-02-12 12:31:19,082 - INFO - Generated cluster name: Simplified Currency & Fair Gameplay
# 2025-02-12 12:31:19,082 - INFO - Tokens used so far: Prompt Tokens: 13121, Completion Tokens: 430
# 2025-02-12 12:31:19,720 - INFO - Generated cluster name: Overpriced Mobile Game Critiques
# 2025-02-12 12:31:19,720 - INFO - Tokens used so far: Prompt Tokens: 13400, Completion Tokens: 437
# 2025-02-12 12:31:20,368 - INFO - Generated cluster name: Continuous Game Updates and Improvements
# 2025-02-12 12:31:20,368 - INFO - Tokens used so far: Prompt Tokens: 13584, Completion Tokens: 443
# 2025-02-12 12:31:20,970 - INFO - Generated cluster name: Highly Recommended Horse Racing Game
# 2025-02-12 12:31:20,970 - INFO - Tokens used so far: Prompt Tokens: 13730, Completion Tokens: 449
# 2025-02-12 12:31:21,578 - INFO - Generated cluster name: Passion for Horse Racing
# 2025-02-12 12:31:21,578 - INFO - Tokens used so far: Prompt Tokens: 13885, Completion Tokens: 455
# 2025-02-12 12:31:22,463 - INFO - Generated cluster name: Repetitive Gameplay Experience
# 2025-02-12 12:31:22,463 - INFO - Tokens used so far: Prompt Tokens: 14101, Completion Tokens: 461
# 2025-02-12 12:31:22,473 - INFO - Preparing to name clusters in column "kmeans_25_id"
# 2025-02-12 12:31:23,038 - INFO - Generated cluster name: Highly Recommended Fun Game
# 2025-02-12 12:31:23,054 - INFO - Tokens used so far: Prompt Tokens: 14264, Completion Tokens: 466
# 2025-02-12 12:31:23,626 - INFO - Generated cluster name: Horse Aesthetics and Appreciation
# 2025-02-12 12:31:23,626 - INFO - Tokens used so far: Prompt Tokens: 14426, Completion Tokens: 473
# 2025-02-12 12:31:24,110 - INFO - Generated cluster name: Passionate Horse Game Enthusiasm
# 2025-02-12 12:31:24,110 - INFO - Tokens used so far: Prompt Tokens: 14613, Completion Tokens: 480
# 2025-02-12 12:31:24,811 - INFO - Generated cluster name: Superior Experience Compared to Mobile
# 2025-02-12 12:31:24,811 - INFO - Tokens used so far: Prompt Tokens: 14822, Completion Tokens: 486
# 2025-02-12 12:31:25,398 - INFO - Generated cluster name: Equestrian Gameplay Variety
# 2025-02-12 12:31:25,398 - INFO - Tokens used so far: Prompt Tokens: 15026, Completion Tokens: 491
# 2025-02-12 12:31:25,980 - INFO - Generated cluster name: Horse Customization Features
# 2025-02-12 12:31:25,980 - INFO - Tokens used so far: Prompt Tokens: 15248, Completion Tokens: 496
# 2025-02-12 12:31:26,425 - INFO - Generated cluster name: Game Value Opinions
# 2025-02-12 12:31:26,425 - INFO - Tokens used so far: Prompt Tokens: 15451, Completion Tokens: 500
# 2025-02-12 12:31:27,063 - INFO - Generated cluster name: Stunning Game Graphics Reviews
# 2025-02-12 12:31:27,063 - INFO - Tokens used so far: Prompt Tokens: 15595, Completion Tokens: 506
# 2025-02-12 12:31:27,551 - INFO - Generated cluster name: Horse Racing Experience Improvement
# 2025-02-12 12:31:27,551 - INFO - Tokens used so far: Prompt Tokens: 15803, Completion Tokens: 511
# 2025-02-12 12:31:28,209 - INFO - Generated cluster name: Horse Game Interaction Features
# 2025-02-12 12:31:28,209 - INFO - Tokens used so far: Prompt Tokens: 16043, Completion Tokens: 516
# 2025-02-12 12:31:28,788 - INFO - Generated cluster name: Horse Racing Game Enthusiasts
# 2025-02-12 12:31:28,788 - INFO - Tokens used so far: Prompt Tokens: 16233, Completion Tokens: 523
# 2025-02-12 12:31:29,369 - INFO - Generated cluster name: Horse Breeding Experiences and Mechanics
# 2025-02-12 12:31:29,369 - INFO - Tokens used so far: Prompt Tokens: 16454, Completion Tokens: 530
# 2025-02-12 12:31:29,985 - INFO - Generated cluster name: Balanced Challenge in Gaming
# 2025-02-12 12:31:29,985 - INFO - Tokens used so far: Prompt Tokens: 16669, Completion Tokens: 535
# 2025-02-12 12:31:30,848 - INFO - Generated cluster name: Engaging Narrative and Character Development
# 2025-02-12 12:31:30,848 - INFO - Tokens used so far: Prompt Tokens: 16857, Completion Tokens: 542
# 2025-02-12 12:31:31,502 - INFO - Generated cluster name: Mixed Reviews on Horse Racing Games
# 2025-02-12 12:31:31,502 - INFO - Tokens used so far: Prompt Tokens: 17023, Completion Tokens: 549
# 2025-02-12 12:31:32,119 - INFO - Generated cluster name: Realistic Gaming Experience
# 2025-02-12 12:31:32,135 - INFO - Tokens used so far: Prompt Tokens: 17180, Completion Tokens: 554
# 2025-02-12 12:31:32,750 - INFO - Generated cluster name: Gold Currency and Game Economy
# 2025-02-12 12:31:32,750 - INFO - Tokens used so far: Prompt Tokens: 17400, Completion Tokens: 560
# 2025-02-12 12:31:33,336 - INFO - Generated cluster name: Pricing Concerns for Mobile Games
# 2025-02-12 12:31:33,352 - INFO - Tokens used so far: Prompt Tokens: 17642, Completion Tokens: 567
# 2025-02-12 12:31:33,986 - INFO - Generated cluster name: Level Progression in Gaming
# 2025-02-12 12:31:33,986 - INFO - Tokens used so far: Prompt Tokens: 17916, Completion Tokens: 573
# 2025-02-12 12:31:34,622 - INFO - Generated cluster name: Continuous Game Updates and Improvements
# 2025-02-12 12:31:34,622 - INFO - Tokens used so far: Prompt Tokens: 18133, Completion Tokens: 579
# 2025-02-12 12:31:35,081 - INFO - Generated cluster name: Highly Recommended Horse Games
# 2025-02-12 12:31:35,081 - INFO - Tokens used so far: Prompt Tokens: 18275, Completion Tokens: 584
# 2025-02-12 12:31:35,580 - INFO - Generated cluster name: Addictive Gaming Experience
# 2025-02-12 12:31:35,580 - INFO - Tokens used so far: Prompt Tokens: 18462, Completion Tokens: 589
# 2025-02-12 12:31:36,237 - INFO - Generated cluster name: Game Repetition and Fatigue
# 2025-02-12 12:31:36,237 - INFO - Tokens used so far: Prompt Tokens: 18678, Completion Tokens: 596
# 2025-02-12 12:31:36,741 - INFO - Generated cluster name: Passion for Horse Racing
# 2025-02-12 12:31:36,741 - INFO - Tokens used so far: Prompt Tokens: 18836, Completion Tokens: 602
# 2025-02-12 12:31:37,710 - INFO - Generated cluster name: Game Completion and Playtime Insights
# 2025-02-12 12:31:37,710 - INFO - Tokens used so far: Prompt Tokens: 18999, Completion Tokens: 609
# 2025-02-12 12:31:37,726 - INFO - Preparing to name clusters in column "kmeans_50_id"
# 2025-02-12 12:31:38,300 - INFO - Generated cluster name: Ultimate Relaxation Game Experience
# 2025-02-12 12:31:38,300 - INFO - Tokens used so far: Prompt Tokens: 19168, Completion Tokens: 615
# 2025-02-12 12:31:39,349 - INFO - Generated cluster name: Horse Racing Management Experience
# 2025-02-12 12:31:39,349 - INFO - Tokens used so far: Prompt Tokens: 19430, Completion Tokens: 620
# 2025-02-12 12:31:39,882 - INFO - Generated cluster name: Addictive Equine Gaming Experience
# 2025-02-12 12:31:39,882 - INFO - Tokens used so far: Prompt Tokens: 19616, Completion Tokens: 627
# 2025-02-12 12:31:40,451 - INFO - Generated cluster name: Praise for Desktop Gaming Experience
# 2025-02-12 12:31:40,451 - INFO - Tokens used so far: Prompt Tokens: 19832, Completion Tokens: 633
# 2025-02-12 12:31:41,851 - INFO - Generated cluster name: Ultimate Horse Management Experience
# 2025-02-12 12:31:41,851 - INFO - Tokens used so far: Prompt Tokens: 20052, Completion Tokens: 638
# 2025-02-12 12:31:42,479 - INFO - Generated cluster name: Comprehensive Customization Options
# 2025-02-12 12:31:42,479 - INFO - Tokens used so far: Prompt Tokens: 20242, Completion Tokens: 644
# 2025-02-12 12:31:43,196 - INFO - Generated cluster name: Value Assessment of Games
# 2025-02-12 12:31:43,212 - INFO - Tokens used so far: Prompt Tokens: 20453, Completion Tokens: 649
# 2025-02-12 12:31:43,688 - INFO - Generated cluster name: Ultimate Game Praise
# 2025-02-12 12:31:43,688 - INFO - Tokens used so far: Prompt Tokens: 20606, Completion Tokens: 653
# 2025-02-12 12:31:44,294 - INFO - Generated cluster name: Stunning Graphics and Gameplay
# 2025-02-12 12:31:44,294 - INFO - Tokens used so far: Prompt Tokens: 20740, Completion Tokens: 659
# 2025-02-12 12:31:45,074 - INFO - Generated cluster name: Desktop Version vs. Mobile Experience
# 2025-02-12 12:31:45,074 - INFO - Tokens used so far: Prompt Tokens: 20963, Completion Tokens: 666
# 2025-02-12 12:31:45,671 - INFO - Generated cluster name: Smooth Gaming Experience
# 2025-02-12 12:31:45,671 - INFO - Tokens used so far: Prompt Tokens: 21163, Completion Tokens: 670
# 2025-02-12 12:31:46,274 - INFO - Generated cluster name: Horse Racing and Breeding Games
# 2025-02-12 12:31:46,274 - INFO - Tokens used so far: Prompt Tokens: 21353, Completion Tokens: 677
# 2025-02-12 12:31:46,917 - INFO - Generated cluster name: Cross Country Excitement and Features
# 2025-02-12 12:31:46,917 - INFO - Tokens used so far: Prompt Tokens: 21540, Completion Tokens: 685
# 2025-02-12 12:31:47,500 - INFO - Generated cluster name: Horse Breeding Enjoyment
# 2025-02-12 12:31:47,502 - INFO - Tokens used so far: Prompt Tokens: 21726, Completion Tokens: 691
# 2025-02-12 12:31:47,987 - INFO - Generated cluster name: Game Bugs and Glitches
# 2025-02-12 12:31:47,987 - INFO - Tokens used so far: Prompt Tokens: 21969, Completion Tokens: 697
# 2025-02-12 12:31:48,522 - INFO - Generated cluster name: Engaging Storylines in Gaming
# 2025-02-12 12:31:48,522 - INFO - Tokens used so far: Prompt Tokens: 22125, Completion Tokens: 704
# 2025-02-12 12:31:49,041 - INFO - Generated cluster name: Exceptional Horse Game Quality
# 2025-02-12 12:31:49,042 - INFO - Tokens used so far: Prompt Tokens: 22306, Completion Tokens: 709
# 2025-02-12 12:31:49,748 - INFO - Generated cluster name: Balanced Game Difficulty Dynamics
# 2025-02-12 12:31:49,749 - INFO - Tokens used so far: Prompt Tokens: 22546, Completion Tokens: 714
# 2025-02-12 12:31:50,276 - INFO - Generated cluster name: Ultra-Realistic Horse Racing Games
# 2025-02-12 12:31:50,279 - INFO - Tokens used so far: Prompt Tokens: 22696, Completion Tokens: 722
# 2025-02-12 12:31:50,817 - INFO - Generated cluster name: Immersive Rewarding Gaming Experiences
# 2025-02-12 12:31:50,817 - INFO - Tokens used so far: Prompt Tokens: 22876, Completion Tokens: 730
# 2025-02-12 12:31:51,354 - INFO - Generated cluster name: Horse Racing Game Mechanics
# 2025-02-12 12:31:51,354 - INFO - Tokens used so far: Prompt Tokens: 23067, Completion Tokens: 735
# 2025-02-12 12:31:51,927 - INFO - Generated cluster name: Coat Color Diversity and Appeal
# 2025-02-12 12:31:51,929 - INFO - Tokens used so far: Prompt Tokens: 23222, Completion Tokens: 742
# 2025-02-12 12:31:52,467 - INFO - Generated cluster name: Horse Customization and Colors
# 2025-02-12 12:31:52,467 - INFO - Tokens used so far: Prompt Tokens: 23413, Completion Tokens: 748
# 2025-02-12 12:31:53,000 - INFO - Generated cluster name: Art and Character Design Evaluation
# 2025-02-12 12:31:53,002 - INFO - Tokens used so far: Prompt Tokens: 23611, Completion Tokens: 754
# 2025-02-12 12:31:53,496 - INFO - Generated cluster name: In-Game Purchase Free Experience
# 2025-02-12 12:31:53,504 - INFO - Tokens used so far: Prompt Tokens: 23802, Completion Tokens: 761
# 2025-02-12 12:31:54,504 - INFO - Generated cluster name: Game Price Concerns and Recommendations
# 2025-02-12 12:31:54,504 - INFO - Tokens used so far: Prompt Tokens: 24085, Completion Tokens: 768
# 2025-02-12 12:31:54,952 - INFO - Generated cluster name: Horse Game Level Progression
# 2025-02-12 12:31:54,952 - INFO - Tokens used so far: Prompt Tokens: 24337, Completion Tokens: 774
# 2025-02-12 12:31:55,488 - INFO - Generated cluster name: Continuous Game Improvements and Upgrades
# 2025-02-12 12:31:55,489 - INFO - Tokens used so far: Prompt Tokens: 24570, Completion Tokens: 781
# 2025-02-12 12:31:56,119 - INFO - Generated cluster name: Value Assessment of Game Pricing
# 2025-02-12 12:31:56,119 - INFO - Tokens used so far: Prompt Tokens: 24781, Completion Tokens: 787
# 2025-02-12 12:31:56,674 - INFO - Generated cluster name: Horse Game Recommendations
# 2025-02-12 12:31:56,674 - INFO - Tokens used so far: Prompt Tokens: 24942, Completion Tokens: 791
# 2025-02-12 12:31:57,230 - INFO - Generated cluster name: Horse Racing and Breeding Experience
# 2025-02-12 12:31:57,230 - INFO - Tokens used so far: Prompt Tokens: 25171, Completion Tokens: 798
# 2025-02-12 12:31:58,418 - INFO - Generated cluster name: Free Roam Riding Experience
# 2025-02-12 12:31:58,432 - INFO - Tokens used so far: Prompt Tokens: 25386, Completion Tokens: 804
# 2025-02-12 12:31:58,893 - INFO - Generated cluster name: Gold Currency System Benefits
# 2025-02-12 12:31:58,893 - INFO - Tokens used so far: Prompt Tokens: 25639, Completion Tokens: 809
# 2025-02-12 12:31:59,536 - INFO - Generated cluster name: Unstoppable Gaming Addiction
# 2025-02-12 12:31:59,537 - INFO - Tokens used so far: Prompt Tokens: 25826, Completion Tokens: 815
# 2025-02-12 12:32:00,055 - INFO - Generated cluster name: Content Quality and Gameplay Issues
# 2025-02-12 12:32:00,055 - INFO - Tokens used so far: Prompt Tokens: 26013, Completion Tokens: 821
# 2025-02-12 12:32:00,617 - INFO - Generated cluster name: Engaging and Enjoyable Gaming Experience
# 2025-02-12 12:32:00,619 - INFO - Tokens used so far: Prompt Tokens: 26180, Completion Tokens: 829
# 2025-02-12 12:32:01,637 - INFO - Generated cluster name: Horse Training Mechanics and Strategy
# 2025-02-12 12:32:01,638 - INFO - Tokens used so far: Prompt Tokens: 26436, Completion Tokens: 835
# 2025-02-12 12:32:02,067 - INFO - Generated cluster name: Outstanding Graphics in Gaming
# 2025-02-12 12:32:02,067 - INFO - Tokens used so far: Prompt Tokens: 26590, Completion Tokens: 840
# 2025-02-12 12:32:03,853 - INFO - Generated cluster name: Ongoing Game Updates and Enhancements
# 2025-02-12 12:32:03,853 - INFO - Tokens used so far: Prompt Tokens: 26794, Completion Tokens: 848
# 2025-02-12 12:32:04,332 - INFO - Generated cluster name: Horse Racing Game Recommendations
# 2025-02-12 12:32:04,332 - INFO - Tokens used so far: Prompt Tokens: 26982, Completion Tokens: 853
# 2025-02-12 12:32:04,855 - INFO - Generated cluster name: Diverse Racing Game Modes
# 2025-02-12 12:32:04,855 - INFO - Tokens used so far: Prompt Tokens: 27155, Completion Tokens: 859
# 2025-02-12 12:32:05,313 - INFO - Generated cluster name: Repetitive Gameplay Experience
# 2025-02-12 12:32:05,313 - INFO - Tokens used so far: Prompt Tokens: 27405, Completion Tokens: 865
# 2025-02-12 12:32:06,032 - INFO - Generated cluster name: Horse Racing Passion and Strategy
# 2025-02-12 12:32:06,032 - INFO - Tokens used so far: Prompt Tokens: 27603, Completion Tokens: 871
# 2025-02-12 12:32:06,669 - INFO - Generated cluster name: Horse Breeding Enjoyment
# 2025-02-12 12:32:06,673 - INFO - Tokens used so far: Prompt Tokens: 27822, Completion Tokens: 877
# 2025-02-12 12:32:07,329 - INFO - Generated cluster name: Desktop Gaming Experience Enhanced
# 2025-02-12 12:32:07,331 - INFO - Tokens used so far: Prompt Tokens: 28037, Completion Tokens: 882
# 2025-02-12 12:32:08,171 - INFO - Generated cluster name: Infrequent and Delayed Game Updates
# 2025-02-12 12:32:08,186 - INFO - Tokens used so far: Prompt Tokens: 28221, Completion Tokens: 891
# 2025-02-12 12:32:09,003 - INFO - Generated cluster name: Engaging and Addictive Gaming Experience
# 2025-02-12 12:32:09,019 - INFO - Tokens used so far: Prompt Tokens: 28402, Completion Tokens: 899
# 2025-02-12 12:32:09,533 - INFO - Generated cluster name: Horse Racing Experience Insights
# 2025-02-12 12:32:09,537 - INFO - Tokens used so far: Prompt Tokens: 28607, Completion Tokens: 904
# 2025-02-12 12:32:10,016 - INFO - Generated cluster name: Game Completion Experiences
# 2025-02-12 12:32:10,016 - INFO - Tokens used so far: Prompt Tokens: 28772, Completion Tokens: 908
# 2025-02-12 12:32:10,633 - INFO - Generated cluster name: Microtransaction-Free Gaming Experience
# 2025-02-12 12:32:10,634 - INFO - Tokens used so far: Prompt Tokens: 29009, Completion Tokens: 914

# %%
# Optionally get rid of the embeddings to save space
df_named.drop(columns=['embedding'], inplace=True)

# %%
save_data_for_streamlit(df_named, path_db_final)
# Out:
# 2025-02-12 12:32:32,505 - INFO - Saving updated data to S:\SID\Analytics\Working Files\Individual\Florian\Projects\DataScience\cluster_analysis\Data\RivalStars\Steam\db_final.json
# 2025-02-12 12:32:32,867 - INFO - Data saved successfully.
