# %%
# My modules
from helper.data_preparation import *
from helper.prompt_templates import *
from helper.data_analysis import *
from helper.embedding import *
from helper.cluster_analysis import *
from helper.cluster_naming import *

# General modules
import os
import openai
from dotenv import load_dotenv

# Language models
load_dotenv()
openai_api_key = os.getenv("OPENAI_API_KEY")
openai.api_key = openai_api_key
client = openai.Client()

chat_model_name = 'gpt-4o-mini'
embed_model_name = "all-MiniLM-L6-v2"
# embedding_model_name = 'sentence-transformers/all-mpnet-base-v2'


# Paths

root_dir = r'C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis'
path_input = prepare_file_path(root_dir, "Data/2024 Trimester 1.xlsx")
path_db_prepared = os.path.join(root_dir, "Data", "db_prepared_HRC.json")

path_db_analysed = os.path.join(root_dir, "Data", "db_analysed_empty.json")
path_db_progress_backup = os.path.join(root_dir, "Data", "db_progress_backup.json")

path_db_embedded = os.path.join(root_dir, "Data", "db_embedded.json")
path_db_clustered = os.path.join(root_dir, "Data", "db_clustered.json")
path_db_final = os.path.join(root_dir, "Data", "db_final.json")

# %% [markdown]
# ## 1. Prepare the Data

# %%
sample_size = 25
set_seed = 42

input_data = load_excel_to_data(path_input)
cleaned_data = clean_data(input_data)
sampled_data = sample_data(cleaned_data, sample_size = sample_size, seed=42)  # Set seed for reproducibility
save_data_to_json(sampled_data, path_db_prepared)
# Out:
# 2024-11-19 08:36:07,644 - INFO - Loading Excel file: C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data/Into the Dead Our Darkest Days_1511resposnes.xlsx
# 2024-11-19 08:36:08,451 - INFO - Excel data successfully loaded and converted to dictionary.
# 2024-11-19 08:36:08,451 - INFO - Cleaning data.
# 2024-11-19 08:36:08,473 - INFO - Data cleaning completed. Entries removed: 239
# 2024-11-19 08:36:08,473 - INFO - Setting random seed to: 42
# 2024-11-19 08:36:08,473 - INFO - Sampling data. Sample size: 25
# 2024-11-19 08:36:08,473 - INFO - Data sampling completed with unique IDs assigned.
# 2024-11-19 08:36:08,473 - INFO - Saving data to JSON: C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\db_prepared.json
# 2024-11-19 08:36:08,473 - INFO - Data successfully saved to JSON.

# %% [markdown]
# ## 2. Analyse the Data

# %%
# Load db_prepared 
db = load_json(path_db_prepared)

batch_size = 10 # How many entries to process before a backup is made. 

# Configure OpenAI API client and model
configure_api(api_client=client, model_name=chat_model_name)

# Load existing progress
processed_data, processed_ids = load_existing_progress(path_db_progress_backup)

# Process entries in batches
try:
    analyse_data(db, processed_data, processed_ids, path_db_progress_backup,,
except KeyboardInterrupt:
    logger.warning("Interrupted by user. Progress saved.")
except Exception as e:
    logger.error(f"Unexpected error: {e}")

# Save final output after all processing
save_progress(processed_data, path_db_analysed)
logger.info(f"Processing completed. Final data saved to {path_db_analysed}")
# Out:
# 2024-11-19 09:11:34,551 - INFO - Loading data from C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\db_prepared.json
# 2024-11-19 09:11:34,551 - INFO - Loading existing progress from C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\db_progress_backup.json
# 2024-11-19 09:11:34,551 - INFO - Skipping already processed entry ID 1
# 2024-11-19 09:11:34,551 - INFO - Skipping already processed entry ID 2
# 2024-11-19 09:11:34,551 - INFO - Skipping already processed entry ID 3
# 2024-11-19 09:11:34,551 - INFO - Processing entry ID 4
# 2024-11-19 09:11:34,551 - INFO - Extracting topics for entry ID 4
# 2024-11-19 09:11:37,268 - INFO - Analyzing sentiment for topic 'Gameplay' (Entry ID 4)
# 2024-11-19 09:11:37,635 - INFO - Analyzing sentiment for topic 'Tutorials' (Entry ID 4)
# 2024-11-19 09:11:38,113 - INFO - Analyzing sentiment for topic 'Game Mechanics' (Entry ID 4)
# 2024-11-19 09:11:38,626 - INFO - Analyzing sentiment for topic 'Graphics' (Entry ID 4)
# 2024-11-19 09:11:39,156 - INFO - Processing entry ID 5
# 2024-11-19 09:11:39,156 - INFO - Extracting topics for entry ID 5
# 2024-11-19 09:11:43,455 - WARNING - Processing interrupted by user. Saving progress...
# 2024-11-19 09:11:43,455 - INFO - Saving progress to C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\db_progress_backup.json
# 2024-11-19 09:11:43,459 - WARNING - Interrupted by user. Progress saved.
# 2024-11-19 09:11:43,459 - INFO - Saving progress to C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\db_analysed.json
# 2024-11-19 09:11:43,459 - INFO - Processing completed. Final data saved to C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\db_analysed.json

# %% [markdown]
# ## 3. Embed the Data

# %%
batch_size = 10 # Embedding is done in batches. After this number of embeddings the cache is cleared to avoid memory issues. Make the number low on weak hardware.
b_override = False  # Change to True if embeddings should be overwritten
embed_key = "topic"  # Change to "sentence" if you want to embed sentences

# Load the JSON data
data = load_json(path_db_analysed)

# Initialize the embedding model once
embed_model = initialize_embedding_model(model_name=embed_model_name)

# Process data in batches
for batch_start in range(0, len(data), batch_size):
    batch_end = min(batch_start + batch_size, len(data))
    batch = data[batch_start:batch_end]
    logger.info(f"Processing batch {batch_start // batch_size + 1} ({batch_start} to {batch_end})")
    batch = process_batch(batch, embed_model, b_override, embed_key=embed_key)
    data[batch_start:batch_end] = batch

# Convert the data to table format
df_table = convert_to_table(data)

# Save the final JSON table
save_to_json(df_table, path_db_embedded)
logger.info("Embedding and conversion to table format completed.")
# Out:
# 2024-11-19 09:49:32,329 - INFO - Loading data from C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\db_analysed.json
# 2024-11-19 09:49:32,336 - INFO - Loading embedding model: all-MiniLM-L6-v2
# C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\helper\data_embedding.py:25: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the langchain-huggingface package and should be used instead. To use it run `pip install -U langchain-huggingface` and import as `from langchain_huggingface import HuggingFaceEmbeddings`.
#   embed_model = LangchainEmbedding(HuggingFaceEmbeddings(model_name=model_name))
# 2024-11-19 09:49:35,683 - INFO - PyTorch version 2.4.0+cu124 available.
# 2024-11-19 09:49:35,695 - INFO - Polars version 1.12.0 available.
# 2024-11-19 09:49:35,695 - INFO - Duckdb version 1.1.2 available.
# 2024-11-19 09:49:36,696 - INFO - Use pytorch device_name: cuda
# 2024-11-19 09:49:36,696 - INFO - Load pretrained SentenceTransformer: all-MiniLM-L6-v2
# 2024-11-19 09:49:39,779 - INFO - Processing batch 1 (0 to 4)
# C:\Users\fbohm\Documents\Venvironments\Lib\site-packages\transformers\models\bert\modeling_bert.py:440: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:555.)
#   attn_output = torch.nn.functional.scaled_dot_product_attention(
# 2024-11-19 09:49:44,511 - INFO - Converting JSON data to a table format.
# 2024-11-19 09:49:44,527 - INFO - Conversion to table format completed.
# 2024-11-19 09:49:44,527 - INFO - Saving data to C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\db_embedded.json
# 2024-11-19 09:49:44,558 - INFO - Embedding and conversion to table format completed.

# %% [markdown]
# ## 4. Cluster the Data

# %%
# Adjustable parameters
dimensionality_methods = ['UMAP', 'PCA', 'tSNE']  # Dimensionality reduction methods
kmeans_clusters = [5, 10, 15]  # Number of clusters for KMeans
kmeans_seed = 42  # Seed for reproducibility
include_2d = True  # Whether to include 2D results
include_3d = True  # Whether to include 3D results
hdbscan_params = {"min_cluster_size": 5, "min_samples": 3, "cluster_selection_epsilon": 0.2}  # HDBSCAN params

# t-SNE specific parameter
perplexity = 15  # Set to a default or user-defined value

# Load data
df_total = load_embedded_data(path_db_embedded)
mat = np.array(df_total['embedding'].tolist())

# Apply dimensionality reduction and clustering
apply_clustering(
    df_total,
    mat,
    dimensionality_methods,
    kmeans_clusters,
    path_db_clustered,
    hdbscan_params=hdbscan_params,
    kmeans_seed=kmeans_seed,
    include_2d=include_2d,
    include_3d=include_3d
)
# Out:
# 2024-11-19 09:50:00,539 - INFO - Loading data from C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\db_embedded.json
# 2024-11-19 09:50:00,555 - INFO - Loaded 23 valid entries with embeddings.
# 2024-11-19 09:50:00,555 - INFO - Applying UMAP with 2 components.
# C:\Users\fbohm\Documents\Venvironments\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# 2024-11-19 09:50:06,339 - INFO - Applying HDBSCAN on UMAP 2D with params: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.2}
# 2024-11-19 09:50:06,339 - INFO - Applying KMeans with 5 clusters on UMAP 2D.
# C:\Users\fbohm\Documents\Venvironments\Lib\site-packages\threadpoolctl.py:1214: RuntimeWarning:
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#   warnings.warn(msg, RuntimeWarning)
# 2024-11-19 09:50:06,664 - INFO - Applying KMeans with 10 clusters on UMAP 2D.
# 2024-11-19 09:50:06,677 - INFO - Applying KMeans with 15 clusters on UMAP 2D.
# 2024-11-19 09:50:06,677 - INFO - Applying UMAP with 3 components.
# C:\Users\fbohm\Documents\Venvironments\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# 2024-11-19 09:50:06,724 - INFO - Applying HDBSCAN on UMAP 3D with params: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.2}
# 2024-11-19 09:50:06,740 - INFO - Applying KMeans with 5 clusters on UMAP 3D.
# 2024-11-19 09:50:06,740 - INFO - Applying KMeans with 10 clusters on UMAP 3D.
# 2024-11-19 09:50:06,765 - INFO - Applying KMeans with 15 clusters on UMAP 3D.
# 2024-11-19 09:50:06,772 - INFO - Applying PCA with 2 components.
# 2024-11-19 09:50:06,772 - INFO - Applying HDBSCAN on PCA 2D with params: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.2}
# 2024-11-19 09:50:06,787 - INFO - Applying KMeans with 5 clusters on PCA 2D.
# 2024-11-19 09:50:06,787 - INFO - Applying KMeans with 10 clusters on PCA 2D.
# 2024-11-19 09:50:06,803 - INFO - Applying KMeans with 15 clusters on PCA 2D.
# 2024-11-19 09:50:06,818 - INFO - Applying PCA with 3 components.
# 2024-11-19 09:50:06,834 - INFO - Applying HDBSCAN on PCA 3D with params: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.2}
# 2024-11-19 09:50:06,834 - INFO - Applying KMeans with 5 clusters on PCA 3D.
# 2024-11-19 09:50:06,850 - INFO - Applying KMeans with 10 clusters on PCA 3D.
# 2024-11-19 09:50:06,850 - INFO - Applying KMeans with 15 clusters on PCA 3D.
# 2024-11-19 09:50:06,866 - INFO - Applying tSNE with 2 components.
# 2024-11-19 09:50:06,866 - INFO - Perplexity not provided, setting to 22 based on sample size.
# 2024-11-19 09:50:07,024 - INFO - Applying HDBSCAN on tSNE 2D with params: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.2}
# 2024-11-19 09:50:07,024 - INFO - Applying KMeans with 5 clusters on tSNE 2D.
# 2024-11-19 09:50:07,040 - INFO - Applying KMeans with 10 clusters on tSNE 2D.
# 2024-11-19 09:50:07,055 - INFO - Applying KMeans with 15 clusters on tSNE 2D.
# 2024-11-19 09:50:07,071 - INFO - Applying tSNE with 3 components.
# 2024-11-19 09:50:07,071 - INFO - Perplexity not provided, setting to 22 based on sample size.
# 2024-11-19 09:50:07,243 - INFO - Applying HDBSCAN on tSNE 3D with params: {'min_cluster_size': 5, 'min_samples': 3, 'cluster_selection_epsilon': 0.2}
# 2024-11-19 09:50:07,243 - INFO - Applying KMeans with 5 clusters on tSNE 3D.
# 2024-11-19 09:50:07,243 - INFO - Applying KMeans with 10 clusters on tSNE 3D.
# 2024-11-19 09:50:07,265 - INFO - Applying KMeans with 15 clusters on tSNE 3D.
# 2024-11-19 09:50:07,275 - INFO - Saving results to C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\db_clustered.json
# 2024-11-19 09:50:07,290 - INFO - Clustering and dimensionality reduction completed.

# %% [markdown]
# ## 5. Name the Clusters

# %%
# Adjustable parameters
dimensionality_methods = ["UMAP", "PCA", "tSNE"]
clustering_algorithms = ["hdbscan", "kmeans"]
kmeans_clusters = [5, 10, 15, 20, 35]  # Number of clusters for KMeans
max_centers = 8  # Maximum number of topics for naming
chat_model_name = 'gpt-4o-mini'

# Load data
df_total = load_data_into_df(path_db_clustered)

# Process clusters and generate names
df_total = process_clusters(df_total, dimensionality_methods, clustering_algorithms, kmeans_clusters, max_centers, chat_model_name)

# Save results
save_data(df_total, path_db_final)
# Out:
# 2024-11-19 10:03:10,119 - INFO - Loading data from C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\db_clustered.json
# 2024-11-19 10:03:10,150 - INFO - Found 4 representative topics for cluster ID 2 in column kmeans_5_UMAP_2D.
# 2024-11-19 10:03:10,150 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:10,978 - INFO - Generated cluster name: Social Gaming Engagement Strategies
# 2024-11-19 10:03:10,993 - INFO - Found 4 representative topics for cluster ID 0 in column kmeans_5_UMAP_2D.
# 2024-11-19 10:03:10,993 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:11,940 - INFO - Generated cluster name: Weapon Aesthetics and Durability Features
# 2024-11-19 10:03:11,956 - INFO - Found 7 representative topics for cluster ID 1 in column kmeans_5_UMAP_2D.
# 2024-11-19 10:03:11,956 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:12,459 - INFO - Generated cluster name: Covert Operations and Surprise Tactics
# 2024-11-19 10:03:12,463 - INFO - Found 4 representative topics for cluster ID 3 in column kmeans_5_UMAP_2D.
# 2024-11-19 10:03:12,463 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:12,896 - INFO - Generated cluster name: Game Mechanics and Player Experience
# 2024-11-19 10:03:12,896 - INFO - Found 4 representative topics for cluster ID 4 in column kmeans_5_UMAP_2D.
# 2024-11-19 10:03:12,896 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:13,361 - INFO - Generated cluster name: Visual Guides for Content Creation
# 2024-11-19 10:03:13,377 - INFO - Found 2 representative topics for cluster ID 8 in column kmeans_10_UMAP_2D.
# 2024-11-19 10:03:13,377 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:14,232 - INFO - Generated cluster name: Team-Based Recruitment Strategies
# 2024-11-19 10:03:14,248 - INFO - Found 1 representative topics for cluster ID 1 in column kmeans_10_UMAP_2D.
# 2024-11-19 10:03:14,248 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:14,800 - INFO - Generated cluster name: Location-Based Alerts
# 2024-11-19 10:03:14,800 - INFO - Found 3 representative topics for cluster ID 4 in column kmeans_10_UMAP_2D.
# 2024-11-19 10:03:14,800 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:15,226 - INFO - Generated cluster name: Weapon Durability and Audio Design
# 2024-11-19 10:03:15,242 - INFO - Found 3 representative topics for cluster ID 2 in column kmeans_10_UMAP_2D.
# 2024-11-19 10:03:15,242 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:15,682 - INFO - Generated cluster name: Arcade Survival Game Elements
# 2024-11-19 10:03:15,682 - INFO - Found 2 representative topics for cluster ID 6 in column kmeans_10_UMAP_2D.
# 2024-11-19 10:03:15,697 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:16,150 - INFO - Generated cluster name: Weapon Terminology and Conclusions
# 2024-11-19 10:03:16,153 - INFO - Found 3 representative topics for cluster ID 9 in column kmeans_10_UMAP_2D.
# 2024-11-19 10:03:16,154 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:16,623 - INFO - Generated cluster name: Covert Tactics and Unexpected Attacks
# 2024-11-19 10:03:16,623 - INFO - Found 1 representative topics for cluster ID 0 in column kmeans_10_UMAP_2D.
# 2024-11-19 10:03:16,638 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:17,353 - INFO - Generated cluster name: Visual Aesthetics and Design Trends
# 2024-11-19 10:03:17,353 - INFO - Found 2 representative topics for cluster ID 3 in column kmeans_10_UMAP_2D.
# 2024-11-19 10:03:17,353 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:17,798 - INFO - Generated cluster name: Stealth Tactics in Nature
# 2024-11-19 10:03:17,798 - INFO - Found 5 representative topics for cluster ID 5 in column kmeans_10_UMAP_2D.
# 2024-11-19 10:03:17,798 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:18,384 - INFO - Generated cluster name: Visual Gameplay Elements
# 2024-11-19 10:03:18,384 - INFO - Found 1 representative topics for cluster ID 7 in column kmeans_10_UMAP_2D.
# 2024-11-19 10:03:18,384 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:18,954 - INFO - Generated cluster name: Learning Resources and Guides
# 2024-11-19 10:03:18,969 - INFO - Found 1 representative topics for cluster ID 8 in column kmeans_15_UMAP_2D.
# 2024-11-19 10:03:18,969 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:19,430 - INFO - Generated cluster name: Collaborative Gaming Dynamics
# 2024-11-19 10:03:19,430 - INFO - Found 1 representative topics for cluster ID 1 in column kmeans_15_UMAP_2D.
# 2024-11-19 10:03:19,430 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:19,916 - INFO - Generated cluster name: Geolocation Alert Systems
# 2024-11-19 10:03:19,916 - INFO - Found 2 representative topics for cluster ID 4 in column kmeans_15_UMAP_2D.
# 2024-11-19 10:03:19,916 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:20,400 - INFO - Generated cluster name: Weapon Durability Metrics
# 2024-11-19 10:03:20,400 - INFO - Found 3 representative topics for cluster ID 2 in column kmeans_15_UMAP_2D.
# 2024-11-19 10:03:20,400 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:20,954 - INFO - Generated cluster name: Arcade Game Design Essentials
# 2024-11-19 10:03:20,969 - INFO - Found 1 representative topics for cluster ID 13 in column kmeans_15_UMAP_2D.
# 2024-11-19 10:03:20,969 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:21,455 - INFO - Generated cluster name: Armament Nomenclature Insights
# 2024-11-19 10:03:21,455 - INFO - Found 3 representative topics for cluster ID 9 in column kmeans_15_UMAP_2D.
# 2024-11-19 10:03:21,455 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:22,025 - INFO - Generated cluster name: Covert Tactics and Sudden Threats
# 2024-11-19 10:03:22,025 - INFO - Found 1 representative topics for cluster ID 6 in column kmeans_15_UMAP_2D.
# 2024-11-19 10:03:22,025 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:22,642 - INFO - Generated cluster name: Variation Resolution Strategies
# 2024-11-19 10:03:22,642 - INFO - Found 1 representative topics for cluster ID 0 in column kmeans_15_UMAP_2D.
# 2024-11-19 10:03:22,642 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:23,231 - INFO - Generated cluster name: Visual Harmony and Expression
# 2024-11-19 10:03:23,233 - INFO - Found 1 representative topics for cluster ID 11 in column kmeans_15_UMAP_2D.
# 2024-11-19 10:03:23,234 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:23,662 - INFO - Generated cluster name: Creative Audio Expression
# 2024-11-19 10:03:23,662 - INFO - Found 1 representative topics for cluster ID 10 in column kmeans_15_UMAP_2D.
# 2024-11-19 10:03:23,662 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:24,085 - INFO - Generated cluster name: Acoustic Monitoring Solutions
# 2024-11-19 10:03:24,085 - INFO - Found 1 representative topics for cluster ID 3 in column kmeans_15_UMAP_2D.
# 2024-11-19 10:03:24,085 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:24,569 - INFO - Generated cluster name: Shadows and Subtlety
# 2024-11-19 10:03:24,569 - INFO - Found 4 representative topics for cluster ID 5 in column kmeans_15_UMAP_2D.
# 2024-11-19 10:03:24,569 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:25,041 - INFO - Generated cluster name: Game Design Elements Summary
# 2024-11-19 10:03:25,041 - INFO - Found 1 representative topics for cluster ID 12 in column kmeans_15_UMAP_2D.
# 2024-11-19 10:03:25,041 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:25,420 - INFO - Generated cluster name: Flexible Hiring Solutions
# 2024-11-19 10:03:25,420 - INFO - Found 1 representative topics for cluster ID 7 in column kmeans_15_UMAP_2D.
# 2024-11-19 10:03:25,420 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:25,812 - INFO - Generated cluster name: Learning Resources and Guides
# 2024-11-19 10:03:25,815 - INFO - Found 1 representative topics for cluster ID 14 in column kmeans_15_UMAP_2D.
# 2024-11-19 10:03:25,816 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:26,206 - INFO - Generated cluster name: Visual Design Essentials
# 2024-11-19 10:03:26,206 - INFO - Found 8 representative topics for cluster ID 0 in column hdbscan_UMAP_3D.
# 2024-11-19 10:03:26,206 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:26,800 - INFO - Generated cluster name: Stealth Mechanics and Weapon Strategies
# 2024-11-19 10:03:26,803 - INFO - Found 8 representative topics for cluster ID 1 in column hdbscan_UMAP_3D.
# 2024-11-19 10:03:26,804 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:27,397 - INFO - Generated cluster name: Game Design and Aesthetic Elements
# 2024-11-19 10:03:27,397 - INFO - Found 5 representative topics for cluster ID 2 in column kmeans_5_UMAP_3D.
# 2024-11-19 10:03:27,397 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:27,939 - INFO - Generated cluster name: Survival Game Mechanics and Features
# 2024-11-19 10:03:27,939 - INFO - Found 6 representative topics for cluster ID 1 in column kmeans_5_UMAP_3D.
# 2024-11-19 10:03:27,939 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:28,578 - INFO - Generated cluster name: Stealth and Surprise Mechanics
# 2024-11-19 10:03:28,578 - INFO - Found 4 representative topics for cluster ID 3 in column kmeans_5_UMAP_3D.
# 2024-11-19 10:03:28,578 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:29,450 - INFO - Generated cluster name: "Stealth Gameplay and Outcomes"
# 2024-11-19 10:03:29,461 - INFO - Found 2 representative topics for cluster ID 0 in column kmeans_5_UMAP_3D.
# 2024-11-19 10:03:29,461 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:29,880 - INFO - Generated cluster name: Audio Aesthetics
# 2024-11-19 10:03:29,880 - INFO - Found 6 representative topics for cluster ID 4 in column kmeans_5_UMAP_3D.
# 2024-11-19 10:03:29,880 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:31,507 - INFO - Generated cluster name: Game Development Resources and Tools
# 2024-11-19 10:03:31,523 - INFO - Found 2 representative topics for cluster ID 3 in column kmeans_10_UMAP_3D.
# 2024-11-19 10:03:31,528 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:31,978 - INFO - Generated cluster name: Collaborative Recruitment Strategies
# 2024-11-19 10:03:31,978 - INFO - Found 4 representative topics for cluster ID 8 in column kmeans_10_UMAP_3D.
# 2024-11-19 10:03:31,978 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:32,513 - INFO - Generated cluster name: Stealth and Surprise Tactics
# 2024-11-19 10:03:32,513 - INFO - Found 2 representative topics for cluster ID 6 in column kmeans_10_UMAP_3D.
# 2024-11-19 10:03:32,513 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:32,970 - INFO - Generated cluster name: Weapon Durability and Performance
# 2024-11-19 10:03:32,970 - INFO - Found 3 representative topics for cluster ID 7 in column kmeans_10_UMAP_3D.
# 2024-11-19 10:03:32,970 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:33,382 - INFO - Generated cluster name: Arcade Survival Mechanics
# 2024-11-19 10:03:33,382 - INFO - Found 2 representative topics for cluster ID 4 in column kmeans_10_UMAP_3D.
# 2024-11-19 10:03:33,382 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:33,978 - INFO - Generated cluster name: "Covert Tactics and Terminology"
# 2024-11-19 10:03:33,978 - INFO - Found 3 representative topics for cluster ID 0 in column kmeans_10_UMAP_3D.
# 2024-11-19 10:03:33,978 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:34,656 - INFO - Generated cluster name: Multisensory Experience Design
# 2024-11-19 10:03:34,656 - INFO - Found 1 representative topics for cluster ID 1 in column kmeans_10_UMAP_3D.
# 2024-11-19 10:03:34,656 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:35,421 - INFO - Generated cluster name: Acoustic Monitoring Solutions
# 2024-11-19 10:03:35,421 - INFO - Found 3 representative topics for cluster ID 5 in column kmeans_10_UMAP_3D.
# 2024-11-19 10:03:35,421 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:36,009 - INFO - Generated cluster name: Visual Content Creation
# 2024-11-19 10:03:36,025 - INFO - Found 2 representative topics for cluster ID 2 in column kmeans_10_UMAP_3D.
# 2024-11-19 10:03:36,025 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:36,806 - INFO - Generated cluster name: Stair-Based Game Dynamics
# 2024-11-19 10:03:36,821 - INFO - Found 1 representative topics for cluster ID 9 in column kmeans_10_UMAP_3D.
# 2024-11-19 10:03:36,821 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:38,219 - INFO - Generated cluster name: Learning Resources and Guides
# 2024-11-19 10:03:38,219 - INFO - Found 1 representative topics for cluster ID 3 in column kmeans_15_UMAP_3D.
# 2024-11-19 10:03:38,234 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:38,735 - INFO - Generated cluster name: Collaborative Gaming Dynamics
# 2024-11-19 10:03:38,735 - INFO - Found 1 representative topics for cluster ID 14 in column kmeans_15_UMAP_3D.
# 2024-11-19 10:03:38,735 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:39,350 - INFO - Generated cluster name: Geolocation Alerts and Notifications
# 2024-11-19 10:03:39,350 - INFO - Found 2 representative topics for cluster ID 6 in column kmeans_15_UMAP_3D.
# 2024-11-19 10:03:39,350 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:40,249 - INFO - Generated cluster name: Weapon Durability Management
# 2024-11-19 10:03:40,249 - INFO - Found 2 representative topics for cluster ID 7 in column kmeans_15_UMAP_3D.
# 2024-11-19 10:03:40,249 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:40,720 - INFO - Generated cluster name: Arcade Shelter Gaming Experience
# 2024-11-19 10:03:40,720 - INFO - Found 1 representative topics for cluster ID 4 in column kmeans_15_UMAP_3D.
# 2024-11-19 10:03:40,720 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:41,430 - INFO - Generated cluster name: Armament Nomenclature Insights
# 2024-11-19 10:03:41,430 - INFO - Found 1 representative topics for cluster ID 8 in column kmeans_15_UMAP_3D.
# 2024-11-19 10:03:41,430 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:42,825 - INFO - Generated cluster name: Unexpected Frights
# 2024-11-19 10:03:42,841 - INFO - Found 2 representative topics for cluster ID 11 in column kmeans_15_UMAP_3D.
# 2024-11-19 10:03:42,841 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:43,351 - INFO - Generated cluster name: "Assassination Outcome Dynamics"
# 2024-11-19 10:03:43,351 - INFO - Found 2 representative topics for cluster ID 0 in column kmeans_15_UMAP_3D.
# 2024-11-19 10:03:43,351 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:43,792 - INFO - Generated cluster name: Auditory Aesthetics and Design
# 2024-11-19 10:03:43,808 - INFO - Found 2 representative topics for cluster ID 10 in column kmeans_15_UMAP_3D.
# 2024-11-19 10:03:43,808 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:44,313 - INFO - Generated cluster name: Shadows and Subterfuge
# 2024-11-19 10:03:44,321 - INFO - Found 1 representative topics for cluster ID 12 in column kmeans_15_UMAP_3D.
# 2024-11-19 10:03:44,321 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:44,866 - INFO - Generated cluster name: Key Life Influences
# 2024-11-19 10:03:44,881 - INFO - Found 1 representative topics for cluster ID 1 in column kmeans_15_UMAP_3D.
# 2024-11-19 10:03:44,881 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:45,371 - INFO - Generated cluster name: Acoustic Monitoring Techniques
# 2024-11-19 10:03:45,371 - INFO - Found 3 representative topics for cluster ID 5 in column kmeans_15_UMAP_3D.
# 2024-11-19 10:03:45,371 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:45,911 - INFO - Generated cluster name: Visual Content Creation
# 2024-11-19 10:03:45,911 - INFO - Found 2 representative topics for cluster ID 2 in column kmeans_15_UMAP_3D.
# 2024-11-19 10:03:45,911 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:46,354 - INFO - Generated cluster name: "Interactive Stairs in Gameplay"
# 2024-11-19 10:03:46,371 - INFO - Found 1 representative topics for cluster ID 13 in column kmeans_15_UMAP_3D.
# 2024-11-19 10:03:46,371 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:46,792 - INFO - Generated cluster name: Hiring Strategies and Choices
# 2024-11-19 10:03:46,800 - INFO - Found 1 representative topics for cluster ID 9 in column kmeans_15_UMAP_3D.
# 2024-11-19 10:03:46,800 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:47,289 - INFO - Generated cluster name: Learning Resources Hub
# 2024-11-19 10:03:47,289 - INFO - Found 6 representative topics for cluster ID 0 in column kmeans_5_PCA_2D.
# 2024-11-19 10:03:47,289 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:47,873 - INFO - Generated cluster name: Multiplayer Arcade Aesthetics and Tutorials
# 2024-11-19 10:03:47,873 - INFO - Found 5 representative topics for cluster ID 3 in column kmeans_5_PCA_2D.
# 2024-11-19 10:03:47,873 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:48,385 - INFO - Generated cluster name: Game Mechanics and Features
# 2024-11-19 10:03:48,401 - INFO - Found 2 representative topics for cluster ID 2 in column kmeans_5_PCA_2D.
# 2024-11-19 10:03:48,401 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:48,793 - INFO - Generated cluster name: Durability in Weaponry Design
# 2024-11-19 10:03:48,808 - INFO - Found 5 representative topics for cluster ID 1 in column kmeans_5_PCA_2D.
# 2024-11-19 10:03:48,808 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:49,519 - INFO - Generated cluster name: Stealth and Surprise Tactics
# 2024-11-19 10:03:49,519 - INFO - Found 5 representative topics for cluster ID 4 in column kmeans_5_PCA_2D.
# 2024-11-19 10:03:49,531 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:49,985 - INFO - Generated cluster name: Game Design Elements Overview
# 2024-11-19 10:03:49,985 - INFO - Found 3 representative topics for cluster ID 7 in column kmeans_10_PCA_2D.
# 2024-11-19 10:03:49,985 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:51,244 - INFO - Generated cluster name: "Multiplayer Game Design Elements"
# 2024-11-19 10:03:51,244 - INFO - Found 2 representative topics for cluster ID 5 in column kmeans_10_PCA_2D.
# 2024-11-19 10:03:51,244 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:51,696 - INFO - Generated cluster name: Location-Based Notification Strategies
# 2024-11-19 10:03:51,711 - INFO - Found 2 representative topics for cluster ID 4 in column kmeans_10_PCA_2D.
# 2024-11-19 10:03:51,711 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:52,151 - INFO - Generated cluster name: Durability Mechanics in Gaming
# 2024-11-19 10:03:52,151 - INFO - Found 3 representative topics for cluster ID 8 in column kmeans_10_PCA_2D.
# 2024-11-19 10:03:52,151 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:52,654 - INFO - Generated cluster name: Interactive Space Design Concepts
# 2024-11-19 10:03:52,669 - INFO - Found 3 representative topics for cluster ID 2 in column kmeans_10_PCA_2D.
# 2024-11-19 10:03:52,669 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:53,213 - INFO - Generated cluster name: Life Choices and Recruitment Strategies
# 2024-11-19 10:03:53,213 - INFO - Found 3 representative topics for cluster ID 1 in column kmeans_10_PCA_2D.
# 2024-11-19 10:03:53,223 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:53,927 - INFO - Generated cluster name: Stealth and Surprise Tactics
# 2024-11-19 10:03:53,927 - INFO - Found 2 representative topics for cluster ID 0 in column kmeans_10_PCA_2D.
# 2024-11-19 10:03:53,927 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:54,889 - INFO - Generated cluster name: Aesthetic Tutorials Hub
# 2024-11-19 10:03:54,889 - INFO - Found 2 representative topics for cluster ID 6 in column kmeans_10_PCA_2D.
# 2024-11-19 10:03:54,889 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:55,353 - INFO - Generated cluster name: Targeted Surveillance Techniques
# 2024-11-19 10:03:55,357 - INFO - Found 2 representative topics for cluster ID 3 in column kmeans_10_PCA_2D.
# 2024-11-19 10:03:55,358 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:55,707 - INFO - Generated cluster name: Graphic Design Essentials
# 2024-11-19 10:03:55,722 - INFO - Found 1 representative topics for cluster ID 9 in column kmeans_10_PCA_2D.
# 2024-11-19 10:03:55,722 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:56,112 - INFO - Generated cluster name: Interactive Player Experience
# 2024-11-19 10:03:56,112 - INFO - Found 1 representative topics for cluster ID 13 in column kmeans_15_PCA_2D.
# 2024-11-19 10:03:56,112 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:56,553 - INFO - Generated cluster name: Social Gaming Dynamics
# 2024-11-19 10:03:56,559 - INFO - Found 2 representative topics for cluster ID 5 in column kmeans_15_PCA_2D.
# 2024-11-19 10:03:56,559 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:57,099 - INFO - Generated cluster name: Location-Based Alerts and Adjustments
# 2024-11-19 10:03:57,099 - INFO - Found 1 representative topics for cluster ID 4 in column kmeans_15_PCA_2D.
# 2024-11-19 10:03:57,099 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:57,525 - INFO - Generated cluster name: Durability Assessment Framework
# 2024-11-19 10:03:57,525 - INFO - Found 2 representative topics for cluster ID 8 in column kmeans_15_PCA_2D.
# 2024-11-19 10:03:57,525 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:57,980 - INFO - Generated cluster name: Arcade Audio Atmosphere
# 2024-11-19 10:03:57,980 - INFO - Found 1 representative topics for cluster ID 14 in column kmeans_15_PCA_2D.
# 2024-11-19 10:03:57,980 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:58,497 - INFO - Generated cluster name: "Naming Conventions for Weaponry"
# 2024-11-19 10:03:58,497 - INFO - Found 3 representative topics for cluster ID 1 in column kmeans_15_PCA_2D.
# 2024-11-19 10:03:58,512 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:59,068 - INFO - Generated cluster name: Covert Approaches and Unexpected Frights
# 2024-11-19 10:03:59,068 - INFO - Found 1 representative topics for cluster ID 12 in column kmeans_15_PCA_2D.
# 2024-11-19 10:03:59,068 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:03:59,671 - INFO - Generated cluster name: Durability of Weaponry
# 2024-11-19 10:03:59,671 - INFO - Found 2 representative topics for cluster ID 0 in column kmeans_15_PCA_2D.
# 2024-11-19 10:03:59,680 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:00,073 - INFO - Generated cluster name: Aesthetic Learning Guides
# 2024-11-19 10:04:00,073 - INFO - Found 2 representative topics for cluster ID 2 in column kmeans_15_PCA_2D.
# 2024-11-19 10:04:00,073 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:00,513 - INFO - Generated cluster name: Life Factors in Recruitment
# 2024-11-19 10:04:00,528 - INFO - Found 1 representative topics for cluster ID 6 in column kmeans_15_PCA_2D.
# 2024-11-19 10:04:00,528 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:00,971 - INFO - Generated cluster name: Acoustic Monitoring Techniques
# 2024-11-19 10:04:00,971 - INFO - Found 2 representative topics for cluster ID 3 in column kmeans_15_PCA_2D.
# 2024-11-19 10:04:00,971 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:01,444 - INFO - Generated cluster name: Graphic Design Essentials
# 2024-11-19 10:04:01,460 - INFO - Found 1 representative topics for cluster ID 10 in column kmeans_15_PCA_2D.
# 2024-11-19 10:04:01,460 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:01,871 - INFO - Generated cluster name: Vertical Movement and Access
# 2024-11-19 10:04:01,882 - INFO - Found 1 representative topics for cluster ID 11 in column kmeans_15_PCA_2D.
# 2024-11-19 10:04:01,882 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:02,347 - INFO - Generated cluster name: Political Homicides and Impact
# 2024-11-19 10:04:02,347 - INFO - Found 2 representative topics for cluster ID 7 in column kmeans_15_PCA_2D.
# 2024-11-19 10:04:02,347 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:03,146 - INFO - Generated cluster name: Game Content Dynamics
# 2024-11-19 10:04:03,162 - INFO - Found 1 representative topics for cluster ID 9 in column kmeans_15_PCA_2D.
# 2024-11-19 10:04:03,162 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:03,710 - INFO - Generated cluster name: Gameplay Mechanics Overview
# 2024-11-19 10:04:03,710 - INFO - Found 5 representative topics for cluster ID 0 in column kmeans_5_PCA_3D.
# 2024-11-19 10:04:03,710 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:04,193 - INFO - Generated cluster name: Creative Multimedia Experience Essentials
# 2024-11-19 10:04:04,193 - INFO - Found 6 representative topics for cluster ID 1 in column kmeans_5_PCA_3D.
# 2024-11-19 10:04:04,193 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:04,635 - INFO - Generated cluster name: Game Mechanics and Player Experience
# 2024-11-19 10:04:04,635 - INFO - Found 3 representative topics for cluster ID 2 in column kmeans_5_PCA_3D.
# 2024-11-19 10:04:04,635 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:05,194 - INFO - Generated cluster name: Weapon Durability and Naming Systems
# 2024-11-19 10:04:05,200 - INFO - Found 5 representative topics for cluster ID 3 in column kmeans_5_PCA_3D.
# 2024-11-19 10:04:05,200 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:05,777 - INFO - Generated cluster name: Stealth and Surprise Tactics
# 2024-11-19 10:04:05,793 - INFO - Found 4 representative topics for cluster ID 4 in column kmeans_5_PCA_3D.
# 2024-11-19 10:04:05,793 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:06,209 - INFO - Generated cluster name: Game Design Essentials
# 2024-11-19 10:04:06,209 - INFO - Found 3 representative topics for cluster ID 8 in column kmeans_10_PCA_3D.
# 2024-11-19 10:04:06,209 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:06,728 - INFO - Generated cluster name: Interactive Learning and Multiplayer Content
# 2024-11-19 10:04:06,744 - INFO - Found 2 representative topics for cluster ID 3 in column kmeans_10_PCA_3D.
# 2024-11-19 10:04:06,744 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:07,234 - INFO - Generated cluster name: Job Alerts and Recruitment Options
# 2024-11-19 10:04:07,234 - INFO - Found 2 representative topics for cluster ID 5 in column kmeans_10_PCA_3D.
# 2024-11-19 10:04:07,234 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:07,865 - INFO - Generated cluster name: Weapon Durability Metrics
# 2024-11-19 10:04:07,880 - INFO - Found 3 representative topics for cluster ID 1 in column kmeans_10_PCA_3D.
# 2024-11-19 10:04:07,880 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:08,348 - INFO - Generated cluster name: "Urban Survival Elements"
# 2024-11-19 10:04:08,348 - INFO - Found 1 representative topics for cluster ID 4 in column kmeans_10_PCA_3D.
# 2024-11-19 10:04:08,348 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:08,912 - INFO - Generated cluster name: Weapon Title Designation
# 2024-11-19 10:04:08,928 - INFO - Found 4 representative topics for cluster ID 2 in column kmeans_10_PCA_3D.
# 2024-11-19 10:04:08,928 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:09,531 - INFO - Generated cluster name: "Surprise and Strategic Elimination"
# 2024-11-19 10:04:09,531 - INFO - Found 2 representative topics for cluster ID 0 in column kmeans_10_PCA_3D.
# 2024-11-19 10:04:09,531 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:09,980 - INFO - Generated cluster name: Auditory Aesthetics and Design
# 2024-11-19 10:04:09,995 - INFO - Found 2 representative topics for cluster ID 7 in column kmeans_10_PCA_3D.
# 2024-11-19 10:04:09,995 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:10,546 - INFO - Generated cluster name: Shadows and Subtlety
# 2024-11-19 10:04:10,546 - INFO - Found 2 representative topics for cluster ID 6 in column kmeans_10_PCA_3D.
# 2024-11-19 10:04:10,546 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:11,190 - INFO - Generated cluster name: Visual Design and Rendering
# 2024-11-19 10:04:11,194 - INFO - Found 2 representative topics for cluster ID 9 in column kmeans_10_PCA_3D.
# 2024-11-19 10:04:11,195 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:11,703 - INFO - Generated cluster name: Game Dynamics and Play Experience
# 2024-11-19 10:04:11,706 - INFO - Found 2 representative topics for cluster ID 8 in column kmeans_15_PCA_3D.
# 2024-11-19 10:04:11,706 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:12,268 - INFO - Generated cluster name: Collaborative Multiplayer Content
# 2024-11-19 10:04:12,268 - INFO - Found 1 representative topics for cluster ID 3 in column kmeans_15_PCA_3D.
# 2024-11-19 10:04:12,268 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:12,677 - INFO - Generated cluster name: Location-Based Alerts
# 2024-11-19 10:04:12,677 - INFO - Found 1 representative topics for cluster ID 11 in column kmeans_15_PCA_3D.
# 2024-11-19 10:04:12,692 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:13,158 - INFO - Generated cluster name: Durability Standards and Measurement
# 2024-11-19 10:04:13,173 - INFO - Found 1 representative topics for cluster ID 14 in column kmeans_15_PCA_3D.
# 2024-11-19 10:04:13,173 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:13,752 - INFO - Generated cluster name: Arcade Haven
# 2024-11-19 10:04:13,754 - INFO - Found 1 representative topics for cluster ID 4 in column kmeans_15_PCA_3D.
# 2024-11-19 10:04:13,754 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:14,213 - INFO - Generated cluster name: Armament Nomenclature Insights
# 2024-11-19 10:04:14,213 - INFO - Found 3 representative topics for cluster ID 2 in column kmeans_15_PCA_3D.
# 2024-11-19 10:04:14,225 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:14,841 - INFO - Generated cluster name: Terror Tactics and Deception
# 2024-11-19 10:04:14,841 - INFO - Found 1 representative topics for cluster ID 5 in column kmeans_15_PCA_3D.
# 2024-11-19 10:04:14,857 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:15,729 - INFO - Generated cluster name: Weapon Lifespan Mechanics
# 2024-11-19 10:04:15,729 - INFO - Found 2 representative topics for cluster ID 10 in column kmeans_15_PCA_3D.
# 2024-11-19 10:04:15,729 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:16,535 - INFO - Generated cluster name: Staircase Design and Variations
# 2024-11-19 10:04:16,551 - INFO - Found 2 representative topics for cluster ID 0 in column kmeans_15_PCA_3D.
# 2024-11-19 10:04:16,551 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:17,070 - INFO - Generated cluster name: Auditory Aesthetics
# 2024-11-19 10:04:17,088 - INFO - Found 2 representative topics for cluster ID 7 in column kmeans_15_PCA_3D.
# 2024-11-19 10:04:17,088 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:17,610 - INFO - Generated cluster name: Shadows and Subtlety
# 2024-11-19 10:04:17,610 - INFO - Found 1 representative topics for cluster ID 1 in column kmeans_15_PCA_3D.
# 2024-11-19 10:04:17,610 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:20,985 - INFO - Generated cluster name: Life Influencing Factors
# 2024-11-19 10:04:20,985 - INFO - Found 2 representative topics for cluster ID 6 in column kmeans_15_PCA_3D.
# 2024-11-19 10:04:20,985 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:21,678 - INFO - Generated cluster name: Visual Arts and Design
# 2024-11-19 10:04:21,693 - INFO - Found 1 representative topics for cluster ID 12 in column kmeans_15_PCA_3D.
# 2024-11-19 10:04:21,693 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:22,717 - INFO - Generated cluster name: Talent Acquisition Strategies
# 2024-11-19 10:04:22,717 - INFO - Found 2 representative topics for cluster ID 9 in column kmeans_15_PCA_3D.
# 2024-11-19 10:04:22,717 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:23,162 - INFO - Generated cluster name: Game Dynamics and Player Interaction
# 2024-11-19 10:04:23,162 - INFO - Found 1 representative topics for cluster ID 13 in column kmeans_15_PCA_3D.
# 2024-11-19 10:04:23,167 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:23,689 - INFO - Generated cluster name: Tutorial Resources and Guides
# 2024-11-19 10:04:23,689 - INFO - Found 4 representative topics for cluster ID 4 in column kmeans_5_tSNE_2D.
# 2024-11-19 10:04:23,702 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:24,144 - INFO - Generated cluster name: Game Design and Social Dynamics
# 2024-11-19 10:04:24,144 - INFO - Found 5 representative topics for cluster ID 3 in column kmeans_5_tSNE_2D.
# 2024-11-19 10:04:24,144 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:24,993 - INFO - Generated cluster name: Visual Content and Location Tracking
# 2024-11-19 10:04:24,993 - INFO - Found 4 representative topics for cluster ID 2 in column kmeans_5_tSNE_2D.
# 2024-11-19 10:04:24,993 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:26,431 - INFO - Generated cluster name: Game Mechanics and Item Management
# 2024-11-19 10:04:26,431 - INFO - Found 5 representative topics for cluster ID 1 in column kmeans_5_tSNE_2D.
# 2024-11-19 10:04:26,431 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:26,858 - INFO - Generated cluster name: Stealth and Atmosphere in Horror
# 2024-11-19 10:04:26,858 - INFO - Found 5 representative topics for cluster ID 0 in column kmeans_5_tSNE_2D.
# 2024-11-19 10:04:26,858 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:27,413 - INFO - Generated cluster name: Game Mechanics and Design Elements
# 2024-11-19 10:04:27,413 - INFO - Found 3 representative topics for cluster ID 5 in column kmeans_10_tSNE_2D.
# 2024-11-19 10:04:27,413 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:28,354 - INFO - Generated cluster name: Stairway Multiplayer Gameplay
# 2024-11-19 10:04:28,354 - INFO - Found 1 representative topics for cluster ID 6 in column kmeans_10_tSNE_2D.
# 2024-11-19 10:04:28,354 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:28,827 - INFO - Generated cluster name: Geolocation Alerts and Updates
# 2024-11-19 10:04:28,827 - INFO - Found 4 representative topics for cluster ID 7 in column kmeans_10_tSNE_2D.
# 2024-11-19 10:04:28,827 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:29,243 - INFO - Generated cluster name: Survival Game Mechanics
# 2024-11-19 10:04:29,243 - INFO - Found 2 representative topics for cluster ID 2 in column kmeans_10_tSNE_2D.
# 2024-11-19 10:04:29,259 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:29,694 - INFO - Generated cluster name: Weapon Characteristics and Resilience
# 2024-11-19 10:04:29,709 - INFO - Found 1 representative topics for cluster ID 4 in column kmeans_10_tSNE_2D.
# 2024-11-19 10:04:29,710 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:30,189 - INFO - Generated cluster name: Unexpected Frights
# 2024-11-19 10:04:30,194 - INFO - Found 4 representative topics for cluster ID 1 in column kmeans_10_tSNE_2D.
# 2024-11-19 10:04:30,194 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:30,824 - INFO - Generated cluster name: "Stealth Mechanics and Sensory Design"
# 2024-11-19 10:04:30,828 - INFO - Found 1 representative topics for cluster ID 0 in column kmeans_10_tSNE_2D.
# 2024-11-19 10:04:30,830 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:31,875 - INFO - Generated cluster name: Visual Appeal and Design
# 2024-11-19 10:04:31,875 - INFO - Found 2 representative topics for cluster ID 3 in column kmeans_10_tSNE_2D.
# 2024-11-19 10:04:31,875 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:32,415 - INFO - Generated cluster name: Visual Design and Graphics
# 2024-11-19 10:04:32,418 - INFO - Found 2 representative topics for cluster ID 8 in column kmeans_10_tSNE_2D.
# 2024-11-19 10:04:32,419 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:33,026 - INFO - Generated cluster name: Violent Media Narratives
# 2024-11-19 10:04:33,026 - INFO - Found 3 representative topics for cluster ID 9 in column kmeans_10_tSNE_2D.
# 2024-11-19 10:04:33,026 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:33,508 - INFO - Generated cluster name: Game Development Overview
# 2024-11-19 10:04:33,510 - INFO - Found 3 representative topics for cluster ID 5 in column kmeans_15_tSNE_2D.
# 2024-11-19 10:04:33,511 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:34,078 - INFO - Generated cluster name: "Multiplayer Gameplay Dynamics"
# 2024-11-19 10:04:34,078 - INFO - Found 1 representative topics for cluster ID 6 in column kmeans_15_tSNE_2D.
# 2024-11-19 10:04:34,078 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:34,519 - INFO - Generated cluster name: Geolocation Alerts and Notifications
# 2024-11-19 10:04:34,519 - INFO - Found 4 representative topics for cluster ID 7 in column kmeans_15_tSNE_2D.
# 2024-11-19 10:04:34,519 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:34,982 - INFO - Generated cluster name: Survival in Harsh Environments
# 2024-11-19 10:04:34,982 - INFO - Found 1 representative topics for cluster ID 2 in column kmeans_15_tSNE_2D.
# 2024-11-19 10:04:34,982 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:35,632 - INFO - Generated cluster name: Creative Weapon Nomenclature
# 2024-11-19 10:04:35,634 - INFO - Found 1 representative topics for cluster ID 4 in column kmeans_15_tSNE_2D.
# 2024-11-19 10:04:35,635 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:36,307 - INFO - Generated cluster name: Unexpected Frights
# 2024-11-19 10:04:36,310 - INFO - Found 1 representative topics for cluster ID 11 in column kmeans_15_tSNE_2D.
# 2024-11-19 10:04:36,310 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:36,774 - INFO - Generated cluster name: Weapon Durability Mechanics
# 2024-11-19 10:04:36,777 - INFO - Found 1 representative topics for cluster ID 12 in column kmeans_15_tSNE_2D.
# 2024-11-19 10:04:36,778 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:37,249 - INFO - Generated cluster name: Game Conclusion Strategies
# 2024-11-19 10:04:37,249 - INFO - Found 1 representative topics for cluster ID 0 in column kmeans_15_tSNE_2D.
# 2024-11-19 10:04:37,249 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:37,661 - INFO - Generated cluster name: Visual Appeal and Design
# 2024-11-19 10:04:37,663 - INFO - Found 3 representative topics for cluster ID 1 in column kmeans_15_tSNE_2D.
# 2024-11-19 10:04:37,663 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:38,134 - INFO - Generated cluster name: Stealth and Atmosphere Design
# 2024-11-19 10:04:38,137 - INFO - Found 2 representative topics for cluster ID 3 in column kmeans_15_tSNE_2D.
# 2024-11-19 10:04:38,137 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:38,878 - INFO - Generated cluster name: Graphic Design Essentials
# 2024-11-19 10:04:38,880 - INFO - Found 1 representative topics for cluster ID 10 in column kmeans_15_tSNE_2D.
# 2024-11-19 10:04:38,881 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:39,328 - INFO - Generated cluster name: Political Murder and Conspiracy
# 2024-11-19 10:04:39,342 - INFO - Found 1 representative topics for cluster ID 8 in column kmeans_15_tSNE_2D.
# 2024-11-19 10:04:39,343 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:39,938 - INFO - Generated cluster name: "Comprehensive Content Strategies"
# 2024-11-19 10:04:39,953 - INFO - Found 1 representative topics for cluster ID 13 in column kmeans_15_tSNE_2D.
# 2024-11-19 10:04:39,953 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:40,600 - INFO - Generated cluster name: Talent Acquisition Strategies
# 2024-11-19 10:04:40,600 - INFO - Found 1 representative topics for cluster ID 14 in column kmeans_15_tSNE_2D.
# 2024-11-19 10:04:40,600 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:41,055 - INFO - Generated cluster name: Learning Resources and Guides
# 2024-11-19 10:04:41,070 - INFO - Found 1 representative topics for cluster ID 9 in column kmeans_15_tSNE_2D.
# 2024-11-19 10:04:41,070 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:41,526 - INFO - Generated cluster name: Game Mechanic Fundamentals
# 2024-11-19 10:04:41,530 - INFO - Found 4 representative topics for cluster ID 4 in column kmeans_5_tSNE_3D.
# 2024-11-19 10:04:41,531 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:42,299 - INFO - Generated cluster name: Game Graphics and Multiplayer Dynamics
# 2024-11-19 10:04:42,304 - INFO - Found 6 representative topics for cluster ID 1 in column kmeans_5_tSNE_3D.
# 2024-11-19 10:04:42,305 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:42,768 - INFO - Generated cluster name: Gameplay Dynamics and Challenges
# 2024-11-19 10:04:42,783 - INFO - Found 3 representative topics for cluster ID 2 in column kmeans_5_tSNE_3D.
# 2024-11-19 10:04:42,783 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:43,195 - INFO - Generated cluster name: Gaming Mechanics Overview
# 2024-11-19 10:04:43,195 - INFO - Found 4 representative topics for cluster ID 3 in column kmeans_5_tSNE_3D.
# 2024-11-19 10:04:43,195 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:43,628 - INFO - Generated cluster name: Creative Engagement and Recruitment Strategies
# 2024-11-19 10:04:43,628 - INFO - Found 6 representative topics for cluster ID 0 in column kmeans_5_tSNE_3D.
# 2024-11-19 10:04:43,628 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:44,078 - INFO - Generated cluster name: "Stealth and Surprise Dynamics"
# 2024-11-19 10:04:44,078 - INFO - Found 3 representative topics for cluster ID 5 in column kmeans_10_tSNE_3D.
# 2024-11-19 10:04:44,078 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:44,649 - INFO - Generated cluster name: Multiplayer Graphics Enhancement Summary
# 2024-11-19 10:04:44,653 - INFO - Found 3 representative topics for cluster ID 9 in column kmeans_10_tSNE_3D.
# 2024-11-19 10:04:44,653 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:45,099 - INFO - Generated cluster name: Interactive Gaming Guidance Systems
# 2024-11-19 10:04:45,102 - INFO - Found 1 representative topics for cluster ID 8 in column kmeans_10_tSNE_3D.
# 2024-11-19 10:04:45,102 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:45,586 - INFO - Generated cluster name: Durability Assessment Tools
# 2024-11-19 10:04:45,590 - INFO - Found 1 representative topics for cluster ID 4 in column kmeans_10_tSNE_3D.
# 2024-11-19 10:04:45,592 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:46,764 - INFO - Generated cluster name: Arcade Homeless Support Initiative
# 2024-11-19 10:04:46,768 - INFO - Found 4 representative topics for cluster ID 7 in column kmeans_10_tSNE_3D.
# 2024-11-19 10:04:46,770 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:47,484 - INFO - Generated cluster name: Shadows of Strategy and Recruitment
# 2024-11-19 10:04:47,485 - INFO - Found 3 representative topics for cluster ID 0 in column kmeans_10_tSNE_3D.
# 2024-11-19 10:04:47,486 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:47,917 - INFO - Generated cluster name: Unexpected Aesthetic Thrills
# 2024-11-19 10:04:47,921 - INFO - Found 4 representative topics for cluster ID 6 in column kmeans_10_tSNE_3D.
# 2024-11-19 10:04:47,921 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:48,483 - INFO - Generated cluster name: Stealth Tactics and Combat Mechanics
# 2024-11-19 10:04:48,483 - INFO - Found 2 representative topics for cluster ID 1 in column kmeans_10_tSNE_3D.
# 2024-11-19 10:04:48,483 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:48,957 - INFO - Generated cluster name: Life Game Dynamics
# 2024-11-19 10:04:48,957 - INFO - Found 1 representative topics for cluster ID 2 in column kmeans_10_tSNE_3D.
# 2024-11-19 10:04:48,957 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:49,538 - INFO - Generated cluster name: Acoustic Monitoring Solutions
# 2024-11-19 10:04:49,541 - INFO - Found 1 representative topics for cluster ID 3 in column kmeans_10_tSNE_3D.
# 2024-11-19 10:04:49,541 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:50,040 - INFO - Generated cluster name: "Vertical Movement and Accessibility"
# 2024-11-19 10:04:50,040 - INFO - Found 1 representative topics for cluster ID 11 in column kmeans_15_tSNE_3D.
# 2024-11-19 10:04:50,040 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:50,472 - INFO - Generated cluster name: Collaborative Gaming Dynamics
# 2024-11-19 10:04:50,475 - INFO - Found 2 representative topics for cluster ID 9 in column kmeans_15_tSNE_3D.
# 2024-11-19 10:04:50,475 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:51,028 - INFO - Generated cluster name: Interactive Location-Based Learning
# 2024-11-19 10:04:51,031 - INFO - Found 1 representative topics for cluster ID 8 in column kmeans_15_tSNE_3D.
# 2024-11-19 10:04:51,031 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:51,669 - INFO - Generated cluster name: Durability Assessment Tools
# 2024-11-19 10:04:51,672 - INFO - Found 1 representative topics for cluster ID 4 in column kmeans_15_tSNE_3D.
# 2024-11-19 10:04:51,673 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:52,236 - INFO - Generated cluster name: Gaming Refuge
# 2024-11-19 10:04:52,238 - INFO - Found 2 representative topics for cluster ID 14 in column kmeans_15_tSNE_3D.
# 2024-11-19 10:04:52,239 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:52,938 - INFO - Generated cluster name: Military Recruitment and Branding Strategies
# 2024-11-19 10:04:52,940 - INFO - Found 3 representative topics for cluster ID 0 in column kmeans_15_tSNE_3D.
# 2024-11-19 10:04:52,942 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:53,361 - INFO - Generated cluster name: Unexpected Aesthetic Shock Techniques
# 2024-11-19 10:04:53,361 - INFO - Found 2 representative topics for cluster ID 7 in column kmeans_15_tSNE_3D.
# 2024-11-19 10:04:53,361 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:54,032 - INFO - Generated cluster name: Durability in Gaming Mechanics
# 2024-11-19 10:04:54,032 - INFO - Found 3 representative topics for cluster ID 6 in column kmeans_15_tSNE_3D.
# 2024-11-19 10:04:54,042 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:54,476 - INFO - Generated cluster name: Silent Execution Techniques
# 2024-11-19 10:04:54,478 - INFO - Found 1 representative topics for cluster ID 12 in column kmeans_15_tSNE_3D.
# 2024-11-19 10:04:54,479 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:54,967 - INFO - Generated cluster name: Life Factor Insights
# 2024-11-19 10:04:54,967 - INFO - Found 1 representative topics for cluster ID 2 in column kmeans_15_tSNE_3D.
# 2024-11-19 10:04:54,967 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:55,756 - INFO - Generated cluster name: Acoustic Monitoring Solutions
# 2024-11-19 10:04:55,774 - INFO - Found 1 representative topics for cluster ID 10 in column kmeans_15_tSNE_3D.
# 2024-11-19 10:04:55,775 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:56,234 - INFO - Generated cluster name: Shadows and Subtlety
# 2024-11-19 10:04:56,237 - INFO - Found 2 representative topics for cluster ID 5 in column kmeans_15_tSNE_3D.
# 2024-11-19 10:04:56,237 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:57,088 - INFO - Generated cluster name: Visual Design Concepts
# 2024-11-19 10:04:57,088 - INFO - Found 1 representative topics for cluster ID 3 in column kmeans_15_tSNE_3D.
# 2024-11-19 10:04:57,088 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:57,719 - INFO - Generated cluster name: Step Up Concepts
# 2024-11-19 10:04:57,722 - INFO - Found 1 representative topics for cluster ID 13 in column kmeans_15_tSNE_3D.
# 2024-11-19 10:04:57,722 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:58,202 - INFO - Generated cluster name: Game Mechanics Overview
# 2024-11-19 10:04:58,205 - INFO - Found 1 representative topics for cluster ID 1 in column kmeans_15_tSNE_3D.
# 2024-11-19 10:04:58,205 - INFO - Generating cluster name using OpenAI API.
# 2024-11-19 10:04:58,710 - INFO - Generated cluster name: Game Dynamics Overview
# 2024-11-19 10:04:58,710 - INFO - Cluster naming process completed.
# 2024-11-19 10:04:58,710 - INFO - Saving updated data to C:\Users\fbohm\Desktop\Projects\DataScience\cluster_analysis\Data\db_final.json
# 2024-11-19 10:04:58,710 - INFO - Data saved successfully.
